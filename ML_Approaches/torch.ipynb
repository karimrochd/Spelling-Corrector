# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = "/content/drive/MyDrive/NLP/spelling_dictionary.json"

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from transformers import BertTokenizer, BertModel
import json

class SpellingDataset(Dataset):
    def __init__(self, spelling_dict, tokenizer, max_length=32):  # Reduced max_length
        self.pairs = []
        for correct, misspellings in spelling_dict.items():
            for misspelling in misspellings:
                self.pairs.append((misspelling, correct))
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __getitem__(self, idx):
        misspelling, correct = self.pairs[idx]

        # Tokenize without special tokens for input
        misspelling_encoding = self.tokenizer(
            misspelling,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,  # No special tokens
            return_tensors='pt'
        )

        correct_encoding = self.tokenizer(
            correct,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,  # No special tokens
            return_tensors='pt'
        )

        return {
            'input_ids': misspelling_encoding['input_ids'].squeeze(),
            'attention_mask': misspelling_encoding['attention_mask'].squeeze(),
            'labels': correct_encoding['input_ids'].squeeze()
        }

    def __len__(self):
        return len(self.pairs)

class SpellingCorrector(nn.Module):
    def __init__(self, vocab_size, hidden_size=768):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')

        # Freeze BERT parameters
        for param in self.bert.parameters():
            param.requires_grad = False

        # Add character-level embedding
        self.char_embedding = nn.Embedding(vocab_size, 128)

        # Bidirectional LSTM for sequence modeling
        lstm_hidden_size = hidden_size  # This will be the size per direction
        self.lstm = nn.LSTM(
            input_size=hidden_size + 128,  # Combined BERT and char embeddings
            hidden_size=lstm_hidden_size,
            num_layers=2,
            bidirectional=True,
            batch_first=True,
            dropout=0.2
        )

        # The LSTM output will be 2*hidden_size due to bidirectional
        lstm_output_size = lstm_hidden_size * 2

        # Linear layer before batch norm
        self.pre_norm = nn.Linear(lstm_output_size, hidden_size)

        # Batch norm on the hidden dimension
        self.batch_norm = nn.BatchNorm1d(hidden_size)

        # Output layer
        self.output = nn.Sequential(
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_size, vocab_size)
        )

    def forward(self, input_ids, attention_mask):
        # Get BERT embeddings
        bert_output = self.bert(input_ids, attention_mask=attention_mask)[0]

        # Get character embeddings
        char_embeds = self.char_embedding(input_ids)

        # Combine embeddings
        combined = torch.cat([bert_output, char_embeds], dim=-1)

        # LSTM processing
        lstm_out, _ = self.lstm(combined)

        # Pre-norm linear layer
        hidden = self.pre_norm(lstm_out)

        # Reshape for batch norm
        batch_size, seq_len, hidden_dim = hidden.shape
        hidden = hidden.permute(0, 2, 1)  # [batch, hidden, seq_len]
        hidden = self.batch_norm(hidden)
        hidden = hidden.permute(0, 2, 1)  # [batch, seq_len, hidden]

        # Generate output probabilities
        logits = self.output(hidden)

        return logits

def train_and_evaluate(num_epochs=10, data_path='spelling_dictionary.json'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Load data
    with open(data_path, 'r') as f:
        spelling_dict = json.load(f)

    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = SpellingCorrector(tokenizer.vocab_size).to(device)

    # Create dataset with smaller max_length
    dataset = SpellingDataset(spelling_dict, tokenizer, max_length=32)

    # Split dataset
    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32)

    # Training setup
    criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)
    optimizer = torch.optim.AdamW(model.parameters(), lr=2e-4)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.5)
    best_accuracy = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            optimizer.zero_grad()
            output = model(batch['input_ids'], batch['attention_mask'])

            # Reshape for loss calculation
            loss = criterion(
                output.view(-1, tokenizer.vocab_size),
                batch['labels'].view(-1)
            )

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

        # Evaluate
        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for batch in test_loader:
                batch = {k: v.to(device) for k, v in batch.items()}
                outputs = model(batch['input_ids'], batch['attention_mask'])

                predictions = outputs.argmax(dim=-1)
                correct += (predictions == batch['labels']).sum().item()
                total += batch['labels'].numel()

                # Print some examples
                if epoch % 2 == 0:
                    for pred, actual in zip(predictions[:2], batch['labels'][:2]):
                        pred_text = tokenizer.decode(pred, skip_special_tokens=True)
                        actual_text = tokenizer.decode(actual, skip_special_tokens=True)
                        print(f"Pred: {pred_text} | Actual: {actual_text}")

        accuracy = correct / total
        print(f"Accuracy: {accuracy:.4f}")

        scheduler.step(avg_loss)

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_spelling_corrector.pth')

    return model, tokenizer

# %%
model, tokenizer = train_and_evaluate(
    num_epochs=10,  # You can adjust this
    data_path= data_path  # Path to your JSON file
)
# Out:
# Using device: cuda
# Epoch 1, Average Loss: 7.4443
# Pred: conscientiousddd'''''''''''''''''''''''inc inc | Actual: conscience
# Pred: biscuitsesies sdd s'''''''''''''''''''''' approximately approximately approximately | Actual: whistling
# Pred: acknowledgingmentmentmentdddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately subterranean | Actual: acknowledging
# Pred: sauceateiesquadd beautiful beautiful beautiful'''''beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful'''' approximately approximately approximately approximately | Actual: anxious
# Pred: guaranteeesesnnd guarantee guarantee guarantee'''' guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee or or or or or or | Actual: purple
# Pred: our'' tddd'''''''''''''''''''''''enthusiasm pneumonia | Actual: sad
# Pred: our's t td'''''''''''''''''''''''' enthusiasm r | Actual: young
# Pred: stomachateatequadddd'''''''''''''''''''''' r r | Actual: stomach
# Pred: answer 'bondddddddddddddddddddddddddd guarantee r r | Actual: avoid
# Pred: initiation 'ies sdd s'''''''''''''''''''''' enthusiastic enthusiastic enthusiastic | Actual: innocent
# Pred: flag 'cy td psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology approximately | Actual: bathe
# Pred: ''' tddd beautiful'''''''''''' beautiful beautiful beautiful'''beautiful beautiful beautiful approximately approximately approximately | Actual: sure
# Pred: recommendationsquisitionionionionion beautiful'''''''''''beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately | Actual: requisition
# Pred: af -uquaddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately subterranean | Actual: friend
# Pred: guarantee 'atequaddd guarantee'''''''''''''''''' s s guarantee r r r | Actual: familiar
# Pred: requiquiionion s s'''''''''''''''''''''' approximately approximately approximately | Actual: recently
# Pred: comparativelyparacytismtismionion beautiful unanimous'''''''''''''''''''' approximately approximately approximately | Actual: comparatively
# Pred: ''' t t s s'''''''''''''''''''''t t r r | Actual: high
# Pred: flag 'cies tddd'''''''''''''''''''''approximately approximately approximately approximately | Actual: aunt
# Pred: answer 'ciesdddd dangerous'''''''''''''''''''' approximately approximately approximately approximately | Actual: about
# Pred: instrumentsistle s sd miscellaneous miscellaneous miscellaneous'''''''''''''''''''' miscellaneous miscellaneous approximately approximately | Actual: insurmountable
# Pred: answer'' tdd'''''''''''''''''''''''' psychology r | Actual: dying
# Pred: guarantee'' s s s s'''''''''''''''''''''''approximately approximately | Actual: sit
# Pred: courtesestableyd unanimous unanimous unanimous'''''unanimous unanimous unanimous unanimous'''''''' miscellaneous miscellaneous miscellaneous approximately approximately approximately | Actual: intellectual
# Pred: our 'ies sddd''''''''''''''''''''''d approximately approximately | Actual: our
# Pred: stomachranciesnddd'''''''''''''''''''''''pneumonia pneumonia | Actual: signature
# Pred: va'sddddd'' 'dddddddddddddddddd or or r | Actual: cake
# Pred: anticipatingfiateititddd miscellaneous beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean approximately approximately approximately approximately | Actual: anticipate
# Pred: recommendationsquisitionionionion'''''''''''''''''''''''pneumonia pneumonia | Actual: requisition
# Pred: our 'cies tdd'''''''''''''''''''''''''enthusiastic | Actual: own
# Pred: affidavitititddd'' 'dddd''''''''''ddd beautiful r subterranean | Actual: affidavit
# Pred: helicopteressydds'''''''''''''''''''''''psychology psychology | Actual: information
# Pred: court'' td anniversary anniversary analysis analysis initiation initiation initiation initiation initiation initiation initiation initiation initiation initiation initiation initiation initiation initiation initiation initiation enthusiasm enthusiasm enthusiasm enthusiasm enthusiasm enthusiasm enthusiastic | Actual: doesn't
# Pred: stomach 'ciesdddd'''''''''''''''''''' 'dd r r | Actual: stayed
# Pred: ' 'ies t t s'''''''''''''''''''''''' r r | Actual: conscious
# Pred: '''yydd'''''''''''''''''''''' un un approximately | Actual: on
# Pred: guaranteed guaranteeesnddd guarantee beautiful beautiful'''beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful'' beautiful beautiful subterranean approximately subterranean | Actual: guaranteed
# Pred: exhibitionateateate s s s s'''''''''''''''''''''approximately approximately approximately | Actual: example
# Pred: guaranteeranuousddddd'''''''''''''''''''''negotiations negotiations negotiations | Actual: politician
# Pred: frightened 'ally tdddd'''''''''''''''''''''beautiful subterranean subterranean | Actual: friend
# Pred: our'' tddd'''''''''''''''''''''' approximately approximately approximately | Actual: sooner
# Pred: guaranteeess tiondd annoyance beautiful'''' beautiful beautiful beautiful beautiful beautiful'''''' beautiful beautiful beautiful beautiful approximately approximately approximately subterranean | Actual: patient
# Pred: aflyuquadddd'''''''''''''''''''' beautiful subterranean subterranean subterranean | Actual: fundamental
# Pred: specificallylycyyy un specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically specifically approximately | Actual: cancelled
# Pred: biscuitsesiesiestism s s'''''''''''''''''''''or or or r | Actual: partial
# Pred: requisitionion s s s'''''''''''''''''''' s s approximately approximately | Actual: raincoat
# Pred: inconveniencedddd beautiful'''beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean approximately approximately subterranean | Actual: inconvenience
# Pred: immediatelylylytismdd approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately | Actual: necessarily
# Pred: miscellaneous miscellaneouslyuousquaiousious miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous approximately approximately approximately approximately subterranean | Actual: miscellaneous
# Pred: epistlecyienceddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean approximately approximately approximately | Actual: absurd
# Pred: inconveniencedddd beautiful''''ient beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautifulient approximately approximately approximately subterranean | Actual: inconvenience
# Pred: scarcelyistlelyyydd'''''''''''''''''''' approximately approximately approximately approximately approximately | Actual: ventilated
# Pred: specialesiesyddds''''ssss'''''''''''''subterranean subterranean subterranean | Actual: specimens
# Pred: ''s s s s s s s s s s s s s s s s s s s s s s s's s s s r r | Actual: specimens
# Pred: surface 'uydddssssssssssssssssssssss specifically specifically approximately | Actual: galloped
# Pred: our't tdddd''dddddddddddddddddddd psychology psychology | Actual: young
# Pred: beautifullylyious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately | Actual: approximate
# Pred: dangerous'' t td s'''''''''''''''''''''''r r | Actual: note
# Pred: ''s tddddd 'dddddddddddddddddddd r subterranean | Actual: cat's
# Pred: our's t t s'''''''''''''''''''''''' financially pneumonia | Actual: stock
# Pred: ''s tdd s s s s s s s s s s s s s s s s s s s s s s s sd r | Actual: hard
# Pred: beautiful 'cy tdd beautiful beautiful'''''''''''''''' beautiful'' beautiful approximately approximately approximately approximately | Actual: frequent
# Pred: sauce 'ciesdddddd beautifuldddddddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately subterranean | Actual: affectionate
# Pred: subterraneanistlesndddd annoyance'''''''''''''''''''' subterranean subterranean subterranean | Actual: improving
# Pred: helicopteresiesiesionss miscellaneous miscellaneousssssssssssssssss's miscellaneous approximately approximately approximately approximately | Actual: departure
# Pred: beautiful 'cy tdddd's sdddddd s sdddddd'tdd enthusiasm r r | Actual: lawn
# Pred: ''' t t s s'''''''''''''''''''''''enthusiasm approximately | Actual: mustn't
# Pred: mortgagefiuquaquaquassssssssssssssssssssssd approximately r r | Actual: mortgage
# Pred: special''yddd'''''''''''''''''''''beautiful approximately approximately approximately | Actual: forward
# Pred: our's t td s'''''''''''''''''''''''psychology pneumonia | Actual: galloped
# Pred: biscuitsesiessiousssssssssssssssssssssssss psychology psychology psychology | Actual: statistics
# Pred: conditionslyientiousddd answer''''d'''''''''''' 'd beautiful especially especially approximately approximately | Actual: contented
# Pred: epistleiesquads miscellaneous miscellaneous'''''''''''''''''''' miscellaneous approximately approximately subterranean | Actual: partial
# Pred: prejudice 'ciesddddd'''''''''''''''''''''' psychology psychology | Actual: prefer
# Pred: special'ssssssssssssssssssssssss'''' specifically psychology | Actual: sphere
# Pred: initiation't tddd'''''''''''''''''''''' immediately immediately immediately | Actual: enthusiastic
# Pred: specialesiesyddd'''''''''''''''''''''approximately approximately approximately approximately | Actual: thoroughly
# Pred: undoubtedlylylyyyy un un undoubtedlylylylylylylylylylylylylylyly approximately approximatelylylyly approximately approximately approximately approximately | Actual: undoubtedly
# Pred: enthusiasm'ment tddd'''''''''''''''''''''''enthusiasm enthusiasm | Actual: entrance
# Pred: criticismlylyienceiousd psychology psychologylylylylylylylylylylylylylylylylylylylylyly approximately approximately approximately | Actual: dormitory
# Pred: miscellaneousescyndd miscellaneous miscellaneous'''''''''''''''''''' miscellaneous miscellaneous miscellaneous pneumonia | Actual: undoubtedly
# Pred: appreciateruedatequatismdss'''''''''''''''''''' r r r r | Actual: approaching
# Pred: ordinarilyrilyd miscellaneous miscellaneous miscellaneous or or or or or or or or or or or or or or or or or or or or or or or approximately | Actual: orchestra
# Pred: sympatheticenassys answer answer answer'''''answer answer answer'''''''''enthusiasm enthusiasm enthusiasm r r r | Actual: sympathetic
# Pred: dangerous'' s t s s s'''''''''''beautiful beautiful beautiful beautiful'''''' approximately approximately approximately | Actual: pictures
# Pred: stomachrenuousdddd'''''''''''''''''''''' subterranean subterranean subterranean | Actual: strenuous
# Pred: inconvenienceddddd'''''beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean subterranean subterranean subterranean subterranean subterranean subterranean | Actual: inconvenienced
# Pred: negotiationson 'ddddd'' 'ddddddddddddd 'ddd negotiations negotiations negotiations inc | Actual: negotiations
# Pred: helicopterateateyyddd'''''''''''''''''''''approximately approximately approximately | Actual: altimeter
# Pred: our'' tdd'''''''''''''''''''''''' r psychology | Actual: climbing
# Pred: biscuits't tdd'''''''''''''''''''''''' approximately approximately | Actual: dunstan's
# Pred: exhibitionateate s sdd'''''''''''''''''''' 'd approximately approximately subterranean | Actual: exists
# Pred: our'' t tddd'''''''''''''''''''''approximately approximately approximately | Actual: captain
# Pred: our'' tddd'''''''''''''''''''''''enthusiasm pneumonia | Actual: send
# Pred: eventuallylylyyyy un un un unlyly approximately approximatelylyly approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately | Actual: ophthalmic
# Pred: answer's t s s'''''''''''''''''''''''' r r | Actual: recently
# Pred: biscuitsesiesquayss miscellaneous miscellaneous'''sssss'''''sssss'miscellaneous miscellaneous approximately approximately | Actual: coarse
# Pred: specificallylylyyddd answer answer or or or or or or or or or or or or or or or or or or or or or or approximately | Actual: temporary
# Pred: skilfmenttableyd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately | Actual: minimum
# Pred: communicatelycyiousddd beautiful'''''''''''''''''''''approximately approximately subterranean | Actual: committees
# Pred: helicopterlylyyddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful'' beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately subterranean | Actual: materially
# Pred: efficiency afdavdddddd''''''''''''''''''dd subterranean subterranean subterranean | Actual: exaggerate
# Pred: discretionlylyitititd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately immediately | Actual: discretion
# Pred: helicopterternlyointydd miscellaneous miscellaneous'''''''''''''''''''approximately approximately approximately approximately | Actual: pneumonia
# Pred: refreshmentionionioniond'''''''''''''''''' 'ientient subterranean subterranean subterranean | Actual: refrigerator
# Pred: surface''ddddd'''''''''''''''''' 'dd subterranean subterranean subterranean | Actual: never
# Pred: answer't tddd''''''''''''''''''''''d subterranean subterranean | Actual: prefer
# Pred: epistleciesddd psychology psychology'''''''''''''''''''''psychology psychology psychology | Actual: turned
# Pred: specificallylylyyyydd beautiful beautiful'''beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately | Actual: preliminary
# Pred: helicopterrancyddddd'''''''''''''''''''''subterranean subterranean subterranean | Actual: privilege
# Pred: prejudice't tddd'''''''''''''''''''''''subterranean subterranean | Actual: pretend
# Pred: negotiationsonveniousddddd''''''''d'''''''' 'dd subterranean subterranean subterranean | Actual: negotiate
# Pred: appropriatelyiesiousdd s'''''''''''''''''''''' approximately approximately subterranean | Actual: apparently
# Pred: eplycyyy guarantee guarantee helicopter helicopterly helicopter helicopter helicopter helicopter helicopter helicopter helicopter helicopter helicopter helicopter helicopter helicopter helicopter helicopter helicopter guarantee guarantee helicopter helicopter helicopter helicopter approximately | Actual: stirring
# Pred: fascinatingistleateateyy s s s'''''''''''''''''''enthusiasm enthusiasm immediately immediately | Actual: fascinating
# Pred: inaccessible'' tdddd'''''''''''''''''''''subterranean subterranean subterranean | Actual: elementary
# Pred: biscuits'syyd miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous approximately approximately approximately approximately approximately approximately | Actual: committees
# Pred: specialsstismydd s'''''''''''''''''' s s s approximately approximately approximately | Actual: specifically
# Pred: beautiful 'cyyddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately | Actual: visited
# Pred: enthusiasticonvenvenienceddd'''''''''''''''''''''subterranean approximately subterranean | Actual: magnificent
# Pred: sure 'ciesddd s'''''''''''''''''''''''especially enthusiastic | Actual: base
# Pred: immediatelylydavyddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately subterranean | Actual: collateral
# Pred: unanimousparagetleddd unanimous unanimous unanimous'''''''''' unanimous unanimous unanimous unanimous unanimous'''' un un approximately approximately | Actual: unanimous
# Pred: answer'' s s s'''''''''''''''''''''''' or r | Actual: schemes
# Pred: ''' t s s s s'''''''''''''''''' s s s s approximately approximately | Actual: roy
# Pred: criticismeslyyiousdd'''''''''''''''''''''' approximately approximately subterranean | Actual: scrambled
# Pred: recommendationsquisitionionion answer answer'''''''''''''''''''''approximately approximately approximately | Actual: resource
# Pred: magnificentistlementquadddd'''' 'dd''dd''''''''dd inc inc inc | Actual: scientific
# Pred: appetitefidavity beautiful beautiful beautiful'''''''''''''''''''''un especially especially | Actual: beautiful
# Pred: dangerous'' sds'''''''''''''''''''''''miscellaneous pneumonia pneumonia | Actual: toboggan
# Pred: immediatelylylyquaquad s s'''''''''''''''unanimous unanimous unanimous unanimous unanimous approximately approximately approximately r | Actual: sorority
# Pred: fraterniesquaddd s''''''''''''''''''''d approximately approximately subterranean | Actual: tracksuit
# Pred: immediatelylylyyydd psychology psychology - - s s s s'''s s s'''s s s immediately immediately immediately immediately immediately | Actual: certainly
# Pred: poetryesiesyyd actually actually philosophyslylys philosophyly philosophy philosophy philosophy philosophy philosophy philosophy philosophy philosophy philosophy philosophyly enthusiastic philosophy philosophy approximately approximately approximately | Actual: familiar
# Pred: especiallylyly sdd answer'''''''''''''''''' 'ly approximately approximately approximately approximately approximately | Actual: especially
# Pred: guaranteededatedddddd'''''''''''''''''''beautiful subterranean subterranean subterranean | Actual: guaranteed
# Pred: communicatelycytismion s s s'''''''''''''''''''''subterranean approximately subterranean | Actual: capacity
# Pred: shaggy'' t s s s'''''''''''''''''''''' approximately approximately subterranean | Actual: searching
# Pred: answer''ddddd'''' 'ddddddd'''''' 'd subterranean subterranean approximately subterranean | Actual: sank
# Pred: poetryesciesquadddssssssssssssssssssssss psychology psychology approximately | Actual: august
# Pred: biscuits''yddd'''''''''''''''''''''approximately approximately approximately approximately | Actual: build
# Pred: surface'' tddd'''''''''''''''''''''approximately approximately approximately approximately | Actual: written
# Pred: scheduledlylyquaydd'''''''''''''''''''''' enthusiastic enthusiastic enthusiastic | Actual: gradually
# Pred: answer'' s s s'''''''''''''''''''''''miscellaneous r r | Actual: cape
# Pred: psychologylylyyyd s'''''''''''''''''''''immediately psychology psychology approximately | Actual: spacecraft
# Pred: biscuits''dddd'''''''''''''''''''''' approximately approximately approximately | Actual: weather
# Pred: distinguishedmentmentitydd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean subterranean subterranean | Actual: distinguished
# Pred: affidavititddd s'''''''''''''''''''' approximately approximately immediately | Actual: chautauqua
# Pred: subterraneanistlebonddddd''''''''''''''''''dddd subterranean subterranean | Actual: politician
# Pred: answer's t t s s'''''''''''''''''''''''approximately approximately | Actual: her a
# Pred: rheumatismtismtismdd beautiful beautiful'' beautifuld beautiful beautifuld beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautifuldd approximately subterranean subterranean | Actual: rheumatism
# Pred: distinguishedranatequadddd beautiful'''''''beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful'beautiful beautiful approximately approximately approximately | Actual: definite
# Pred: biscuits's s s s s'''''''''''''''''''''''r r | Actual: class
# Pred: answer'' s s s s'''''''''''''''''''''''r r | Actual: breathe
# Pred: ''' tdddd'''''''''''''''''''' beautiful subterranean subterranean subterranean | Actual: whites
# Pred: biscuitsesiesdddd'''''''''''''''''''''' psychology psychology psychology | Actual: preference
# Pred: flag'' tdddd''''''''''''''''''''d approximately approximately approximately | Actual: determined
# Pred: subterraneanficiesitddddd'''''''''''''''''''''subterranean subterranean | Actual: sufficient
# Pred: temperaturelyciesiousiousddd'''''''''''''''''''''approximately approximately approximately | Actual: temperature
# Pred: prejudiceranlyiesnddd'''''''''''''''''''''approximately approximately approximately | Actual: customary
# Pred: sure'' tddd'''''''''''''''''''''beautiful beautiful approximately approximately | Actual: bored
# Pred: subterraneanistlementdddd'''''''''''''''''''''subterranean subterranean subterranean subterranean | Actual: restoration
# Pred: occasionallylylyiousiousdd'''''''''''''''''''''''psychology enthusiastic | Actual: occasionally
# Pred: affectionatelyfidavititititdddd''ddddd''''''''ddd approximately approximately approximately | Actual: affectionately
# Pred: ''' tdd'''''''''''''''''''''''' psychology psychology | Actual: carried
# Pred: designed'' s s s'''''''''''''''''''''''immediately approximately approximately | Actual: destination
# Pred: communicatelycyquaious s s s'''''''''''''''''''''enthusiastic approximately subterranean | Actual: communication
# Pred: miscellaneous miscellaneousiesiesiousd miscellaneous miscellaneous miscellaneous'''''''''''''''''''' miscellaneous miscellaneous subterranean | Actual: miscellaneous
# Pred: our 'bonyddddssssdddddddssssssdddd approximately approximately approximately | Actual: rang
# Pred: helicopter''n s s s s'''''''''''''''''''''approximately approximately subterranean | Actual: trial - run
# Pred: our 'cy tddd'''''''''''''''''''''beautiful subterranean subterranean subterranean | Actual: breathe
# Pred: surface 'ies tdddsss s s ssssssssssss s s s s or or or r | Actual: birthmark
# Pred: refreshmentionioniondd beautiful'' 'ddddddd'''' beautiful beautiful beautiful beautifuldd approximately approximately subterranean | Actual: refrigerator
# Pred: womensssdddsssssssssssssssssssdddd psychology magnificent | Actual: temporary
# Pred: answer 'uitdddd''''ddddddddd'''' 'ddd approximately approximately approximately | Actual: found
# Pred: immediatelylycyyd approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately | Actual: necessarily
# Pred: affiateitdd beautiful beautiful'''''''''''''''''''''immediately immediately immediately | Actual: voucher
# Pred: satisfaction's t s s s s'''''''''''''''''''''' r pneumonia | Actual: safe
# Pred: answer't tdddd''''''''dddddd'''' 'dddd r | Actual: dangerous
# Pred: appropriatelymentdddd'''''''''''''''''''''' approximately approximately subterranean | Actual: appreciate
# Pred: unanimouslylyquayss answer answer'''unanimous unanimous unanimous unanimous'unanimous unanimous unanimous unanimous unanimous unanimous unanimous unanimous unanimous unanimous enthusiastic enthusiastic approximately approximately approximately | Actual: february
# Pred: perceivelyuousiousiousiousious stomach'''''''''''''''''''' subterranean subterranean subterranean subterranean | Actual: prejudice
# Pred: guaranteed 'rndddd beautiful'''''''''''''''''' subterranean subterranean subterranean subterranean subterranean | Actual: guardian
# Pred: our's tddd beautiful'''''''''''''''''''' beautiful beautiful immediately immediately | Actual: blue
# Pred: annoyance 'iesies sd s s'''''''''''''''''''' s approximately approximately approximately | Actual: annoyance
# Pred: magnificentquiquiitionddd unanimous'''unanimous unanimous unanimous unanimous unanimous unanimous unanimous unanimous unanimous'unanimous unanimous unanimous unanimous unanimous unanimous approximately approximately approximately subterranean | Actual: magnificent
# Pred: indefiniteondddddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean subterranean subterranean subterranean subterranean | Actual: indefinite
# Pred: equippedquimentitddd'''''''''''''''''''''' psychology psychology approximately | Actual: equipped
# Pred: our's tdddd'''''''''''''''''''''beautiful approximately subterranean | Actual: conscious
# Pred: guaranteeistleiesitddd'''''''''''''''''''''''pneumonia pneumonia | Actual: privilege
# Pred: requiiesiestisms'''''''''''''''''''''''miscellaneous r r | Actual: relief
# Pred: va''nddd'''''''''''''''''''''' miscellaneous psychology subterranean | Actual: tried
# Pred: initiationescy tion s beautiful'''''''''''''''''''''approximately approximately approximately approximately | Actual: tournament
# Pred: women''dddddddd 'ddddddddddddd 'ddd subterranean subterranean subterranean | Actual: sleep
# Pred: infinitequiquiioniond beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately | Actual: newcomer
# Pred: helicopterateutabledddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately subterranean | Actual: sacrilegious
# Pred: prejudice prejudice 'ddddd'''''''''''''''''''''negotiations negotiations inc | Actual: prejudice
# Pred: requiquiionionion s answer'''''''''''''''''''''enthusiasm r r | Actual: remember
# Pred: our'' t t s s'''''''''''''''''''''' t r r | Actual: rich
# Pred: shaggy 'ies t s s s'''''''''''''''''''''''approximately approximately | Actual: possessing
# Pred: shaggyesiesyss psychologysssssssssssssssssssss psychology psychology psychology psychology | Actual: liked
# Pred: economicsedmentquaddd psychology psychology'''sdds'''philosophy psychology psychology'''''psychology philosophy philosophy philosophy approximately | Actual: economic
# Pred: biscuitsesies s s s'''''''''''''''''''''''' psychology enthusiastic | Actual: virtues
# Pred: inclyvenienceddd beautiful beautiful beautifullyly beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately approximately | Actual: incompatibility
# Pred: rheumatism s s s s'''''''''''''''''''''approximately approximately subterranean | Actual: repairs
# Pred: answer'sddddsssssssssssssssssssssdd r r | Actual: me
# Pred: conscientiousiousiousiousd''''''''''''''''''ientientious subterranean approximately subterranean | Actual: conscientious
# Pred: helicopterlylyiousddd s'''''''s'''''''''' s s s r r r | Actual: spacecraft
# Pred: answeresiesyss'''''''''''''''''''''''or r r | Actual: scarcely
# Pred: i's td s s'''''' s s'''''''''''''' immediately immediately immediately | Actual: connected
# Pred: answer't t s s s'''''''''''''''''''''' subterranean subterranean subterranean | Actual: tells
# Pred: ''t t t s s'''''''''''''''''''''''r r | Actual: fuel
# Pred: shaggy'' sdd'''''''''''''''''''''''' r r | Actual: pity
# Pred: epistleiesddddddddddddddddddddddddd approximately approximately approximately subterranean | Actual: society
# Pred: ''t tdss'''''''''''''''''''''''r r | Actual: organisms
# Pred: sufficiently'' s s s s s'''''''''''''''''''''approximately approximately approximately | Actual: surplus
# Pred: affidavititionionionion'''''''''''''''''' 'd approximately approximately approximately | Actual: affectionately
# Pred: answer'' t sdd'''''''''''''''''''''' approximately approximately approximately | Actual: something
# Pred: biscuitsrsny guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee psychology psychology | Actual: anxious
# Pred: answer 'iesy s s s s s's s s s s s s s s s s s'''''s s s r r | Actual: courtesies
# Pred: diranuquaddd unanimous'''' s s 'dd unanimous'''''''' 'd enthusiastic enthusiastic enthusiastic enthusiastic | Actual: different
# Pred: speciallytabletabletableyd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately subterranean | Actual: special
# Pred: requisitionionion unanimous unanimous'''''''''''''''''''' enthusiasm enthusiasm enthusiasm r | Actual: receipt
# Pred: inaccessiblequicy s s s approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately | Actual: admitted
# Pred: distinguishedvenvenitddddd'''''''''''''''''' subterranean subterranean subterranean subterranean subterranean | Actual: distinguished
# Pred: sufficientlyistleatequadddd'''''''''''''''''''' subterranean subterranean subterranean subterranean | Actual: supplement
# Pred: our'' t s s s'''''''''''''''''''''' beautiful approximately approximately | Actual: alright
# Pred: immediatelyumaumatismtismd guarantee guarantee guarantee beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately subterranean | Actual: rheumatism
# Pred: infinitequisitionionion s'''''''''''''''''''''' approximately approximately approximately | Actual: infinite
# Pred: to'sy s s s'''''''''''''''''''''' psychology psychology approximately | Actual: paw
# Pred: solemnrbonddddd'''''''''''''''''''''subterranean subterranean subterranean | Actual: solemn
# Pred: flag 'cy tdd'''''''''''''''''''''' or or or approximately | Actual: desk
# Pred: flag 'cy tddd'''''''''''''''''''' 'd subterranean subterranean subterranean | Actual: girl
# Pred: affidavitititdddd 'dddddd''''''''ddddd pneumonia pneumonia | Actual: affidavit
# Pred: guaranteedesuydd un un un beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately approximately | Actual: number
# Pred: specialesiesyyd guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee guarantee approximately approximately approximately | Actual: develop
# Pred: necessarilylylytismdddd beautiful beautiful subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean subterranean | Actual: necessarily
# Pred: exhibitionateate siousdd'''''''''''''''''''''''subterranean subterranean | Actual: exists
# Pred: infinitequimentit t s s s beautiful beautiful'''''''''''''''''' beautiful approximately approximately subterranean | Actual: heartbreak
# Pred: helicopteresies sddd'''''''''''''''''''''' psychology psychology pneumonia | Actual: pneumonia
# Pred: sure's t sd s s'''''''''''''''''''''' approximately approximately | Actual: alright
# Pred: conscientiousiousiousiousious''iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious sufficiently subterranean subterranean | Actual: conscience
# Pred: field 'lyyddlylylylylylylylylylylylylylylylylylylylylylyly approximately approximately approximately | Actual: latter
# Pred: our'' td'''''''''''''''''''''''''especially especially | Actual: as
# Pred: immediatelyistlelyyiousdd s'''''''' beautiful beautiful beautiful'' beautiful'''''beautiful approximately approximately approximately approximately | Actual: pinnacle
# Pred: enthusiasm enthusiasmienceiencetismddd unanimous'''''''''''''''''''enthusiastic enthusiastic immediately immediately | Actual: enthusiasm
# Pred: biscuitsesiesnddd guarantee'''''''''''''''''''guarantee guarantee guarantee r r | Actual: curtains
# Pred: answer'sitdds'''''''''''''''''''''''r r | Actual: solemn
# Pred: field't tddd'''''''''''''''''''''' approximately approximately subterranean | Actual: wanted
# Pred: permanentlyly'sddddddddddddddddddddddddd approximately approximately subterranean | Actual: occasionally
# Pred: efficiencylylytableilyilydd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean approximately approximately subterranean | Actual: affectionately
# Pred: flagrancies tddd'''''''''''''''''''''''pneumonia pneumonia | Actual: mustn't
# Pred: discretionlylyiousdd approximately approximately approximately approximately approximately approximately approximately approximately approximately beautiful beautiful beautiful approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately approximately | Actual: adequate
# Pred: done'' tdd'''''''''''''''''''''''miscellaneous approximately approximately | Actual: prior
# Pred: res tdddd'''''''''''''''''''''' subterranean subterranean subterranean | Actual: voucher
# Pred: appropriatelylyiousious s s s'''''''''''''''''''''approximately approximately approximately | Actual: appreciate
# Pred: guaranteedesiesquaydd'''''''''''''''''''''' approximately approximately approximately | Actual: immediately
# Pred: helicopterlylyyyy miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous or miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous or or or or or or or or | Actual: bankruptcy
# Pred: economicmentveniencedddd actually actually'''''''''''''''''approximately approximately approximately approximately approximately | Actual: economics
# Pred: answer'' sdd'''''''''''''''''''''''' enthusiastic enthusiastic | Actual: choice
# Pred: eventuallylylyyydd beautifulssssssssssssssssss approximately approximately approximately approximately approximately approximately | Actual: special
# Pred: epesdavquaydd s'''''''''''''''''''approximately approximately approximately approximately approximately | Actual: apology
# Pred: answer'sddddddd 'ientientddddientientientientientientientientientientient subterranean subterranean subterranean subterranean | Actual: sank
# Pred: exhibitionateateate sddd'''''''''''''''''''' subterranean subterranean subterranean subterranean | Actual: exhibition
# Pred: prejudice's t s s'''''''''''''''''''''' approximately approximately approximately approximately | Actual: presuming
# Pred: asesiesnion s'''''''''''''''''''''' or or or r | Actual: form
# Pred: sure 'cy tddd'''' t t t'''''''''''' t'''approximately approximately | Actual: legal
# Pred: disamentitquadd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean subterranean subterranean | Actual: disappointed
# Pred: done 'ciesdddd''''''''''''''''''''''d subterranean subterranean | Actual: loads
# Pred: instruments 'cydddd'''''''''''''''''''''subterranean subterranean subterranean subterranean | Actual: incense
# Pred: answer's tddd''''''''''''''''''''''d r r | Actual: length
# Pred: refreshmentionionioniond''''''''''''''''''''dd subterranean subterranean | Actual: refreshment
# Pred: specialesiesyyy s'''''''''''''''''''''' r r r | Actual: special
# Pred: beautiful''yddd'''''''''''''''''''''beautiful approximately approximately subterranean | Actual: getaway
# Pred: vacanciesddddd''''ddd''''''''''''ddd psychology psychology | Actual: value
# Pred: prejudiceoncyienceddd beautiful beautiful'''''' beautiful beautiful beautiful beautiful beautiful beautiful beautiful'''''subterranean subterranean subterranean approximately approximately | Actual: wanted
# Pred: efficiencyfiateateitdd answer answer'''''''answer answer answer answer answer answer answer answer'''' enthusiastic enthusiastic enthusiastic enthusiastic | Actual: efficiency
# Pred: va 'iesydd guarantee'''''''''''''''''''''guarantee guarantee r r | Actual: buried
# Pred: ''t t td s'''''''''''''''''''''''approximately approximately | Actual: deem
# Pred: dangerous'' s s s'''''''''''''''''''''''subterranean subterranean subterranean | Actual: groups
# Pred: beautifulateateyydddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately subterranean | Actual: heightened
# Pred: materiallylyyydd miscellaneous miscellaneous'''''beautiful beautiful'''''''' beautiful approximately approximately approximately approximately approximately approximately approximately | Actual: intellectual
# Pred: biscuitsly's s s s'''''''''''''''''''''' approximately approximately approximately | Actual: procedure
# Pred: answer't tddd'''''''''''''''''''''''approximately subterranean | Actual: did
# Pred: scarcelyistlelyyy actually actuallylylylylylylylylylylylylylylylylylylyly approximately approximately approximately approximately approximately approximately | Actual: detailed
# Pred: immediatelylylytableyydd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately subterranean | Actual: specifically
# Pred: shaggy's ss enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic enthusiastic approximately approximately approximately approximately approximately | Actual: delivered
# Pred: sauce 'ulldddd answer'''''''''''''''''''''subterranean subterranean subterranean | Actual: lumber
# Pred: immediately immediatelyatedddddd beautiful'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately subterranean | Actual: imitation
# Pred: our's sddd'''''''''''''''''''''' subterranean subterranean subterranean | Actual: lay
# Pred: actuallyriesydddd''''''''''''''''''''d subterranean subterranean subterranean | Actual: heavy
# Pred: destination'' sddd unanimous unanimous'''''''' unanimous unanimous unanimous unanimous unanimous unanimous'''''' approximately approximately approximately | Actual: designed
# Pred: recommendationsquisitionionioniond answer'''''''''''''''''' approximately approximately approximately approximately approximately | Actual: recognition
# Pred: answer't t s s s'''''''''''''''''''''s s psychology psychology | Actual: looking
# Pred: ''t tddd'''''''''''''''''''''''approximately approximately | Actual: yard
# Pred: guaranteedrueduquaddddd''''''''''''''''''dd subterranean subterranean subterranean | Actual: guarantee
# Pred: ''' t t s'''''''''''''''''''''''' approximately approximately | Actual: fire
# Pred: va 'uyd especially especially especially ep ep ep ep ep especially especially especially especially especially especially especially ep ep ep ep ep ep especially especially immediately immediately immediately immediately | Actual: sure
# Pred: facilitiesransquaqua s s s s'''' s'' s s s s'''''''s s enthusiasm enthusiasm approximately | Actual: facilities
# Pred: immediatelylylylyyyd beautiful beautiful'''''''''''''''''beautiful beautiful beautiful approximately approximately immediately | Actual: gradually
# Pred: splendid'' t s s'''''''''''''''''''''''' enthusiastic approximately | Actual: courses
# Pred: especially 'ciesquaddd'''''''''''''''''''''' enthusiastic enthusiastic enthusiastic | Actual: especially
# Pred: opposite's tdddd'' 'ddddddddddddddddd or or or r | Actual: handful
# Pred: answer'sdddd answer'''''''''''''''''''''guarantee negotiations immediately | Actual: knife
# Pred: especiallyaggerateddd s'''''''''''''''''''''' enthusiasm enthusiasm subterranean | Actual: esteemed
# Pred: immediatelyistleuquaiond beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately approximately approximately approximately subterranean | Actual: familiar
# Pred: miscellaneous miscellaneousesiesiousious miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous miscellaneous approximately approximately approximately | Actual: miscellaneous
# Pred: immediately'' sdd s'''''''''''''''''''''' enthusiastic approximately approximately | Actual: amongst
# Pred: sufficientlycanciesciesdddd'''''''''''''''''''''subterranean subterranean subterranean | Actual: successful
# Pred: inc 'cydddddd''dddddddddddd'''' 'd approximately approximately subterranean | Actual: enquire
# Pred: ''' t t s s s'''''''''''''''''''''' approximately approximately | Actual: taking
# Pred: sufficientlylyciesiousddd'''''''''''''''''''''' anniversary approximately approximately | Actual: suspicion
# Pred: beautiful 'bondddd unanimous unanimous'''''''''''''''''''beautiful beautiful approximately subterranean | Actual: breathe
# Pred: surfacees'tdddd'''''''''''''''''''''psychology approximately approximately | Actual: dart
# Pred: answer 'cy tddd'''''''''''''''''''''beautiful approximately approximately approximately | Actual: with
# Pred: acknowledgingmentmentititdd answer dangerous dangerous'''''''''''''''''' miscellaneous approximately approximately approximately | Actual: accommodation
# Pred: awfulescies tdd'''''''''''''''''''''''' enthusiastic enthusiastic | Actual: satisfaction
# Pred: exhibitionateateate sddd''''''''''''''''''''ient subterranean approximately approximately | Actual: exaggerate
# Pred: answer'' tdddd'''''''''''''''''' 'dd subterranean subterranean subterranean | Actual: should
# Pred: accompanyingmentmentledledyd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful approximately approximately immediately | Actual: accommodation
# Pred: actually's s ss actually actuallyssssssssssslylylylylysss approximately approximately approximately approximately approximately | Actual: hate
# Pred: biscuitsesiesies s s s s'''''''''''''''''''''approximately approximately subterranean | Actual: vegetables
# Pred: inconienceiencedddd'''''''''''''''''''''subterranean subterranean subterranean | Actual: inconvenienced
# Pred: recommendationsquisitionionionion beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean approximately subterranean | Actual: recommendations
# Pred: avoid 'cydddd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful subterranean subterranean | Actual: frightened
# Pred: affiateitit beautiful beautiful actually actually actually actually actually actually actually actually actually actually actually actually actually actually specifically specifically specifically specifically specifically specifically specifically specifically approximately approximately approximately | Actual: searched
# Pred: ''' s s s s'''''''''''''''''''''' or or r | Actual: guided
# Pred: our's t t s s s s s s s s s s s s s s s s s s s s s s s s s pneumonia pneumonia | Actual: sure
# Pred: helicopterlyesiesnns'''''''''''''''''''''or or or r | Actual: dormitory
# ...
# Pred: curiousesiesiousious s s s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient kindergarten | Actual: curious
# Pred: conditionsvalescenceiouse 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: consummated
# Pred: familiarcanciesdds s s s s s s s s s s s s s s s s s s s s s s s ss approximately | Actual: know
# Pred: splendid splendid runyye s s s s s s s s s s s s s s s s s s s s s s s sment enthusiastic | Actual: splendid
# Pred: convenientlyientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: conveniently
# Pred: formpedcyyd s s s s s s s s s s s s s s s s s s s siousiousiousious sment philosophy | Actual: form
# Pred: field - s s s s s s s s s s s s s s s s s s s s s s s s s s s s s psychology | Actual: feed
# Pred: becausepengddiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious philosophy | Actual: beautiful
# Pred: initialsallyallyydeientientientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientient philosophy | Actual: ennui
# Pred: virtuesilateddddd s s s s s s s s s s s s s s s s s s s s s sientient enthusiastic | Actual: various
# Pred: committeesvalescenceiouse s s s s s s s s s s s s s s s s s sientientiousious sientient un | Actual: congress
# Pred: initiation fascinatingedtismeeee siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious enthusiastic enthusiastic | Actual: anticipating
# Pred: inaccessiblesunceientioneee s s s s s s s s s s s s s s s s s s siousiousiousient enthusiastic | Actual: innocent
# Pred: itemizedmentdeeeeeeeee s s s seeeeeee s s s s sient approximately philosophy | Actual: itemized
# Pred: talk -vedye s s s s s s s s s s s s s s s s s s s s s s s s s enthusiasm enthusiastic | Actual: local
# Pred: calculate -daviteeeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious un memorandum | Actual: calculated
# Pred: folkedullyyious siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: folk
# Pred: where 'ngy s s s s s s s s s s s s s s s s s s s s s s s s s sient psychology | Actual: quite
# Pred: latests siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: latest
# Pred: initiation initiationallytismde s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious un kindergarten | Actual: initiation
# Pred: crowdedpe siousious s s s s s s s s s sious s s s s s s s s siousiousiousiousiousient approximately | Actual: crowd
# Pred: machinee s s s s s sientientientientientientientientientientientientientientientientientientiousiousientientient philosophy | Actual: plus
# Pred: ton 'iesious s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: tonnage
# Pred: privilege's s s s s s s s s s s s s s s s s s s s s s s s s s s sious philosophy | Actual: privilege
# Pred: storiess siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious philosophy | Actual: storey
# Pred: classes's s s s s s s s s s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: classes
# Pred: negotiationssiansion s s s s s s s s s s s s s s s s s s s s s s s s s re enthusiastic | Actual: negotiations
# Pred: alumniheumatismeeeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient approximately | Actual: alumni
# Pred: poetry - s s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient un | Actual: peculiar
# Pred: determinedrued siousiousious s s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious un un | Actual: determined
# Pred: requestinginginging s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious psychology philosophy | Actual: requesting
# Pred: acquaintancementientilydeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious un un | Actual: acquaintance
# Pred: sympatheticsmetriciousnssddd psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology | Actual: sympathetic
# Pred: before -ingddious siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: behind
# Pred: darkped'td s s s s s s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdient philosophy | Actual: dart
# Pred: immenselylyyyilye s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: immensely
# Pred: committeesuitsoint s s s s s s s s s s s s s s s s see ssss s s ss enthusiastic | Actual: committees
# Pred: satisfactorilyilyily re reiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious enthusiastic enthusiastic | Actual: satisfactorily
# Pred: want't t t t t s s s sientientientientientiousiousiousiousientientientientientientiousiousiousientient philosophy | Actual: wasn't
# Pred: negotiations negotiationsientienceddeeientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientient kindergarten | Actual: negotiations
# Pred: analysiseoususointeeeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious approximately philosophy | Actual: analysis
# Pred: asistle llious s s s s s s s s s s s s s s s s s s s s s s s s s s s memorandum | Actual: have
# Pred: lodgeedrnedyiousiousiousiousiousious psychology psychology psychologyiousiousiousiousiousiousiousiousiousiousious psychology psychology psychologyiousiousious psychology dormitory | Actual: lodge
# Pred: conscientiousiousiousiousientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: conscience
# Pred: chemistryeouseousioniousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: cemetery
# Pred: prejudice 'ientiousd s s s s s s s s s s s s s s s s s s s s s s s s sient enthusiastic | Actual: prestigious
# Pred: disobedientointeee re re re re re re re re reious re re re re re re re reiousiousiousiousient enthusiastic | Actual: disobedient
# Pred: fightd t tious s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious psychology philosophy | Actual: fidget
# Pred: laugh - run t s s s s s s s s s s s sious s s s s s s s s siousiousiousious psychology memorandum | Actual: leisure
# Pred: bluer syious s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious siousiousiousiousient philosophy | Actual: walking
# Pred: ordinarilyrilyiousious s s s s s s s s siousiousious s s s s s s s siousiousiousious approximately approximately | Actual: ordinarily
# Pred: kind's s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient memorandum | Actual: frightened
# Pred: quantity bicyclemityyye s s anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety approximately approximately anniversary | Actual: quantity
# Pred: deliveredinquentiousiouseiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient pneumonia | Actual: delivered
# Pred: avoidededointeeeientientientientientientientientientientientientientientientientientientientientientientientient enthusiastic | Actual: advantage
# Pred: prejudice prejudiceppience -e s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientiousiousiousientient philosophy | Actual: prejudice
# Pred: recognitionquisitionion sympathetic enthusiasm psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology immediately immediately psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology enthusiastic | Actual: recognition
# Pred: extraordinary extraordinaryaggerientouslyeeeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientiousiousientient approximately | Actual: extraordinary
# Pred: remembermitmentdddedientient re re reientientientientientientient re re reientientientientientientientient enthusiastic | Actual: remember
# Pred: curiosityeousientiousiouse's s s s re s re re re re s s s s s s s re re re re re reient enthusiastic | Actual: courtesies
# Pred: chautauquaquaquaeeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientient enthusiastic | Actual: chautauqua
# Pred: telephoneddddddddddddddddddddddddddddd enthusiastic enthusiastic | Actual: telephoned
# Pred: adequatevanizediousilyesiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: auditorium
# Pred: eventuallyallyallyyylyly s s s s s s s s s s s s s s s s s s sious re s sient memorandum | Actual: attentively
# Pred: phase's s s s s s s s s s s s s s s s s s s s siousious sious s siousient approximately | Actual: oats
# Pred: splendided runyee s psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology psychology | Actual: splendid
# Pred: incidentallyallyallyiousious sientientientient sientientientientientientientientientientientientientientientientientientient enthusiastic | Actual: incidentally
# Pred: aroundeddavititeeientientientientientientientientientientientientientientientientientientientientiousientientient enthusiastic | Actual: around
# Pred: coming'siousious s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: bath
# Pred: didn't t t s s s s s s s s s s s s s s s s s s s s s s s s sient un | Actual: didn't
# Pred: lostere tee s s s s s s s s s s s s s s s s s s s s s s s sd extraordinary | Actual: contributor
# Pred: unanimous unanimousuousointeee siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious enthusiasmious enthusiasm enthusiastic | Actual: unanimous
# Pred: pamphletnaireateeee s s s s s s s s s s s s s s s s s s s s s s s sient enthusiastic | Actual: pamphlet
# Pred: when'siousious s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious psychology | Actual: rug
# Pred: wishessientdd s s s siousious s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: enemies
# Pred: actuallyruedlyyyeeeeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious approximately philosophy | Actual: accomplished
# Pred: deliveredinquentdiousiouseiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: delivered
# Pred: undoubtedly undoubtedlyrilyledeee s s s siousiousiousiousiousiousious siousiousiousiousiousiousious siousiousious approximately philosophy | Actual: undoubtedly
# Pred: extraordinary extraordinaryallydaviousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: extraordinary
# Pred: materiallyyyee s s s s s s s s s s s s s sddd s sdddddd enthusiastic | Actual: materially
# Pred: temporary -bondion s s s s s s s s s s s s s s s s s s s siousiousious s sious psychology | Actual: tennis
# Pred: noisy -ggannee siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious approximately dormitory | Actual: noisy
# Pred: classroomss siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient approximately philosophy | Actual: touched
# Pred: splendidlfullyy's s s anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety anxiety enthusiasm anxiety enthusiasm s psychology philosophy | Actual: splendid
# Pred: thoroughly -ateitsssiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious enthusiastic enthusiastic | Actual: thorough
# Pred: flagrancyyyydiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: flagrancy
# Pred: surplusomeoniseeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient philosophy | Actual: ceremonies
# Pred: definitelye s s s s s siousiousiousiousiousiousiousiousiousiousiousiousious psychology psychology psychology psychologyiousiousiousiousious psychology philosophy | Actual: definite
# Pred: melancholy melancholyallyyyeeeeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousment philosophy | Actual: melancholy
# Pred: some 'ngddd s s s s s s s s s s s s s s s s s s s s s s sdient approximately | Actual: pot
# Pred: elementary elementary sronnn s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientient enthusiastic | Actual: elementary
# Pred: adequatesteenceilye s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousment philosophy | Actual: adequate
# Pred: immediatelylyyyyeeiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious approximately philosophy | Actual: immediately
# Pred: especiallylyallyyyee s s s s s s s s s s s s s s s s s s s s s s sient philosophy | Actual: especially
# Pred: altimetermentientdddientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientient enthusiastic | Actual: altimeter
# Pred: exceptionallyallyallytismtisme s s s s s s s s s s s s s s s s s s s s s s s s enthusiastic enthusiastic | Actual: exceptionally
# Pred: unexpectedlycesbleeeeeientientientientientientiousiousiousiousiousiousiousiousiousiousiousiousientientientientient un | Actual: unintelligible
# Pred: helicopterlyrecteee s s s s s s s s s s s s s s s s s s siousious s s psychology philosophy | Actual: hierarchy
# Pred: actuallyruedullyye 'ientientientientientientientientientientientientientientientientientientientient especiallyientient approximately beneficial | Actual: accrued
# Pred: customer'siousious s sientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientient philosophy | Actual: courteous
# Pred: magnificentonientiousilyee siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient enthusiastic | Actual: magnificent
# Pred: initiationrientddeientientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientient enthusiastic | Actual: curious
# Pred: explainedacerbatedddiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientient enthusiastic | Actual: excerpt
# Pred: toottingn s s s s s siousiousiousiousiousiousiousiousious psychology psychology psychology psychology psychology psychology psychology psychology psychology psychologyd philosophy philosophy | Actual: poems
# Pred: counsel 'er t s s s siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousient approximately | Actual: council
# Accuracy: 0.0182
# Epoch 10, Average Loss: 1.8049
# Accuracy: 0.0186

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from transformers import BertTokenizer, BertModel
import json

class SpellingDataset(Dataset):
    def __init__(self, spelling_dict, tokenizer, max_length=32):
        self.pairs = []
        for correct, misspellings in spelling_dict.items():
            for misspelling in misspellings:
                self.pairs.append((misspelling, correct))
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __getitem__(self, idx):
        misspelling, correct = self.pairs[idx]

        # Tokenize without special tokens for input
        misspelling_encoding = self.tokenizer(
            misspelling,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,
            return_tensors='pt'
        )

        correct_encoding = self.tokenizer(
            correct,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,
            return_tensors='pt'
        )

        return {
            'input_ids': misspelling_encoding['input_ids'].squeeze(),
            'attention_mask': misspelling_encoding['attention_mask'].squeeze(),
            'labels': correct_encoding['input_ids'].squeeze()
        }

    def __len__(self):
        return len(self.pairs)

class SpellingCorrector(nn.Module):
    def __init__(self, vocab_size, hidden_size=768):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')

        # Freeze BERT parameters
        for param in self.bert.parameters():
            param.requires_grad = False

        # Reduce embedding size for characters
        self.char_embedding = nn.Embedding(vocab_size, 64)  # Reduced from 128

        # Add position embeddings
        self.pos_embedding = nn.Parameter(torch.randn(1, 32, 64))  # For max_length=32

        # Transformer encoder layer
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_size + 64,  # Combined size
            nhead=8,
            dim_feedforward=2048,
            dropout=0.1,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)

        # Output layers with residual connections
        self.fc1 = nn.Linear(hidden_size + 64, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size // 2)
        self.fc3 = nn.Linear(hidden_size // 2, vocab_size)

        self.layer_norm1 = nn.LayerNorm(hidden_size + 64)
        self.layer_norm2 = nn.LayerNorm(hidden_size)
        self.dropout = nn.Dropout(0.1)

    def forward(self, input_ids, attention_mask):
        # Get BERT embeddings
        bert_output = self.bert(input_ids, attention_mask=attention_mask)[0]

        # Get character embeddings and add positional encoding
        char_embeds = self.char_embedding(input_ids)
        char_embeds = char_embeds + self.pos_embedding[:, :char_embeds.size(1), :]

        # Combine embeddings
        combined = torch.cat([bert_output, char_embeds], dim=-1)
        combined = self.layer_norm1(combined)

        # Transform through transformer
        transformed = self.transformer(combined, src_key_padding_mask=~attention_mask.bool())

        # Process through output layers with residual connections
        out = self.fc1(transformed)
        out = self.layer_norm2(out)
        out = self.dropout(F.relu(out))

        residual = out
        out = self.fc2(out)
        out = F.relu(out)
        out = self.dropout(out)

        out = self.fc3(out)

        return out

def train_and_evaluate(num_epochs=10, data_path='spelling_dictionary.json'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Load data
    with open(data_path, 'r') as f:
        spelling_dict = json.load(f)

    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = SpellingCorrector(tokenizer.vocab_size).to(device)

    # Create dataset
    dataset = SpellingDataset(spelling_dict, tokenizer, max_length=32)

    # Split dataset with better ratio
    train_size = int(0.9 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=64)

    # Training setup
    criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)
    optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5, weight_decay=0.01)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer, T_0=5, T_mult=2, eta_min=1e-6
    )

    best_accuracy = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            optimizer.zero_grad()
            output = model(batch['input_ids'], batch['attention_mask'])

            # Reshape for loss calculation
            loss = criterion(
                output.view(-1, tokenizer.vocab_size),
                batch['labels'].view(-1)
            )

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

        # Evaluate
        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for batch in test_loader:
                batch = {k: v.to(device) for k, v in batch.items()}
                outputs = model(batch['input_ids'], batch['attention_mask'])

                predictions = outputs.argmax(dim=-1)
                correct += (predictions == batch['labels']).sum().item()
                total += batch['labels'].numel()

                # Print some examples
                if epoch % 2 == 0:
                    for pred, actual in zip(predictions[:2], batch['labels'][:2]):
                        pred_text = tokenizer.decode(pred, skip_special_tokens=True)
                        actual_text = tokenizer.decode(actual, skip_special_tokens=True)
                        print(f"Pred: {pred_text} | Actual: {actual_text}")

        accuracy = correct / total
        print(f"Accuracy: {accuracy:.4f}")

        scheduler.step()

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_spelling_corrector.pth')

    return model, tokenizer

# To train and evaluate:
model, tokenizer = train_and_evaluate(num_epochs=10, data_path= data_path)
# Out:
# Using device: cuda
# Epoch 1, Average Loss: 8.3573
# Pred: re'''''''''''''''''''''''''''''' ' | Actual: women
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: analysis
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at ../aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: secondary
# Pred: enthusiastic''ious'''''''''''''''''''''''''''' | Actual: principles
# Pred: re'''''''''''''''''''''''''''''' ' | Actual: pilot's
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: accommodations
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: card
# Pred: con'veniousven'''''''''''''''''''''''''' ' | Actual: specifically
# Pred: inc'''''''''''''''''''''''''''''' ' | Actual: analysis
# Pred: inc''ious'''''''''''''''''''''''''''' | Actual: technical
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: accustomed
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: phase
# Pred: inc''ious'''''''''''''''''''''''''''' | Actual: memorandum
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: knife
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: manoeuvrable
# Pred: material'''''''''''''''''''''''''''''' ' | Actual: quiz
# Pred: inc''ious'''''''''''''''''''''''''''' | Actual: rheumatism
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: peanut
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: pneumonia
# Pred: con'scious'''''''''''''''''''''''''''' | Actual: exhibition
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: traffic
# Pred: cononientious'''''''''''''''''''''''''''' | Actual: conscientious
# Pred: con'''''''''''''''''''''''''''''' ' | Actual: extraordinary
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: attach
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: forgotten
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: particular
# Pred: re'''''''''''''''''''''''''''''' ' | Actual: pamphlets
# Pred: con'sc'''''''''''''''''''''''''''' ' | Actual: conscientious
# Pred: inc 'ientious'''''''''''''''''''''''''''' | Actual: approximately
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: moustache
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: courtesy
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: road
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: chautauqua
# Pred: inc''ious'''''''''''''''''''''''''''' | Actual: refrigerator
# Pred: con 'ientiousious'''''''''''''''''''''''''' ' | Actual: conscience
# Pred: dangerous'''''''''''''''''''''''''''''' ' | Actual: goes
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: courtesies
# Pred: dangerous'''''''''''''''''''''''''''''' ' | Actual: actually
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: shell
# Pred: dangerous'''''''''''''''''''''''''''''' ' | Actual: altitude
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: suffer
# Pred: surface'''''''''''''''''''''''''''''' ' | Actual: children
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: irish
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: regretted
# Pred: enthusiasm'''''''''''''''''''''''''''''' ' | Actual: judaism
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: curtain
# Pred: enthusiasm'''''''''''''''''''''''''''''' ' | Actual: efficiency
# Pred: enthusiasm'''''''''''''''''''''''''''''' ' | Actual: special
# Pred: re'''''''''''''''''''''''''''''' ' | Actual: hidden
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: favourite
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: field
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: gale
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: form
# Pred: inc'venious'''''''''''''''''''''''''''' | Actual: organizations
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: done
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: acknowledging
# Pred: inc''ious'''''''''''''''''''''''''''' | Actual: beautiful
# Pred: inc''ious'''''''''''''''''''''''''''' | Actual: remembrance
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: special
# Pred: inc 'ientious'''''''''''''''''''''''''''' | Actual: sacrilegious
# Pred: con'''''''''''''''''''''''''''''' ' | Actual: preserved
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: financially
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: a little
# Pred: actually'''''''''''''''''''''''''''''' ' | Actual: grew
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: curtains
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: us
# Pred: flag'''''''''''''''''''''''''''''' ' | Actual: eye
# Pred: con''iousious'''''''''''''''''''''''''' ' | Actual: successfully
# Pred: inc'''''''''''''''''''''''''''''' ' | Actual: geometry
# Pred: re'''''''''''''''''''''''''''''' ' | Actual: noisy
# Pred: guarantee'''''''''''''''''''''''''''''' ' | Actual: as
# Pred: inc''ious'''''''''''''''''''''''''''' | Actual: individualistic
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: phase
# Pred: cononvenious'''''''''''''''''''''''''''' | Actual: enthusiastic
# Pred: magnificent''ious'''''''''''''''''''''''''''' | Actual: exaggerate
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: vulgar
# Pred: dangerous'''''''''''''''''''''''''''''' ' | Actual: volley
# Pred: miscellaneous'''''''''''''''''''''''''''''' ' | Actual: continent
# Pred: re'''''''''''''''''''''''''''''' ' | Actual: purpose
# Pred: enthusiasm'sc'''''''''''''''''''''''''''' ' | Actual: accompanying
# Pred: dangerous'''''''''''''''''''''''''''''' ' | Actual: shaggy
# Pred: ''''''''''''''''''''''''''''''' ' | Actual: beg
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: not
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: story
# Pred: inc'''''''''''''''''''''''''''''' ' | Actual: its
# Pred: re'''''''''''''''''''''''''''''' ' | Actual: customer
# Pred: beautiful'''''''''''''''''''''''''''''' ' | Actual: region
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: guarantee
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: many
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: departure
# Pred: miscellaneous'''''''''''''''''''''''''''''' ' | Actual: philosophy
# Pred: dangerous'''''''''''''''''''''''''''''' ' | Actual: born
# Pred: especially'''''''''''''''''''''''''''''' ' | Actual: ecstasy
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: spun
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: correspondence
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: around
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: annulled
# Pred: subterranean'''''''''''''''''''''''''''''' ' | Actual: subtract
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: searched
# Pred: miscellaneous'''''''''''''''''''''''''''''' ' | Actual: philosophy
# Pred: unanimous'''''''''''''''''''''''''''''' ' | Actual: unforgettable
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: heave
# Pred: enthusiasm'''''''''''''''''''''''''''''' ' | Actual: judaism
# Pred: surface'''''''''''''''''''''''''''''' ' | Actual: becoming
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: library
# Pred: prejudice 'ientious'''''''''''''''''''''''''''' | Actual: preliminary
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: spacecraft
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: breaking
# Pred: inc'''''''''''''''''''''''''''''' ' | Actual: psychology
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: disappointment
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: done
# Pred: cononsciousious'''''''''''''''''''''''''' ' | Actual: contemporary
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: epistle
# Pred: answer'''''''''''''''''''''''''''''' ' | Actual: horse
# Pred: enthusiasm'ven'''''''''''''''''''''''''''' ' | Actual: specimens
# Pred: unanimous'''''''''''''''''''''''''''''' ' | Actual: different
# Pred: miscellaneous'''''''''''''''''''''''''''''' ' | Actual: restaurant
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: cancelled
# Pred: unanimous'''''''''''''''''''''''''''''' ' | Actual: requisition
# Pred: miscellaneous'''''''''''''''''''''''''''''' ' | Actual: admitted
# Pred: con''ious'''''''''''''''''''''''''''' | Actual: indisputably
# Pred: enthusiasm'''''''''''''''''''''''''''''' ' | Actual: afterwards
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: kind
# Pred: enthusiastic'''''''''''''''''''''''''''''' ' | Actual: efficiency
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: us
# Pred: opposite'''''''''''''''''''''''''''''' ' | Actual: again
# Accuracy: 0.0015
# Epoch 2, Average Loss: 6.9386
# Accuracy: 0.0042
# Epoch 3, Average Loss: 6.3371
# Pred: women'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: women
# Pred: analysishedav beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: analysis
# Pred: turned'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: secondary
# Pred: va - sious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: principles
# Pred: poetry's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: pilot's
# Pred: acclydavious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: accommodations
# Pred: answer beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: card
# Pred: speciallyvenitd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: specifically
# Pred: analysis's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: analysis
# Pred: philosophy'sy beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: technical
# Pred: accfidav beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: accustomed
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: phase
# Pred: unanimouslydavy beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: memorandum
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: knife
# Pred: beautifullyientious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: manoeuvrable
# Pred: women'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: quiz
# Pred: rlyumatism beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: rheumatism
# Pred: women'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: peanut
# Pred: peculiar's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: pneumonia
# Pred: exhibitionlyientious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: exhibition
# Pred: beautiful's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: traffic
# Pred: conscientious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: conscientious
# Pred: exhibitionlyuma beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: extraordinary
# Pred: answer beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: attach
# Pred: alumni'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: forgotten
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: particular
# Pred: prejudice's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: pamphlets
# Pred: conscient beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: conscientious
# Pred: approximatelylymentious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: approximately
# Pred: guarantee'squa beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: moustache
# Pred: miscellaneous'sious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: courtesy
# Pred: answer's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: road
# Pred: cha's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: chautauqua
# Pred: refrigeratoronvenience beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: refrigerator
# Pred: conscientiousious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: conscience
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: goes
# Pred: courtly s beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: courtesies
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: actually
# Pred: answer beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: shell
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: altitude
# Pred: fight'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: suffer
# Pred: beautiful'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: children
# Pred: beautiful'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: irish
# Pred: special'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: regretted
# Pred: sorority -uma beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: judaism
# Pred: women'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: curtain
# Pred: efficiency's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: efficiency
# Pred: special'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: special
# Pred: women's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: hidden
# Pred: fascinating's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: favourite
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: field
# Pred: guarantee'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: gale
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: form
# Pred: technicallydavious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: organizations
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: done
# Pred: acquaintancelyientient t beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: acknowledging
# Pred: material'sious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: beautiful
# Pred: requisitious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: remembrance
# Pred: speciallydav beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: special
# Pred: especiallylyumaiousd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: sacrilegious
# Pred: permanentlyheuma beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: preserved
# Pred: financiallylyu beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: financially
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: a little
# Pred: women beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: grew
# Pred: curiosity's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: curtains
# Pred: answer beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: us
# Pred: women'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: eye
# Pred: successful'siousd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: successfully
# Pred: geometrylydav beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: geometry
# Pred: scarcely's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: noisy
# Pred: guarantee'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: as
# Pred: unlyallytableally beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: individualistic
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: phase
# Pred: criticismlyvenious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: enthusiastic
# Pred: efficiencylyallyiousd beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: exaggerate
# Pred: beautiful's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: vulgar
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: volley
# Pred: countenance beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: continent
# Pred: permanently's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: purpose
# Pred: accfidav beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: accompanying
# Pred: shaggy'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: shaggy
# Pred: answer beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: beg
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: not
# Pred: turned beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: story
# Pred: special 'dav beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: its
# Pred: court'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: customer
# Pred: beautifully beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: region
# Pred: guarantee'tious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: guarantee
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: many
# Pred: valy s beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: departure
# Pred: philosophylyally beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: philosophy
# Pred: answer beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: born
# Pred: exhibitionlyment beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: ecstasy
# Pred: fight's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: spun
# Pred: con'sious'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: correspondence
# Pred: answer's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: around
# Pred: annum'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: annulled
# Pred: subterranean's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: subtract
# Pred: avoid's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: searched
# Pred: philosophylyally beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: philosophy
# Pred: un'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: unforgettable
# Pred: material 'u beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: heave
# Pred: beautifulheuma beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: judaism
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: becoming
# Pred: philosophy's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: library
# Pred: prejudice'sy beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: preliminary
# Pred: especially's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: spacecraft
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: breaking
# Pred: ridiculouslyu beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: psychology
# Pred: dilyallyious beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: disappointment
# Pred: answer beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: done
# Pred: conscientiousient beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: contemporary
# Pred: unanimous's beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: epistle
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: horse
# Pred: specificallylyient beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: specimens
# Pred: dilyu beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: different
# Pred: recognitionquisit beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: restaurant
# Pred: answer'beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: cancelled
# Pred: women beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful beautiful | Actual: requisition
# ...
# Pred: gauge - gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: gale
# Pred: fight - gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: form
# Pred: technicalsauious gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: organizations
# Pred: dart'gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: done
# Pred: acknowledgementmentmentment gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: acknowledging
# Pred: beautiful -ullqua gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: beautiful
# Pred: requisition gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: remembrance
# Pred: speciallyull gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: special
# Pred: asrilquentiousily gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: sacrilegious
# Pred: permanentparapp gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: preserved
# Pred: financiallylyull gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: financially
# Pred: answer - gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: a little
# Pred: laugh gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: grew
# Pred: curiosity's gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: curtains
# Pred: dangerous gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: us
# Pred: womenly gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: eye
# Pred: sufficientlysallyyily gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: successfully
# Pred: geometryizedlle gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: geometry
# Pred: scarcelylyu gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: noisy
# Pred: temperature'gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: as
# Pred: itemableallytabled gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: individualistic
# Pred: answer - gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: phase
# Pred: definitelyallyuqua gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: enthusiastic
# Pred: efficiencyfiateledd gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: exaggerate
# Pred: beautifulablence gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: vulgar
# Pred: fight - gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: volley
# Pred: countenance gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: continent
# Pred: permanent's gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: purpose
# Pred: accruedment gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: accompanying
# Pred: shaggys gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: shaggy
# Pred: beneath gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: beg
# Pred: done'gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: not
# Pred: dodged gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: story
# Pred: item's gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: its
# Pred: shaggy - gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: customer
# Pred: peculiared gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: region
# Pred: guaranteedquigetious gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: guarantee
# Pred: anyly gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: many
# Pred: debitu gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: departure
# Pred: philosophylyally gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: philosophy
# Pred: women gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: born
# Pred: ecstasyaggerate gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: ecstasy
# Pred: turned's gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: spun
# Pred: correspondenceonientiousd gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: correspondence
# Pred: avoid -re gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: around
# Pred: annums gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: annulled
# Pred: subterranean -u gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: subtract
# Pred: suitable - s gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: searched
# Pred: philosophyternally gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: philosophy
# Pred: unfor gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: unforgettable
# Pred: suitable -u gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: heave
# Pred: virtuesheuma gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: judaism
# Pred: caught'gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: becoming
# Pred: scarcelylyull gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: library
# Pred: prejudicelyallyy gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: preliminary
# Pred: spacecraftscies gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: spacecraft
# Pred: answerrued gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: breaking
# Pred: sororityheu gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: psychology
# Pred: disappoint gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: disappointment
# Pred: sure gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: done
# Pred: conscientiousious gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: contemporary
# Pred: des s gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: epistle
# Pred: harassed'gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: horse
# Pred: specimenreshment gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: specimens
# Pred: disapp gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: different
# Pred: requisit gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: restaurant
# Pred: turned'gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: cancelled
# Pred: alumni gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: requisition
# Pred: itemablelle gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: admitted
# Pred: indefiniteisallyion gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: indisputably
# Pred: af -uous gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: afterwards
# Pred: circling - gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: kind
# Pred: equippedistletain gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: efficiency
# Pred: there's gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: us
# Pred: agencies - gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo gallo | Actual: again
# Accuracy: 0.0119
# Epoch 10, Average Loss: 4.5198
# Accuracy: 0.0127

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from transformers import BertTokenizer, BertModel
import json

class SpellingDataset(Dataset):
    def __init__(self, spelling_dict, tokenizer, max_length=32):
        self.pairs = []
        for correct, misspellings in spelling_dict.items():
            for misspelling in misspellings:
                self.pairs.append((misspelling, correct))
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __getitem__(self, idx):
        misspelling, correct = self.pairs[idx]

        misspelling_encoding = self.tokenizer(
            misspelling,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,
            return_tensors='pt'
        )

        correct_encoding = self.tokenizer(
            correct,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,
            return_tensors='pt'
        )

        return {
            'input_ids': misspelling_encoding['input_ids'].squeeze(),
            'attention_mask': misspelling_encoding['attention_mask'].squeeze(),
            'labels': correct_encoding['input_ids'].squeeze()
        }

    def __len__(self):
        return len(self.pairs)

class SpellingCorrector(nn.Module):
    def __init__(self, vocab_size, hidden_size=768):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')

        # Freeze only some BERT layers
        for param in list(self.bert.parameters())[:-2]:  # Keep last 2 layers trainable
            param.requires_grad = False

        self.char_embedding = nn.Embedding(vocab_size, 64)

        self.encoder = nn.GRU(
            input_size=hidden_size + 64,
            hidden_size=hidden_size,
            num_layers=2,
            dropout=0.1,
            bidirectional=True,
            batch_first=True
        )

        self.output = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.LayerNorm(hidden_size),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size, vocab_size)
        )

    def forward(self, input_ids, attention_mask):
        # Get BERT embeddings
        bert_output = self.bert(input_ids, attention_mask=attention_mask)[0]

        # Get character embeddings
        char_embeds = self.char_embedding(input_ids)

        # Combine embeddings
        combined = torch.cat([bert_output, char_embeds], dim=-1)

        # Encode sequence
        encoded, _ = self.encoder(combined)

        # Generate output probabilities
        logits = self.output(encoded)

        return logits

def train_and_evaluate(num_epochs=10, data_path='spelling_dictionary.json'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    with open(data_path, 'r') as f:
        spelling_dict = json.load(f)

    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = SpellingCorrector(tokenizer.vocab_size).to(device)

    dataset = SpellingDataset(spelling_dict, tokenizer, max_length=32)

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32)

    criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)
    optimizer = torch.optim.AdamW([
        {'params': model.bert.parameters(), 'lr': 1e-5},
        {'params': model.char_embedding.parameters(), 'lr': 1e-3},
        {'params': model.encoder.parameters(), 'lr': 1e-3},
        {'params': model.output.parameters(), 'lr': 1e-3}
    ])

    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=[1e-5, 1e-3, 1e-3, 1e-3],
        epochs=num_epochs,
        steps_per_epoch=len(train_loader)
    )

    best_accuracy = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            optimizer.zero_grad()
            output = model(batch['input_ids'], batch['attention_mask'])

            loss = criterion(
                output.view(-1, tokenizer.vocab_size),
                batch['labels'].view(-1)
            )

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            scheduler.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for batch in test_loader:
                batch = {k: v.to(device) for k, v in batch.items()}
                outputs = model(batch['input_ids'], batch['attention_mask'])

                predictions = outputs.argmax(dim=-1)
                correct += (predictions == batch['labels']).sum().item()
                total += batch['labels'].numel()

                if epoch % 2 == 0:
                    for pred, actual in zip(predictions[:2], batch['labels'][:2]):
                        pred_text = tokenizer.decode(pred, skip_special_tokens=True)
                        actual_text = tokenizer.decode(actual, skip_special_tokens=True)
                        print(f"Pred: {pred_text} | Actual: {actual_text}")

        accuracy = correct / total
        print(f"Accuracy: {accuracy:.4f}")

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_spelling_corrector.pth')

    return model, tokenizer
model, tokenizer = train_and_evaluate(num_epochs=10, data_path= data_path)
# Out:
# Using device: cuda
# Epoch 1, Average Loss: 7.8209
# Pred: thin'sddddddddddddddddddddddddddddd | Actual: next
# Pred: anniversaryonveniencedddddddddddddddddddddddddddd | Actual: overshadowed
# Pred: fraternallyddddddddddddddddddddddddddddd | Actual: frightened
# Pred: shaggy''ddddddddddddddddddddddddddddd | Actual: judge
# Pred: vaenanceddddddddddddddddddddddddddddd | Actual: chapter
# Pred: sympatheticlynceddddddddddddddddddddddddddddd | Actual: sympathetic
# Pred: shaggy 'bonddddddddddddddddddddddddddddd | Actual: opposite
# Pred: magnificentheientiousdddddddddddddddddddddddddddd | Actual: documents
# Pred: exaggerateddddddddddddddddddddddddddddd | Actual: existence
# Pred: guaranteelyciesddddddddddddddddddddddddddddd | Actual: dangerous
# Pred: sound'siousdddddddddddddddddddddddddddd | Actual: class
# Pred: enthusiasmesnceiousdddddddddddddddddddddddddddd | Actual: memories
# Pred: shaggy''ddddddddddddddddddddddddddddd | Actual: married
# Pred: recently 'bonddddddddddddddddddddddddddddd | Actual: standard
# Pred: enthusiasmenancetismdddddddddddddddddddddddddddd | Actual: application
# Pred: appropriateesciesddddddddddddddddddddddddddddd | Actual: epistle
# Pred: subterraneanhenceddddddddddddddddddddddddddddd | Actual: voucher
# Pred: answer'sddddddddddddddddddddddddddddd | Actual: own
# Pred: distinguishedaggerateddddddddddddddddddddddddddddd | Actual: departure
# Pred: va 'ciesddddddddddddddddddddddddddddd | Actual: technical
# Pred: unforgettabletableddddddddddddddddddddddddddd | Actual: unfortunately
# Pred: conscientiousiousiousiousiousiousddddddddddddddddddddddd | Actual: conscience
# Pred: psychologyesiestismdddddddddddddddddddddddddddd | Actual: statistics
# Pred: unforientiousdddddddddddddddddddddddddddd | Actual: unfortunately
# Pred: gallery'sddddddddddddddddddddddddddddd | Actual: type
# Pred: acc -bonddddddddddddddddddddddddddddd | Actual: pretend
# Pred: correspondencesnceddddddddddddddddddddddddddddd | Actual: certainly
# Pred: curiosityheumaiousdddddddddddddddddddddddddddd | Actual: curiosity
# Pred: prejudicefiientiousdddddddddddddddddddddddddddd | Actual: prejudice
# Pred: saw'' tdddddddddddddddddddddddddddd | Actual: married
# Pred: af -bonddddddddddddddddddddddddddddd | Actual: motorway
# Pred: minimumheumaddddddddddddddddddddddddddddd | Actual: grateful
# Pred: peculiar -bonddddddddddddddddddddddddddddd | Actual: prefer
# Pred: initiationhenceiousdddddddddddddddddddddddddddd | Actual: guardian
# Pred: va -bonddddddddddddddddddddddddddddd | Actual: worried
# Pred: va -bonddddddddddddddddddddddddddddd | Actual: copper
# Pred: initiationenanceiousdddddddddddddddddddddddddddd | Actual: handling
# Pred: va'sddddddddddddddddddddddddddddd | Actual: trotting
# Pred: conscientiousiousiousiousiousdddddddddddddddddddddddd | Actual: conscientious
# Pred: pamphlets -nceddddddddddddddddddddddddddddd | Actual: strenuous
# Pred: definiteenanceiousdddddddddddddddddddddddddddd | Actual: scheduled
# Pred: countenanceddddddddddddddddddddddddddddd | Actual: brake
# Pred: initiation -bonddddddddddddddddddddddddddddd | Actual: make
# Pred: definite -nceddddddddddddddddddddddddddddd | Actual: scold
# Pred: miscellaneous -bonddddddddddddddddddddddddddddd | Actual: contacted
# Pred: va -bonddddddddddddddddddddddddddddd | Actual: you
# Pred: permanentlyheateddddddddddddddddddddddddddddd | Actual: perceive
# Pred: indefinitelyaggerumaddddddddddddddddddddddddddddd | Actual: indefinitely
# Pred: inconvenddddddddddddddddddddddddddddd | Actual: increasing
# Pred: vacanumatismdddddddddddddddddddddddddddd | Actual: chapter
# Pred: pamphletslyumaiousdddddddddddddddddddddddddddd | Actual: preliminary
# Pred: unforgettabledddddddddddddddddddddddddddd | Actual: unwieldy
# Pred: tragedyheciesddddddddddddddddddddddddddddd | Actual: trotting
# Pred: rheumatismdddddddddddddddddddddddddddd | Actual: rheumatism
# Pred: form'sddddddddddddddddddddddddddddd | Actual: here
# Pred: thin''ddddddddddddddddddddddddddddd | Actual: words
# Pred: conscientiousiousiousiousiousiousddddddddddddddddddddddd | Actual: convalescence
# Pred: should'siousdddddddddddddddddddddddddddd | Actual: couldn't
# Pred: privilegelynceiousdddddddddddddddddddddddddddd | Actual: pretty
# Pred: va''ddddddddddddddddddddddddddddd | Actual: there
# Pred: intellectuallyumaiousdddddddddddddddddddddddddddd | Actual: certificates
# Pred: accenanceiousdddddddddddddddddddddddddddd | Actual: actually
# Pred: competentaggerumaiousdddddddddddddddddddddddddddd | Actual: customary
# Pred: soundssddddddddddddddddddddddddddddd | Actual: answer
# Pred: court - sddddddddddddddddddddddddddddd | Actual: kind
# Pred: dormitorylynceiousdddddddddddddddddddddddddddd | Actual: altitude
# Pred: psychologyenanceiousdddddddddddddddddddddddddddd | Actual: psychology
# Pred: must'sddddddddddddddddddddddddddddd | Actual: anxious
# Pred: tied - sddddddddddddddddddddddddddddd | Actual: than
# Pred: noticeable''ddddddddddddddddddddddddddddd | Actual: notes
# Pred: biscuitssncetismdddddddddddddddddddddddddddd | Actual: biscuits
# Pred: pamphletsenanceiousdddddddddddddddddddddddddddd | Actual: recommendations
# Pred: definiteheumatismdddddddddddddddddddddddddddd | Actual: memorandum
# Pred: beautiful -bonddddddddddddddddddddddddddddd | Actual: local
# Pred: recognitionquiumaiondddddddddddddddddddddddddddd | Actual: recognition
# Pred: accruedumaddddddddddddddddddddddddddddd | Actual: accustomed
# Pred: satisfactionsciesddddddddddddddddddddddddddddd | Actual: distinguished
# Pred: satisfactioncanciesddddddddddddddddddddddddddddd | Actual: satisfactorily
# Pred: recognitionquiumaiousdddddddddddddddddddddddddddd | Actual: recognition
# Pred: negotiationsheumatismdddddddddddddddddddddddddddd | Actual: opportunities
# Pred: immediatelyheumatismdddddddddddddddddddddddddddd | Actual: immediately
# Pred: requiatetismdddddddddddddddddddddddddddd | Actual: interrelated
# Pred: visitedaggerateddddddddddddddddddddddddddddd | Actual: visited
# Pred: recognitionquiumatismdddddddddddddddddddddddddddd | Actual: recognition
# Pred: va 'ciesddddddddddddddddddddddddddddd | Actual: region
# Pred: originallylyumatismdddddddddddddddddddddddddddd | Actual: ordinary
# Pred: court -iestismdddddddddddddddddddddddddddd | Actual: cheaper
# Pred: enthusiasticesiesddddddddddddddddddddddddddddd | Actual: genius
# Pred: negotiationsheumaiousdddddddddddddddddddddddddddd | Actual: anticipation
# Pred: requibonddddddddddddddddddddddddddddd | Actual: satisfaction
# Pred: stomach -nceddddddddddddddddddddddddddddd | Actual: stubborn
# Pred: initiationfiumaddddddddddddddddddddddddddddd | Actual: anticipation
# Pred: embarrassedlyallyiousdddddddddddddddddddddddddddd | Actual: enemy
# Pred: exaggerateddddddddddddddddddddddddddddd | Actual: exaggerate
# Pred: guarantee 'bonddddddddddddddddddddddddddddd | Actual: that
# Pred: melancholylynceddddddddddddddddddddddddddddd | Actual: genius
# Pred: enthusiasmheumaiousdddddddddddddddddddddddddddd | Actual: enamored
# Pred: economicalheatetismdddddddddddddddddddddddddddd | Actual: acknowledging
# Pred: enthusiasmfiumaiousdddddddddddddddddddddddddddd | Actual: enthusiasm
# Pred: guarantee 'ciesddddddddddddddddddddddddddddd | Actual: leave
# Pred: court 'nceiousdddddddddddddddddddddddddddd | Actual: courtesies
# Pred: flag -nceiousdddddddddddddddddddddddddddd | Actual: flagrancy
# Pred: conscientiousiousiousiousiousdddddddddddddddddddddddd | Actual: conceive
# Pred: enthusiasmquiumatismdddddddddddddddddddddddddddd | Actual: biscuits
# Pred: pamphletsenaientiousdddddddddddddddddddddddddddd | Actual: functions
# Pred: flagenanceddddddddddddddddddddddddddddd | Actual: poetry
# Pred: satisfaction'sddddddddddddddddddddddddddddd | Actual: suitable
# Pred: far - s s s s s s s s s s s s s s s s s s s s s s s s s s s s sd | Actual: man
# Pred: initiationquincetismdddddddddddddddddddddddddddd | Actual: impeach
# Pred: suspicioncanciesddddddddddddddddddddddddddddd | Actual: suspicion
# Pred: comparativelyonumaddddddddddddddddddddddddddddd | Actual: comfortable
# Pred: magnificentsbonddddddddddddddddddddddddddddd | Actual: carried
# Pred: speciallyumaddddddddddddddddddddddddddddd | Actual: special
# Pred: melancholylyumaiousdddddddddddddddddddddddddddd | Actual: bankruptcy
# Pred: attorneysenanceiousdddddddddddddddddddddddddddd | Actual: attaching
# Pred: unforumaiousdddddddddddddddddddddddddddd | Actual: unfortunately
# Pred: afficiesddddddddddddddddddddddddddddd | Actual: affectionate
# Pred: oppositeficiesddddddddddddddddddddddddddddd | Actual: opposite
# Pred: courtesciesddddddddddddddddddddddddddddd | Actual: baggage
# Pred: definiteenancetismdddddddddddddddddddddddddddd | Actual: representative
# Pred: guarantee -nceddddddddddddddddddddddddddddd | Actual: special
# Pred: anniversarylynceiousdddddddddddddddddddddddddddd | Actual: analysis
# Pred: determinedheientiousdddddddddddddddddddddddddddd | Actual: determining
# Pred: recognitionquiumaiondddddddddddddddddddddddddddd | Actual: receiver
# Pred: miscellaneousquiumatismdddddddddddddddddddddddddddd | Actual: miscellaneous
# Pred: unanimousheumatismdddddddddddddddddddddddddddd | Actual: destination
# Pred: resource -ncetismdddddddddddddddddddddddddddd | Actual: absurd
# Pred: accustomedheumatismdddddddddddddddddddddddddddd | Actual: accustomed
# Pred: criticismheumatismdddddddddddddddddddddddddddd | Actual: criticism
# Pred: magnificentsnceiousdddddddddddddddddddddddddddd | Actual: conditions
# Pred: va'sddddddddddddddddddddddddddddd | Actual: accordingly
# Pred: distinguishedssiousdddddddddddddddddddddddddddd | Actual: biscuits
# Pred: gallery'siousdddddddddddddddddddddddddddd | Actual: said
# Pred: exaggerateddddddddddddddddddddddddddddd | Actual: exacerbated
# Pred: delheumaddddddddddddddddddddddddddddd | Actual: altimeter
# Pred: guaranteelyciesddddddddddddddddddddddddddddd | Actual: paralysed
# Pred: dormitorylyumatismdddddddddddddddddddddddddddd | Actual: satisfactorily
# Pred: specificheumaddddddddddddddddddddddddddddd | Actual: specimens
# Pred: melancholy -nceddddddddddddddddddddddddddddd | Actual: sorority
# Pred: stomachenanceddddddddddddddddddddddddddddd | Actual: skip
# Pred: refrigeratorheumatismdddddddddddddddddddddddddddd | Actual: representatives
# Pred: recognitionquiumatismdddddddddddddddddddddddddddd | Actual: requisition
# Pred: vacanbonddddddddddddddddddddddddddddd | Actual: dart
# Pred: count'sddddddddddddddddddddddddddddd | Actual: since
# Pred: resource'sddddddddddddddddddddddddddddd | Actual: graceful
# Pred: anniversaryheumatismdddddddddddddddddddddddddddd | Actual: exceptionally
# Pred: satisfaction -ciesddddddddddddddddddddddddddddd | Actual: tennis player
# Pred: initiation -nceiousdddddddddddddddddddddddddddd | Actual: playground
# Pred: countenanceiousdddddddddddddddddddddddddddd | Actual: contented
# Pred: miscellaneousquiiesiondddddddddddddddddddddddddddd | Actual: missile
# Pred: countenanceiousdddddddddddddddddddddddddddd | Actual: efficiency
# Pred: initiation 'nceiousdddddddddddddddddddddddddddd | Actual: be
# Pred: accheumaiousdddddddddddddddddddddddddddd | Actual: acceptable
# Pred: appropriate 'ciesddddddddddddddddddddddddddddd | Actual: apparent
# Pred: courtsbonddddddddddddddddddddddddddddd | Actual: dart
# Pred: accommodateheumatismdddddddddddddddddddddddddddd | Actual: accommodation
# Pred: requiumaiondddddddddddddddddddddddddddd | Actual: requisition
# Pred: enthusiasmquiumatismdddddddddddddddddddddddddddd | Actual: resources
# Pred: embarrassedenaenaientdddddddddddddddddddddddddddd | Actual: economic
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: inconvenient
# Pred: criticismheientiousiousdiousddddddddddddddddddddddddd | Actual: criticism
# Pred: negotiationscannceiousdddddddddddddddddddddddddddd | Actual: potatoes
# Pred: undoubtedlylyciesddddddddddddddddddddddddddddd | Actual: problem
# Pred: subterraneanquiumatismdddddddddddddddddddddddddddd | Actual: substantial
# Pred: definite 'ciesddddddddddddddddddddddddddddd | Actual: mustn't
# Pred: exaggerateddddddddddddddddddddddddddddd | Actual: exception
# Pred: definite 'nceddddddddddddddddddddddddddddd | Actual: strove
# Pred: cemeterylybonddddddddddddddddddddddddddddd | Actual: colonel
# Pred: schedule -bonddddddddddddddddddddddddddddd | Actual: scraping
# Pred: pamphlets -nceiousdddddddddddddddddddddddddddd | Actual: performed
# Pred: annum'sddddddddddddddddddddddddddddd | Actual: bridge
# Pred: enthusiasmlyumatismdddddddddddddddddddddddddddd | Actual: secondary
# Pred: courtsbonddddddddddddddddddddddddddddd | Actual: juice
# Pred: va 'bonddddddddddddddddddddddddddddd | Actual: about
# Pred: form'sddddddddddddddddddddddddddddd | Actual: past
# Pred: anxiety - s sdddddddddddddddddddddddddddd | Actual: answer
# Pred: enthusiasmquiumaiousdddddddddddddddddddddddddddd | Actual: enthusiastic
# Pred: specialheumaiousdddddddddddddddddddddddddddd | Actual: special
# Pred: answer - sddddddddddddddddddddddddddddd | Actual: leeway
# Pred: anniversaryheumatismdddddddddddddddddddddddddddd | Actual: anniversary
# Pred: answer'siousdddddddddddddddddddddddddddd | Actual: a
# Pred: stomach - sddddddddddddddddddddddddddddd | Actual: dawn
# Pred: magnificentheumaddddddddddddddddddddddddddddd | Actual: magnificent
# Pred: courtesbonddddddddddddddddddddddddddddd | Actual: duly
# Pred: enthusiasmenanceiousdddddddddddddddddddddddddddd | Actual: attorney
# Pred: miscellaneousesumaddddddddddddddddddddddddddddd | Actual: proportions
# Pred: pamphletsquinceiousdddddddddddddddddddddddddddd | Actual: cancellation
# Pred: anxietylyientiousiousddiousdddddddddddddddddddddddd | Actual: annoyance
# Pred: melancholylynceiousdddddddddddddddddddddddddddd | Actual: certainly
# Pred: economicalheumatismdddddddddddddddddddddddddddd | Actual: economics
# Pred: distinguishedheumaddddddddddddddddddddddddddddd | Actual: debit
# Pred: cemeteryquibonddddddddddddddddddddddddddddd | Actual: severely
# Pred: definiteenanceddddddddddddddddddddddddddddd | Actual: future
# Pred: women'sddddddddddddddddddddddddddddd | Actual: best
# Pred: answer'sddddddddddddddddddddddddddddd | Actual: too
# Pred: cemeteryesnceiousdddddddddddddddddddddddddddd | Actual: cemetery
# Pred: efficiencyscientiousdddddddddddddddddddddddddddd | Actual: effluence
# Pred: conscientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: countenance
# Pred: gorgeous -nceddddddddddddddddddddddddddddd | Actual: gorgeous
# Pred: unanimoussnceiousdddddddddddddddddddddddddddd | Actual: daughters
# Pred: vacanciesiousdddddddddddddddddddddddddddd | Actual: vagabond
# Pred: equipped -nceddddddddddddddddddddddddddddd | Actual: affectionately
# Pred: pamphlets'sddddddddddddddddddddddddddddd | Actual: woodwork
# Pred: afficiesddddddddddddddddddddddddddddd | Actual: detonated
# Pred: competentheientddddddddddddddddddddddddddddd | Actual: confirmation
# Pred: exaggerateiousdddddddddddddddddddddddddddd | Actual: ecstasy
# Pred: shaggy''ddddddddddddddddddddddddddddd | Actual: stay
# Pred: miscellaneousesnceddddddddddddddddddddddddddddd | Actual: tedious
# Pred: unforgettabledddddddddddddddddddddddddddd | Actual: unemployed
# Pred: equippedscientiousdddddddddddddddddddddddddddd | Actual: equipped
# Pred: must -bonddddddddddddddddddddddddddddd | Actual: mutual
# Pred: magnificentheumatismdddddddddddddddddddddddddddd | Actual: magnificent
# Pred: minimumheumaddddddddddddddddddddddddddddd | Actual: solemn
# Pred: beautifulenanceddddddddddddddddddddddddddddd | Actual: scandal
# Pred: beautiful - sddddddddddddddddddddddddddddd | Actual: trotting
# Pred: negotiationsesciesiousdddddddddddddddddddddddddddd | Actual: accompanying
# Pred: requiiesiondddddddddddddddddddddddddddd | Actual: remember
# Pred: guarantee -bonddddddddddddddddddddddddddddd | Actual: galloped
# Pred: surpluslyciesiousdddddddddddddddddddddddddddd | Actual: telephoned
# Pred: tied'sddddddddddddddddddddddddddddd | Actual: calf
# Pred: suspicionheumatismdddddddddddddddddddddddddddd | Actual: sufficient
# Pred: shaggy'' sdddddddddddddddddddddddddddd | Actual: clothes
# Pred: peculiarsateddddddddddddddddddddddddddddd | Actual: prison
# Pred: guarantee -nceddddddddddddddddddddddddddddd | Actual: always
# Pred: recognitionquiumatismdddddddddddddddddddddddddddd | Actual: requisition
# Pred: removed 'ciesddddddddddddddddddddddddddddd | Actual: splendid
# Pred: correspondence -nceddddddddddddddddddddddddddddd | Actual: country
# Pred: requiumaiondddddddddddddddddddddddddddd | Actual: recently
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: incorruptible
# Pred: court'sddddddddddddddddddddddddddddd | Actual: courtesy
# Pred: sound - sddddddddddddddddddddddddddddd | Actual: damaged
# Pred: court's sdd sddddddddddddddddddddddddd | Actual: medical
# Pred: beautiful -bonddddddddddddddddddddddddddddd | Actual: easy
# Pred: oppositeistleateddddddddddddddddddddddddddddd | Actual: opposite
# Pred: miscellaneous -bonddddddddddddddddddddddddddddd | Actual: christian
# Pred: answer 'bonddddddddddddddddddddddddddddd | Actual: region
# Pred: psychologysnceddddddddddddddddddddddddddddd | Actual: so - called
# Pred: politicianheumatismdddddddddddddddddddddddddddd | Actual: policeman
# Pred: sound''ddddddddddddddddddddddddddddd | Actual: should
# Pred: court'siousdddddddddddddddddddddddddddd | Actual: boys
# Pred: requiiesddddddddddddddddddddddddddddd | Actual: relief
# Pred: appropriate 'umaddddddddddddddddddddddddddddd | Actual: apartment
# Pred: va -bonddddddddddddddddddddddddddddd | Actual: idea
# Pred: psychologylyiestismdddddddddddddddddddddddddddd | Actual: ice - cream
# Pred: shaggy - 'ddddddddddddddddddddddddddddd | Actual: led
# Pred: sound'sddddddddddddddddddddddddddddd | Actual: avoid
# Pred: cemeterylyciesddddddddddddddddddddddddddddd | Actual: cemetery
# Pred: latest - sddddddddddddddddddddddddddddd | Actual: city
# Pred: immediatelyheatetismdddddddddddddddddddddddddddd | Actual: about
# Pred: pamphletsheciestismdddddddddddddddddddddddddddd | Actual: unemployed
# Pred: suitablesciesiousdddddddddddddddddddddddddddd | Actual: slide
# Pred: definiteenanceiousdddddddddddddddddddddddddddd | Actual: quandary
# Pred: shaggy -bonddddddddddddddddddddddddddddd | Actual: grandpa
# Pred: definite 'ciesddddddddddddddddddddddddddddd | Actual: behind
# Pred: answer -nceydddddddddddddddddddddddddddd | Actual: make
# Pred: beautifulesnceiousdddddddddddddddddddddddddddd | Actual: because
# Pred: magnificenthenceddddddddddddddddddddddddddddd | Actual: altimeter
# Pred: answer 'bonddddddddddddddddddddddddddddd | Actual: about
# Pred: enthusiasmheumatismdddddddddddddddddddddddddddd | Actual: proclamation
# Pred: shaggy'sddddddddddddddddddddddddddddd | Actual: lamb
# Pred: miscellaneouses siousdddddddddddddddddddddddddddd | Actual: courtesies
# Pred: anniversaryss sdddddddddddddddddddddddddddd | Actual: answer
# Pred: conenaientiousiousddddddddddddddddddddddddddd | Actual: cancelled
# Pred: schedule -bonddddddddddddddddddddddddddddd | Actual: scarcely
# Pred: rheientiousdddddddddddddddddddddddddddd | Actual: reckon
# Pred: biscuitsenanceiousiousddddddddddddddddddddddddddd | Actual: biscuits
# Pred: va''ddddddddddddddddddddddddddddd | Actual: thoughts
# Pred: court''iousdddddddddddddddddddddddddddd | Actual: fork
# Pred: specialheumatismdddddddddddddddddddddddddddd | Actual: special
# Pred: competentaggerumaddddddddddddddddddddddddddddd | Actual: committed
# Pred: oppositeaggerbonddddddddddddddddddddddddddddd | Actual: opposite
# Pred: sororityheiestismdddddddddddddddddddddddddddd | Actual: suitable
# Pred: comparativelyaggerumaiousdddddddddddddddddddddddddddd | Actual: commanded
# Pred: va - sddddddddddddddddddddddddddddd | Actual: horses
# Pred: latestly siousdddddddddddddddddddddddddddd | Actual: later
# Pred: negotiationsenanceiousdddddddddddddddddddddddddddd | Actual: tournament
# Pred: friend'sddddddddddddddddddddddddddddd | Actual: clause
# Pred: pamphletsesiesiousdddddddddddddddddddddddddddd | Actual: pamphlets
# Pred: va 'bonddddddddddddddddddddddddddddd | Actual: tractor
# Pred: annum -nceiousdddddddddddddddddddddddddddd | Actual: museum
# Pred: definite'sddddddddddddddddddddddddddddd | Actual: flight
# Pred: refrigeratorheumaddddddddddddddddddddddddddddd | Actual: belief
# Pred: guarantee''ddddddddddddddddddddddddddddd | Actual: fishy
# Pred: conscientiousiousiousiousiousiousiousiousddddddddddddddddddddd | Actual: compendium
# Pred: conscientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddddddddd | Actual: continuous
# Pred: beautifulquincetismdddddddddddddddddddddddddddd | Actual: colonel
# Pred: guarantee -bonddddddddddddddddddddddddddddd | Actual: know
# Pred: anniversaryheciesddddddddddddddddddddddddddddd | Actual: analysis
# Pred: conscientiousiousddddddddddddddddddddddddddd | Actual: concerned
# Pred: requiumatismdddddddddddddddddddddddddddd | Actual: reminders
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: inconvenienced
# Pred: saw'sddddddddddddddddddddddddddddd | Actual: tree
# Pred: exaggerateddddddddddddddddddddddddddddd | Actual: experiments
# Pred: answer'sddddddddddddddddddddddddddddd | Actual: finding
# Pred: distinguishedenanceiousdddddddddddddddddddddddddddd | Actual: negotiations
# Pred: unforgetiousdddddddddddddddddddddddddddd | Actual: unusually
# Pred: definite'sddddddddddddddddddddddddddddd | Actual: mixed
# Pred: va'sddddddddddddddddddddddddddddd | Actual: respectfully
# Pred: va -bonddddddddddddddddddddddddddddd | Actual: women
# Pred: enthusiasmheumaiousdddddddddddddddddddddddddddd | Actual: anxious
# Pred: beautiful -ciesddddddddddddddddddddddddddddd | Actual: bulletin
# Pred: conscientiousiousiousiousiousdddddddddddddddddddddddd | Actual: conditions
# Pred: prejudiceenaientiousdddddddddddddddddddddddddddd | Actual: prejudice
# Pred: miscellaneousquiiesiondddddddddddddddddddddddddddd | Actual: miscellaneous
# Pred: re'siondddddddddddddddddddddddddddd | Actual: rises
# Pred: countenanceiousdddddddddddddddddddddddddddd | Actual: purple
# Pred: designedheatetismdddddddddddddddddddddddddddd | Actual: described
# Pred: especiallyheciesddddddddddddddddddddddddddddd | Actual: altimeter
# Pred: oppositefiumaddddddddddddddddddddddddddddd | Actual: operator
# Pred: gallery'sddddddddddddddddddddddddddddd | Actual: bridge
# Pred: definiteheumatismdddddddddddddddddddddddddddd | Actual: memorandum
# Pred: requiumaiousdddddddddddddddddddddddddddd | Actual: sacrilegious
# Pred: enthusiasmheumaiousdddddddddddddddddddddddddddd | Actual: accommodation
# Pred: criticismheumaiousdddddddddddddddddddddddddddd | Actual: criticisms
# Pred: affidavddddddddddddddddddddddddddddd | Actual: determined
# Pred: fundamentalenanceiousdddddddddddddddddddddddddddd | Actual: fundamental
# Pred: guarantee 'bonddddddddddddddddddddddddddddd | Actual: whatever
# Pred: sound'sddddddddddddddddddddddddddddd | Actual: lived
# Pred: initiation - sddddddddddddddddddddddddddddd | Actual: into
# Pred: beautifulquiumaddddddddddddddddddddddddddddd | Actual: bungalow
# Pred: va'sddddddddddddddddddddddddddddd | Actual: give
# Pred: pamphlets -bontismdddddddddddddddddddddddddddd | Actual: secondary
# Pred: caught'sddddddddddddddddddddddddddddd | Actual: pamphlets
# Pred: answer'sddddddddddddddddddddddddddddd | Actual: except
# Pred: distinguishedheumatismdddddddddddddddddddddddddddd | Actual: distinguished
# Pred: fraternallyiousdddddddddddddddddddddddddddd | Actual: friendship
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: inconvenienced
# Pred: shaggy 'bonddddddddddddddddddddddddddddd | Actual: ordered
# Pred: vaesciesddddddddddddddddddddddddddddd | Actual: receipts
# Pred: guarantee -bonddddddddddddddddddddddddddddd | Actual: nature
# Pred: exaggeratetismdddddddddddddddddddddddddddd | Actual: extraordinary
# Pred: permanent''ddddddddddddddddddddddddddddd | Actual: laid
# Pred: attorneyslyciestismdddddddddddddddddddddddddddd | Actual: attorney
# Pred: unforgettabledddddddddddddddddddddddddddd | Actual: unforgettable
# Pred: court''ddddddddddddddddddddddddddddd | Actual: daddy's
# Pred: exaggeratetismdddddddddddddddddddddddddddd | Actual: exaggerate
# Pred: guaranteecanciesddddddddddddddddddddddddddddd | Actual: anxiety
# Pred: conscientiousiousiousiousiousdddddddddddddddddddddddd | Actual: continent
# Pred: surplus''ddddddddddddddddddddddddddddd | Actual: surface
# Pred: vacanciesddddddddddddddddddddddddddddd | Actual: temperature
# Pred: guaranteelyallyddddddddddddddddddddddddddddd | Actual: trilby
# Pred: resource -bonddddddddddddddddddddddddddddd | Actual: resource
# Pred: definite - sddddddddddddddddddddddddddddd | Actual: scare
# Pred: beautifulheumaiousdddddddddddddddddddddddddddd | Actual: beautiful
# Pred: accommodateheumaddddddddddddddddddddddddddddd | Actual: occasionally
# Pred: distinguishedaggeratetismdddddddddddddddddddddddddddd | Actual: suitable
# Pred: initiation -nceiousdddddddddddddddddddddddddddd | Actual: secretarial
# Pred: form''ddddddddddddddddddddddddddddd | Actual: patience
# Pred: annumenanceiousdddddddddddddddddddddddddddd | Actual: anxiety
# Pred: saw''ddddddddddddddddddddddddddddd | Actual: married
# Pred: loud 'bonddddddddddddddddddddddddddddd | Actual: placed
# Pred: delheumaddddddddddddddddddddddddddddd | Actual: stomach
# Pred: dormitoryheumaddddddddddddddddddddddddddddd | Actual: auditorium
# Pred: epistleciesddddddddddddddddddddddddddddd | Actual: epistle
# Pred: countenanceddddddddddddddddddddddddddddd | Actual: arctic
# Pred: guaranteelyncetismdddddddddddddddddddddddddddd | Actual: character
# Pred: fra''ddddddddddddddddddddddddddddd | Actual: friends
# Pred: shaggy 'bonddddddddddddddddddddddddddddd | Actual: fit
# Pred: receipts -nceddddddddddddddddddddddddddddd | Actual: transcending
# Pred: competentheumaddddddddddddddddddddddddddddd | Actual: comical
# Pred: unlyciesddddddddddddddddddddddddddddd | Actual: laboratory
# Pred: surpluss sddddddddddddddddddddddddddddd | Actual: surface
# Pred: conscientiousiousddddddddddddddddddddddddddd | Actual: convalescence
# Pred: va -bonddddddddddddddddddddddddddddd | Actual: rumour
# Pred: rsnceddddddddddddddddddddddddddddd | Actual: maintenance
# Pred: definitesnceiousdddddddddddddddddddddddddddd | Actual: referring
# Pred: valyientiousdddddddddddddddddddddddddddd | Actual: anxiety
# Pred: mountainousesientiousdddddddddddddddddddddddddddd | Actual: mountainous
# Pred: especiallyesciesddddddddddddddddddddddddddddd | Actual: surplus
# Pred: miscellaneous 'bonddddddddddddddddddddddddddddd | Actual: saucer
# Pred: miscellaneousheciesddddddddddddddddddddddddddddd | Actual: affidavit
# Pred: answer'sddddddddddddddddddddddddddddd | Actual: earth
# Pred: accident -bonddddddddddddddddddddddddddddd | Actual: antarctic
# Pred: definite -bonddddddddddddddddddddddddddddd | Actual: damaged
# Pred: exaggeratetismdddddddddddddddddddddddddddd | Actual: exceptionally
# Pred: va -bonddddddddddddddddddddddddddddd | Actual: where
# Pred: suspicionheumaddddddddddddddddddddddddddddd | Actual: successful
# Pred: pamphlets -ncetismdddddddddddddddddddddddddddd | Actual: toboggan
# Pred: privilegelyciesddddddddddddddddddddddddddddd | Actual: privilege
# Pred: enthusiasticlyientiousdddddddddddddddddddddddddddd | Actual: eliminate
# Pred: satisfactionisumatismdddddddddddddddddddddddddddd | Actual: satisfactorily
# Pred: anniversarylyumaiousdddddddddddddddddddddddddddd | Actual: kindergarten
# Pred: especiallycanbonddddddddddddddddddddddddddddd | Actual: easy
# Pred: surplusenaientiousdddddddddddddddddddddddddddd | Actual: surplus
# Pred: definite - sddddddddddddddddddddddddddddd | Actual: monkey
# Pred: requiumatismdddddddddddddddddddddddddddd | Actual: rewrite
# Pred: exaggerateddddddddddddddddddddddddddddd | Actual: expenditure
# Pred: initiationenanceiousiousddddddddddddddddddddddddddd | Actual: annoyance
# Pred: guaranteelyumaiousdddddddddddddddddddddddddddd | Actual: philosophy
# Pred: definite 'ciesddddddddddddddddddddddddddddd | Actual: led
# Pred: refrigeratorquiumaiousdddddddddddddddddddddddddddd | Actual: representatives
# Pred: dormitorylynceiousdddddddddddddddddddddddddddd | Actual: dormitory
# Pred: shaggy 'ateddddddddddddddddddddddddddddd | Actual: classes
# Pred: stomachcanbonddddddddddddddddddddddddddddd | Actual: stomach
# Pred: exaggeratetismdddddddddddddddddddddddddddd | Actual: exercises
# Pred: guarantee -bonddddddddddddddddddddddddddddd | Actual: neck
# Pred: fra''ddddddddddddddddddddddddddddd | Actual: fight
# Pred: turned 'bonddddddddddddddddddddddddddddd | Actual: wanted
# Pred: permanentlyheumaddddddddddddddddddddddddddddd | Actual: permanent
# Pred: competent''ddddddddddddddddddddddddddddd | Actual: come
# Pred: negotiationsesciesddddddddddddddddddddddddddddd | Actual: potatoes
# Pred: originallyheatetismdddddddddddddddddddddddddddd | Actual: ordinarily
# Pred: definiteenanceiousdddddddddddddddddddddddddddd | Actual: flesh
# Pred: must 'bonddddddddddddddddddddddddddddd | Actual: virtues
# Pred: beautifullynceddddddddddddddddddddddddddddd | Actual: gallery
# Pred: answer'sddddddddddddddddddddddddddddd | Actual: owner
# Pred: dormitorylyncetismdddddddddddddddddddddddddddd | Actual: actually
# Pred: definiteenanceiousdddddddddddddddddddddddddddd | Actual: activities
# Pred: laugh -bonddddddddddddddddddddddddddddd | Actual: left
# Pred: miscellaneoussnceiousdddddddddddddddddddddddddddd | Actual: earth
# Pred: requiumatismdddddddddddddddddddddddddddd | Actual: rheumatism
# Pred: tied'sddddddddddddddddddddddddddddd | Actual: disappointment
# Pred: vacanbonddddddddddddddddddddddddddddd | Actual: the
# Pred: va -bonddddddddddddddddddddddddddddd | Actual: cow
# Pred: exaggeratetismdddddddddddddddddddddddddddd | Actual: exceptionally
# Pred: suspicioncanciesddddddddddddddddddddddddddddd | Actual: success
# Pred: annum -nceddddddddddddddddddddddddddddd | Actual: annum
# Pred: enthusiasmaggerumatismdddddddddddddddddddddddddddd | Actual: indefinite
# Pred: attorneyshedavtismdddddddddddddddddddddddddddd | Actual: affidavit
# Pred: negotiations 'ciesiousdddddddddddddddddddddddddddd | Actual: negotiations
# Pred: stomachenanceddddddddddddddddddddddddddddd | Actual: destroy
# Pred: court'sddddddddddddddddddddddddddddd | Actual: hall
# Pred: answer'sddddddddddddddddddddddddddddd | Actual: seen
# Pred: gallery -bonddddddddddddddddddddddddddddd | Actual: comfortable
# Pred: enthusiasmheumaddddddddddddddddddddddddddddd | Actual: special
# Pred: sound'sddddddddddddddddddddddddddddd | Actual: give
# Pred: indefinitelyheumaddddddddddddddddddddddddddddd | Actual: industrial
# Pred: epquibonddddddddddddddddddddddddddddd | Actual: latest
# Pred: initiation 'nceiousdddddddddddddddddddddddddddd | Actual: down
# Pred: distinguishedheumaiousdddddddddddddddddddddddddddd | Actual: disappoint
# Pred: philosophylyumaiousdddddddddddddddddddddddddddd | Actual: capacity
# Pred: criticismsientiousdddddddddddddddddddddddddddd | Actual: curtains
# Pred: accruedumaddddddddddddddddddddddddddddd | Actual: accompanying
# Pred: definite 'bonddddddddddddddddddddddddddddd | Actual: larvae
# Pred: recognitionquiumatismdddddddddddddddddddddddddddd | Actual: recommendation
# Pred: del 'ientddddddddddddddddddddddddddddd | Actual: delegates
# Pred: designed 'bonddddddddddddddddddddddddddddd | Actual: dislikes
# Pred: minimum -bonddddddddddddddddddddddddddddd | Actual: purple
# Pred: anniversarylynceiousdddddddddddddddddddddddddddd | Actual: answer
# Pred: unforgettabledddddddddddddddddddddddddddd | Actual: unscramble
# Pred: guarantee -nceddddddddddddddddddddddddddddd | Actual: behind
# Pred: unforienttabledddddddddddddddddddddddddddd | Actual: unusually
# Pred: courtes siousdddddddddddddddddddddddddddd | Actual: gallery
# Pred: acc -nceddddddddddddddddddddddddddddd | Actual: electron
# Pred: shaggy'sddddddddddddddddddddddddddddd | Actual: drawn
# Pred: sound''ddddddddddddddddddddddddddddd | Actual: laugh
# Pred: sound'' sdddddddddddddddddddddddddddd | Actual: sorority
# Pred: cemeteryes sddddddddddddddddddddddddddddd | Actual: likes
# Pred: gallery - sddddddddddddddddddddddddddddd | Actual: humbly
# Pred: necessarilyquiciestismdddddddddddddddddddddddddddd | Actual: necessary
# Pred: renanceiondddddddddddddddddddddddddddd | Actual: maintenance
# Pred: enthusiasmheumaddddddddddddddddddddddddddddd | Actual: intellectual
# Pred: turned'sddddddddddddddddddddddddddddd | Actual: yes
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: inconvenient
# Pred: valy sddddddddddddddddddddddddddddd | Actual: exceptionally
# Pred: vagabonddddddddddddddddddddddddddddd | Actual: collateral
# Pred: immediatelyheallytismdddddddddddddddddddddddddddd | Actual: immensely
# Pred: enthusiasmruedciesddddddddddddddddddddddddddddd | Actual: initials
# Pred: negotiationslyientiousiousiousiousiousdddddddddddddddddddddddd | Actual: sorority
# Pred: appropriate 'nceddddddddddddddddddddddddddddd | Actual: apparatus
# Pred: guarantee - sddddddddddddddddddddddddddddd | Actual: juice
# Pred: psychologysbonddddddddddddddddddddddddddddd | Actual: tact
# Pred: refrigeratorheumaddddddddddddddddddddddddddddd | Actual: refreshment
# Pred: sororitylyciesddddddddddddddddddddddddddddd | Actual: story
# Pred: enthusiasmheumatismdddddddddddddddddddddddddddd | Actual: establishing
# Pred: immediatelyenanceddddddddddddddddddddddddddddd | Actual: embed
# Pred: enthusiasmheumaiousiousddddddddddddddddddddddddddd | Actual: enthusiasm
# Pred: unlyciesddddddddddddddddddddddddddddd | Actual: laboratory
# Pred: answer -bonddddddddddddddddddddddddddddd | Actual: stating
# Pred: initiationquiumatismdddddddddddddddddddddddddddd | Actual: employer
# Pred: definite 'iesddddddddddddddddddddddddddddd | Actual: sitting
# Pred: specialheumaddddddddddddddddddddddddddddd | Actual: special
# Pred: court'sddddddddddddddddddddddddddddd | Actual: recommendation
# Pred: negotiationsenanceddddddddddddddddddddddddddddd | Actual: politician
# Pred: psychologyhebonddddddddddddddddddddddddddddd | Actual: esteemed
# Pred: enthusiasmfiateiousdddddddddddddddddddddddddddd | Actual: affectionate
# Pred: initiationesnceiousdddddddddddddddddddddddddddd | Actual: explore
# Pred: courtesiesddddddddddddddddddddddddddddd | Actual: courtesies
# Pred: conscientiousiousiousiousiousdddddddddddddddddddddddd | Actual: conscientious
# Pred: form'sddddddddddddddddddddddddddddd | Actual: city
# Pred: decidedlyheiestismdddddddddddddddddddddddddddd | Actual: genius
# Pred: embarrassedonvenientdddddddddddddddddddddddddddd | Actual: initiation
# Pred: anniversaryfiumatismdddddddddddddddddddddddddddd | Actual: memorandum
# Pred: prejudice 'ciestismdddddddddddddddddddddddddddd | Actual: president's
# Pred: vagabonddddddddddddddddddddddddddddd | Actual: gradually
# Pred: unanimoussciesddddddddddddddddddddddddddddd | Actual: unanimous
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: inconvenienced
# Pred: enthusiasmheientiousdddddddddddddddddddddddddddd | Actual: inconvenienced
# Pred: rheumatismdddddddddddddddddddddddddddd | Actual: rheumatism
# Pred: shaggy'sddddddddddddddddddddddddddddd | Actual: done
# Pred: guarantee 'bonddddddddddddddddddddddddddddd | Actual: cupboard
# Pred: valyciesiousdddddddddddddddddddddddddddd | Actual: calculate
# Pred: must'sddddddddddddddddddddddddddddd | Actual: height
# Pred: cemeterylyboniousdddddddddddddddddddddddddddd | Actual: cemetery
# Pred: surplus -bonddddddddddddddddddddddddddddd | Actual: dark
# Pred: requiumaiondddddddddddddddddddddddddddd | Actual: receipt
# Pred: initiationlynceiousdddddddddddddddddddddddddddd | Actual: elementary
# Pred: pamphlets -nceddddddddddddddddddddddddddddd | Actual: folk
# Pred: initiationlyumatismdddddddddddddddddddddddddddd | Actual: inaccessible
# Pred: satisfactionesumaiousdddddddddddddddddddddddddddd | Actual: satisfaction
# Pred: sound'sddddddddddddddddddddddddddddd | Actual: due
# Pred: definitefiateddddddddddddddddddddddddddddd | Actual: gauge
# Accuracy: 0.0069
# Epoch 2, Average Loss: 5.3717
# Accuracy: 0.0123
# Epoch 3, Average Loss: 3.8228
# Pred: necks sious s s s s of of of of of of of from from from from from from from from from from from from from from from from freezing | Actual: next
# Pred: available -egitdditiousilyilyily to to to to to to to to to to anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious flag | Actual: overshadowed
# Pred: friendternallyiencedily s to to to to to to to fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire freezing | Actual: frightened
# Pred: hand'snneeeeeeee to to to to to from from from from from from from to from from from from anxious orchestra | Actual: judge
# Pred: chautauquaquaquaquaquaqua s s s s s s s s s s s s s s s s s s s s s s s | Actual: chapter
# Pred: sympatheticlfullyyyyn to fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire fire freezing | Actual: sympathetic
# Pred: must't tdd tdd t t t t t t t field fieldcycycycycycycypedcypedpedcycycy | Actual: opposite
# Pred: documentsmpmentleddquentientenced field field field field field field field field field field field field from from from freezing freezing freezing freezing freezing freezingquentcy | Actual: documents
# Pred: existenceaggervenientddddddientientientientientientientientientientientientientientientientientientientientientd | Actual: existence
# Pred: dangerousranullydddddeeeeeee fieldeeeeeeeee field field field fieldcycy | Actual: dangerous
# Pred: nows siousious s siousously siousiouss siousously siousouslysientiousously sienceiouss siousily sience | Actual: class
# Pred: representativess siousious s s s s s s s freezing freezing freezing freezing freezing freezing freezing freezing freezing freezing freezing freezing anxious freezing anxious freezing freezing freezing freezing freezing | Actual: memories
# Pred: of 'ititititititititititititit anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious | Actual: married
# Pred: street's tily s sily s s s s s s s s s s s s s se seeeeee t freezing | Actual: standard
# Pred: approachingfidavitit sititititit to to to anxious to anxious anxious to anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious | Actual: application
# Pred: approvalistleuitd sdd field field field field field field field field field field field field field field field field field to to to to to edge equally | Actual: epistle
# Pred: follyscientiousioususiousiousious to to to to to to to to to to to to to to to to to to to to to enthusiasm enthusiasm | Actual: voucher
# Pred: answere sndeee annum annum annum fire fire fire fire fire fire fire fire fire fire fire fire fire anxious anxious anxious anxious anxious anxious anxious anxious | Actual: own
# Pred: differentablequentointdableienteeeeeeee from from from from from from from from from fire fire fire fire from fire fire orchestra | Actual: departure
# Pred: technicalableulldddddddddddd anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious enthusiasm enthusiasm | Actual: technical
# Pred: unforgetsarisariledledledledledledledledledledledledledledledledledledledledledledledledledledience | Actual: unfortunately
# Pred: conscientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousientientientientientientientientientientd | Actual: conscience
# Pred: availablehtquentiousilyilyiousilyilyily from to from from from from from from from from from from from from from from from from from from or orchestra | Actual: statistics
# Pred: unfortunatelynecessarilysciousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: unfortunately
# Pred: frightenedped sious to to to to to to to to to to to to to to to to to to to to to to to to to to to alumni | Actual: type
# Pred: infinite's t t t t t t t t to field field field field field field field field field field field field field field field field field field fire freezing | Actual: pretend
# Pred: cancellingulliousiousyiousiousiousiousiousiousiousiousiousienceienceience from from from from from from fromienceienceience fire fire fire orchestra | Actual: certainly
# Pred: curiosityvalescenceiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousily | Actual: curiosity
# Pred: prejudice'sientd s s t s s s s s s s s s s s s s s s s s s s s from from s from | Actual: prejudice
# Pred: i'' td s s s s s s seeee to to to to to to to to to to anxious anxious to anxious anxious alumni | Actual: married
# Pred: guaranteeped siousd to to to to to to to to to to to to to to to to to to to to to to to to to to orchestra | Actual: motorway
# Pred: graduallyutaullquadd sd s s s s s sn sn s s increasing increasing increasing increasing increasing increasingn increasing increasing increasing increasing increasing t | Actual: grateful
# Pred: peach - squay s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: prefer
# Pred: guaranteeuitientiousdddiousiousiousiousiousious from from from from from from from from from from from from from from from from orchestra orchestra orchestra | Actual: guardian
# Pred: worries'siousd t t t t t t t t t t t to to to to to to to to to t t increasing to t t t | Actual: worried
# Pred: ami -ngdddddddddddddddd to to to to to to to to to to to to orchestra | Actual: copper
# Pred: fascinatingotti syy s increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing increasing freezing freezing freezing freezing increasing increasing always always | Actual: handling
# Pred: traffic -bondddddmmmmmmmmmmm to to to to to to to to to to to to to | Actual: trotting
# Pred: conscientiousiousientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious from fromious freezing | Actual: conscientious
# Pred: curiosity -bonquade sdecyydcycydecycyecycycycycycycycycycycycycy | Actual: strenuous
# Pred: scheduledableuquayyiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious from from from from from freezing orchestra | Actual: scheduled
# Pred: break -ientiousious siousious s sious s s from to from from from from from from from from from from fire fire fire fire fire fire freezing | Actual: brake
# Pred: mamaquiggaiousddionious to to to to to to to to to to to to to to to to to to to to to to to alumni | Actual: make
# Pred: scout -ngvreysvressienceienceienceienceienceience from from from from from from from from from fire fire fire from from from from orchestra | Actual: scold
# Pred: insablengnious toiousious to toious to toiousious to to to to to to to to to to toiousious to toious orchestra | Actual: contacted
# Pred: sure - siousd t t t t t t t t t t t to to to to to to to to to fire fire fire fire fire fire flag | Actual: you
# Pred: precisionsoniencenn snnnn to to to to to to to to to to to to to to to to to to to to freezing | Actual: perceive
# Pred: indefinitelyallyreiencedddddienceddiencedddddddd to to todddddddience | Actual: indefinitely
# Pred: insallyveniencedddddddd to to to to to to to to to to from from from to anxious anxious anxious anxious anxious orchestra | Actual: increasing
# Pred: chautauquaquaquaquaquaquaquaquaquaquaquaquaquaqua to to to to to to to to tocy climb to to to flag | Actual: chapter
# Pred: preliminary 'ullyy s s t s s s s s s s s s s s s s s s s s s from from from from fire freezing | Actual: preliminary
# Pred: unparallesariledledledledledledledledledledledledledledledledledledledledledledledledledledledled | Actual: unwieldy
# Pred: trafficuitngddddddddddddddddd to to to to todientienceienceienceienceience | Actual: trotting
# Pred: rheumatismtismtismtismddddddeeeeeeeeeeeeeeeeeee | Actual: rheumatism
# Pred: three'siousious s sious from from from from from from from from from from from from from from from from from from from from from from to to | Actual: here
# Pred: shaggy'squae s s from from from from from from from from from from from from from from from from from from from from from from from from flag | Actual: words
# Pred: conscientiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: convalescence
# Pred: cloudss siousily s s s from s s from from from from from from from from from from from from from from from from from from from from freezing | Actual: couldn't
# Pred: privilege'snn snnnnnnnnnncynnnnnnnnncynnnncy | Actual: pretty
# Pred: thereer lly s s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: there
# Pred: chemistry -ullyy syointeeeeeeeeeeeeeeee anxious anxious anxious anxious anxious anxious anxious anxious | Actual: certificates
# Pred: actuallyruedrneditus to to to to anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious | Actual: actually
# Pred: competitionnairesciousiousdiousiousiousiousiousious from from from from from from from from from from from from from fromientient from from freezing orchestra | Actual: customary
# Pred: sounded syously syious s s from from from from from from from from from from from from from from from from from from from from from orchestra | Actual: answer
# Pred: curiosity - siousious s s s s s seeeeeee to to to to to toeeeeeee freezing | Actual: kind
# Pred: chautauquaquaquaiousiousiousiousiousiousiousious from from from from from from from from from from from from from from from from orchestra orchestra | Actual: altitude
# Pred: psychology psychologyullyyy field field field field field field field field field field field field field field field field field field fieldcycycycycycycy | Actual: psychology
# Pred: pilot -ngnious siousious t t to to to to to to to to to to to to to freezing freezing to to to to freezing freezing freezing | Actual: anxious
# Pred: thorough - squaddddeeeeeeeeeeeeeeeeeeeeeeee | Actual: than
# Pred: noticeable's s s s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: notes
# Pred: biscuitss sientddientdientientientientientientientientientientientientientientientientientientientientientientientient | Actual: biscuits
# Pred: precisionedggaiousn snn s snn snn s s to to to to to to to to to to to tonnn | Actual: recommendations
# Pred: memorandumn 'nn t tn t t t t t t t tnnn t tn t t t t tn t t t t | Actual: memorandum
# Pred: shaggy'squan s t t s s s s s s s s s s s to to to to to to to to to to to to orchestra | Actual: local
# Pred: recognitionquisitionionionionionionionionionionionionionionionionionionionionionionion to to to to to orchestra | Actual: recognition
# Pred: accruedtainitd susdedddeeee edge edge edge edge edge edge anxious anxious anxious anxious anxious anxious anxious edge anxious anxious | Actual: accustomed
# Pred: chaimeterreiousiousily tious t t t t t t t t t t t t t t t t t t field field field field enthusiasm enthusiasm | Actual: distinguished
# Pred: satisfactionis siousily s silyily sily to to to to to to to to to to to to to to anxious anxious anxious to to freezing freezing | Actual: satisfactorily
# Pred: recognitionquisitionionionionionionionionionionionionionion to to to to to to to to tomm to to toion | Actual: recognition
# Pred: arrangementsrilegiousious s siouse seee to to to to from to to to from to to to from from from from from freezing freezing | Actual: opportunities
# Pred: immediatelylyullyledeientdouslyeeeeeeeeeeeeeeeeeeeeee anxious | Actual: immediately
# Pred: intereddavititeeeeeeeeeeeeeeeeeeeeeeeeeeily | Actual: interrelated
# Pred: visibleeddavitdddd field field field field field from from from from from from from from from from from from from from from from from from orchestra | Actual: visited
# Pred: recognitioningsitionionionionionionionionionionionionionion to to to to to to to to to increasing increasing to to to orchestra | Actual: recognition
# Pred: region -'td t t t t t t t t t t t t t t t t t t t t t t t t t t t | Actual: region
# Pred: originallydinarilyiousilyrilyrilyiouseeee anxious anxiouse anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious anxious | Actual: ordinary
# Pred: chemistry -quentiousiousususiousioususiousiousususiousiousiouseiouseeeeeeeeeeeee | Actual: cheaper
# Pred: geniusquincedd to to to to to to to to to to to to to to to to to to to to to to from from from to gallo | Actual: genius
# Pred: anticipatingcipatetismd stismously s s s s s s s s s s s s s s s s s s s s s s s s | Actual: anticipation
# Pred: romanticrhaliousiousiousiousiousiousiousiousiousiousiousiousiousiousious from from from from from from from to from from from from to orchestra | Actual: satisfaction
# Pred: stomachuitquentquadd tdd t t t t t t t t t t t t t t t t t t t t t t t | Actual: stubborn
# Pred: elementary'sddddddddddddddddddddedddddddd | Actual: anticipation
# ...
# Pred: transferredsresssssssssssssssssssssssssssss | Actual: transcending
# Pred: com spiritualalyssssssssssssionionionionionionionionionionionionionionionion | Actual: comical
# Pred: laboratorylfreyssssssssssssssssssssssss m m m s | Actual: laboratory
# Pred: surplusssssssssss s s s s s s s s s s s s s s s s s s s s s | Actual: surface
# Pred: confirmationvalescenceious llenceenceenceenceenceenceenceenceenceenceenceenceenceesssssenceenceencesencesence | Actual: convalescence
# Pred: rumheumatismtismtismtismtismtismtismtismtismtismtismtismtismtismmentmentmentmentmentmentmentmentmentmentmentmentmentment s | Actual: rumour
# Pred: existence -hasssssssssmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentionion | Actual: maintenance
# Pred: refteringmentnioningionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: referring
# Pred: vicinityallyallyysssssssssssssssssssssssssssd | Actual: anxiety
# Pred: mountainousgiesusions sionionionionionionionionionionionionionionionionionionionion sion sion s s | Actual: mountainous
# Pred: separateesonssssssssssssssssssssssssionssss | Actual: surplus
# Pred: so - hour - re reinginginginginginginginginginginginginginginginginginginginginginginginging s | Actual: saucer
# Pred: affidavitddavitititititititititititititititititititititititititit | Actual: affidavit
# Pred: ours siousddsssssionionionionionionionionionionionionionionionionionionionionion | Actual: earth
# Pred: enthusiasticcipateddddddsionionionionionionionionionionionionionionionionionionionionionion | Actual: antarctic
# Pred: damaged -ssssssssssssssssssssssssssssss | Actual: damaged
# Pred: exceptionallylyallyylyusilyilyingingingingingingingingingingingingingingingingingingingingingingingily | Actual: exceptionally
# Pred: wereeetory ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll s s | Actual: where
# Pred: successful successfuluquaioususiousiousssssssssssssssssssssssss | Actual: successful
# Pred: toboggan'tn t t t t t s s s t t s s s s s s s s t t t t t s s | Actual: toboggan
# Pred: privilege privilegeee vemomentmentmentmenteeeeeeeeeeeeeeeee llingee s | Actual: privilege
# Pred: eliminateaggerateteointtoryointointointointointointointointointointointointointointointointointointointointointointointointointoint | Actual: eliminate
# Pred: satisfactorilyilyingilyilyilyilyilyilyilyilyilyilyilyointointointointointointointointointointointointilyily | Actual: satisfactorily
# Pred: kindergarten kindergartentainianminguringingingingsingingingingingingingingingingingingingingingingingingings | Actual: kindergarten
# Pred: especiallylyedlyeeeeeeeeeeeeeeeeeeeeeeeeeeee | Actual: easy
# Pred: surplusrousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious s s s s s s s s s s s s s s | Actual: surplus
# Pred: monkeypepeylogistpeslogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistlogistenen tlogist | Actual: monkey
# Pred: receiptcoatmenttion sionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: rewrite
# Pred: exaggerateustorylogistlogistsnessnessnessnessnessnessnessnessnessnessnessnessnessnessnessnessnessinginginginginglogistlogist | Actual: expenditure
# Pred: annum oneenyingingointionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: annoyance
# Pred: philosophylyantnsmentionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: philosophy
# Pred: leisureereee llee lle ll llee ll ll ll ll ll ll ll ll llee ll llee ll lle | Actual: led
# Pred: representativesingentingingingionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: representatives
# Pred: dormitorysyys tss reiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveive | Actual: dormitory
# Pred: clothessss s s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: classes
# Pred: stomachrenuousdduousdssssnessionnessnessionionionionionionionionionioniesioniesionioniesies | Actual: stomach
# Pred: exercisesestsss sssssss s s s s s s s s s s s s s s s s s s s | Actual: exercises
# Pred: naucherchsssssssssssssssssssssssssssss | Actual: neck
# Pred: fightternallyally s s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: fight
# Pred: went 'davititititit re re re re re re re re re re re re re re re re re re re re re reee | Actual: wanted
# Pred: permanentisancentn's t s s s s s t t t t t t t s s s s s s s s s s s s s | Actual: permanent
# Pred: comener llence ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll s s | Actual: come
# Pred: potatoesuteilns sss ss s s s s s s s s s s s s s s s s s s s s s s | Actual: potatoes
# Pred: ordinarilyyeousiesalaliesiesiesiesiesionionionionionionionionionionionionionionionioniesiesies | Actual: ordinarily
# Pred: flirtingysssssssssssssssssssssssssssssment | Actual: flesh
# Pred: president'senceily t tingingingingingingingingingingingingingingingingingingingingingingingingily | Actual: virtues
# Pred: galleryerychddddddddddddd re re re re re re re re field re field field field fieldcycy | Actual: gallery
# Pred: ourcula s t s s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: owner
# Pred: actuallyallyallyzationilymentdilyddeeeeeeeeeeeeeeeeeeeeeily | Actual: actually
# Pred: activitiesesiesussinginginginginginginginginginginginginginginginginginginginginginginginginginging | Actual: activities
# Pred: laughhiff downnessness re re re re re re re re re re re re re re re re re re re re re re re re re re re | Actual: left
# Pred: eaticumactord stismoint s tion t t t s s s s sionionionionionionionionionion sion s | Actual: earth
# Pred: rheumatismtismmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentment | Actual: rheumatism
# Pred: now to red re re re re re re re re re re re re re re re re re re re re re re re re re re reies | Actual: disappointment
# Pred: teeth -ngdeingdinginginginginginginginginginginginginginginginginginginginginginginginging | Actual: the
# Pred: cakewry re s s s s s s s s s s s s s s re re re re re re re re s s s s s | Actual: cow
# Pred: exceptionallylyallylyeionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: exceptionally
# Pred: saucerssssssssssssssssssssssssssssss | Actual: success
# Pred: annum -torointointointointointointointointointointointointointointointointointointointointointointointointointointointointoint | Actual: annum
# Pred: indefinitequige mentioneddpateionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: indefinite
# Pred: affidavititdavitititititititititititititititititititititititititit | Actual: affidavit
# Pred: negotiations negotiationsyn stationeonusientious sionionionionionionionionionionionionionionionionionionionionionionion | Actual: negotiations
# Pred: stomachrenuousdsuousionsionionionionionionionionionionionionionionionionionionionionionionionion | Actual: destroy
# Pred: holepedbonddddddddddddddddddddddddddddd | Actual: hall
# Pred: sea'sointingionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: seen
# Pred: thorough - runys ssssssssssssssssssssionion s s s s s | Actual: comfortable
# Pred: specialslysssionssssionionionionionionionionionionionionionionionionionionionion | Actual: special
# Pred: halfoffgettablee llointeointoint lloint lloint ll ll ll ll lleeeee ll ll ll ll ll ll lloint | Actual: give
# Pred: industryucherallyteioningingionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: industrial
# Pred: latestestingssmentingsitsitsitsitsitsitsitsitsitsitsitsitsitsitsitsitsitsitsitsitsitsitingingsit | Actual: latest
# Pred: diebit tointoint tointointingingointingingingingingingingingingingingingingingingingingingingingion | Actual: down
# Pred: disappointointointointointointointointointointointointointointointointointointointointointointointointointointointointoint | Actual: disappoint
# Pred: capacitylyallyys sssssssssssssssssssssssssss | Actual: capacity
# Pred: surplusssquasiesionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: curtains
# Pred: accompanyingompmentralruedmentmentmentmentruedruedruedruedruedruedruedruedruedruedruedruedruedruedruedruedruedruedruedruedruedruedrued | Actual: accompanying
# Pred: youngpepatedddointointointointointointointointointointointointointointointointmentmentmentmentmentmentmentmentingoint | Actual: larvae
# Pred: recommendationquisitionionionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: recommendation
# Pred: delegates't t s t t t t t t t t t t t t t t t t t t t t t t t t t t t | Actual: delegates
# Pred: disease likelyppointointointointointointointointointointointointointointointointointointointointointointointointointointointointoint | Actual: dislikes
# Pred: surplussaquad sdsssssssssssss s s s s s s s s s s s s | Actual: purple
# Pred: answer rightrectctointointointointointointointointointointointointointointointointointointointointointointointointointointoint | Actual: answer
# Pred: unanimousquilleledledtabletableledledledledledledledledledledledledledledledledledledledledledledledionled | Actual: unscramble
# Pred: behindbitrnedmointointointointointointointointointointointointointointointointointointointointointointointointointointointoint | Actual: behind
# Pred: unusuallylygettableledyddddddalalalalalalalalalaldddalalalalalalal | Actual: unusually
# Pred: primary'sy s t t s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: gallery
# Pred: electioneonsiousiousionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: electron
# Pred: sank to s t singingingingingingingingingingingingingingingingingingingingingingingionioning s | Actual: drawn
# Pred: laughhakpedpetttttingingingingingingionionionionionionionionionionionionionioniveion | Actual: laugh
# Pred: sor calledy re reing ll ll ll ll ll ll ll ll ll ll re re re re re re re re re ll ll ll ll s s | Actual: sorority
# Pred: like'ss ssssss s s s s s s s s s s s s s s s s s s s s s s | Actual: likes
# Pred: reallylyullyilyyyyyyyyyyyyyyyyyyyyyyyyyyyy | Actual: humbly
# Pred: necessarilylyryddddd telephoned telephonee telephone telephonee telephone telephone telephone telephone telephone telephone telephone telephone telephoneeeeeeeed | Actual: necessary
# Pred: maintenancenoanceiaurs sionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: maintenance
# Pred: intellectualallyreraldingingdddionionionionionionionionionionionionionionionionionionionionionion | Actual: intellectual
# Pred: yet's t s s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: yes
# Pred: inconvenientdddddddddddddddddddddddddddd | Actual: inconvenient
# Pred: colonelly runyyyyyyyyy re re re re re re re re re re re re re re re re re re re re | Actual: exceptionally
# Pred: collateralduvressssssssssssssssssssssssssss | Actual: collateral
# Pred: immenselylyyyyyyyyyssssssssssssssssssssss | Actual: immensely
# Pred: initialruedruedruedruedruedruedruedruedruedruedruedruednessnessnessnessmentmentmentmentmentmentmentmentnessmentmentmentmentruedrued | Actual: initials
# Pred: sororitylyullyy syyyyyysysssssssssssyyyssyy | Actual: sorority
# Pred: apparatusousous mentionedusionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: apparatus
# Pred: geniusries s's s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: juice
# Pred: turnedledmentddssssssssssionionionionionionionionionionionionionionionions | Actual: tact
# Pred: refreshmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentmentment | Actual: refreshment
# Pred: satyrryyinginginginginginginginginginginginginginging s s s s s s s s s s s s | Actual: story
# Pred: establishingcertainurius ssssionionionionionionionionionionionionionionionionionionionionionionion | Actual: establishing
# Pred: imitation'mt m m m m m m m m m m m m m m m m m m m m m m m m m m m t | Actual: embed
# Pred: enthusiasm enthusiasmumaredsssssssssssssssssssssssssss | Actual: enthusiasm
# Pred: laboratorycipatedssssssssioniondddionionionionionionionionddddionions | Actual: laboratory
# Pred: shaggyotti t td t t t t t t t t t t t t t t t t t t t t t t t t t t t | Actual: stating
# Pred: employerquireedddddddddddddddddddddddddded | Actual: employer
# Pred: sittingotti t tily t t t t re re re re re re re re re re re re re re re re re re re re re re s | Actual: sitting
# Pred: specialternallyyy sys eny en en en en en s s s s s s s s s s s s s s s s s | Actual: special
# Pred: recommendationssmentointoint sointmentmentoint s s soint sointointointointointointointointointointointointoint s s s s | Actual: recommendation
# Pred: politician -ismqua s s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: politician
# Pred: esteemededointointedointointointointointointointointointointointointointmentmentmentmentmentmentointointointointingingoint | Actual: esteemed
# Pred: affectionateatetedditmomomomomomomomomomomomomomomomomomomomomomomomomo | Actual: affectionate
# Pred: explored'doint ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll ll s | Actual: explore
# Pred: courtesyesiesyeousiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesiesies | Actual: courtesies
# Pred: conscientiousioususiousious siousiousious s s s s s s s s s s s s s s s s s s s s | Actual: conscientious
# Pred: shouldpilitmentmentmentmentmentmentmentmentmentmentmentmentmentmentionionionionionionionionionionionionionion | Actual: city
# Pred: jeopardyhtegiaurslogist reointlogist re re re re re re re re re re re re re re re re re re s s s s s | Actual: genius
# Pred: imitationbarrasionsssssssssssssssssssionsionionionssss | Actual: initiation
# Pred: memorandum -uydddddddddalalalalalalalalalalalalalalalalalalal | Actual: memorandum
# Pred: president's s s s s s s s s s s s s s s s s s s s s s s s s s s s s s | Actual: president's
# Pred: gaugenagee te ll ll ll ll ll ll ll llinginginging llinging ll ll ll ll llinginginginginginging | Actual: gradually
# Pred: unanimoususeuousquasststtsionionionionionionionionionionionionionionionionionionionionion | Actual: unanimous
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: inconvenienced
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: inconvenienced
# Pred: rheumatismtismstismtismtismtismtismtismtismtismtismiontismtismtismtismtismtismtismtismtismtismionionionionionion | Actual: rheumatism
# Pred: dangerouseesssssssssssingssssssingingingingingingingingingings | Actual: done
# Pred: carriedgaddddddddddddddddddddddddddd s sd | Actual: cupboard
# Pred: collateralucnceenceencesenceenceenceenceenceiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveiveion | Actual: calculate
# Pred: neck - runy re ll re re re re re re re re re re re re re re re re re re re re re re ll ll re re | Actual: height
# Pred: symmetryyyyily syyyenceenceenceenceenceenceenceenceenceenceenceence re re re re s re re re re sy | Actual: cemetery
# Pred: dartkeyciesddinginginginginginginginginginginginginginginginginginginginginginginginginginging | Actual: dark
# Pred: receiptmitsitionionionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: receipt
# Pred: elementaryly chemistryydedioususionionionionionionionionionionionionionionionionionionionionionionion | Actual: elementary
# Pred: folksmentsssssssssss s s s s s s s s s s s s s s s s s s | Actual: folk
# Pred: inaccessibleciismbledstsssssssssssssssssssssssss | Actual: inaccessible
# Pred: satisfactionisfactorily sctorilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: satisfaction
# Pred: countenanceions tionsionionionionionionionionionionionionionionionionionionionionionionionion | Actual: due
# Pred: glowedes sddedddddddddddddddddddeeeddingd | Actual: gauge
# Accuracy: 0.0206
# Epoch 10, Average Loss: 0.1347
# Accuracy: 0.0206

# %%
from transformers import get_linear_schedule_with_warmup
class SpellingCorrector(nn.Module):
    def __init__(self, vocab_size, hidden_size=768, max_length=32):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')
        self.max_length = max_length

        # Freeze BERT
        for param in self.bert.parameters():
            param.requires_grad = False

        self.char_embedding = nn.Embedding(vocab_size, 32)

        self.encoder = nn.GRU(
            input_size=hidden_size + 32,
            hidden_size=256,
            num_layers=1,
            bidirectional=True,
            batch_first=True
        )

        # Remove the attention mechanism to simplify
        self.output = nn.Sequential(
            nn.Linear(512, vocab_size),
            nn.LogSoftmax(dim=-1)
        )

    def forward(self, input_ids, attention_mask):
        # Get BERT embeddings
        with torch.no_grad():
            bert_output = self.bert(input_ids, attention_mask=attention_mask)[0]

        # Get character embeddings
        char_embeds = self.char_embedding(input_ids)

        # Combine embeddings
        combined = torch.cat([bert_output, char_embeds], dim=-1)

        # Encode sequence
        encoded, _ = self.encoder(combined)

        # Generate output probabilities
        logits = self.output(encoded)

        return logits

def train_and_evaluate(num_epochs=10, data_path='spelling_dictionary.json'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    with open(data_path, 'r') as f:
        spelling_dict = json.load(f)

    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = SpellingCorrector(tokenizer.vocab_size).to(device)

    dataset = SpellingDataset(spelling_dict, tokenizer, max_length=32)

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=16)

    criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    num_training_steps = num_epochs * len(train_loader)
    num_warmup_steps = num_training_steps // 10

    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=num_warmup_steps,
        num_training_steps=num_training_steps
    )

    best_accuracy = 0
    patience = 3
    no_improve = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            optimizer.zero_grad()
            output = model(batch['input_ids'], batch['attention_mask'])

            # Reshape for loss calculation to match dimensions
            loss = criterion(
                output.contiguous().view(-1, tokenizer.vocab_size),
                batch['labels'].contiguous().view(-1)
            )

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
            optimizer.step()
            scheduler.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for batch in test_loader:
                batch = {k: v.to(device) for k, v in batch.items()}
                outputs = model(batch['input_ids'], batch['attention_mask'])

                # Get predictions for each position in the sequence
                predictions = outputs.argmax(dim=-1)

                # Mask out padding tokens
                mask = batch['labels'] != tokenizer.pad_token_id
                correct += ((predictions == batch['labels']) & mask).sum().item()
                total += mask.sum().item()

                if epoch % 2 == 0:
                    for pred, actual in zip(predictions[:2], batch['labels'][:2]):
                        pred_text = tokenizer.decode(pred, skip_special_tokens=True)
                        actual_text = tokenizer.decode(actual, skip_special_tokens=True)
                        print(f"Pred: {pred_text} | Actual: {actual_text}")

        accuracy = correct / total if total > 0 else 0
        print(f"Accuracy: {accuracy:.4f}")

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            no_improve = 0
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_spelling_corrector.pth')
        else:
            no_improve += 1
            if no_improve >= patience:
                print("Early stopping triggered")
                break

    return model, tokenizer

model, tokenizer = train_and_evaluate(num_epochs=10, data_path= data_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: capacity
# Pred: psychology'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: occurrence
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: involving
# Pred: magnificent 'iousiousiousdiousiousiousiousiousddddddiousiousiousiousiousdddddddddd | Actual: refrigerator
# Pred: miscellaneous'siousdddddddddddddddddddddddddddd | Actual: initial
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdd | Actual: possibility
# Pred: ''siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: allowed
# Pred: con 'iousiousiousiousdddddddddddddddddddddiousiousiousiousd | Actual: arguing
# Pred: court'sddddddddddddddddddddddddddddd | Actual: saucer
# Pred: miscellaneous 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: curiosity
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: extraordinary
# Pred: court'sddddddddddddddddddddddddddddd | Actual: hedge
# Pred: miscellaneous 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: financially
# Pred: enthusiasmsiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: equipped
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: tomorrow
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdiousiousiousiousiousd | Actual: magnificent
# Pred: court 'dddddddddddddddddddddddddddddd | Actual: hydraulic
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: philosophy
# Pred: enthusiasm 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: physician
# Pred: magnificent'sddddddddddddddddddddddddddddd | Actual: specimen
# Pred: prejudice'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: every
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: conditions
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: restaurant
# Pred: magnificentssiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: neck
# Pred: prejudice'sddddddddddddddddddddddddddddd | Actual: solemn
# Pred: magnificentsdddddddddddddddddddddddddddddd | Actual: decidedly
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: phase
# Pred: court 'iousiousiousiousddiousiousiousiousiousiousiousiousiousiousiousddddddddddddd | Actual: quarantine
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: curiosity
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdiousiousiousiousiousious | Actual: note
# Pred: prejudice'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddiousiousiousiousdd | Actual: that
# Pred: court 'iousiousdddddddddddddddddddddddddddd | Actual: addressable
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: determined
# Pred: miscellaneous'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: epistle
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: miracle
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: correspondence
# Pred: ''sddddddddddddddddddddddddddddd | Actual: remember
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: ridiculous
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: nice
# Pred: inc 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: justified
# Pred: enthusiasm'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: eye
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: surplus
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: southern
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: conscientious
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: old - fashioned
# Pred: miscellaneous'mentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: picturesque
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: organized
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: annum
# Pred: court'sddddddddddddddddddddddddddddd | Actual: imprison
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: genius
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: counselor
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: exhibition
# Pred: court 'dddddddddddddddddddddddddddddd | Actual: anniversary
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: pretend
# Pred: prejudice 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: luckily
# Pred: magnificentsiousiousdddddddddddddddddddddddddddd | Actual: mrs
# Pred: immediately'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddiousiousiousiousious | Actual: negligible
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: controversy
# Pred: guaranteesiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: characterized
# Pred: con 'dddddddddddddddddddddddddddddd | Actual: requisition
# Pred: magnificent'sddddddddddddddddddddddddddddd | Actual: dinner
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: delinquent
# Pred: enthusiasm'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: permanently
# Pred: court'siousiousiousdddddiousddiousdddddddddiousiousiousiousiousiousiousd | Actual: suspicion
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: geometry
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: cancelling
# Pred: court 'iousiousiousiousiousiousiousiousdiousiousiousiousiousiousiousiousdiousiousiousiousdiousiousiousiousiousiousd | Actual: altitude
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: melancholy
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: unusually
# Pred: enthusiasm 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: enemy
# Pred: court'sddddddddddddddddddddddddddddd | Actual: always
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddiousdiousiousdd | Actual: beautiful
# Pred: prejudice 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: prejudice
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: statistics
# Pred: court 'diousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: embarrass
# Pred: courts siousiousiousdddddddddddddddddddddddddd | Actual: pogroms
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddddddddiousiousiousdddd | Actual: technical
# Pred: court 'dddddddddddddddddddddddddddddious | Actual: ides
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: flagrancy
# Pred: miscellaneous'siousiousiousiousiousiousiousiousiousiousiousiousiousiousdddddddiousiousiousiousiousiousiousd | Actual: approximate
# Pred: courts sddddddddddddddddddddddddddddd | Actual: avoid
# Pred: courtsiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: approximately
# Pred: prejudicesiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: bankruptcy
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: cumulative
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddddiousiousiousiousiousiousiousddd | Actual: biscuit
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: poetry
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: jobcentre
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: gallery
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: circling
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: bungalow
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: fight
# Pred: enthusiasm'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: enemies
# Pred: enthusiasm'mentiousddddddddddddddddddddddiousiousiousiousiousious | Actual: airport
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: remember
# Pred: immediately 'iousddddddddddddddddddddddddddddd | Actual: dangerous
# Pred: court 'ddddiousiousiousiousiousiousddddddiousiousdddiousiousiousdddddd | Actual: eminently
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: chautauqua
# Pred: con 'iousdddiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdddddddd | Actual: apparent
# Pred: courtsiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: remember
# Pred: magnificent'siousddddddddddiousddddddddddddddddd | Actual: vacancy
# Pred: con'sddddddddddddddddddddddddddddd | Actual: ascertain
# Pred: courtsiousiousiousiousddddddddddddddddddiousiousiousiousiousiousiousd | Actual: discuss
# Pred: court'siousiousiousiousiousiousdddddddddddddddddddiousiousiousious | Actual: equipped
# Pred: prejudices sddddddddddddddddddddddddddddd | Actual: dirt
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: ridiculous
# Pred: guarantee 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: type
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddiousiousiousiousd | Actual: diphthongs
# Pred: miscellaneous'siousiousiousiousiousddddiousiousdiousddddddddddddiousiousiousious | Actual: rating
# Pred: court 'iousiousiousiousiousiousiousdddddddddddddddiousiousiousiousiousiousiousd | Actual: pamphlet
# Pred: con'sddddddddddddddddddddddddddddd | Actual: last
# Pred: court 'diousiousiousddddddddiousdddddddddddiousiousiousiousiousd | Actual: analysis
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: polluted
# Pred: miscellaneous'sddddddddddddddddddddddddddddd | Actual: had
# Pred: con'mentddddddddddddddddddddddddddddd | Actual: cancelled
# Pred: enthusiasm'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: representatives
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: otherwise
# Pred: miscellaneous 'iousddddddddddddddddddddddddddddd | Actual: spiritual
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: annum
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: any
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousddddddddddddddd | Actual: down
# Pred: court 'diousdddddddddddddddddddddddddddd | Actual: bankruptcy
# Pred: court'sddddddddddddddddddddddddddddd | Actual: cost
# Pred: courts sddddddddddddddddddddddddddddd | Actual: glad
# Pred: miscellaneouss siousdddddddddddddddddddddiousdddddd | Actual: equipped
# Pred: miscellaneous'mentiousdddddddddddddddddddddddddddd | Actual: specifically
# Pred: prejudice'sddddddddddddddddddddddddddddd | Actual: harassed
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: bouquet
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: connived
# Pred: court'siousdddddddddddddddddddddddddiousiousious | Actual: very
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: leaving
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdiousiousiousiousiousious | Actual: tome
# Pred: enthusiasm 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: entrance
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddiousiousiousiousiousiousiousiousiousiousious | Actual: memories
# Pred: miscellaneous 'diousiousiousiousiousiousiousddiousiousiousiousiousiousiousdddddddiousiousiousiousiousious | Actual: scheduled
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: possess
# Pred: court'sddddddddddddddddddddddddddddd | Actual: croak
# Pred: consdddddddddddddddddddddddddddddd | Actual: duly
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: young
# Pred: court'siousdddddddddddddddddddddddddddd | Actual: dose
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: loud
# Pred: prejudice'mentddddddddddddddddddddddddddddd | Actual: instrument
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: bring
# Pred: magnificent'sddddddddddddddddddddddddddddd | Actual: cynical
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: beneficial
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: duly
# Pred: courtsiousiousiousiousdiousiousiousiousiousiousiousiousiousddiousdiousiousiousiousiousiousiousiousiousddd | Actual: destination
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: caught
# Pred: court'mentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: scrambled
# Pred: court'siousdddddddddddddddddddddddddddd | Actual: congratulations
# Pred: miscellaneous 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: biscuits
# Pred: courtsmentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: appreciate
# Pred: guarantee 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: guarantee
# Pred: guarantee 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: sunday
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: willing
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: biscuits
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: suits
# Pred: con'sddddddddddddddddddddddddddddd | Actual: pretend
# Pred: court's siousddddddddddddddddddddddddddd | Actual: meet
# Pred: courtsiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: deem
# Pred: court''ddddddddddddddddddddddddddddd | Actual: prologue
# Pred: court'mentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdddddd | Actual: anxiety
# Pred: court 'iousiousiousiousddddiousiousdiousiousiousiousdddddddiousiousiousiousdddd | Actual: anxious
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: attaching
# Pred: court 'iousiousdddddddddddddddddddddddddddd | Actual: telephoned
# Pred: court 'iousiousiousiousiousdddddddiousiousiousddddddddiousiousiousiousiousiousd | Actual: dormitory
# Pred: court'siousiousiousdddddiousddiousddddddddddddddddd | Actual: galloped
# Pred: con'siousdddddddddddddddddddddiousdddddd | Actual: walked
# Pred: court'siousiousiousiousddddiousiousiousiousddddddddddddddddd | Actual: out
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: easier
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: mustn't
# Pred: prejudice'sddddddddddddddddddddddddddddd | Actual: dawn
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: affectionately
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: controversy
# Pred: court'siousdddddddddddddddddddddddddddd | Actual: specimen
# Pred: ''siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: wrote
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: satisfaction
# Pred: courtsmentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: conveniently
# Pred: inc 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: technical
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: obligation
# Pred: con 'dddddddddddddddddddddddddddddd | Actual: flagrancy
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: conscience
# Pred: miscellaneoussiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: equally
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: wants
# Pred: ##ssddddddddddddddddddddddddddddiousious | Actual: surplus
# Pred: magnificent 'iousiousiousddddddddddddddddddddddddddd | Actual: refrigerator
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: especially
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: continent
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: pinnacle
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: courses
# Pred: court'mentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: diamond
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: nearly
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: connection
# Pred: inc'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: surface
# Pred: con'sddddddddddddddddddddddddddddd | Actual: politician
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: similar
# Pred: court'mentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: gate
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: restriction
# Pred: con 'iousddddddddddddddddddddddddddddd | Actual: beautiful
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: vacancies
# Pred: enthusiasmsmentddddddddddddddddddddddddddddd | Actual: field
# Pred: inc 'dddddddddddddddddddddddddddddd | Actual: through
# Pred: guarantee 'iousdddddddddddddddddddddddddddiousious | Actual: statistics
# Pred: ''siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: belief
# Pred: magnificent's sdddddddddddddddddddddddddddd | Actual: leave
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: bureau
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: magnificent
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: trifle
# Pred: guaranteesiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: teachers
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: restaurant
# Pred: court's siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: earth
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: honoured
# Pred: miscellaneous'sddddddddddiousdddddddddddddddddious | Actual: politician
# Pred: court'mentiousdddddddddddddddddddddddddddd | Actual: playground
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: operator
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: license
# Pred: court 'iousiousiousdddddddddiousiousdddddddddiousiousiousiousiousiousious | Actual: parameter
# Pred: court'siousiousiousiousiousiousiousiousiousiousddddddddddddiousdddddd | Actual: notes
# Pred: ''siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: cultures
# Pred: court 'iousdiousiousddddiousiousiousiousiousiousiousddddddiousiousiousiousiousiousiousiousious | Actual: sympathetic
# Pred: miscellaneous 'iousddddddddddddddddddddddddddddd | Actual: oppression
# Pred: court'sddddddddddddddddddddddddddddd | Actual: sandwich
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdddd | Actual: received
# Pred: court 'diousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdd | Actual: exhibition
# Pred: prejudice 'iousddddddddddddddddddddddddddddd | Actual: gauge
# Pred: guarantee'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: into
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: inaccessible
# Pred: courtsmentddddddddddddddddddddddddddddd | Actual: headmistress
# Pred: con's siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdd | Actual: helped
# Pred: enthusiasm 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: apparatus
# Pred: magnificent'siousdddiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: specimens
# Pred: magnificent'sddddddddddddddddddddddddddddd | Actual: androgynous
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: dangerous
# Pred: magnificent'mentddddddddddddddddddddddddddddd | Actual: interested
# Pred: court'sddddddddddddddddddddddddddddd | Actual: ranked
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: emitting
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: than
# Pred: magnificent 'iousddddddddddddddddddddddddddddd | Actual: indefinitely
# Pred: courtsiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: sure
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddddd | Actual: quickly
# Pred: magnificent 'iousdiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdiousiousiousiousiousious | Actual: magnificent
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: noisy
# Pred: courtsmentddddddddddddddddddddddddddiousiousious | Actual: recognition
# Pred: guarantee 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: families
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: conscious
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: watching
# Pred: magnificent'siousiousdiousiousdddddddddddddddddddddddd | Actual: dodged
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdddddd | Actual: eventually
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: executed
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdd | Actual: appreciate
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: down
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: brain
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: wrap
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: eliminate
# Pred: courtsiousddddddddddddddddddddddddddddd | Actual: designed
# Pred: courtssiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddddddddiousious | Actual: door
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: nagging
# Pred: inc 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: incidentally
# Pred: court 'dddddddddddddddddddddddddddddd | Actual: shepherd
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: experience
# Pred: court 'iousiousiousddddddddddddddddddddddddddd | Actual: sympathetic
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: statistics
# Pred: miscellaneous'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: housebreaking
# Pred: prejudice'siousiousiousiousiousiousddddddddddddddddddddddd | Actual: gael
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: spacecraft
# Pred: inc 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: inconvenience
# Pred: ''sddddddddddddddddddddddddddddd | Actual: cease
# Pred: courtsmentdiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: fraternally
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: any
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: ridiculous
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: dangerous
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: signature
# Pred: prejudice 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: belt
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: workmen
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: exaggerate
# Pred: prejudice 'diousdddiousdddddddddddddddddddddddd | Actual: melancholy
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: answer
# Pred: miscellaneous'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: consistent
# Pred: con 'dddddddddddddddddddddddddddddd | Actual: opened
# Pred: ' 'iousiousiousiousiousiousiousddddddddddddddddddddddd | Actual: space
# Pred: consiousddddddddddddddddddddddddddddd | Actual: often
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: sorority
# Pred: magnificent'sddddddddddddddddddddddddddddd | Actual: ere
# Pred: court'siousiousiousiousiousddiousiousiousiousiousiousiousiousiousddddddddddddd | Actual: haul
# Pred: court 'iousiousdddddddddddddddddddddddddddd | Actual: fifth
# Pred: enthusiasm 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: apparently
# Pred: consdddddddddddddddddddddddddddddd | Actual: unsuccessful
# Pred: court 'iousiousiousddddddddddddiousiousiousiousiousiousddddddddd | Actual: ordinarily
# Pred: courtsmentddddddddddddddddddddddddddddd | Actual: documents
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: field
# Pred: psychologysiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: mathematics
# Pred: con'siousdddddddddddddddddddddddddddd | Actual: queries
# Pred: miscellaneous'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: pamphlet
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: poetry
# Pred: miscellaneoussdddddddddddddddddddddddddddddd | Actual: about
# Pred: court'siousdiousddddddddddddddddddiousiousiousiousiousddd | Actual: temple
# Pred: prejudice 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: prejudice
# Pred: miscellaneoussiousddddddddddddddddddddddddddddd | Actual: scarcely
# Pred: court'siousiousiousiousddddddddddddddddddddddddd | Actual: kissed
# Pred: con'sdddddddiousiousiousiousiousiousddddddddddddiousddd | Actual: comfortable
# Pred: ' 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: damaged
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: ceased
# Pred: prejudice 'iousiousdddddddddddddddddddddddddddd | Actual: aboard
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: prefer
# Pred: court 'dddddddddddddddddddddddddddddd | Actual: sufficient
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: poetry
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: own
# Pred: court'mentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: wrong
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: beechwood
# Pred: enthusiasm 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: enthusiastic
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: brown
# Pred: prejudicesiousiousdddddddddddddddddddddddddddd | Actual: windows
# Pred: prejudice'sddddddddddddddddddddddddddddd | Actual: man
# Pred: ''sddddddddddddddddddddddddddddd | Actual: hard
# Pred: miscellaneoussiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: your
# Pred: miscellaneoussmentddddddddddddddddddddddddddddious | Actual: eliminate
# Pred: court'sddddddddddddddddddddddddddddd | Actual: her a
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: terrible
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: consent
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: convalescence
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: criticises
# Pred: enthusiasm 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: enthusiasm
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: scrambled
# Pred: court 'iousiousiousddiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: exceptionally
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: approaching
# Pred: courtsdddddddddddddddddddddddddddddd | Actual: employees
# Pred: magnificent 'iousdiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddddddd | Actual: perceive
# Pred: prejudice'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdiousdiousdiousious | Actual: restaurant
# Pred: magnificent'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: save
# Pred: con'siousiousiousiousiousiousiousiousdiousddddiousiousddddddddddiousiousious | Actual: dart
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: retaliated
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: statistics
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: vacancies
# Pred: court's sdddddddddddddddddddddddddddd | Actual: bleed
# Pred: miscellaneous 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: chief
# Pred: magnificent 'ddddddddddddddddddddddddddddiousious | Actual: frames
# Pred: court'mentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: coefficient
# Pred: courtsmentddddddddddddddddddddddddddddd | Actual: groups
# Pred: con 'dddddddddddddddddddddddddddddd | Actual: date
# Pred: miscellaneous 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: stomach
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: active
# Pred: court 'iousiousdddddiousddiousiousiousiousdddddddddiousiousiousiousiousiousious | Actual: enthusiasm
# Pred: miscellaneouss sddddddddddddddddddddddddddddious | Actual: diverged
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: food
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: precision
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: conception
# Pred: enthusiasm 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: initials
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: embarrassed
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: attempted
# Pred: courtsiousiousiousiousiousiousiousiousiousdiousiousdiousiousiousiousiousiousiousiousddiousiousiousiousiousdd | Actual: traffic
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: built
# Pred: court 'iousddddddddddddddddddddddddddddd | Actual: beautiful
# Pred: inc 'dddddddddddddddddddddddiousiousddddd | Actual: inconvenience
# Pred: immediately 'dddddddddddddddddddddddddddddd | Actual: southern
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: fundamental
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: freezing
# Pred: miscellaneoussdddiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousdiousddd | Actual: specifically
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: into
# Pred: courtsdddddddddddddddddddddddddddddd | Actual: recovery
# Pred: magnificent'mentddddddddddddddddddddddddddddd | Actual: asphalt
# Pred: prejudice 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: prejudice
# Pred: miscellaneous'siousddddddddiousiousdddddddddddiousdddddd | Actual: courteous
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: accommodation
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: satisfaction
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: aside
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: back
# Pred: court'mentddddiousiousiousiousiousiousiousdddiousiousiousiousiousdddddddddd | Actual: temperature
# Pred: miscellaneouss sdddddddddddddddddddddddddiousiousiousious | Actual: flower
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: principles
# Pred: con'mentiousiousdiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddiousiousiousiousiousious | Actual: visible
# Pred: magnificentsdddddddddddddddddddddddddddddd | Actual: laboratory
# Pred: court 'dddddddddddddddddddddddddddddd | Actual: against
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: miscellaneous
# Pred: court'sddddddddddddddddddddddddiousiousiousiousious | Actual: considerably
# Pred: prejudicesiousiousiousiousdddddiousddiousdddddddddiousiousiousiousiousiousiousd | Actual: research
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: able
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: been
# Pred: court'sddddddddddddddddddddddddddddd | Actual: but
# Pred: con'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousddd | Actual: politician
# Pred: court 'dddddddddddddddddddddddddddddd | Actual: dormitory
# Pred: con 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: competitions
# Pred: court 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: buried
# Pred: con'sddddddddddddddddddddddddddddd | Actual: any
# Pred: court 'iousiousdddddddddddddddddddddddddddd | Actual: entrance
# Pred: court''ddddddddiousiousddddddddiousiousddddddddd | Actual: needlework
# Pred: court'sddddddddddddddddddddddddddddd | Actual: existence
# Pred: magnificent 'iousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: politician
# Pred: court'mentiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: satellite
# Pred: court'siousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousious | Actual: far
# Pred: consmentddddddddddddddddddddddddddddd | Actual: psychology
# Pred: court'mentiousiousdiousdiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousiousd | Actual: literally
# Pred: court'sddddddddddddddddddddddddddddd | Actual: along
# ...
# Pred: galleryable sydddddddddddddddddddddddddddd | Actual: delivered
# Pred: dart's tdddddddddddddddddddddddddddd | Actual: late
# Pred: cemeteryesiesiousdddddddddddddddddddddddddddd | Actual: circling
# Pred: virtues's tdddddddddddddddddddddddddddd | Actual: virtue
# Pred: comfortableenanceyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: rang
# Pred: enthusiasticfippquadddddddddddddddddddddddddddd | Actual: enthusiastic
# Pred: exhibitionaggeratetismdddddddddddddddddddddddddddd | Actual: exaggerate
# Pred: beautiful -davddddddddddddddddddddddddddddd | Actual: backyard
# Pred: poetry - sddddddddddddddddddddddddddddd | Actual: teacher
# Pred: sound - s tdddddddddddddddddddddddddddd | Actual: stay
# Pred: bicyclequiuquadddddddddddddddydddddddddddily | Actual: bicycle
# Pred: memorandumutauquadddddddddddddddddddddddddddd | Actual: acceptable
# Pred: politician'siousdddddddddddddddddddddddddddd | Actual: cease
# Pred: biscuitss siondddddddddddddddddddddddddddd | Actual: inter - schools
# Pred: surpluss sydddddddilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: special
# Pred: virtues's tdddddddddddddddddddddddddddd | Actual: virtues
# Pred: must's tdddddddddddddddddddddddddddd | Actual: i'd
# Pred: temporarylyullydddddddddddddddddddddddddddd | Actual: temporary
# Pred: field - sydddddddddddddddddddddddddddd | Actual: year
# Pred: mortgage -bonquadddddddddddddddddddddddddddd | Actual: modern
# Pred: efficiencyternallyydddddddddddddddddddddddddddd | Actual: efficiently
# Pred: refrigeratorreshmenttismdddddddddddddddddddddddddddd | Actual: refreshment
# Pred: suspicion's tdddddddddddddddddddddddddddd | Actual: suitable
# Pred: immediatelyistlequenttismdddddddddddddddddddddddddddd | Actual: imagination
# Pred: whistlingforumaquadddddddddddddddddddddddddddd | Actual: whistling
# Pred: contentedientiousdddddddddddddddddddddddddddd | Actual: contention
# Pred: deablequenttismdddddddddddddddddddddddddddd | Actual: departure
# Pred: there's tdddddddddddddddddddddddddddily | Actual: sign
# Pred: instrumentss siondddddddddddddddddddddddddddd | Actual: incense
# Pred: dormitoryternsitiondddddddddddddddddddddddddddd | Actual: dormitory
# Pred: beautiful's tdddddddddddddddddddddddddddd | Actual: about
# Pred: gorgeousutauquadddddddddddddddddddddddddddd | Actual: gorgeous
# Pred: beautiful -bonddddddddddddddddddddddddddddd | Actual: sound
# Pred: suspicionquisitiousdddddddddddddddddddddddddddd | Actual: suspicion
# Pred: criticisms stismdtismntismntismnntismnntismntismtismtismtismtismtism t t t t t tdionion | Actual: arrangements
# Pred: gallopedbonddddddddddddddddddddddddddddd | Actual: golden
# Pred: laugh's tdddddddddddddddddddddddddddd | Actual: based
# Pred: remitsitionionionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: remittance
# Pred: sororityallyrilyydddddddddddddddddddddddddddd | Actual: sorority
# Pred: unanimous -davitdddddddddddddddddddddddddddd | Actual: politician
# Pred: canvass siondddddddddddddddddddddddddddd | Actual: canvass
# Pred: competentimeterientientdddddddddddddddddddddddddddd | Actual: competent
# Pred: who'ssd sdddddddddddddddddddddddddily | Actual: unfortunately
# Pred: annums sydddddddddddddddddddddddddddily | Actual: plaintiff
# Pred: schedulededuousydddddddddddddddddddddddddddd | Actual: scheduled
# Pred: street - sddddddddddddddddddddddddddddd | Actual: steam
# Pred: enthusiasmaggerateitdddddddddddddddddddddddddddd | Actual: enthusiastic
# Pred: approximatelyternallyctorilyddddddddddddddddddddddddddd | Actual: approximately
# Pred: altablementquadddddddddddddddddddddddddddd | Actual: settlement
# Pred: contentenanceiousdddddddddddddddddddddddddddd | Actual: colonel
# Pred: visited's tdddddddddddddddddddddddddddd | Actual: heap
# Pred: openeded t tdddddddddddddddddddddddddddd | Actual: own
# Pred: unforgettableilyddddddddddddddddddddddddddd | Actual: unforgettable
# Pred: expenditureaggeratetismdddddddddddddddddddddddddddd | Actual: expenditure
# Pred: relief't tdddddddddddddddddddddddddddd | Actual: relief
# Pred: del'siondddddddddddddddddddddddddddd | Actual: it's
# Pred: pilot's tdddddddddddddddddddddddddddd | Actual: competent
# Pred: psychologylyegiondddddddddddddddddddddddddddd | Actual: psychology
# Pred: ordinarilyyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyddily | Actual: ordinarily
# Pred: determinedateumaitdddddddddddddddddddddddddddd | Actual: determined
# Pred: splendid - s tdddddddddddddddddddddddddddd | Actual: wrong
# Pred: technicalquisitiondddddddddddddddddddddddddddd | Actual: politician
# Pred: curiositylyrilyydddddddddddddddddddddddddddd | Actual: customary
# Pred: poetry'squadddddddddddddddddddddddddddd | Actual: pockets
# Pred: sure's tdddddddddddddddddddddddddddd | Actual: want
# Pred: memorandum - sddddddddddddddddddddddddddddd | Actual: minimum
# Pred: criticism -ngddddddddddddddddddddddddddddd | Actual: tracksuit
# Pred: politician's td tdddddddddddddddddddddddddd | Actual: policemen
# Pred: familiarlyuydddddddddddddddddddddddddddd | Actual: symmetry
# Pred: prejudice'siousdddddddddddddddddddddddddddd | Actual: prejudice
# Pred: rough - s tdddddddddddddddddddddddddddd | Actual: rug
# Pred: removeded sydddddddddddddddddddddddddddily | Actual: diverse
# Pred: unforgettabledddddddddddddddddddddddddddd | Actual: unforgettable
# Pred: there's tdddddddddddddddddddddddddddd | Actual: cane
# Pred: comfortable - sydddddddddddddddddddddddddddd | Actual: feeble
# Pred: specificallyternallyctorilyddddddddddddddddddddddddddily | Actual: specifically
# Pred: auditoriumnaire squadddddddddddddddddddddddddddily | Actual: temporarily
# Pred: there'sndddddddddddddddddddddddddddily | Actual: a
# Pred: extraordinaryaggerateiousdddddddddddddddddddddddddddd | Actual: experience
# Pred: avoidgabonddddddddddddddddddddddddddddd | Actual: divine
# Pred: behind - stismdddddddddddddddddddddddddddd | Actual: beg
# Pred: picturesquesmentddddddddddddddddddddddddddddd | Actual: playing
# Pred: suitablepedcyquadddddddddddddddddddddddddddily | Actual: field
# Pred: poemssies tdddddddddddddddddddddddddddd | Actual: poems
# Pred: women'squadddddddddddddddddddddddddddd | Actual: fight
# Pred: again -quent tdddddddddddddddddddddddddddd | Actual: about
# Pred: touched - s tdddddddddddddddddddddddddddd | Actual: truth
# Pred: anniversarylyallyyilyilydddddddddddddddddilyilyilyilyilyilyilyilyily | Actual: scarcely
# Pred: graduallyable sydddddddddddddddddddddddddddd | Actual: grippe
# Pred: regionqui siousdddddddddddddddddddddddddddd | Actual: reckon
# Pred: pamphlets'ssddddddddddddddddddddd sdddddd | Actual: juice
# Pred: prejudice'' tdddddddddddddddddddddddddddd | Actual: pregnant
# Pred: epistleallyyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: epistle
# Pred: accordancerueddavitdddddddddddddddddddddddddddd | Actual: actually
# Pred: acknowledgementmentitdddddddddddddddddddddddddddd | Actual: acknowledging
# Pred: infiniterilumatableilyddddddddddddddddddddddddddd | Actual: inexhaustible
# Pred: vacanciesddddddddddddddddddddddddddddd | Actual: vacancies
# Pred: ?'s tdddddddddddddddddddddddddddd | Actual: interned
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: inconvenient
# Pred: beautifulheumatismdddddddddddddddddddddddddddd | Actual: rheumatism
# Pred: requisitionionionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: requisition
# Pred: pilotable syilyyyyyyyyyyyyyyyyyyyyyyyyilyilyilyily | Actual: pillow
# Pred: conscientiousdddddddddddddddddddddddddddd | Actual: convenient
# Pred: satisfaction - squadddddddddddddddddddddddddddd | Actual: original
# Pred: anniversarysumatismdddddddddddddddddddddddddddd | Actual: anxious
# Pred: who's tddd tddddddddddddddd t t t t t tddd | Actual: tongue
# Pred: content'tiousdddddddddddddddddddddddddddd | Actual: shouldn't
# Pred: restaurantizedmentddddddddddddddddddddddddddddd | Actual: restaurant
# Pred: any'sydddddddddddddddddddddddddddd | Actual: them
# Pred: specialistle sydddddddddddddddddddddddddddd | Actual: epistle
# Pred: approachingquiquenttismdddtismtismtismtismddddddtismtismtismtismtismtismtismdddddddd | Actual: accrued
# Pred: conscientiousiousddddddddddddddddddddddddddd | Actual: conscientious
# Pred: infinite -allyddddddddddddddddddddddddddddd | Actual: immediately
# Pred: fascinatinglycyydddddddddddddddddddddddddddd | Actual: failed
# Pred: peculiargauddddddddddddddddddddddddddddd | Actual: peculiar
# Pred: understandfippddddddddddddddddddddddddddddd | Actual: understand
# Pred: turned'syilyilydilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: principal
# Pred: materiallyallyyilyilydddilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: familiar
# Pred: telephoneistleallyddddddddddddddddddddddddddddd | Actual: telephone
# Pred: cemeteryutauousquadddddddddddddddddddddddddddd | Actual: cemetery
# Pred: flag - squadddionionddddddionionionionionionionionioniondionionionionionily | Actual: flagrancy
# Pred: anxietyquisititdddddddddddddddddddddddddddd | Actual: initiation
# Pred: definiteable siondionddddddddddddddddddddionionioniondily | Actual: quarters
# Pred: stomachren s tdddddddddddddddddddddddddddd | Actual: stomach
# Pred: openedingngddddddddddddddddddddddddddddd | Actual: packing
# Pred: oppositeeduquadddddddddddddddddddddddddddd | Actual: opinion
# Pred: appropriateistleuiondddddddddddddddddddddddddddd | Actual: apparatus
# Pred: climbnaireng tdddddddddddddddddddddddddddily | Actual: clown
# Pred: gorgeousquiuiondddddddddddddddddddddddddddd | Actual: gorgeous
# Pred: beautifulreshment tdddddddddddddddddddddddddddd | Actual: altimeter
# Pred: juices sydddddddddddddddddddddddddddd | Actual: notebooks
# Pred: fascinatingrancyydddddddddddddddddddddddddddd | Actual: family
# Pred: determinedrued titdddddddddddddddddddddddddddd | Actual: brave
# Pred: inconveniencedddddddddddddddddddddddddddd | Actual: encouragement
# Pred: women'squadddddddddddddddddddddddddddd | Actual: procedure
# Pred: picturesque'stismdddddddddddddddddddddddddddd | Actual: each
# Pred: picturesquequiuiondddddddddddddddddddddddddddd | Actual: picturesque
# Pred: efficiencyistleallyquadddddddddddddddddddddddddddd | Actual: equally
# Pred: there's tdddddddddddddddddddddddddddd | Actual: got
# Pred: surfaces sddddddddddddddddddddddddddddd | Actual: sons
# Pred: i's tdddddddddddddddddddddddddddd | Actual: the
# Pred: should - sydddddddddddddddddddddddddddd | Actual: hide
# Pred: pamphletsable siondiondioniondionddddddiondionionionionionionddionionionionily | Actual: reference
# Pred: said -bon tdddddddddddddddddddddddddddd | Actual: sign
# Pred: acc'sitdddddddddddddddddddddddddddily | Actual: to
# Pred: graduallyreshmentitdddddddddddddddddddddddddddd | Actual: government
# Pred: accordancerued sitdddddddddddddddddddddddddddd | Actual: accident
# Pred: correspondencevaleumatismilydd t t t t t t t t td t t t t t t t tddddddd | Actual: correspondents
# Pred: any - squadddddddddddddddddddddddddddd | Actual: any
# Pred: materiallyrilyyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: temporarily
# Pred: altitudeableuquadddddddddddddddddddddddddddd | Actual: junior
# Pred: with's tddddddd tdd tddddddddd t t t t tddd | Actual: which
# Pred: answer - sddddddddddddddddddddddddddddd | Actual: personality
# Pred: playgroundes sddddddddddddddddddddddddddddd | Actual: playtimes
# Pred: enthusiasmaggerateiousdddddddddddddddddddddddddddd | Actual: anxious
# Pred: undoubtedlyruedlleledilydilyilyilyilyddilyddilyilyilyilyilyilyilyilyilydddddddily | Actual: undoubtedly
# Pred: answer - sydddddddddddddddddddddddddddd | Actual: freeze
# Pred: women't tdddddddddddddddddddddddddddd | Actual: when
# Pred: analysis 'umatismdddddddddddddddddddddddddddd | Actual: analysis
# Pred: scheduledranumatismdddddddddddddddddddddddddddd | Actual: schedule
# Pred: miscellaneousrilumatismdddddddddddddddddddddddddddd | Actual: miscellaneous
# Pred: damagedenanceiondddddddddddddddddddddddddddd | Actual: damage
# Pred: affectionatelylyullyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: affectionately
# Pred: minimum -bon tdddddddddddddddddddddddddddd | Actual: level
# Pred: mountainouss siondddddddddddddddddddddddddddd | Actual: mountainous
# Pred: increasingingmentddddddddddddddddddddddddddddd | Actual: circling
# Pred: shaggy'sitdddddddddddddddddddddddddddd | Actual: shop
# Pred: guaranteeheumatismdddddddddddddddddddddddddddd | Actual: guarantee
# Pred: juice's tilyddddilyilyilyilyddddddddyyy t t t tilyilyilyily | Actual: came
# Pred: adrenuoustismdddddddddddddddddddddddddddd | Actual: auditorium
# Pred: exceptionallyaggerallyyilyddddddddddddddddddddddddddd | Actual: exactly
# Pred: consciencescientiousiousddddddddddddddddddddddddddd | Actual: concerning
# Pred: repairss siondddddddddddddddddddddddddddd | Actual: repairs
# Pred: financiallyternallyyilyddddddddddddddddddddddddddd | Actual: fraternally
# Pred: exhibitionaggeratetismdddddddddddddddddddddddddddd | Actual: experience
# Pred: beautiful - tddddddddddddddddddddddddddddd | Actual: caught
# Pred: efficiencyheumatismdddddddddddddddddddddddddddd | Actual: existence
# Pred: psychologyternallyydddddddddddddddddddddddddddd | Actual: philosophy
# Pred: problemable syilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: tablet
# Pred: comparativelyrilegiousdddddddddddddddddddddddddddd | Actual: communicate
# Pred: comfortable's tdddddddddddddddddddddddddddd | Actual: curtain
# Pred: tragedyuit sydddddddddddddddddddddddddddd | Actual: track
# Pred: rememberhesitiondionionionionionionionionionionionionionionionionionionionionionionionionionionion | Actual: resemble
# Pred: comfortableableuquadddddddddddddddddddddddddddd | Actual: community
# Pred: facilitiescanciesiondddddddddddddddddddddddddddd | Actual: vacancies
# Pred: actuallylyullydddddddddddddddddddddddddddd | Actual: certainly
# Pred: acc 'davitdddddddddddddddddddddddddddd | Actual: toe
# Pred: unfortunatelylylleleddddddddddddddddddddddddddddd | Actual: unusually
# Pred: sure'sydddddddddddddddddddddddddddily | Actual: dark
# Pred: women'stismdddddddddddddddddddddddddddd | Actual: walking
# Pred: suspicionquimentiondddddddddddddddddddddddddddd | Actual: supplement
# Pred: anxietyvaniuousydddddddddddddddddddddddddddd | Actual: anxious
# Pred: mutualquisitiondddddddddddddddddddddddddddd | Actual: materially
# Pred: ami'titdddddddddddddddddddddddddddd | Actual: pavement
# Pred: bulletinotti squadddddddddddddddddddddddddddd | Actual: shipping
# Pred: poetry - sydddddddddddddddddddddddddddd | Actual: only
# Pred: biscuitsing siondddddddddddddddddddddddddddily | Actual: freezing
# Pred: vacan s tdddddddddddddddddddddddddddd | Actual: lessons
# Pred: privilegees siondddddddddddddddddddddddddddd | Actual: privileges
# Pred: familiarqui sydddddddddddddddddddddddddddd | Actual: further
# Pred: behind'squadddddddddddddddddddddddddddd | Actual: destination
# Pred: analysisquisitiondddddddddddddddddddddddddddily | Actual: bankruptcy
# Pred: refrigeratorreshmentiondddddddddddddddddddddddddddd | Actual: refreshment
# Pred: again's tdddddddddddddddddddddddddddd | Actual: ago
# Pred: juices siondddddddddddddddddddddddddddd | Actual: cookies
# Pred: conscientiousdddddddddddddddddddddddddddd | Actual: continuous
# Pred: suspicionquisitiondddddddddddddddddddddddddddd | Actual: suspicion
# Pred: analysisriluousiousdddddddddddddddddddddddddddd | Actual: analysis
# Pred: certainlylyallyyilyddddddddilyilydddddddilyilyilyddddddd | Actual: certainly
# Pred: specialistlementiondddddddddddddddddddddddddddd | Actual: sponsor
# Pred: res siondddddddddddddddddddddddddddd | Actual: freezing
# Pred: delinquenttismdddddddddddddddddddddddddddd | Actual: delinquent
# Pred: special's td t t t t t t t t t t t t t t t t t t t t t t t t tdily | Actual: talk
# Pred: ordinarilyrilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyilyily | Actual: ordinarily
# Pred: comfortable 'atetismdddtismdtismdddddddddtismtismtismdddddddddily | Actual: answer
# Pred: amiableullyilydddddddddddddddddddilyilyilyilydddd | Actual: eventually
# Accuracy: 0.2960
# Epoch 10, Average Loss: 4.4828
# Accuracy: 0.2972

# %%
class SpellingCorrector(nn.Module):
    def __init__(self, vocab_size, hidden_size=768):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')

        # Freeze BERT
        for param in self.bert.parameters():
            param.requires_grad = False

        self.char_embedding = nn.Embedding(vocab_size, 32)

        # Use a single GRU layer
        self.gru = nn.GRU(
            input_size=hidden_size + 32,
            hidden_size=256,
            num_layers=1,
            bidirectional=True,
            batch_first=True
        )

        # Global average pooling followed by output layers
        self.output = nn.Sequential(
            nn.Linear(512, 256),
            nn.LayerNorm(256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, vocab_size)
        )

    def forward(self, input_ids, attention_mask):
        # Get BERT embeddings
        with torch.no_grad():
            bert_output = self.bert(input_ids, attention_mask=attention_mask)[0]

        # Get character embeddings
        char_embeds = self.char_embedding(input_ids)

        # Combine embeddings
        combined = torch.cat([bert_output, char_embeds], dim=-1)

        # Process through GRU
        gru_out, _ = self.gru(combined)

        # Global average pooling
        pooled = torch.mean(gru_out * attention_mask.unsqueeze(-1), dim=1)

        # Generate single word prediction
        logits = self.output(pooled)

        return logits

def train_and_evaluate(num_epochs=10, data_path='spelling_dictionary.json'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    with open(data_path, 'r') as f:
        spelling_dict = json.load(f)

    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = SpellingCorrector(tokenizer.vocab_size).to(device)

    # Modify the dataset to use only first token of correct word
    class ModifiedSpellingDataset(Dataset):
        def __init__(self, spelling_dict, tokenizer, max_length=32):
            self.pairs = []
            for correct, misspellings in spelling_dict.items():
                # Get the first token ID of the correct word
                correct_id = tokenizer(
                    correct,
                    padding='max_length',
                    max_length=1,
                    truncation=True,
                    add_special_tokens=False,
                    return_tensors='pt'
                )['input_ids'][0][0]

                for misspelling in misspellings:
                    self.pairs.append((misspelling, correct_id))
            self.tokenizer = tokenizer
            self.max_length = max_length

        def __getitem__(self, idx):
            misspelling, correct_id = self.pairs[idx]

            misspelling_encoding = self.tokenizer(
                misspelling,
                padding='max_length',
                max_length=self.max_length,
                truncation=True,
                add_special_tokens=False,
                return_tensors='pt'
            )

            return {
                'input_ids': misspelling_encoding['input_ids'].squeeze(),
                'attention_mask': misspelling_encoding['attention_mask'].squeeze(),
                'labels': correct_id
            }

        def __len__(self):
            return len(self.pairs)

    dataset = ModifiedSpellingDataset(spelling_dict, tokenizer, max_length=32)

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    num_training_steps = num_epochs * len(train_loader)
    num_warmup_steps = num_training_steps // 10

    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=num_warmup_steps,
        num_training_steps=num_training_steps
    )

    best_accuracy = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            optimizer.zero_grad()
            output = model(batch['input_ids'], batch['attention_mask'])

            loss = criterion(output, batch['labels'])

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
            optimizer.step()
            scheduler.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for batch in test_loader:
                batch = {k: v.to(device) for k, v in batch.items()}
                outputs = model(batch['input_ids'], batch['attention_mask'])

                predictions = outputs.argmax(dim=-1)
                correct += (predictions == batch['labels']).sum().item()
                total += len(predictions)

                if epoch % 2 == 0:
                    for pred, actual in zip(predictions[:2], batch['labels'][:2]):
                        pred_text = tokenizer.decode([pred], skip_special_tokens=True)
                        actual_text = tokenizer.decode([actual], skip_special_tokens=True)
                        print(f"Pred: {pred_text} | Actual: {actual_text}")

        accuracy = correct / total
        print(f"Accuracy: {accuracy:.4f}")

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_spelling_corrector.pth')

    return model, tokenizer
model, tokenizer = train_and_evaluate(num_epochs=10, data_path= data_path)
# Out:
# Using device: cuda
# Epoch 1, Average Loss: 9.0999
# Pred: especially | Actual: base
# Pred: miscellaneous | Actual: suspicion
# Pred: miscellaneous | Actual: chapter
# Pred: miscellaneous | Actual: peculiar
# Pred: miscellaneous | Actual: indefinite
# Pred: enthusiasm | Actual: avoid
# Pred: miscellaneous | Actual: tell
# Pred: miscellaneous | Actual: trial
# Pred: miscellaneous | Actual: technically
# Pred: miscellaneous | Actual: general
# Pred: miscellaneous | Actual: smoking
# Pred: miscellaneous | Actual: jam
# Pred: miscellaneous | Actual: region
# Pred: miscellaneous | Actual: gradually
# Pred: miscellaneous | Actual: annoyance
# Pred: miscellaneous | Actual: street
# Pred: miscellaneous | Actual: fundamental
# Pred: miscellaneous | Actual: magnificent
# Pred: miscellaneous | Actual: recipe
# Pred: miscellaneous | Actual: con
# Pred: miscellaneous | Actual: above
# Pred: miscellaneous | Actual: juice
# Pred: miscellaneous | Actual: execution
# Pred: miscellaneous | Actual: initiation
# Pred: miscellaneous | Actual: un
# Pred: miscellaneous | Actual: who
# Pred: miscellaneous | Actual: about
# Pred: miscellaneous | Actual: auditorium
# Pred: miscellaneous | Actual: philosophy
# Pred: miscellaneous | Actual: anniversary
# Pred: miscellaneous | Actual: fundamental
# Pred: miscellaneous | Actual: attorneys
# Pred: miscellaneous | Actual: disgrace
# Pred: miscellaneous | Actual: remembrance
# Pred: miscellaneous | Actual: apparatus
# Pred: miscellaneous | Actual: powder
# Pred: especially | Actual: seem
# Pred: miscellaneous | Actual: er
# Pred: miscellaneous | Actual: miscellaneous
# Pred: miscellaneous | Actual: scandal
# Pred: miscellaneous | Actual: literature
# Pred: miscellaneous | Actual: food
# Pred: miscellaneous | Actual: counselor
# Pred: miscellaneous | Actual: museum
# Pred: miscellaneous | Actual: vo
# Pred: miscellaneous | Actual: head
# Pred: miscellaneous | Actual: vehicles
# Pred: miscellaneous | Actual: ridiculous
# Pred: miscellaneous | Actual: miscellaneous
# Pred: miscellaneous | Actual: bicycle
# Pred: miscellaneous | Actual: satisfaction
# Pred: miscellaneous | Actual: ami
# Pred: miscellaneous | Actual: restaurant
# Pred: miscellaneous | Actual: surplus
# Pred: miscellaneous | Actual: privilege
# Pred: miscellaneous | Actual: gallo
# Pred: miscellaneous | Actual: un
# Pred: miscellaneous | Actual: governor
# Pred: miscellaneous | Actual: sympathetic
# Pred: miscellaneous | Actual: training
# Pred: miscellaneous | Actual: infinite
# Pred: miscellaneous | Actual: these
# Pred: miscellaneous | Actual: functional
# Pred: miscellaneous | Actual: all
# Pred: miscellaneous | Actual: ambulance
# Pred: miscellaneous | Actual: friend
# Pred: miscellaneous | Actual: me
# Pred: miscellaneous | Actual: receipt
# Pred: miscellaneous | Actual: facilities
# Pred: miscellaneous | Actual: thanksgiving
# Pred: miscellaneous | Actual: monetary
# Pred: miscellaneous | Actual: exhibitions
# Pred: miscellaneous | Actual: not
# Pred: miscellaneous | Actual: especially
# Pred: miscellaneous | Actual: dark
# Pred: miscellaneous | Actual: approaching
# Pred: miscellaneous | Actual: scarcely
# Pred: miscellaneous | Actual: request
# Pred: miscellaneous | Actual: enthusiasm
# Pred: miscellaneous | Actual: alright
# Pred: miscellaneous | Actual: sympathetic
# Pred: miscellaneous | Actual: leave
# Pred: miscellaneous | Actual: decidedly
# Pred: miscellaneous | Actual: attach
# Pred: miscellaneous | Actual: dropped
# Pred: miscellaneous | Actual: one
# Pred: miscellaneous | Actual: back
# Pred: miscellaneous | Actual: confirmation
# Pred: magnificent | Actual: count
# Pred: miscellaneous | Actual: sympathetic
# Pred: miscellaneous | Actual: children
# Pred: miscellaneous | Actual: football
# Pred: miscellaneous | Actual: unemployed
# Pred: miscellaneous | Actual: cancelled
# Pred: miscellaneous | Actual: enthusiastic
# Pred: miscellaneous | Actual: forward
# Pred: miscellaneous | Actual: thorough
# Pred: miscellaneous | Actual: recurring
# Pred: miscellaneous | Actual: preliminary
# Pred: miscellaneous | Actual: heightened
# Pred: miscellaneous | Actual: that
# Pred: miscellaneous | Actual: miscellaneous
# Pred: miscellaneous | Actual: trouble
# Pred: miscellaneous | Actual: recently
# Pred: miscellaneous | Actual: ref
# Pred: miscellaneous | Actual: fought
# Pred: miscellaneous | Actual: guaranteed
# Pred: miscellaneous | Actual: would
# Pred: especially | Actual: road
# Pred: miscellaneous | Actual: en
# Pred: miscellaneous | Actual: another
# Pred: miscellaneous | Actual: marble
# Pred: miscellaneous | Actual: va
# Pred: miscellaneous | Actual: stomach
# Pred: miscellaneous | Actual: gorgeous
# Pred: miscellaneous | Actual: nearer
# Pred: miscellaneous | Actual: wearing
# Pred: especially | Actual: form
# Pred: miscellaneous | Actual: hydraulic
# Pred: miscellaneous | Actual: beneath
# Pred: miscellaneous | Actual: o
# Pred: miscellaneous | Actual: what
# Pred: miscellaneous | Actual: dart
# Pred: miscellaneous | Actual: aunt
# Pred: miscellaneous | Actual: head
# Pred: miscellaneous | Actual: community
# Pred: miscellaneous | Actual: unanimous
# Pred: miscellaneous | Actual: fascinating
# Pred: miscellaneous | Actual: determined
# Pred: miscellaneous | Actual: dumb
# Pred: miscellaneous | Actual: belt
# Pred: miscellaneous | Actual: hours
# Pred: miscellaneous | Actual: determined
# Pred: miscellaneous | Actual: i
# Pred: miscellaneous | Actual: prologue
# Pred: miscellaneous | Actual: occasionally
# Pred: miscellaneous | Actual: possess
# Pred: miscellaneous | Actual: heard
# Pred: miscellaneous | Actual: disposal
# Pred: miscellaneous | Actual: want
# Pred: miscellaneous | Actual: conditions
# Pred: miscellaneous | Actual: opposite
# Pred: miscellaneous | Actual: bulletin
# Pred: miscellaneous | Actual: signature
# Pred: miscellaneous | Actual: count
# Pred: miscellaneous | Actual: eventually
# Pred: miscellaneous | Actual: dinner
# Pred: miscellaneous | Actual: work
# Pred: miscellaneous | Actual: approximate
# Pred: miscellaneous | Actual: guarantee
# Pred: miscellaneous | Actual: acceptable
# Pred: miscellaneous | Actual: planets
# Pred: miscellaneous | Actual: che
# Pred: miscellaneous | Actual: sat
# Pred: miscellaneous | Actual: principle
# Pred: miscellaneous | Actual: syrup
# Pred: miscellaneous | Actual: vo
# Pred: miscellaneous | Actual: take
# Pred: miscellaneous | Actual: r
# Pred: miscellaneous | Actual: sufficient
# Pred: miscellaneous | Actual: alumni
# Pred: miscellaneous | Actual: depth
# Pred: miscellaneous | Actual: bankruptcy
# Pred: miscellaneous | Actual: nothing
# Pred: miscellaneous | Actual: enough
# Pred: miscellaneous | Actual: prejudice
# Pred: miscellaneous | Actual: apple
# Pred: miscellaneous | Actual: deal
# Pred: miscellaneous | Actual: street
# Pred: miscellaneous | Actual: subterranean
# Pred: miscellaneous | Actual: recognize
# Pred: miscellaneous | Actual: brought
# Pred: miscellaneous | Actual: cried
# Pred: miscellaneous | Actual: matter
# Pred: miscellaneous | Actual: cricket
# Pred: miscellaneous | Actual: initials
# Pred: miscellaneous | Actual: dangerous
# Pred: miscellaneous | Actual: attorneys
# Pred: miscellaneous | Actual: destination
# Pred: miscellaneous | Actual: prejudice
# Pred: miscellaneous | Actual: verse
# Pred: miscellaneous | Actual: restaurant
# Pred: miscellaneous | Actual: commitment
# Pred: miscellaneous | Actual: opposite
# Pred: miscellaneous | Actual: familiar
# Pred: miscellaneous | Actual: recommend
# Pred: miscellaneous | Actual: affectionately
# Pred: miscellaneous | Actual: repairs
# Pred: miscellaneous | Actual: alcohol
# Pred: miscellaneous | Actual: misery
# Pred: miscellaneous | Actual: turned
# Pred: miscellaneous | Actual: peculiar
# Pred: miscellaneous | Actual: giggling
# Pred: miscellaneous | Actual: ate
# Pred: miscellaneous | Actual: triumph
# Pred: miscellaneous | Actual: engine
# Pred: miscellaneous | Actual: pilot
# Pred: miscellaneous | Actual: subterranean
# Pred: miscellaneous | Actual: incident
# Pred: miscellaneous | Actual: sufficiently
# Pred: miscellaneous | Actual: count
# Pred: miscellaneous | Actual: children
# Pred: miscellaneous | Actual: con
# Pred: miscellaneous | Actual: drunken
# Pred: miscellaneous | Actual: sauce
# Pred: miscellaneous | Actual: was
# Pred: miscellaneous | Actual: answer
# Pred: miscellaneous | Actual: enthusiasm
# Pred: miscellaneous | Actual: as
# Pred: miscellaneous | Actual: became
# Pred: miscellaneous | Actual: association
# Pred: miscellaneous | Actual: di
# Pred: miscellaneous | Actual: women
# Pred: miscellaneous | Actual: un
# Pred: miscellaneous | Actual: gallery
# Pred: miscellaneous | Actual: enthusiastic
# Pred: miscellaneous | Actual: discretion
# Pred: miscellaneous | Actual: refrigerator
# Pred: miscellaneous | Actual: scare
# Pred: miscellaneous | Actual: reckon
# Pred: miscellaneous | Actual: curiosity
# Pred: miscellaneous | Actual: often
# Pred: miscellaneous | Actual: commissioning
# Pred: miscellaneous | Actual: adequate
# Pred: miscellaneous | Actual: obligation
# Pred: miscellaneous | Actual: earth
# Pred: miscellaneous | Actual: ridiculous
# Pred: miscellaneous | Actual: comfortable
# Pred: miscellaneous | Actual: apple
# Pred: miscellaneous | Actual: single
# Pred: miscellaneous | Actual: heard
# Pred: miscellaneous | Actual: southern
# Pred: miscellaneous | Actual: calmed
# Pred: miscellaneous | Actual: week
# Pred: miscellaneous | Actual: late
# Pred: miscellaneous | Actual: immediately
# Pred: miscellaneous | Actual: gorgeous
# Pred: miscellaneous | Actual: exists
# Pred: miscellaneous | Actual: various
# Pred: miscellaneous | Actual: any
# Pred: miscellaneous | Actual: away
# Pred: miscellaneous | Actual: scare
# Pred: miscellaneous | Actual: know
# Pred: miscellaneous | Actual: potatoes
# Pred: miscellaneous | Actual: con
# Pred: miscellaneous | Actual: arranged
# Pred: miscellaneous | Actual: philosophy
# Pred: miscellaneous | Actual: unfortunately
# Pred: miscellaneous | Actual: prominent
# Pred: miscellaneous | Actual: supervisor
# Pred: miscellaneous | Actual: injury
# Pred: miscellaneous | Actual: becoming
# Pred: miscellaneous | Actual: hydraulic
# Pred: miscellaneous | Actual: transferred
# Pred: miscellaneous | Actual: competent
# Pred: miscellaneous | Actual: did
# Pred: miscellaneous | Actual: swap
# Pred: miscellaneous | Actual: to
# Pred: miscellaneous | Actual: tr
# Pred: miscellaneous | Actual: committees
# Pred: miscellaneous | Actual: such
# Pred: miscellaneous | Actual: prejudice
# Pred: miscellaneous | Actual: elbow
# Pred: miscellaneous | Actual: curious
# Pred: miscellaneous | Actual: sunk
# Pred: miscellaneous | Actual: special
# Pred: miscellaneous | Actual: cancellation
# Pred: miscellaneous | Actual: divide
# Pred: miscellaneous | Actual: the
# Pred: miscellaneous | Actual: classrooms
# Pred: miscellaneous | Actual: gorgeous
# Pred: miscellaneous | Actual: scarcely
# Pred: miscellaneous | Actual: coarse
# Pred: miscellaneous | Actual: orchestra
# Pred: miscellaneous | Actual: solemn
# Pred: miscellaneous | Actual: last
# Pred: miscellaneous | Actual: rain
# Pred: miscellaneous | Actual: especially
# Pred: miscellaneous | Actual: machine
# Pred: miscellaneous | Actual: representatives
# Pred: miscellaneous | Actual: customary
# Pred: miscellaneous | Actual: knife
# Pred: miscellaneous | Actual: excel
# Pred: miscellaneous | Actual: cooperation
# Pred: miscellaneous | Actual: centre
# Pred: miscellaneous | Actual: virtue
# Pred: miscellaneous | Actual: determined
# Pred: miscellaneous | Actual: earth
# Pred: miscellaneous | Actual: talent
# Pred: miscellaneous | Actual: imitation
# Pred: miscellaneous | Actual: contract
# Pred: miscellaneous | Actual: doubtful
# Pred: miscellaneous | Actual: cemetery
# Pred: miscellaneous | Actual: relevant
# Pred: miscellaneous | Actual: cannot
# Pred: miscellaneous | Actual: inc
# Pred: miscellaneous | Actual: colonel
# Pred: miscellaneous | Actual: edition
# Pred: miscellaneous | Actual: discretion
# Pred: miscellaneous | Actual: acquaintance
# Pred: miscellaneous | Actual: expected
# Pred: miscellaneous | Actual: con
# Pred: miscellaneous | Actual: exquisite
# Pred: miscellaneous | Actual: tr
# Pred: miscellaneous | Actual: metal
# Pred: miscellaneous | Actual: economical
# Pred: miscellaneous | Actual: delicate
# Pred: miscellaneous | Actual: actually
# Pred: miscellaneous | Actual: about
# Pred: miscellaneous | Actual: tragedy
# Pred: miscellaneous | Actual: motor
# Pred: miscellaneous | Actual: del
# Pred: miscellaneous | Actual: chemistry
# Pred: miscellaneous | Actual: cult
# Pred: miscellaneous | Actual: unanimous
# Pred: miscellaneous | Actual: comfortable
# Pred: miscellaneous | Actual: idea
# Pred: miscellaneous | Actual: walking
# Pred: miscellaneous | Actual: ami
# Pred: miscellaneous | Actual: psychology
# Pred: miscellaneous | Actual: peculiar
# Pred: miscellaneous | Actual: inc
# Pred: miscellaneous | Actual: originally
# Pred: miscellaneous | Actual: taken
# Pred: miscellaneous | Actual: tournament
# Pred: miscellaneous | Actual: af
# Pred: miscellaneous | Actual: guarantee
# Pred: miscellaneous | Actual: irrelevant
# Pred: miscellaneous | Actual: recognition
# Pred: miscellaneous | Actual: anxious
# Pred: miscellaneous | Actual: forward
# Pred: miscellaneous | Actual: prof
# Pred: miscellaneous | Actual: residents
# Pred: miscellaneous | Actual: waiting
# Pred: miscellaneous | Actual: laughs
# Pred: miscellaneous | Actual: however
# Pred: miscellaneous | Actual: originally
# Pred: miscellaneous | Actual: slide
# Pred: miscellaneous | Actual: gal
# Pred: miscellaneous | Actual: mathematics
# Pred: miscellaneous | Actual: determined
# Pred: miscellaneous | Actual: enthusiastic
# Pred: miscellaneous | Actual: competent
# Pred: miscellaneous | Actual: experience
# Pred: miscellaneous | Actual: favour
# Pred: miscellaneous | Actual: lodge
# Pred: enthusiasm | Actual: equipped
# Pred: miscellaneous | Actual: distinguished
# Pred: miscellaneous | Actual: specifically
# Pred: miscellaneous | Actual: sorority
# Pred: miscellaneous | Actual: being
# Pred: miscellaneous | Actual: peculiar
# Pred: miscellaneous | Actual: immediately
# Pred: miscellaneous | Actual: tentacles
# Pred: miscellaneous | Actual: bungalow
# Pred: miscellaneous | Actual: material
# Pred: miscellaneous | Actual: bridge
# Pred: miscellaneous | Actual: colonel
# Pred: miscellaneous | Actual: enthusiastic
# Pred: miscellaneous | Actual: per
# Pred: miscellaneous | Actual: enthusiastic
# Pred: miscellaneous | Actual: spare
# Pred: miscellaneous | Actual: heard
# Pred: miscellaneous | Actual: pledge
# Pred: miscellaneous | Actual: biscuits
# Pred: miscellaneous | Actual: answer
# Pred: miscellaneous | Actual: steering
# Pred: miscellaneous | Actual: des
# Pred: miscellaneous | Actual: financial
# Pred: miscellaneous | Actual: removed
# Pred: miscellaneous | Actual: sufficient
# Pred: miscellaneous | Actual: truth
# Pred: miscellaneous | Actual: apparently
# Pred: miscellaneous | Actual: biscuits
# Pred: miscellaneous | Actual: member
# Pred: miscellaneous | Actual: destination
# Pred: miscellaneous | Actual: furnace
# Pred: miscellaneous | Actual: ep
# Pred: miscellaneous | Actual: mathematics
# Pred: miscellaneous | Actual: acknowledge
# Pred: miscellaneous | Actual: staring
# Pred: miscellaneous | Actual: punishment
# Pred: miscellaneous | Actual: especially
# Pred: miscellaneous | Actual: about
# Pred: miscellaneous | Actual: minimum
# Pred: miscellaneous | Actual: women
# Pred: miscellaneous | Actual: gauge
# Pred: miscellaneous | Actual: destination
# Pred: miscellaneous | Actual: form
# Pred: miscellaneous | Actual: biscuits
# Pred: miscellaneous | Actual: statistics
# Pred: miscellaneous | Actual: decidedly
# Pred: miscellaneous | Actual: remembered
# Pred: miscellaneous | Actual: cha
# Pred: miscellaneous | Actual: similar
# Pred: miscellaneous | Actual: op
# Pred: miscellaneous | Actual: weight
# Pred: miscellaneous | Actual: suspicion
# Pred: miscellaneous | Actual: they
# Pred: miscellaneous | Actual: curious
# Pred: miscellaneous | Actual: fundamentally
# Pred: miscellaneous | Actual: fight
# Pred: miscellaneous | Actual: visited
# Pred: miscellaneous | Actual: equipped
# Pred: miscellaneous | Actual: remember
# Pred: miscellaneous | Actual: di
# Pred: miscellaneous | Actual: del
# Pred: miscellaneous | Actual: primitive
# Pred: miscellaneous | Actual: searched
# Pred: miscellaneous | Actual: circling
# Pred: miscellaneous | Actual: er
# Pred: miscellaneous | Actual: re
# Pred: miscellaneous | Actual: kindergarten
# Pred: miscellaneous | Actual: curtains
# Pred: miscellaneous | Actual: deer
# Pred: miscellaneous | Actual: ski
# Pred: miscellaneous | Actual: faint
# Pred: miscellaneous | Actual: surface
# Pred: miscellaneous | Actual: negotiations
# Pred: miscellaneous | Actual: structure
# Pred: miscellaneous | Actual: pamphlets
# Pred: miscellaneous | Actual: unanimous
# Pred: miscellaneous | Actual: go
# Pred: miscellaneous | Actual: head
# Pred: miscellaneous | Actual: during
# Pred: miscellaneous | Actual: establishing
# Pred: miscellaneous | Actual: va
# Pred: miscellaneous | Actual: competent
# Pred: miscellaneous | Actual: folk
# Pred: miscellaneous | Actual: interpretations
# Pred: miscellaneous | Actual: council
# Pred: miscellaneous | Actual: sorority
# Pred: miscellaneous | Actual: belief
# Pred: miscellaneous | Actual: wait
# Pred: miscellaneous | Actual: back
# Pred: miscellaneous | Actual: duplicate
# Pred: miscellaneous | Actual: coefficient
# Pred: miscellaneous | Actual: back
# Pred: miscellaneous | Actual: because
# Pred: miscellaneous | Actual: chemistry
# Pred: miscellaneous | Actual: prior
# Pred: miscellaneous | Actual: permanently
# Pred: miscellaneous | Actual: very
# Pred: miscellaneous | Actual: economic
# Pred: miscellaneous | Actual: walk
# Pred: miscellaneous | Actual: dip
# Pred: miscellaneous | Actual: pena
# Pred: miscellaneous | Actual: controls
# Pred: miscellaneous | Actual: who
# Pred: miscellaneous | Actual: aero
# Pred: miscellaneous | Actual: date
# Pred: miscellaneous | Actual: enthusiasm
# Pred: miscellaneous | Actual: sheets
# Pred: miscellaneous | Actual: collateral
# Pred: miscellaneous | Actual: physician
# Pred: miscellaneous | Actual: the
# Pred: miscellaneous | Actual: attorneys
# Pred: miscellaneous | Actual: valle
# Pred: miscellaneous | Actual: constraints
# Pred: miscellaneous | Actual: anxiety
# Pred: miscellaneous | Actual: successes
# Pred: miscellaneous | Actual: chosen
# Pred: miscellaneous | Actual: loads
# Pred: miscellaneous | Actual: alumni
# Pred: miscellaneous | Actual: succeeded
# Pred: miscellaneous | Actual: begun
# Pred: miscellaneous | Actual: with
# Pred: miscellaneous | Actual: perpetual
# Pred: miscellaneous | Actual: groups
# Pred: miscellaneous | Actual: economic
# Pred: miscellaneous | Actual: certainly
# Pred: miscellaneous | Actual: conscious
# Pred: miscellaneous | Actual: ecstasy
# Pred: miscellaneous | Actual: sufficiently
# Pred: miscellaneous | Actual: curious
# Pred: miscellaneous | Actual: anniversary
# Pred: miscellaneous | Actual: orchestra
# Pred: miscellaneous | Actual: pastoral
# Pred: miscellaneous | Actual: mystery
# Pred: miscellaneous | Actual: specific
# Pred: miscellaneous | Actual: plan
# Pred: miscellaneous | Actual: digging
# Pred: miscellaneous | Actual: pretend
# Pred: miscellaneous | Actual: indefinite
# Pred: miscellaneous | Actual: magnificent
# Pred: miscellaneous | Actual: pillow
# Pred: miscellaneous | Actual: counsel
# Pred: miscellaneous | Actual: machine
# Pred: miscellaneous | Actual: ridiculous
# Pred: miscellaneous | Actual: neighbours
# Pred: enthusiasm | Actual: embarrassed
# Pred: miscellaneous | Actual: scrambled
# Pred: miscellaneous | Actual: re
# Pred: miscellaneous | Actual: exhibition
# Pred: miscellaneous | Actual: sound
# Pred: miscellaneous | Actual: industry
# Pred: miscellaneous | Actual: on
# Pred: miscellaneous | Actual: dee
# Pred: miscellaneous | Actual: immediately
# Pred: miscellaneous | Actual: knife
# Pred: miscellaneous | Actual: spacecraft
# Pred: miscellaneous | Actual: tomorrow
# Accuracy: 0.0050
# Epoch 2, Average Loss: 7.4589
# Accuracy: 0.0398
# Epoch 3, Average Loss: 7.0287
# Pred: answer | Actual: base
# Pred: sure | Actual: suspicion
# Pred: va | Actual: chapter
# Pred: anniversary | Actual: peculiar
# Pred: indefinitely | Actual: indefinite
# Pred: af | Actual: avoid
# Pred: court | Actual: tell
# Pred: court | Actual: trial
# Pred: inc | Actual: technically
# Pred: beautiful | Actual: general
# Pred: sympathetic | Actual: smoking
# Pred: special | Actual: jam
# Pred: scheduled | Actual: region
# Pred: beautiful | Actual: gradually
# Pred: court | Actual: annoyance
# Pred: court | Actual: street
# Pred: un | Actual: fundamental
# Pred: magnificent | Actual: magnificent
# Pred: answer | Actual: recipe
# Pred: con | Actual: con
# Pred: answer | Actual: above
# Pred: answer | Actual: juice
# Pred: ex | Actual: execution
# Pred: enthusiasm | Actual: initiation
# Pred: un | Actual: un
# Pred: beautiful | Actual: who
# Pred: beautiful | Actual: about
# Pred: answer | Actual: auditorium
# Pred: especially | Actual: philosophy
# Pred: miscellaneous | Actual: anniversary
# Pred: magnificent | Actual: fundamental
# Pred: un | Actual: attorneys
# Pred: dangerous | Actual: disgrace
# Pred: magnificent | Actual: remembrance
# Pred: re | Actual: apparatus
# Pred: sure | Actual: powder
# Pred: answer | Actual: seem
# Pred: special | Actual: er
# Pred: miscellaneous | Actual: miscellaneous
# Pred: beautiful | Actual: scandal
# Pred: af | Actual: literature
# Pred: answer | Actual: food
# Pred: philosophy | Actual: counselor
# Pred: beautiful | Actual: museum
# Pred: beautiful | Actual: vo
# Pred: answer | Actual: head
# Pred: material | Actual: vehicles
# Pred: ridiculous | Actual: ridiculous
# Pred: miscellaneous | Actual: miscellaneous
# Pred: philosophy | Actual: bicycle
# Pred: satisfaction | Actual: satisfaction
# Pred: beautiful | Actual: ami
# Pred: satisfaction | Actual: restaurant
# Pred: any | Actual: surplus
# Pred: especially | Actual: privilege
# Pred: stomach | Actual: gallo
# Pred: beautiful | Actual: un
# Pred: dangerous | Actual: governor
# Pred: court | Actual: sympathetic
# Pred: surface | Actual: training
# Pred: beautiful | Actual: infinite
# Pred: court | Actual: these
# Pred: un | Actual: functional
# Pred: philosophy | Actual: all
# Pred: especially | Actual: ambulance
# Pred: dangerous | Actual: friend
# Pred: court | Actual: me
# Pred: dangerous | Actual: receipt
# Pred: facilities | Actual: facilities
# Pred: answer | Actual: thanksgiving
# Pred: especially | Actual: monetary
# Pred: con | Actual: exhibitions
# Pred: answer | Actual: not
# Pred: especially | Actual: especially
# Pred: sure | Actual: dark
# Pred: facilities | Actual: approaching
# Pred: scheduled | Actual: scarcely
# Pred: re | Actual: request
# Pred: enthusiasm | Actual: enthusiasm
# Pred: answer | Actual: alright
# Pred: sympathetic | Actual: sympathetic
# Pred: answer | Actual: leave
# Pred: enthusiasm | Actual: decidedly
# Pred: un | Actual: attach
# Pred: answer | Actual: dropped
# Pred: avoid | Actual: one
# Pred: court | Actual: back
# Pred: con | Actual: confirmation
# Pred: count | Actual: count
# Pred: sympathetic | Actual: sympathetic
# Pred: court | Actual: children
# Pred: beautiful | Actual: football
# Pred: un | Actual: unemployed
# Pred: con | Actual: cancelled
# Pred: enthusiasm | Actual: enthusiastic
# Pred: beautiful | Actual: forward
# Pred: va | Actual: thorough
# Pred: re | Actual: recurring
# Pred: philosophy | Actual: preliminary
# Pred: prejudice | Actual: heightened
# Pred: dart | Actual: that
# Pred: miscellaneous | Actual: miscellaneous
# Pred: court | Actual: trouble
# Pred: answer | Actual: recently
# Pred: refrigerator | Actual: ref
# Pred: answer | Actual: fought
# Pred: guarantee | Actual: guaranteed
# Pred: answer | Actual: would
# Pred: answer | Actual: road
# Pred: va | Actual: en
# Pred: va | Actual: another
# Pred: dangerous | Actual: marble
# Pred: va | Actual: va
# Pred: beautiful | Actual: stomach
# Pred: answer | Actual: gorgeous
# Pred: court | Actual: nearer
# Pred: women | Actual: wearing
# Pred: sure | Actual: form
# Pred: un | Actual: hydraulic
# Pred: court | Actual: beneath
# Pred: sure | Actual: o
# Pred: answer | Actual: what
# Pred: answer | Actual: dart
# Pred: answer | Actual: aunt
# Pred: special | Actual: head
# Pred: comfortable | Actual: community
# Pred: unanimous | Actual: unanimous
# Pred: especially | Actual: fascinating
# Pred: opposite | Actual: determined
# Pred: answer | Actual: dumb
# Pred: court | Actual: belt
# Pred: answer | Actual: hours
# Pred: del | Actual: determined
# Pred: special | Actual: i
# Pred: answer | Actual: prologue
# Pred: especially | Actual: occasionally
# Pred: prejudice | Actual: possess
# Pred: answer | Actual: heard
# Pred: distinguished | Actual: disposal
# Pred: answer | Actual: want
# Pred: con | Actual: conditions
# Pred: opposite | Actual: opposite
# Pred: magnificent | Actual: bulletin
# Pred: va | Actual: signature
# Pred: con | Actual: count
# Pred: enthusiasm | Actual: eventually
# Pred: beautiful | Actual: dinner
# Pred: answer | Actual: work
# Pred: affectionately | Actual: approximate
# Pred: guarantee | Actual: guarantee
# Pred: sympathetic | Actual: acceptable
# Pred: answer | Actual: planets
# Pred: court | Actual: che
# Pred: magnificent | Actual: sat
# Pred: beautiful | Actual: principle
# Pred: sympathetic | Actual: syrup
# Pred: beautiful | Actual: vo
# Pred: dangerous | Actual: take
# Pred: miscellaneous | Actual: r
# Pred: satisfaction | Actual: sufficient
# Pred: answer | Actual: alumni
# Pred: answer | Actual: depth
# Pred: enthusiasm | Actual: bankruptcy
# Pred: answer | Actual: nothing
# Pred: del | Actual: enough
# Pred: prejudice | Actual: prejudice
# Pred: answer | Actual: apple
# Pred: court | Actual: deal
# Pred: answer | Actual: street
# Pred: satisfaction | Actual: subterranean
# Pred: re | Actual: recognize
# Pred: answer | Actual: brought
# Pred: court | Actual: cried
# Pred: answer | Actual: matter
# Pred: criticism | Actual: cricket
# Pred: court | Actual: initials
# Pred: court | Actual: dangerous
# Pred: enthusiasm | Actual: attorneys
# Pred: con | Actual: destination
# Pred: prejudice | Actual: prejudice
# Pred: answer | Actual: verse
# Pred: del | Actual: restaurant
# Pred: enthusiasm | Actual: commitment
# Pred: opposite | Actual: opposite
# Pred: especially | Actual: familiar
# Pred: special | Actual: recommend
# Pred: inc | Actual: affectionately
# Pred: beautiful | Actual: repairs
# Pred: beautiful | Actual: alcohol
# Pred: miscellaneous | Actual: misery
# Pred: sure | Actual: turned
# Pred: dangerous | Actual: peculiar
# Pred: answer | Actual: giggling
# Pred: court | Actual: ate
# Pred: court | Actual: triumph
# Pred: initiation | Actual: engine
# Pred: court | Actual: pilot
# Pred: af | Actual: subterranean
# Pred: especially | Actual: incident
# Pred: sufficiently | Actual: sufficiently
# Pred: answer | Actual: count
# Pred: court | Actual: children
# Pred: con | Actual: con
# Pred: con | Actual: drunken
# Pred: con | Actual: sauce
# Pred: court | Actual: was
# Pred: beautiful | Actual: answer
# Pred: enthusiasm | Actual: enthusiasm
# Pred: surface | Actual: as
# Pred: beautiful | Actual: became
# Pred: court | Actual: association
# Pred: con | Actual: di
# Pred: answer | Actual: women
# Pred: un | Actual: un
# Pred: court | Actual: gallery
# Pred: especially | Actual: enthusiastic
# Pred: beautiful | Actual: discretion
# Pred: refrigerator | Actual: refrigerator
# Pred: answer | Actual: scare
# Pred: recognition | Actual: reckon
# Pred: especially | Actual: curiosity
# Pred: surface | Actual: often
# Pred: competent | Actual: commissioning
# Pred: enthusiastic | Actual: adequate
# Pred: va | Actual: obligation
# Pred: va | Actual: earth
# Pred: ridiculous | Actual: ridiculous
# Pred: comfortable | Actual: comfortable
# Pred: special | Actual: apple
# Pred: answer | Actual: single
# Pred: answer | Actual: heard
# Pred: answer | Actual: southern
# Pred: court | Actual: calmed
# Pred: answer | Actual: week
# Pred: answer | Actual: late
# Pred: especially | Actual: immediately
# Pred: facilities | Actual: gorgeous
# Pred: ex | Actual: exists
# Pred: answer | Actual: various
# Pred: stomach | Actual: any
# Pred: court | Actual: away
# Pred: court | Actual: scare
# Pred: answer | Actual: know
# Pred: answer | Actual: potatoes
# Pred: con | Actual: con
# Pred: scarcely | Actual: arranged
# Pred: psychology | Actual: philosophy
# Pred: beautiful | Actual: unfortunately
# Pred: special | Actual: prominent
# Pred: especially | Actual: supervisor
# Pred: court | Actual: injury
# Pred: answer | Actual: becoming
# Pred: inc | Actual: hydraulic
# Pred: magnificent | Actual: transferred
# Pred: comfortable | Actual: competent
# Pred: answer | Actual: did
# Pred: court | Actual: swap
# Pred: court | Actual: to
# Pred: court | Actual: tr
# Pred: court | Actual: committees
# Pred: answer | Actual: such
# Pred: prejudice | Actual: prejudice
# Pred: court | Actual: elbow
# Pred: special | Actual: curious
# Pred: answer | Actual: sunk
# Pred: special | Actual: special
# Pred: especially | Actual: cancellation
# Pred: beautiful | Actual: divide
# Pred: answer | Actual: the
# Pred: answer | Actual: classrooms
# Pred: beautiful | Actual: gorgeous
# Pred: court | Actual: scarcely
# Pred: dangerous | Actual: coarse
# Pred: un | Actual: orchestra
# Pred: answer | Actual: solemn
# Pred: surface | Actual: last
# Pred: answer | Actual: rain
# Pred: especially | Actual: especially
# Pred: va | Actual: machine
# Pred: answer | Actual: representatives
# Pred: immediately | Actual: customary
# Pred: answer | Actual: knife
# Pred: special | Actual: excel
# Pred: un | Actual: cooperation
# Pred: special | Actual: centre
# Pred: court | Actual: virtue
# Pred: con | Actual: determined
# Pred: answer | Actual: earth
# Pred: answer | Actual: talent
# Pred: immediately | Actual: imitation
# Pred: stomach | Actual: contract
# Pred: prejudice | Actual: doubtful
# Pred: beautiful | Actual: cemetery
# Pred: re | Actual: relevant
# Pred: dangerous | Actual: cannot
# Pred: inc | Actual: inc
# Pred: special | Actual: colonel
# Pred: sympathetic | Actual: edition
# Pred: magnificent | Actual: discretion
# Pred: va | Actual: acquaintance
# Pred: ex | Actual: expected
# Pred: con | Actual: con
# Pred: ex | Actual: exquisite
# Pred: answer | Actual: tr
# Pred: miscellaneous | Actual: metal
# Pred: miscellaneous | Actual: economical
# Pred: del | Actual: delicate
# Pred: especially | Actual: actually
# Pred: answer | Actual: about
# Pred: beautiful | Actual: tragedy
# Pred: beautiful | Actual: motor
# Pred: ref | Actual: del
# Pred: psychology | Actual: chemistry
# Pred: philosophy | Actual: cult
# Pred: enthusiasm | Actual: unanimous
# Pred: con | Actual: comfortable
# Pred: answer | Actual: idea
# Pred: women | Actual: walking
# Pred: dangerous | Actual: ami
# Pred: psychology | Actual: psychology
# Pred: material | Actual: peculiar
# Pred: inc | Actual: inc
# Pred: enthusiasm | Actual: originally
# Pred: answer | Actual: taken
# Pred: answer | Actual: tournament
# Pred: af | Actual: af
# Pred: guarantee | Actual: guarantee
# Pred: del | Actual: irrelevant
# Pred: recognition | Actual: recognition
# Pred: answer | Actual: anxious
# Pred: answer | Actual: forward
# Pred: prejudice | Actual: prof
# Pred: enthusiasm | Actual: residents
# Pred: court | Actual: waiting
# Pred: answer | Actual: laughs
# Pred: special | Actual: however
# Pred: indefinitely | Actual: originally
# Pred: women | Actual: slide
# Pred: guarantee | Actual: gal
# Pred: answer | Actual: mathematics
# Pred: enthusiasm | Actual: determined
# Pred: enthusiasm | Actual: enthusiastic
# Pred: answer | Actual: competent
# Pred: magnificent | Actual: experience
# Pred: surface | Actual: favour
# Pred: loud | Actual: lodge
# Pred: enthusiasm | Actual: equipped
# Pred: dangerous | Actual: distinguished
# Pred: approximately | Actual: specifically
# Pred: enthusiasm | Actual: sorority
# Pred: court | Actual: being
# Pred: especially | Actual: peculiar
# Pred: immediately | Actual: immediately
# Pred: dangerous | Actual: tentacles
# Pred: beautiful | Actual: bungalow
# Pred: beautiful | Actual: material
# Pred: answer | Actual: bridge
# Pred: court | Actual: colonel
# Pred: enthusiasm | Actual: enthusiastic
# Pred: prejudice | Actual: per
# Pred: enthusiasm | Actual: enthusiastic
# Pred: answer | Actual: spare
# Pred: answer | Actual: heard
# Pred: answer | Actual: pledge
# Pred: surplus | Actual: biscuits
# Pred: answer | Actual: answer
# Pred: court | Actual: steering
# Pred: di | Actual: des
# Pred: magnificent | Actual: financial
# Pred: answer | Actual: removed
# Pred: successful | Actual: sufficient
# Pred: beautiful | Actual: truth
# Pred: special | Actual: apparently
# Pred: dangerous | Actual: biscuits
# Pred: va | Actual: member
# Pred: unanimous | Actual: destination
# Pred: especially | Actual: furnace
# Pred: va | Actual: ep
# Pred: prejudice | Actual: mathematics
# Pred: inc | Actual: acknowledge
# Pred: court | Actual: staring
# Pred: un | Actual: punishment
# Pred: court | Actual: especially
# Pred: answer | Actual: about
# Pred: surface | Actual: minimum
# Pred: surface | Actual: women
# Pred: beautiful | Actual: gauge
# Pred: enthusiasm | Actual: destination
# Pred: answer | Actual: form
# Pred: beautiful | Actual: biscuits
# Pred: st | Actual: statistics
# Pred: un | Actual: decidedly
# Pred: re | Actual: remembered
# Pred: satisfaction | Actual: cha
# Pred: cha | Actual: similar
# Pred: re | Actual: op
# Pred: answer | Actual: weight
# Pred: enthusiastic | Actual: suspicion
# Pred: answer | Actual: they
# Pred: surface | Actual: curious
# Pred: immediately | Actual: fundamentally
# Pred: answer | Actual: fight
# Pred: un | Actual: visited
# Pred: efficiency | Actual: equipped
# Pred: re | Actual: remember
# Pred: enthusiasm | Actual: di
# Pred: del | Actual: del
# Pred: answer | Actual: primitive
# Pred: court | Actual: searched
# Pred: inc | Actual: circling
# Pred: miscellaneous | Actual: er
# Pred: enthusiasm | Actual: re
# Pred: answer | Actual: kindergarten
# Pred: answer | Actual: curtains
# Pred: sure | Actual: deer
# Pred: psychology | Actual: ski
# Pred: sure | Actual: faint
# Pred: stomach | Actual: surface
# Pred: special | Actual: negotiations
# Pred: stomach | Actual: structure
# Pred: philosophy | Actual: pamphlets
# Pred: unanimous | Actual: unanimous
# Pred: beautiful | Actual: go
# Pred: especially | Actual: head
# Pred: stomach | Actual: during
# Pred: inc | Actual: establishing
# Pred: va | Actual: va
# Pred: un | Actual: competent
# Pred: answer | Actual: folk
# Pred: initiation | Actual: interpretations
# Pred: count | Actual: council
# Pred: beautiful | Actual: sorority
# Pred: beautiful | Actual: belief
# Pred: dangerous | Actual: wait
# Pred: answer | Actual: back
# Pred: un | Actual: duplicate
# Pred: recognition | Actual: coefficient
# Pred: women | Actual: back
# Pred: answer | Actual: because
# Pred: af | Actual: chemistry
# Pred: va | Actual: prior
# Pred: permanently | Actual: permanently
# Pred: court | Actual: very
# Pred: magnificent | Actual: economic
# Pred: answer | Actual: walk
# Pred: beautiful | Actual: dip
# Pred: answer | Actual: pena
# Pred: answer | Actual: controls
# Pred: answer | Actual: who
# Pred: psychology | Actual: aero
# Pred: special | Actual: date
# Pred: enthusiasm | Actual: enthusiasm
# Pred: beautiful | Actual: sheets
# Pred: beautiful | Actual: collateral
# Pred: psychology | Actual: physician
# Pred: court | Actual: the
# Pred: immediately | Actual: attorneys
# Pred: answer | Actual: valle
# Pred: con | Actual: constraints
# Pred: anxiety | Actual: anxiety
# Pred: successful | Actual: successes
# Pred: answer | Actual: chosen
# Pred: court | Actual: loads
# Pred: va | Actual: alumni
# Pred: successful | Actual: succeeded
# Pred: dangerous | Actual: begun
# Pred: beautiful | Actual: with
# Pred: especially | Actual: perpetual
# Pred: answer | Actual: groups
# Pred: miscellaneous | Actual: economic
# Pred: undoubtedly | Actual: certainly
# Pred: enthusiasm | Actual: conscious
# Pred: philosophy | Actual: ecstasy
# Pred: un | Actual: sufficiently
# Pred: miscellaneous | Actual: curious
# Pred: anniversary | Actual: anniversary
# Pred: especially | Actual: orchestra
# Pred: beautiful | Actual: pastoral
# Pred: court | Actual: mystery
# Pred: magnificent | Actual: specific
# Pred: beautiful | Actual: plan
# Pred: stomach | Actual: digging
# Pred: beautiful | Actual: pretend
# Pred: indefinitely | Actual: indefinite
# Pred: prejudice | Actual: magnificent
# Pred: answer | Actual: pillow
# Pred: con | Actual: counsel
# Pred: beautiful | Actual: machine
# Pred: con | Actual: ridiculous
# Pred: negotiations | Actual: neighbours
# Pred: especially | Actual: embarrassed
# Pred: beautiful | Actual: scrambled
# Pred: enthusiasm | Actual: re
# Pred: exhibition | Actual: exhibition
# Pred: answer | Actual: sound
# Pred: actually | Actual: industry
# Pred: answer | Actual: on
# Pred: answer | Actual: dee
# Pred: un | Actual: immediately
# Pred: answer | Actual: knife
# Pred: special | Actual: spacecraft
# Pred: dangerous | Actual: tomorrow
# Accuracy: 0.0819
# Epoch 4, Average Loss: 6.7031
# Accuracy: 0.1194
# Epoch 5, Average Loss: 6.4354
# Pred: dart | Actual: base
# Pred: sure | Actual: suspicion
# Pred: va | Actual: chapter
# Pred: peculiar | Actual: peculiar
# Pred: indefinite | Actual: indefinite
# Pred: recommend | Actual: avoid
# Pred: court | Actual: tell
# Pred: court | Actual: trial
# Pred: approximately | Actual: technically
# Pred: beautiful | Actual: general
# Pred: material | Actual: smoking
# Pred: answer | Actual: jam
# Pred: scheduled | Actual: region
# Pred: beautiful | Actual: gradually
# Pred: anxious | Actual: annoyance
# Pred: answer | Actual: street
# Pred: immediately | Actual: fundamental
# Pred: magnificent | Actual: magnificent
# Pred: dart | Actual: recipe
# Pred: con | Actual: con
# Pred: answer | Actual: above
# Pred: must | Actual: juice
# Pred: exhibition | Actual: execution
# Pred: enthusiasm | Actual: initiation
# Pred: un | Actual: un
# Pred: beautiful | Actual: who
# Pred: beautiful | Actual: about
# Pred: court | Actual: auditorium
# Pred: especially | Actual: philosophy
# Pred: anniversary | Actual: anniversary
# Pred: immediately | Actual: fundamental
# Pred: enthusiasm | Actual: attorneys
# Pred: dangerous | Actual: disgrace
# Pred: re | Actual: remembrance
# Pred: re | Actual: apparatus
# Pred: sure | Actual: powder
# Pred: sure | Actual: seem
# Pred: af | Actual: er
# Pred: miscellaneous | Actual: miscellaneous
# Pred: beautiful | Actual: scandal
# Pred: beautiful | Actual: literature
# Pred: answer | Actual: food
# Pred: cha | Actual: counselor
# Pred: must | Actual: museum
# Pred: beautiful | Actual: vo
# Pred: beautiful | Actual: head
# Pred: cha | Actual: vehicles
# Pred: ridiculous | Actual: ridiculous
# Pred: miscellaneous | Actual: miscellaneous
# Pred: philosophy | Actual: bicycle
# Pred: satisfaction | Actual: satisfaction
# Pred: familiar | Actual: ami
# Pred: re | Actual: restaurant
# Pred: any | Actual: surplus
# Pred: va | Actual: privilege
# Pred: stomach | Actual: gallo
# Pred: beautiful | Actual: un
# Pred: gorgeous | Actual: governor
# Pred: anxious | Actual: sympathetic
# Pred: surface | Actual: training
# Pred: beautiful | Actual: infinite
# Pred: court | Actual: these
# Pred: beautiful | Actual: functional
# Pred: tournament | Actual: all
# Pred: di | Actual: ambulance
# Pred: women | Actual: friend
# Pred: court | Actual: me
# Pred: recognition | Actual: receipt
# Pred: facilities | Actual: facilities
# Pred: visited | Actual: thanksgiving
# Pred: sorority | Actual: monetary
# Pred: exhibition | Actual: exhibitions
# Pred: answer | Actual: not
# Pred: especially | Actual: especially
# Pred: sure | Actual: dark
# Pred: r | Actual: approaching
# Pred: scheduled | Actual: scarcely
# Pred: re | Actual: request
# Pred: enthusiasm | Actual: enthusiasm
# Pred: really | Actual: alright
# Pred: sympathetic | Actual: sympathetic
# Pred: beautiful | Actual: leave
# Pred: especially | Actual: decidedly
# Pred: indefinitely | Actual: attach
# Pred: answer | Actual: dropped
# Pred: sure | Actual: one
# Pred: court | Actual: back
# Pred: con | Actual: confirmation
# Pred: count | Actual: count
# Pred: sympathetic | Actual: sympathetic
# Pred: annum | Actual: children
# Pred: beautiful | Actual: football
# Pred: un | Actual: unemployed
# Pred: con | Actual: cancelled
# Pred: enthusiasm | Actual: enthusiastic
# Pred: beautiful | Actual: forward
# Pred: special | Actual: thorough
# Pred: re | Actual: recurring
# Pred: temporarily | Actual: preliminary
# Pred: guaranteed | Actual: heightened
# Pred: dart | Actual: that
# Pred: miscellaneous | Actual: miscellaneous
# Pred: ? | Actual: trouble
# Pred: pilot | Actual: recently
# Pred: refrigerator | Actual: ref
# Pred: answer | Actual: fought
# Pred: guarantee | Actual: guaranteed
# Pred: answer | Actual: would
# Pred: answer | Actual: road
# Pred: va | Actual: en
# Pred: va | Actual: another
# Pred: dangerous | Actual: marble
# Pred: va | Actual: va
# Pred: criticism | Actual: stomach
# Pred: answer | Actual: gorgeous
# Pred: court | Actual: nearer
# Pred: beautiful | Actual: wearing
# Pred: sure | Actual: form
# Pred: magnificent | Actual: hydraulic
# Pred: beautiful | Actual: beneath
# Pred: sure | Actual: o
# Pred: answer | Actual: what
# Pred: answer | Actual: dart
# Pred: answer | Actual: aunt
# Pred: loud | Actual: head
# Pred: comparatively | Actual: community
# Pred: unanimous | Actual: unanimous
# Pred: fascinating | Actual: fascinating
# Pred: definite | Actual: determined
# Pred: answer | Actual: dumb
# Pred: court | Actual: belt
# Pred: answer | Actual: hours
# Pred: beautiful | Actual: determined
# Pred: guarantee | Actual: i
# Pred: friend | Actual: prologue
# Pred: occasionally | Actual: occasionally
# Pred: prejudice | Actual: possess
# Pred: va | Actual: heard
# Pred: distinguished | Actual: disposal
# Pred: answer | Actual: want
# Pred: con | Actual: conditions
# Pred: opposite | Actual: opposite
# Pred: beautiful | Actual: bulletin
# Pred: va | Actual: signature
# Pred: con | Actual: count
# Pred: enthusiasm | Actual: eventually
# Pred: annum | Actual: dinner
# Pred: women | Actual: work
# Pred: approximately | Actual: approximate
# Pred: guarantee | Actual: guarantee
# Pred: sympathetic | Actual: acceptable
# Pred: sure | Actual: planets
# Pred: court | Actual: che
# Pred: sat | Actual: sat
# Pred: competent | Actual: principle
# Pred: sympathetic | Actual: syrup
# Pred: temperature | Actual: vo
# Pred: dangerous | Actual: take
# Pred: r | Actual: r
# Pred: satisfaction | Actual: sufficient
# Pred: answer | Actual: alumni
# Pred: sure | Actual: depth
# Pred: enthusiasm | Actual: bankruptcy
# Pred: sure | Actual: nothing
# Pred: del | Actual: enough
# Pred: prejudice | Actual: prejudice
# Pred: answer | Actual: apple
# Pred: beautiful | Actual: deal
# Pred: sure | Actual: street
# Pred: suspicion | Actual: subterranean
# Pred: re | Actual: recognize
# Pred: answer | Actual: brought
# Pred: court | Actual: cried
# Pred: answer | Actual: matter
# Pred: criticism | Actual: cricket
# Pred: initiation | Actual: initials
# Pred: court | Actual: dangerous
# Pred: enthusiasm | Actual: attorneys
# Pred: di | Actual: destination
# Pred: prejudice | Actual: prejudice
# Pred: answer | Actual: verse
# Pred: del | Actual: restaurant
# Pred: comparatively | Actual: commitment
# Pred: opposite | Actual: opposite
# Pred: especially | Actual: familiar
# Pred: special | Actual: recommend
# Pred: affectionately | Actual: affectionately
# Pred: beautiful | Actual: repairs
# Pred: beautiful | Actual: alcohol
# Pred: miscellaneous | Actual: misery
# Pred: sure | Actual: turned
# Pred: cha | Actual: peculiar
# Pred: beautiful | Actual: giggling
# Pred: court | Actual: ate
# Pred: court | Actual: triumph
# Pred: initiation | Actual: engine
# Pred: court | Actual: pilot
# Pred: statistics | Actual: subterranean
# Pred: immediately | Actual: incident
# Pred: successful | Actual: sufficiently
# Pred: sure | Actual: count
# Pred: court | Actual: children
# Pred: con | Actual: con
# Pred: surface | Actual: drunken
# Pred: con | Actual: sauce
# Pred: court | Actual: was
# Pred: beautiful | Actual: answer
# Pred: enthusiasm | Actual: enthusiasm
# Pred: answer | Actual: as
# Pred: beautiful | Actual: became
# Pred: initiation | Actual: association
# Pred: di | Actual: di
# Pred: answer | Actual: women
# Pred: un | Actual: un
# Pred: gallery | Actual: gallery
# Pred: immediately | Actual: enthusiastic
# Pred: beautiful | Actual: discretion
# Pred: refrigerator | Actual: refrigerator
# Pred: scarcely | Actual: scare
# Pred: recognition | Actual: reckon
# Pred: sorority | Actual: curiosity
# Pred: annum | Actual: often
# Pred: comparatively | Actual: commissioning
# Pred: af | Actual: adequate
# Pred: va | Actual: obligation
# Pred: fight | Actual: earth
# Pred: ridiculous | Actual: ridiculous
# Pred: comparatively | Actual: comfortable
# Pred: special | Actual: apple
# Pred: definite | Actual: single
# Pred: sure | Actual: heard
# Pred: answer | Actual: southern
# Pred: guarantee | Actual: calmed
# Pred: answer | Actual: week
# Pred: answer | Actual: late
# Pred: or | Actual: immediately
# Pred: gorgeous | Actual: gorgeous
# Pred: exhibition | Actual: exists
# Pred: avoid | Actual: various
# Pred: initiation | Actual: any
# Pred: anxiety | Actual: away
# Pred: sure | Actual: scare
# Pred: sure | Actual: know
# Pred: court | Actual: potatoes
# Pred: con | Actual: con
# Pred: answer | Actual: arranged
# Pred: psychology | Actual: philosophy
# Pred: or | Actual: unfortunately
# Pred: tournament | Actual: prominent
# Pred: magnificent | Actual: supervisor
# Pred: poetry | Actual: injury
# Pred: sure | Actual: becoming
# Pred: af | Actual: hydraulic
# Pred: magnificent | Actual: transferred
# Pred: comparatively | Actual: competent
# Pred: answer | Actual: did
# Pred: court | Actual: swap
# Pred: beautiful | Actual: to
# Pred: poetry | Actual: tr
# Pred: court | Actual: committees
# Pred: beautiful | Actual: such
# Pred: prejudice | Actual: prejudice
# Pred: court | Actual: elbow
# Pred: answer | Actual: curious
# Pred: answer | Actual: sunk
# Pred: special | Actual: special
# Pred: initiation | Actual: cancellation
# Pred: beautiful | Actual: divide
# Pred: va | Actual: the
# Pred: answer | Actual: classrooms
# Pred: gorgeous | Actual: gorgeous
# Pred: court | Actual: scarcely
# Pred: dangerous | Actual: coarse
# Pred: un | Actual: orchestra
# Pred: answer | Actual: solemn
# Pred: fight | Actual: last
# Pred: guarantee | Actual: rain
# Pred: ex | Actual: especially
# Pred: r | Actual: machine
# Pred: sure | Actual: representatives
# Pred: immediately | Actual: customary
# Pred: friend | Actual: knife
# Pred: special | Actual: excel
# Pred: enthusiastic | Actual: cooperation
# Pred: accident | Actual: centre
# Pred: dangerous | Actual: virtue
# Pred: content | Actual: determined
# Pred: sure | Actual: earth
# Pred: answer | Actual: talent
# Pred: immediately | Actual: imitation
# Pred: stomach | Actual: contract
# Pred: beautiful | Actual: doubtful
# Pred: beautiful | Actual: cemetery
# Pred: re | Actual: relevant
# Pred: dangerous | Actual: cannot
# Pred: inc | Actual: inc
# Pred: special | Actual: colonel
# Pred: recognition | Actual: edition
# Pred: recognition | Actual: discretion
# Pred: va | Actual: acquaintance
# Pred: exhibition | Actual: expected
# Pred: con | Actual: con
# Pred: ex | Actual: exquisite
# Pred: answer | Actual: tr
# Pred: psychology | Actual: metal
# Pred: magnificent | Actual: economical
# Pred: del | Actual: delicate
# Pred: permanently | Actual: actually
# Pred: sure | Actual: about
# Pred: beautiful | Actual: tragedy
# Pred: beautiful | Actual: motor
# Pred: guarantee | Actual: del
# Pred: psychology | Actual: chemistry
# Pred: comfortable | Actual: cult
# Pred: unanimous | Actual: unanimous
# Pred: con | Actual: comfortable
# Pred: turned | Actual: idea
# Pred: stomach | Actual: walking
# Pred: material | Actual: ami
# Pred: psychology | Actual: psychology
# Pred: material | Actual: peculiar
# Pred: inc | Actual: inc
# Pred: incident | Actual: originally
# Pred: dangerous | Actual: taken
# Pred: tournament | Actual: tournament
# Pred: af | Actual: af
# Pred: guarantee | Actual: guarantee
# Pred: del | Actual: irrelevant
# Pred: recognition | Actual: recognition
# Pred: answer | Actual: anxious
# Pred: court | Actual: forward
# Pred: prejudice | Actual: prof
# Pred: recognition | Actual: residents
# Pred: court | Actual: waiting
# Pred: answer | Actual: laughs
# Pred: special | Actual: however
# Pred: indefinitely | Actual: originally
# Pred: va | Actual: slide
# Pred: guarantee | Actual: gal
# Pred: annum | Actual: mathematics
# Pred: immediately | Actual: determined
# Pred: enthusiasm | Actual: enthusiastic
# Pred: answer | Actual: competent
# Pred: immediately | Actual: experience
# Pred: familiar | Actual: favour
# Pred: loud | Actual: lodge
# Pred: efficiency | Actual: equipped
# Pred: dangerous | Actual: distinguished
# Pred: approximately | Actual: specifically
# Pred: sorority | Actual: sorority
# Pred: court | Actual: being
# Pred: especially | Actual: peculiar
# Pred: immediately | Actual: immediately
# Pred: dangerous | Actual: tentacles
# Pred: beautiful | Actual: bungalow
# Pred: material | Actual: material
# Pred: sure | Actual: bridge
# Pred: beautiful | Actual: colonel
# Pred: enthusiasm | Actual: enthusiastic
# Pred: prejudice | Actual: per
# Pred: enthusiasm | Actual: enthusiastic
# Pred: special | Actual: spare
# Pred: answer | Actual: heard
# Pred: fight | Actual: pledge
# Pred: surplus | Actual: biscuits
# Pred: answer | Actual: answer
# Pred: guarantee | Actual: steering
# Pred: di | Actual: des
# Pred: re | Actual: financial
# Pred: beautiful | Actual: removed
# Pred: successful | Actual: sufficient
# Pred: beautiful | Actual: truth
# Pred: material | Actual: apparently
# Pred: biscuits | Actual: biscuits
# Pred: va | Actual: member
# Pred: destination | Actual: destination
# Pred: especially | Actual: furnace
# Pred: psychology | Actual: ep
# Pred: opposite | Actual: mathematics
# Pred: acknowledging | Actual: acknowledge
# Pred: guarantee | Actual: staring
# Pred: refrigerator | Actual: punishment
# Pred: court | Actual: especially
# ...
# Pred: gorgeous | Actual: smoking
# Pred: juice | Actual: jam
# Pred: scheduled | Actual: region
# Pred: familiar | Actual: gradually
# Pred: anxious | Actual: annoyance
# Pred: answer | Actual: street
# Pred: fundamental | Actual: fundamental
# Pred: magnificent | Actual: magnificent
# Pred: stomach | Actual: recipe
# Pred: con | Actual: con
# Pred: answer | Actual: above
# Pred: must | Actual: juice
# Pred: exhibition | Actual: execution
# Pred: initiation | Actual: initiation
# Pred: unfortunately | Actual: un
# Pred: beautiful | Actual: who
# Pred: beautiful | Actual: about
# Pred: court | Actual: auditorium
# Pred: especially | Actual: philosophy
# Pred: anniversary | Actual: anniversary
# Pred: immediately | Actual: fundamental
# Pred: attorneys | Actual: attorneys
# Pred: beautiful | Actual: disgrace
# Pred: re | Actual: remembrance
# Pred: re | Actual: apparatus
# Pred: beg | Actual: powder
# Pred: sure | Actual: seem
# Pred: af | Actual: er
# Pred: miscellaneous | Actual: miscellaneous
# Pred: beautiful | Actual: scandal
# Pred: beautiful | Actual: literature
# Pred: answer | Actual: food
# Pred: cha | Actual: counselor
# Pred: must | Actual: museum
# Pred: beautiful | Actual: vo
# Pred: beautiful | Actual: head
# Pred: cha | Actual: vehicles
# Pred: ridiculous | Actual: ridiculous
# Pred: miscellaneous | Actual: miscellaneous
# Pred: philosophy | Actual: bicycle
# Pred: satisfaction | Actual: satisfaction
# Pred: familiar | Actual: ami
# Pred: restaurant | Actual: restaurant
# Pred: surplus | Actual: surplus
# Pred: va | Actual: privilege
# Pred: stomach | Actual: gallo
# Pred: beautiful | Actual: un
# Pred: gorgeous | Actual: governor
# Pred: permanent | Actual: sympathetic
# Pred: surface | Actual: training
# Pred: infinite | Actual: infinite
# Pred: court | Actual: these
# Pred: beautiful | Actual: functional
# Pred: tournament | Actual: all
# Pred: magnificent | Actual: ambulance
# Pred: friend | Actual: friend
# Pred: gallery | Actual: me
# Pred: recognition | Actual: receipt
# Pred: facilities | Actual: facilities
# Pred: content | Actual: thanksgiving
# Pred: poetry | Actual: monetary
# Pred: exhibition | Actual: exhibitions
# Pred: really | Actual: not
# Pred: especially | Actual: especially
# Pred: sure | Actual: dark
# Pred: r | Actual: approaching
# Pred: scheduled | Actual: scarcely
# Pred: re | Actual: request
# Pred: enthusiasm | Actual: enthusiasm
# Pred: really | Actual: alright
# Pred: negotiations | Actual: sympathetic
# Pred: beautiful | Actual: leave
# Pred: destination | Actual: decidedly
# Pred: indefinitely | Actual: attach
# Pred: answer | Actual: dropped
# Pred: loud | Actual: one
# Pred: court | Actual: back
# Pred: con | Actual: confirmation
# Pred: count | Actual: count
# Pred: sympathetic | Actual: sympathetic
# Pred: stomach | Actual: children
# Pred: beautiful | Actual: football
# Pred: unexpected | Actual: unemployed
# Pred: con | Actual: cancelled
# Pred: enthusiasm | Actual: enthusiastic
# Pred: beautiful | Actual: forward
# Pred: gallery | Actual: thorough
# Pred: re | Actual: recurring
# Pred: special | Actual: preliminary
# Pred: guaranteed | Actual: heightened
# Pred: dart | Actual: that
# Pred: miscellaneous | Actual: miscellaneous
# Pred: ? | Actual: trouble
# Pred: restaurant | Actual: recently
# Pred: refrigerator | Actual: ref
# Pred: answer | Actual: fought
# Pred: guarantee | Actual: guaranteed
# Pred: juice | Actual: would
# Pred: sure | Actual: road
# Pred: vacancy | Actual: en
# Pred: minimum | Actual: another
# Pred: dangerous | Actual: marble
# Pred: va | Actual: va
# Pred: comfortable | Actual: stomach
# Pred: juice | Actual: gorgeous
# Pred: negotiations | Actual: nearer
# Pred: beautiful | Actual: wearing
# Pred: sure | Actual: form
# Pred: magnificent | Actual: hydraulic
# Pred: anxiety | Actual: beneath
# Pred: sure | Actual: o
# Pred: answer | Actual: what
# Pred: er | Actual: dart
# Pred: answer | Actual: aunt
# Pred: loud | Actual: head
# Pred: comparatively | Actual: community
# Pred: unanimous | Actual: unanimous
# Pred: fascinating | Actual: fascinating
# Pred: definite | Actual: determined
# Pred: annum | Actual: dumb
# Pred: court | Actual: belt
# Pred: sure | Actual: hours
# Pred: determined | Actual: determined
# Pred: guarantee | Actual: i
# Pred: procedure | Actual: prologue
# Pred: occasionally | Actual: occasionally
# Pred: court | Actual: possess
# Pred: va | Actual: heard
# Pred: distinguished | Actual: disposal
# Pred: i | Actual: want
# Pred: con | Actual: conditions
# Pred: opposite | Actual: opposite
# Pred: beautiful | Actual: bulletin
# Pred: shaggy | Actual: signature
# Pred: con | Actual: count
# Pred: enthusiastic | Actual: eventually
# Pred: frightened | Actual: dinner
# Pred: answer | Actual: work
# Pred: approximately | Actual: approximate
# Pred: guarantee | Actual: guarantee
# Pred: opposite | Actual: acceptable
# Pred: sure | Actual: planets
# Pred: dangerous | Actual: che
# Pred: sat | Actual: sat
# Pred: competent | Actual: principle
# Pred: sympathetic | Actual: syrup
# Pred: temperature | Actual: vo
# Pred: there | Actual: take
# Pred: r | Actual: r
# Pred: satisfaction | Actual: sufficient
# Pred: answer | Actual: alumni
# Pred: sure | Actual: depth
# Pred: enthusiasm | Actual: bankruptcy
# Pred: sure | Actual: nothing
# Pred: ? | Actual: enough
# Pred: prejudice | Actual: prejudice
# Pred: answer | Actual: apple
# Pred: sure | Actual: deal
# Pred: sure | Actual: street
# Pred: suspicion | Actual: subterranean
# Pred: re | Actual: recognize
# Pred: loud | Actual: brought
# Pred: ? | Actual: cried
# Pred: answer | Actual: matter
# Pred: criticism | Actual: cricket
# Pred: initiation | Actual: initials
# Pred: court | Actual: dangerous
# Pred: attorneys | Actual: attorneys
# Pred: di | Actual: destination
# Pred: prejudice | Actual: prejudice
# Pred: fight | Actual: verse
# Pred: del | Actual: restaurant
# Pred: completion | Actual: commitment
# Pred: opposite | Actual: opposite
# Pred: cha | Actual: familiar
# Pred: sure | Actual: recommend
# Pred: affectionately | Actual: affectionately
# Pred: beautiful | Actual: repairs
# Pred: comfortable | Actual: alcohol
# Pred: miscellaneous | Actual: misery
# Pred: there | Actual: turned
# Pred: guarantee | Actual: peculiar
# Pred: beautiful | Actual: giggling
# Pred: court | Actual: ate
# Pred: ? | Actual: triumph
# Pred: initiation | Actual: engine
# Pred: court | Actual: pilot
# Pred: minimum | Actual: subterranean
# Pred: immediately | Actual: incident
# Pred: sufficiently | Actual: sufficiently
# Pred: sure | Actual: count
# Pred: court | Actual: children
# Pred: con | Actual: con
# Pred: surface | Actual: drunken
# Pred: con | Actual: sauce
# Pred: court | Actual: was
# Pred: beautiful | Actual: answer
# Pred: enthusiasm | Actual: enthusiasm
# Pred: women | Actual: as
# Pred: beautiful | Actual: became
# Pred: answer | Actual: association
# Pred: di | Actual: di
# Pred: definite | Actual: women
# Pred: un | Actual: un
# Pred: gallery | Actual: gallery
# Pred: actually | Actual: enthusiastic
# Pred: discretion | Actual: discretion
# Pred: refrigerator | Actual: refrigerator
# Pred: scarcely | Actual: scare
# Pred: recognition | Actual: reckon
# Pred: curiosity | Actual: curiosity
# Pred: annum | Actual: often
# Pred: completion | Actual: commissioning
# Pred: af | Actual: adequate
# Pred: va | Actual: obligation
# Pred: va | Actual: earth
# Pred: ridiculous | Actual: ridiculous
# Pred: comfortable | Actual: comfortable
# Pred: special | Actual: apple
# Pred: definite | Actual: single
# Pred: sure | Actual: heard
# Pred: answer | Actual: southern
# Pred: ? | Actual: calmed
# Pred: sure | Actual: week
# Pred: sure | Actual: late
# Pred: or | Actual: immediately
# Pred: gorgeous | Actual: gorgeous
# Pred: exhibition | Actual: exists
# Pred: er | Actual: various
# Pred: initiation | Actual: any
# Pred: anxious | Actual: away
# Pred: sure | Actual: scare
# Pred: sure | Actual: know
# Pred: court | Actual: potatoes
# Pred: con | Actual: con
# Pred: answer | Actual: arranged
# Pred: psychology | Actual: philosophy
# Pred: indefinitely | Actual: unfortunately
# Pred: tournament | Actual: prominent
# Pred: beautiful | Actual: supervisor
# Pred: infinite | Actual: injury
# Pred: tr | Actual: becoming
# Pred: af | Actual: hydraulic
# Pred: magnificent | Actual: transferred
# Pred: completion | Actual: competent
# Pred: sure | Actual: did
# Pred: court | Actual: swap
# Pred: frightened | Actual: to
# Pred: tr | Actual: tr
# Pred: court | Actual: committees
# Pred: southern | Actual: such
# Pred: prejudice | Actual: prejudice
# Pred: court | Actual: elbow
# Pred: curiosity | Actual: curious
# Pred: answer | Actual: sunk
# Pred: special | Actual: special
# Pred: initiation | Actual: cancellation
# Pred: beautiful | Actual: divide
# Pred: va | Actual: the
# Pred: sure | Actual: classrooms
# Pred: gorgeous | Actual: gorgeous
# Pred: poetry | Actual: scarcely
# Pred: dangerous | Actual: coarse
# Pred: orchestra | Actual: orchestra
# Pred: sure | Actual: solemn
# Pred: fight | Actual: last
# Pred: guarantee | Actual: rain
# Pred: exceptionally | Actual: especially
# Pred: unanimous | Actual: machine
# Pred: sure | Actual: representatives
# Pred: necessarily | Actual: customary
# Pred: friend | Actual: knife
# Pred: special | Actual: excel
# Pred: enthusiastic | Actual: cooperation
# Pred: procedure | Actual: centre
# Pred: virtues | Actual: virtue
# Pred: determined | Actual: determined
# Pred: sure | Actual: earth
# Pred: answer | Actual: talent
# Pred: immensely | Actual: imitation
# Pred: permanent | Actual: contract
# Pred: beautiful | Actual: doubtful
# Pred: or | Actual: cemetery
# Pred: re | Actual: relevant
# Pred: canvas | Actual: cannot
# Pred: inc | Actual: inc
# Pred: special | Actual: colonel
# Pred: sympathetic | Actual: edition
# Pred: discretion | Actual: discretion
# Pred: va | Actual: acquaintance
# Pred: exhibition | Actual: expected
# Pred: con | Actual: con
# Pred: ex | Actual: exquisite
# Pred: touched | Actual: tr
# Pred: psychology | Actual: metal
# Pred: economics | Actual: economical
# Pred: del | Actual: delicate
# Pred: eventually | Actual: actually
# Pred: loud | Actual: about
# Pred: stomach | Actual: tragedy
# Pred: beautiful | Actual: motor
# Pred: guarantee | Actual: del
# Pred: psychology | Actual: chemistry
# Pred: procedure | Actual: cult
# Pred: unanimous | Actual: unanimous
# Pred: con | Actual: comfortable
# Pred: turned | Actual: idea
# Pred: friend | Actual: walking
# Pred: viewed | Actual: ami
# Pred: psychology | Actual: psychology
# Pred: material | Actual: peculiar
# Pred: inc | Actual: inc
# Pred: incident | Actual: originally
# Pred: must | Actual: taken
# Pred: tournament | Actual: tournament
# Pred: af | Actual: af
# Pred: guarantee | Actual: guarantee
# Pred: del | Actual: irrelevant
# Pred: recognition | Actual: recognition
# Pred: answer | Actual: anxious
# Pred: court | Actual: forward
# Pred: court | Actual: prof
# Pred: recognition | Actual: residents
# Pred: ? | Actual: waiting
# Pred: annum | Actual: laughs
# Pred: material | Actual: however
# Pred: incident | Actual: originally
# Pred: women | Actual: slide
# Pred: guarantee | Actual: gal
# Pred: statistics | Actual: mathematics
# Pred: immediately | Actual: determined
# Pred: enthusiasm | Actual: enthusiastic
# Pred: sure | Actual: competent
# Pred: immediately | Actual: experience
# Pred: familiar | Actual: favour
# Pred: loud | Actual: lodge
# Pred: efficiency | Actual: equipped
# Pred: comfortable | Actual: distinguished
# Pred: specifically | Actual: specifically
# Pred: sorority | Actual: sorority
# Pred: you | Actual: being
# Pred: peculiar | Actual: peculiar
# Pred: immediately | Actual: immediately
# Pred: dangerous | Actual: tentacles
# Pred: beautiful | Actual: bungalow
# Pred: material | Actual: material
# Pred: sure | Actual: bridge
# Pred: poetry | Actual: colonel
# Pred: enthusiasm | Actual: enthusiastic
# Pred: prejudice | Actual: per
# Pred: enthusiasm | Actual: enthusiastic
# Pred: special | Actual: spare
# Pred: sure | Actual: heard
# Pred: fight | Actual: pledge
# Pred: biscuits | Actual: biscuits
# Pred: answer | Actual: answer
# Pred: ? | Actual: steering
# Pred: di | Actual: des
# Pred: va | Actual: financial
# Pred: stomach | Actual: removed
# Pred: successful | Actual: sufficient
# Pred: beautiful | Actual: truth
# Pred: material | Actual: apparently
# Pred: biscuits | Actual: biscuits
# Pred: surface | Actual: member
# Pred: destination | Actual: destination
# Pred: surface | Actual: furnace
# Pred: actually | Actual: ep
# Pred: opposite | Actual: mathematics
# Pred: acknowledging | Actual: acknowledge
# Pred: ? | Actual: staring
# Pred: refrigerator | Actual: punishment
# Pred: court | Actual: especially
# Pred: answer | Actual: about
# Pred: latest | Actual: minimum
# Pred: gallery | Actual: women
# Pred: guarantee | Actual: gauge
# Pred: destination | Actual: destination
# Pred: sure | Actual: form
# Pred: beautiful | Actual: biscuits
# Pred: st | Actual: statistics
# Pred: melancholy | Actual: decidedly
# Pred: remember | Actual: remembered
# Pred: cha | Actual: cha
# Pred: cha | Actual: similar
# Pred: beautiful | Actual: op
# Pred: answer | Actual: weight
# Pred: suspicion | Actual: suspicion
# Pred: answer | Actual: they
# Pred: curiosity | Actual: curious
# Pred: fundamental | Actual: fundamentally
# Pred: answer | Actual: fight
# Pred: beautiful | Actual: visited
# Pred: efficiency | Actual: equipped
# Pred: re | Actual: remember
# Pred: destination | Actual: di
# Pred: del | Actual: del
# Pred: answer | Actual: primitive
# Pred: turned | Actual: searched
# Pred: acc | Actual: circling
# Pred: miscellaneous | Actual: er
# Pred: r | Actual: re
# Pred: answer | Actual: kindergarten
# Pred: court | Actual: curtains
# Pred: sure | Actual: deer
# Pred: psychology | Actual: ski
# Pred: sure | Actual: faint
# Pred: stomach | Actual: surface
# Pred: count | Actual: negotiations
# Pred: stomach | Actual: structure
# Pred: pamphlets | Actual: pamphlets
# Pred: unanimous | Actual: unanimous
# Pred: guarantee | Actual: go
# Pred: enthusiasm | Actual: head
# Pred: annum | Actual: during
# Pred: acknowledging | Actual: establishing
# Pred: va | Actual: va
# Pred: competent | Actual: competent
# Pred: court | Actual: folk
# Pred: initiation | Actual: interpretations
# Pred: count | Actual: council
# Pred: beautiful | Actual: sorority
# Pred: beautiful | Actual: belief
# Pred: there | Actual: wait
# Pred: beautiful | Actual: back
# Pred: un | Actual: duplicate
# Pred: correspondence | Actual: coefficient
# Pred: must | Actual: back
# Pred: beautiful | Actual: because
# Pred: special | Actual: chemistry
# Pred: va | Actual: prior
# Pred: permanently | Actual: permanently
# Pred: dangerous | Actual: very
# Pred: economics | Actual: economic
# Pred: women | Actual: walk
# Pred: sympathetic | Actual: dip
# Pred: dangerous | Actual: pena
# Pred: answer | Actual: controls
# Pred: chop | Actual: who
# Pred: psychology | Actual: aero
# Pred: beautiful | Actual: date
# Pred: enthusiasm | Actual: enthusiasm
# Pred: beautiful | Actual: sheets
# Pred: beautiful | Actual: collateral
# Pred: psychology | Actual: physician
# Pred: answer | Actual: the
# Pred: anniversary | Actual: attorneys
# Pred: answer | Actual: valle
# Pred: con | Actual: constraints
# Pred: anxiety | Actual: anxiety
# Pred: suspicion | Actual: successes
# Pred: sure | Actual: chosen
# Pred: comfortable | Actual: loads
# Pred: va | Actual: alumni
# Pred: successful | Actual: succeeded
# Pred: turned | Actual: begun
# Pred: beautiful | Actual: with
# Pred: permanently | Actual: perpetual
# Pred: sure | Actual: groups
# Pred: economics | Actual: economic
# Pred: undoubtedly | Actual: certainly
# Pred: curiosity | Actual: conscious
# Pred: philosophy | Actual: ecstasy
# Pred: scheduled | Actual: sufficiently
# Pred: va | Actual: curious
# Pred: anniversary | Actual: anniversary
# Pred: va | Actual: orchestra
# Pred: beautiful | Actual: pastoral
# Pred: court | Actual: mystery
# Pred: af | Actual: specific
# Pred: beautiful | Actual: plan
# Pred: stomach | Actual: digging
# Pred: chop | Actual: pretend
# Pred: indefinite | Actual: indefinite
# Pred: friend | Actual: magnificent
# Pred: answer | Actual: pillow
# Pred: con | Actual: counsel
# Pred: sure | Actual: machine
# Pred: ridiculous | Actual: ridiculous
# Pred: negotiations | Actual: neighbours
# Pred: embarrassed | Actual: embarrassed
# Pred: special | Actual: scrambled
# Pred: recognition | Actual: re
# Pred: exhibition | Actual: exhibition
# Pred: sure | Actual: sound
# Pred: actually | Actual: industry
# Pred: who | Actual: on
# Pred: dart | Actual: dee
# Pred: immediately | Actual: immediately
# Pred: answer | Actual: knife
# Pred: special | Actual: spacecraft
# Pred: beautiful | Actual: tomorrow
# Accuracy: 0.1870
# Epoch 10, Average Loss: 5.7386
# Accuracy: 0.1875

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.26.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.26.1 (from python-Levenshtein)
#   Downloading levenshtein-0.26.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.26.1->python-Levenshtein)
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading python_Levenshtein-0.26.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.26.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 12.8 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 97.6 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.26.1 python-Levenshtein-0.26.1 rapidfuzz-3.12.1

# %%
class SpellingCorrector(nn.Module):
    def __init__(self, vocab_size, hidden_size=768):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')

        # Freeze BERT
        for param in self.bert.parameters():
            param.requires_grad = False

        # Character and n-gram embeddings
        self.char_embedding = nn.Embedding(vocab_size, 32)
        self.ngram_embedding = nn.Embedding(vocab_size, 32)
        self.edit_dist_embedding = nn.Embedding(10, 32)

        # Feature combination
        self.feature_combine = nn.Sequential(
            nn.Linear(hidden_size + 96, hidden_size),  # 96 = 32 * 3 (char + ngram + edit)
            nn.LayerNorm(hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1)
        )

        # BiGRU encoder
        self.encoder = nn.GRU(
            input_size=hidden_size,
            hidden_size=256,
            num_layers=2,
            bidirectional=True,
            batch_first=True,
            dropout=0.1
        )

        # Output layers
        self.output = nn.Sequential(
            nn.Linear(512, 256),
            nn.LayerNorm(256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, vocab_size)
        )

    def forward(self, input_ids, attention_mask, ngram_ids=None, edit_distances=None):
        # Get BERT embeddings
        with torch.no_grad():
            bert_output = self.bert(input_ids, attention_mask=attention_mask)[0]

        # Get character embeddings
        char_embeds = self.char_embedding(input_ids)
        char_embeds = torch.mean(char_embeds, dim=1)

        # Get n-gram embeddings
        if ngram_ids is not None:
            ngram_embeds = self.ngram_embedding(ngram_ids)
            ngram_embeds = torch.mean(ngram_embeds, dim=1)
        else:
            ngram_embeds = torch.zeros(input_ids.size(0), 32, device=input_ids.device)

        # Get edit distance embeddings
        if edit_distances is not None:
            edit_embeds = self.edit_dist_embedding(edit_distances)
        else:
            edit_embeds = torch.zeros(input_ids.size(0), 32, device=input_ids.device)

        # Get BERT sequence representation
        bert_pooled = torch.mean(bert_output * attention_mask.unsqueeze(-1), dim=1)

        # Combine all features
        combined = torch.cat([
            bert_pooled,
            char_embeds,
            ngram_embeds,
            edit_embeds
        ], dim=-1)

        # Process through feature combiner
        features = self.feature_combine(combined)
        features = features.unsqueeze(1).expand(-1, input_ids.size(1), -1)

        # Encode sequence
        encoded, _ = self.encoder(features)

        # Global average pooling
        pooled = torch.mean(encoded * attention_mask.unsqueeze(-1), dim=1)

        # Generate logits
        logits = self.output(pooled)

        return logits



import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from transformers import BertTokenizer, BertModel, get_linear_schedule_with_warmup
import json
from Levenshtein import distance  # You might need to install this: pip install python-Levenshtein

def get_char_ngrams(word, n=3):
    if len(word) < n:
        return [word]
    return [word[i:i+n] for i in range(len(word)-n+1)]

class SpellingDataset(Dataset):
    def __init__(self, spelling_dict, tokenizer, max_length=32):
        self.pairs = []
        for correct, misspellings in spelling_dict.items():
            # Get target token ID
            correct_id = tokenizer(
                correct,
                add_special_tokens=False,
                return_tensors='pt'
            )['input_ids'][0][0]

            for misspelling in misspellings:
                # Get character n-grams
                ngrams = get_char_ngrams(misspelling)
                # Convert to IDs, handling unknown tokens
                ngram_ids = []
                for ngram in ngrams:
                    try:
                        ngram_id = tokenizer.convert_tokens_to_ids(ngram)
                        ngram_ids.append(ngram_id)
                    except:
                        ngram_ids.append(0)

                # Pad ngram_ids
                ngram_ids = ngram_ids[:max_length]
                ngram_ids.extend([0] * (max_length - len(ngram_ids)))

                # Calculate edit distance
                edit_dist = min(distance(misspelling, correct), 9)

                self.pairs.append((
                    misspelling,
                    correct_id,
                    torch.tensor(ngram_ids),
                    edit_dist
                ))

        self.tokenizer = tokenizer
        self.max_length = max_length

    def __getitem__(self, idx):
        misspelling, correct_id, ngram_ids, edit_dist = self.pairs[idx]

        encoding = self.tokenizer(
            misspelling,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,
            return_tensors='pt'
        )

        return {
            'input_ids': encoding['input_ids'].squeeze(),
            'attention_mask': encoding['attention_mask'].squeeze(),
            'labels': torch.tensor(correct_id),
            'ngram_ids': ngram_ids,
            'edit_distances': torch.tensor(edit_dist)
        }

    def __len__(self):
        return len(self.pairs)



def train_and_evaluate(num_epochs=10, data_path='spelling_dictionary.json'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    with open(data_path, 'r') as f:
        spelling_dict = json.load(f)

    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = SpellingCorrector(tokenizer.vocab_size).to(device)

    dataset = SpellingDataset(spelling_dict, tokenizer, max_length=32)

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5, weight_decay=0.01)

    num_training_steps = num_epochs * len(train_loader)
    num_warmup_steps = num_training_steps // 10

    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=num_warmup_steps,
        num_training_steps=num_training_steps
    )

    best_accuracy = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            optimizer.zero_grad()
            output = model(
                batch['input_ids'],
                batch['attention_mask'],
                batch['ngram_ids'],
                batch['edit_distances']
            )

            loss = criterion(output, batch['labels'])

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
            optimizer.step()
            scheduler.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for batch in test_loader:
                batch = {k: v.to(device) for k, v in batch.items()}
                outputs = model(
                    batch['input_ids'],
                    batch['attention_mask'],
                    batch['ngram_ids'],
                    batch['edit_distances']
                )

                predictions = outputs.argmax(dim=-1)
                correct += (predictions == batch['labels']).sum().item()
                total += len(predictions)

                if epoch % 2 == 0:
                    for pred, actual in zip(predictions[:2], batch['labels'][:2]):
                        pred_text = tokenizer.decode([pred], skip_special_tokens=True)
                        actual_text = tokenizer.decode([actual], skip_special_tokens=True)
                        print(f"Pred: {pred_text} | Actual: {actual_text}")

        accuracy = correct / total
        print(f"Accuracy: {accuracy:.4f}")

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_spelling_corrector.pth')

    return model, tokenizer
model, tokenizer = train_and_evaluate(num_epochs=10, data_path= data_path)
# Out:
# Using device: cuda
# <ipython-input-29-1d32c0be43c4>:160: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'labels': torch.tensor(correct_id),
# Epoch 1, Average Loss: 9.9641
# Pred: facilities | Actual: comparatively
# Pred: con | Actual: schemes
# Pred: con | Actual: del
# Pred: facilities | Actual: tournament
# Pred: con | Actual: mysterious
# Pred: con | Actual: ruler
# Pred: con | Actual: violence
# Pred: facilities | Actual: ru
# Pred: con | Actual: memory
# Pred: facilities | Actual: un
# Pred: con | Actual: phase
# Pred: facilities | Actual: examination
# Pred: facilities | Actual: accommodations
# Pred: facilities | Actual: del
# Pred: con | Actual: rope
# Pred: con | Actual: city
# Pred: con | Actual: enjoy
# Pred: facilities | Actual: strategy
# Pred: con | Actual: altitude
# Pred: con | Actual: climb
# Pred: facilities | Actual: extraordinary
# Pred: facilities | Actual: expenditure
# Pred: facilities | Actual: criticism
# Pred: facilities | Actual: folk
# Pred: con | Actual: admitted
# Pred: con | Actual: who
# Pred: facilities | Actual: opposite
# Pred: facilities | Actual: acquaintance
# Pred: con | Actual: initiation
# Pred: con | Actual: material
# Pred: facilities | Actual: fundamental
# Pred: con | Actual: rough
# Pred: facilities | Actual: statistics
# Pred: con | Actual: advantage
# Pred: con | Actual: his
# Pred: con | Actual: brush
# Pred: con | Actual: row
# Pred: con | Actual: re
# Pred: facilities | Actual: millennium
# Pred: con | Actual: introduced
# Pred: facilities | Actual: referring
# Pred: con | Actual: never
# Pred: facilities | Actual: understood
# Pred: con | Actual: opposite
# Pred: facilities | Actual: facilities
# Pred: con | Actual: adjust
# Pred: facilities | Actual: fundamental
# Pred: con | Actual: restaurant
# Pred: facilities | Actual: recommendation
# Pred: con | Actual: favourite
# Pred: facilities | Actual: conscious
# Pred: facilities | Actual: miscellaneous
# Pred: facilities | Actual: grown
# Pred: con | Actual: content
# Pred: facilities | Actual: guaranteed
# Pred: facilities | Actual: customer
# Pred: facilities | Actual: station
# Pred: facilities | Actual: immediately
# Pred: con | Actual: army
# Pred: con | Actual: cher
# Pred: facilities | Actual: con
# Pred: facilities | Actual: anxiety
# Pred: facilities | Actual: ready
# Pred: facilities | Actual: indefinite
# Pred: con | Actual: leading
# Pred: con | Actual: sell
# Pred: con | Actual: enemies
# Pred: con | Actual: give
# Pred: con | Actual: now
# Pred: con | Actual: downstairs
# Pred: facilities | Actual: stopped
# Pred: facilities | Actual: determined
# Pred: con | Actual: beg
# Pred: facilities | Actual: auto
# Pred: con | Actual: definite
# Pred: con | Actual: dangerous
# Pred: con | Actual: lake
# Pred: facilities | Actual: specifically
# Pred: facilities | Actual: gallo
# Pred: facilities | Actual: melancholy
# Pred: con | Actual: to
# Pred: con | Actual: bankruptcy
# Pred: facilities | Actual: unfortunate
# Pred: con | Actual: scar
# Pred: facilities | Actual: adequate
# Pred: con | Actual: jam
# Pred: facilities | Actual: rain
# Pred: facilities | Actual: successful
# Pred: facilities | Actual: alumni
# Pred: con | Actual: scraping
# Pred: facilities | Actual: beautiful
# Pred: con | Actual: women
# Pred: con | Actual: unfortunate
# Pred: con | Actual: breathe
# Pred: facilities | Actual: resulting
# Pred: con | Actual: better
# Pred: facilities | Actual: destructive
# Pred: facilities | Actual: immigrant
# Pred: con | Actual: freezing
# Pred: con | Actual: led
# Pred: facilities | Actual: precision
# Pred: con | Actual: customer
# Pred: con | Actual: smell
# Pred: facilities | Actual: precision
# Pred: con | Actual: caught
# Pred: con | Actual: fight
# Pred: facilities | Actual: becoming
# Pred: facilities | Actual: undoubtedly
# Pred: con | Actual: conditions
# Pred: facilities | Actual: con
# Pred: con | Actual: lights
# Pred: facilities | Actual: successive
# Pred: con | Actual: log
# Pred: facilities | Actual: af
# Pred: con | Actual: want
# Pred: facilities | Actual: beautiful
# Pred: facilities | Actual: friends
# Pred: con | Actual: were
# Pred: con | Actual: of
# Pred: con | Actual: saying
# Pred: con | Actual: elementary
# Pred: con | Actual: patronage
# Pred: facilities | Actual: valley
# Pred: facilities | Actual: infinite
# Pred: facilities | Actual: ecstasy
# Pred: facilities | Actual: elementary
# Pred: facilities | Actual: head
# Pred: con | Actual: definitely
# Pred: facilities | Actual: seized
# Pred: con | Actual: bullying
# Pred: con | Actual: deep
# Pred: facilities | Actual: flag
# Pred: con | Actual: geometry
# Pred: con | Actual: primary
# Pred: facilities | Actual: bending
# Pred: facilities | Actual: accordance
# Pred: con | Actual: sauce
# Pred: facilities | Actual: wa
# Pred: con | Actual: grandpa
# Pred: facilities | Actual: amend
# Pred: facilities | Actual: decidedly
# Pred: facilities | Actual: sufficient
# Pred: facilities | Actual: soon
# Pred: con | Actual: poetry
# Pred: con | Actual: spiritual
# Pred: con | Actual: said
# Pred: con | Actual: street
# Pred: facilities | Actual: immediately
# Pred: facilities | Actual: necessarily
# Pred: facilities | Actual: tournament
# Pred: con | Actual: acknowledging
# Pred: con | Actual: various
# Pred: facilities | Actual: admitted
# Pred: facilities | Actual: convenient
# Pred: facilities | Actual: arrangements
# Pred: con | Actual: believe
# Pred: facilities | Actual: permanently
# Pred: con | Actual: edge
# Pred: con | Actual: quiet
# Pred: con | Actual: cemetery
# Pred: con | Actual: departure
# Pred: con | Actual: emission
# Pred: con | Actual: genius
# Pred: facilities | Actual: discussion
# Pred: facilities | Actual: disappointment
# Pred: facilities | Actual: innocent
# Pred: con | Actual: anxious
# Pred: con | Actual: here
# Pred: con | Actual: pretty
# Pred: facilities | Actual: says
# Pred: con | Actual: shaggy
# Pred: con | Actual: come
# Pred: con | Actual: even
# Pred: facilities | Actual: math
# Pred: con | Actual: imperial
# Pred: facilities | Actual: miscellaneous
# Pred: con | Actual: lo
# Pred: con | Actual: collects
# Pred: con | Actual: removed
# Pred: facilities | Actual: hydraulic
# Pred: con | Actual: would
# Pred: con | Actual: removed
# Pred: facilities | Actual: eliminate
# Pred: con | Actual: horn
# Pred: con | Actual: towel
# Pred: con | Actual: reporter
# Pred: con | Actual: surface
# Pred: con | Actual: bicycle
# Pred: facilities | Actual: un
# Pred: facilities | Actual: conception
# Pred: con | Actual: renew
# Pred: facilities | Actual: peculiar
# Pred: facilities | Actual: or
# Pred: facilities | Actual: suspicion
# Pred: facilities | Actual: customer
# Pred: con | Actual: talked
# Pred: con | Actual: potentially
# Pred: con | Actual: dangerous
# Pred: facilities | Actual: enthusiastic
# Pred: con | Actual: someone
# Pred: con | Actual: designed
# Pred: con | Actual: trial
# Pred: facilities | Actual: laboratory
# Pred: facilities | Actual: reckon
# Pred: facilities | Actual: precision
# Pred: facilities | Actual: permanently
# Pred: con | Actual: run
# Pred: con | Actual: dee
# Pred: facilities | Actual: alt
# Pred: con | Actual: leeds
# Pred: con | Actual: business
# Pred: facilities | Actual: consistent
# Pred: facilities | Actual: gauge
# Pred: con | Actual: melancholy
# Pred: facilities | Actual: acceptable
# Pred: con | Actual: wherever
# Pred: facilities | Actual: attempts
# Pred: con | Actual: perceive
# Pred: con | Actual: waist
# Pred: facilities | Actual: con
# Pred: facilities | Actual: miscellaneous
# Pred: facilities | Actual: spiritual
# Pred: facilities | Actual: fra
# Pred: facilities | Actual: negotiations
# Pred: con | Actual: hello
# Pred: facilities | Actual: imagination
# Pred: con | Actual: do
# Pred: con | Actual: open
# Pred: con | Actual: mono
# Pred: facilities | Actual: successful
# Pred: facilities | Actual: supplement
# Pred: con | Actual: weaken
# Pred: con | Actual: triumph
# Pred: facilities | Actual: facilities
# Pred: facilities | Actual: familiar
# Pred: con | Actual: noisy
# Pred: con | Actual: guided
# Pred: con | Actual: should
# Pred: con | Actual: agencies
# Pred: facilities | Actual: unsuccessfully
# Pred: facilities | Actual: politician
# Pred: facilities | Actual: exciting
# Pred: con | Actual: quality
# Pred: facilities | Actual: pilot
# Pred: con | Actual: capacity
# Pred: con | Actual: orchestra
# Pred: con | Actual: fin
# Pred: facilities | Actual: courtesy
# Pred: facilities | Actual: embrace
# Pred: facilities | Actual: peculiar
# Pred: facilities | Actual: pursuing
# Pred: con | Actual: bared
# Pred: con | Actual: fairly
# Pred: facilities | Actual: inc
# Pred: facilities | Actual: grateful
# Pred: facilities | Actual: fra
# Pred: facilities | Actual: dip
# Pred: facilities | Actual: basket
# Pred: facilities | Actual: supplement
# Pred: facilities | Actual: accustomed
# Pred: facilities | Actual: approximately
# Pred: con | Actual: answer
# Pred: con | Actual: of
# Pred: con | Actual: at
# Pred: facilities | Actual: seized
# Pred: con | Actual: cars
# Pred: facilities | Actual: dangerous
# Pred: facilities | Actual: symmetry
# Pred: con | Actual: material
# Pred: con | Actual: opened
# Pred: facilities | Actual: picturesque
# Pred: facilities | Actual: circling
# Pred: facilities | Actual: familiar
# Pred: facilities | Actual: scissors
# Pred: con | Actual: argument
# Pred: facilities | Actual: financial
# Pred: facilities | Actual: arch
# Pred: con | Actual: work
# Pred: con | Actual: recommendations
# Pred: facilities | Actual: fundamental
# Pred: facilities | Actual: vacuum
# Pred: con | Actual: grip
# Pred: facilities | Actual: pneumonia
# Pred: con | Actual: understanding
# Pred: facilities | Actual: possess
# Pred: con | Actual: leading
# Pred: facilities | Actual: r
# Pred: con | Actual: employer
# Pred: con | Actual: prepare
# Pred: con | Actual: anniversary
# Pred: con | Actual: what
# Pred: facilities | Actual: del
# Pred: con | Actual: truth
# Pred: con | Actual: think
# Pred: con | Actual: content
# Pred: con | Actual: rat
# Pred: con | Actual: anything
# Pred: con | Actual: reckon
# Pred: facilities | Actual: dangerous
# Pred: facilities | Actual: va
# Pred: con | Actual: temporarily
# Pred: facilities | Actual: temperature
# Pred: con | Actual: suits
# Pred: facilities | Actual: sorority
# Pred: facilities | Actual: surface
# Pred: con | Actual: mouth
# Pred: facilities | Actual: anxious
# Pred: con | Actual: happy
# Pred: con | Actual: regained
# Pred: con | Actual: refrigerator
# Pred: facilities | Actual: destination
# Pred: con | Actual: stomach
# Pred: facilities | Actual: privilege
# Pred: facilities | Actual: anniversary
# Pred: facilities | Actual: collateral
# Pred: con | Actual: colonel
# Pred: con | Actual: arrive
# Pred: facilities | Actual: break
# Pred: con | Actual: kindly
# Pred: con | Actual: eaten
# Pred: con | Actual: loud
# Pred: facilities | Actual: special
# Pred: facilities | Actual: miscellaneous
# Pred: con | Actual: regained
# Pred: con | Actual: children
# Pred: facilities | Actual: re
# Pred: con | Actual: are
# Pred: facilities | Actual: cl
# Pred: facilities | Actual: irresistible
# Pred: con | Actual: dial
# Pred: facilities | Actual: sat
# Pred: con | Actual: touched
# Pred: con | Actual: permanent
# Pred: con | Actual: glowed
# Pred: con | Actual: rain
# Pred: con | Actual: looks
# Pred: facilities | Actual: receiver
# Pred: con | Actual: pretend
# Pred: con | Actual: thin
# Pred: con | Actual: climbing
# Pred: facilities | Actual: apparent
# Pred: con | Actual: wanted
# Pred: facilities | Actual: re
# Pred: con | Actual: necessarily
# Pred: facilities | Actual: court
# Pred: facilities | Actual: beautiful
# Pred: facilities | Actual: especially
# Pred: con | Actual: give
# Pred: con | Actual: eliminate
# Pred: facilities | Actual: initials
# Pred: facilities | Actual: oxygen
# Pred: facilities | Actual: various
# Pred: con | Actual: vulgar
# Pred: con | Actual: ton
# Pred: facilities | Actual: attorneys
# Pred: con | Actual: ex
# Pred: facilities | Actual: unanimous
# Pred: con | Actual: fight
# Pred: facilities | Actual: gradually
# Pred: con | Actual: tied
# Pred: con | Actual: decidedly
# Pred: facilities | Actual: af
# Pred: con | Actual: glass
# Pred: facilities | Actual: end
# Pred: facilities | Actual: counsel
# Pred: con | Actual: wrote
# Pred: facilities | Actual: peculiar
# Pred: con | Actual: destination
# Pred: con | Actual: gem
# Pred: facilities | Actual: infinite
# Pred: facilities | Actual: agreement
# Pred: facilities | Actual: mechanical
# Pred: con | Actual: back
# Pred: con | Actual: accomplished
# Pred: facilities | Actual: job
# Pred: facilities | Actual: miscellaneous
# Pred: con | Actual: continent
# Pred: facilities | Actual: in
# Pred: con | Actual: about
# Pred: facilities | Actual: closely
# Pred: facilities | Actual: pro
# Pred: facilities | Actual: financially
# Pred: facilities | Actual: remembrance
# Pred: facilities | Actual: miscellaneous
# Pred: con | Actual: task
# Pred: facilities | Actual: conscious
# Pred: con | Actual: have
# Pred: con | Actual: berries
# Pred: facilities | Actual: re
# Pred: con | Actual: appropriate
# Pred: con | Actual: parent
# Pred: facilities | Actual: va
# Pred: con | Actual: divine
# Pred: con | Actual: broom
# Pred: facilities | Actual: created
# Pred: con | Actual: half
# Pred: facilities | Actual: pro
# Pred: con | Actual: ski
# Pred: con | Actual: his
# Pred: con | Actual: package
# Pred: con | Actual: scrambled
# Pred: facilities | Actual: psychology
# Pred: facilities | Actual: altitude
# Pred: facilities | Actual: high
# Pred: con | Actual: sometimes
# Pred: facilities | Actual: upon
# Pred: facilities | Actual: repairs
# Pred: con | Actual: wasn
# Pred: con | Actual: accident
# Pred: con | Actual: beneficial
# Pred: facilities | Actual: collateral
# Pred: facilities | Actual: re
# Pred: con | Actual: affection
# Pred: facilities | Actual: innocent
# Pred: con | Actual: phase
# Pred: facilities | Actual: telephone
# Pred: facilities | Actual: breakfast
# Pred: facilities | Actual: eliminated
# Pred: facilities | Actual: attorneys
# Pred: facilities | Actual: inaccessible
# Pred: facilities | Actual: refrigerator
# Pred: con | Actual: timing
# Pred: con | Actual: beneath
# Pred: con | Actual: gauge
# Pred: con | Actual: certainly
# Pred: facilities | Actual: another
# Pred: facilities | Actual: cemetery
# Pred: facilities | Actual: alt
# Pred: con | Actual: so
# Pred: facilities | Actual: tragedy
# Pred: con | Actual: analyze
# Pred: con | Actual: means
# Pred: facilities | Actual: specialization
# Pred: con | Actual: lost
# Pred: con | Actual: didn
# Pred: con | Actual: latest
# Pred: facilities | Actual: del
# Pred: facilities | Actual: annoyance
# Pred: con | Actual: pounding
# Pred: con | Actual: passenger
# Pred: facilities | Actual: fundamental
# Pred: facilities | Actual: sufficient
# Pred: facilities | Actual: persuade
# Pred: con | Actual: hydraulic
# Pred: facilities | Actual: recommend
# Pred: con | Actual: myself
# Pred: facilities | Actual: happily
# Pred: facilities | Actual: scheduled
# Pred: facilities | Actual: picturesque
# Pred: con | Actual: idea
# Pred: con | Actual: appear
# Pred: con | Actual: tr
# Pred: con | Actual: summary
# Pred: con | Actual: avoid
# Pred: con | Actual: laboratory
# Pred: con | Actual: peninsula
# Pred: facilities | Actual: miscellaneous
# Pred: con | Actual: toad
# Pred: facilities | Actual: scarcely
# Pred: con | Actual: mill
# Pred: facilities | Actual: accustomed
# Pred: con | Actual: chemistry
# Pred: con | Actual: immediately
# Pred: facilities | Actual: recognition
# Pred: facilities | Actual: structures
# Pred: facilities | Actual: everywhere
# Pred: con | Actual: beautiful
# Pred: facilities | Actual: preliminary
# Pred: facilities | Actual: pneumonia
# Pred: facilities | Actual: con
# Pred: con | Actual: mountainous
# Pred: facilities | Actual: affectionately
# Pred: facilities | Actual: effort
# Pred: facilities | Actual: necessarily
# Pred: con | Actual: specific
# Pred: con | Actual: thorough
# Pred: con | Actual: flag
# Pred: facilities | Actual: individual
# Pred: facilities | Actual: factor
# Pred: con | Actual: incident
# Pred: facilities | Actual: kindergarten
# Pred: con | Actual: cane
# Pred: con | Actual: courtyard
# Pred: con | Actual: would
# Pred: con | Actual: silhouette
# Pred: facilities | Actual: portuguese
# Pred: facilities | Actual: initials
# Pred: facilities | Actual: expenditure
# Pred: facilities | Actual: pamphlets
# Pred: con | Actual: dr
# Pred: con | Actual: acknowledge
# Pred: con | Actual: accident
# Pred: con | Actual: initials
# Pred: con | Actual: conscious
# Pred: facilities | Actual: affects
# Pred: facilities | Actual: table
# Pred: facilities | Actual: conscience
# Pred: con | Actual: helicopter
# Pred: facilities | Actual: enjoying
# Pred: facilities | Actual: gallery
# Pred: facilities | Actual: philosophical
# Pred: con | Actual: duly
# Accuracy: 0.0029
# Epoch 2, Average Loss: 8.2704
# Accuracy: 0.0061
# Epoch 3, Average Loss: 7.7491
# Pred: con | Actual: comparatively
# Pred: con | Actual: schemes
# Pred: con | Actual: del
# Pred: con | Actual: tournament
# Pred: con | Actual: mysterious
# Pred: con | Actual: ruler
# Pred: con | Actual: violence
# Pred: con | Actual: ru
# Pred: con | Actual: memory
# Pred: con | Actual: un
# Pred: con | Actual: phase
# Pred: con | Actual: examination
# Pred: con | Actual: accommodations
# Pred: con | Actual: del
# Pred: con | Actual: rope
# Pred: con | Actual: city
# Pred: con | Actual: enjoy
# Pred: con | Actual: strategy
# Pred: con | Actual: altitude
# Pred: con | Actual: climb
# Pred: con | Actual: extraordinary
# Pred: con | Actual: expenditure
# Pred: con | Actual: criticism
# Pred: con | Actual: folk
# Pred: con | Actual: admitted
# Pred: con | Actual: who
# Pred: con | Actual: opposite
# Pred: con | Actual: acquaintance
# Pred: con | Actual: initiation
# Pred: con | Actual: material
# Pred: con | Actual: fundamental
# Pred: con | Actual: rough
# Pred: con | Actual: statistics
# Pred: con | Actual: advantage
# Pred: con | Actual: his
# Pred: con | Actual: brush
# Pred: con | Actual: row
# Pred: con | Actual: re
# Pred: con | Actual: millennium
# Pred: con | Actual: introduced
# Pred: con | Actual: referring
# Pred: con | Actual: never
# Pred: con | Actual: understood
# Pred: con | Actual: opposite
# Pred: con | Actual: facilities
# Pred: con | Actual: adjust
# Pred: con | Actual: fundamental
# Pred: con | Actual: restaurant
# Pred: con | Actual: recommendation
# Pred: con | Actual: favourite
# Pred: con | Actual: conscious
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: grown
# Pred: con | Actual: content
# Pred: con | Actual: guaranteed
# Pred: con | Actual: customer
# Pred: con | Actual: station
# Pred: con | Actual: immediately
# Pred: con | Actual: army
# Pred: con | Actual: cher
# Pred: con | Actual: con
# Pred: con | Actual: anxiety
# Pred: con | Actual: ready
# Pred: con | Actual: indefinite
# Pred: con | Actual: leading
# Pred: con | Actual: sell
# Pred: con | Actual: enemies
# Pred: con | Actual: give
# Pred: con | Actual: now
# Pred: con | Actual: downstairs
# Pred: con | Actual: stopped
# Pred: con | Actual: determined
# Pred: con | Actual: beg
# Pred: con | Actual: auto
# Pred: con | Actual: definite
# Pred: con | Actual: dangerous
# Pred: con | Actual: lake
# Pred: con | Actual: specifically
# Pred: con | Actual: gallo
# Pred: con | Actual: melancholy
# Pred: con | Actual: to
# Pred: con | Actual: bankruptcy
# Pred: con | Actual: unfortunate
# Pred: con | Actual: scar
# Pred: con | Actual: adequate
# Pred: con | Actual: jam
# Pred: con | Actual: rain
# Pred: con | Actual: successful
# Pred: con | Actual: alumni
# Pred: con | Actual: scraping
# Pred: con | Actual: beautiful
# Pred: con | Actual: women
# Pred: con | Actual: unfortunate
# Pred: con | Actual: breathe
# Pred: con | Actual: resulting
# Pred: con | Actual: better
# Pred: con | Actual: destructive
# Pred: con | Actual: immigrant
# Pred: con | Actual: freezing
# Pred: con | Actual: led
# Pred: con | Actual: precision
# Pred: con | Actual: customer
# Pred: con | Actual: smell
# Pred: con | Actual: precision
# Pred: con | Actual: caught
# Pred: con | Actual: fight
# Pred: con | Actual: becoming
# Pred: con | Actual: undoubtedly
# Pred: con | Actual: conditions
# Pred: con | Actual: con
# Pred: con | Actual: lights
# Pred: con | Actual: successive
# Pred: con | Actual: log
# Pred: con | Actual: af
# Pred: con | Actual: want
# Pred: con | Actual: beautiful
# Pred: con | Actual: friends
# Pred: con | Actual: were
# Pred: con | Actual: of
# Pred: con | Actual: saying
# Pred: con | Actual: elementary
# Pred: con | Actual: patronage
# Pred: con | Actual: valley
# Pred: con | Actual: infinite
# Pred: con | Actual: ecstasy
# Pred: con | Actual: elementary
# Pred: con | Actual: head
# Pred: con | Actual: definitely
# Pred: con | Actual: seized
# Pred: con | Actual: bullying
# Pred: con | Actual: deep
# Pred: con | Actual: flag
# Pred: con | Actual: geometry
# Pred: con | Actual: primary
# Pred: con | Actual: bending
# Pred: con | Actual: accordance
# Pred: con | Actual: sauce
# Pred: con | Actual: wa
# Pred: con | Actual: grandpa
# Pred: con | Actual: amend
# Pred: con | Actual: decidedly
# Pred: con | Actual: sufficient
# Pred: con | Actual: soon
# Pred: con | Actual: poetry
# Pred: con | Actual: spiritual
# Pred: con | Actual: said
# Pred: con | Actual: street
# Pred: con | Actual: immediately
# Pred: con | Actual: necessarily
# Pred: con | Actual: tournament
# Pred: con | Actual: acknowledging
# Pred: con | Actual: various
# Pred: con | Actual: admitted
# Pred: con | Actual: convenient
# Pred: con | Actual: arrangements
# Pred: con | Actual: believe
# Pred: con | Actual: permanently
# Pred: con | Actual: edge
# Pred: con | Actual: quiet
# Pred: con | Actual: cemetery
# Pred: con | Actual: departure
# Pred: con | Actual: emission
# Pred: con | Actual: genius
# Pred: con | Actual: discussion
# Pred: con | Actual: disappointment
# Pred: con | Actual: innocent
# Pred: con | Actual: anxious
# Pred: con | Actual: here
# Pred: con | Actual: pretty
# Pred: con | Actual: says
# Pred: con | Actual: shaggy
# Pred: con | Actual: come
# Pred: con | Actual: even
# Pred: con | Actual: math
# Pred: con | Actual: imperial
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: lo
# Pred: con | Actual: collects
# Pred: con | Actual: removed
# Pred: con | Actual: hydraulic
# Pred: con | Actual: would
# Pred: con | Actual: removed
# Pred: con | Actual: eliminate
# Pred: con | Actual: horn
# Pred: con | Actual: towel
# Pred: con | Actual: reporter
# Pred: con | Actual: surface
# Pred: con | Actual: bicycle
# Pred: con | Actual: un
# Pred: con | Actual: conception
# Pred: con | Actual: renew
# Pred: con | Actual: peculiar
# Pred: con | Actual: or
# Pred: con | Actual: suspicion
# Pred: con | Actual: customer
# Pred: con | Actual: talked
# Pred: con | Actual: potentially
# Pred: con | Actual: dangerous
# Pred: con | Actual: enthusiastic
# Pred: con | Actual: someone
# Pred: con | Actual: designed
# Pred: con | Actual: trial
# Pred: con | Actual: laboratory
# Pred: con | Actual: reckon
# Pred: con | Actual: precision
# Pred: con | Actual: permanently
# Pred: con | Actual: run
# Pred: con | Actual: dee
# Pred: con | Actual: alt
# Pred: con | Actual: leeds
# Pred: con | Actual: business
# Pred: con | Actual: consistent
# Pred: con | Actual: gauge
# Pred: con | Actual: melancholy
# Pred: con | Actual: acceptable
# Pred: con | Actual: wherever
# Pred: con | Actual: attempts
# Pred: con | Actual: perceive
# Pred: con | Actual: waist
# Pred: con | Actual: con
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: spiritual
# Pred: con | Actual: fra
# Pred: con | Actual: negotiations
# Pred: con | Actual: hello
# Pred: con | Actual: imagination
# Pred: con | Actual: do
# Pred: con | Actual: open
# Pred: con | Actual: mono
# Pred: con | Actual: successful
# Pred: con | Actual: supplement
# Pred: con | Actual: weaken
# Pred: con | Actual: triumph
# Pred: con | Actual: facilities
# Pred: con | Actual: familiar
# Pred: con | Actual: noisy
# Pred: con | Actual: guided
# Pred: con | Actual: should
# Pred: con | Actual: agencies
# Pred: con | Actual: unsuccessfully
# Pred: con | Actual: politician
# Pred: con | Actual: exciting
# Pred: con | Actual: quality
# Pred: con | Actual: pilot
# Pred: con | Actual: capacity
# Pred: con | Actual: orchestra
# Pred: con | Actual: fin
# Pred: con | Actual: courtesy
# Pred: con | Actual: embrace
# Pred: con | Actual: peculiar
# Pred: con | Actual: pursuing
# Pred: con | Actual: bared
# Pred: con | Actual: fairly
# Pred: con | Actual: inc
# Pred: con | Actual: grateful
# Pred: con | Actual: fra
# Pred: con | Actual: dip
# Pred: con | Actual: basket
# Pred: con | Actual: supplement
# Pred: con | Actual: accustomed
# Pred: con | Actual: approximately
# Pred: con | Actual: answer
# Pred: con | Actual: of
# Pred: con | Actual: at
# Pred: con | Actual: seized
# Pred: con | Actual: cars
# Pred: con | Actual: dangerous
# Pred: con | Actual: symmetry
# Pred: con | Actual: material
# Pred: con | Actual: opened
# Pred: con | Actual: picturesque
# Pred: con | Actual: circling
# Pred: con | Actual: familiar
# Pred: con | Actual: scissors
# Pred: con | Actual: argument
# Pred: con | Actual: financial
# Pred: con | Actual: arch
# Pred: con | Actual: work
# Pred: con | Actual: recommendations
# Pred: con | Actual: fundamental
# Pred: con | Actual: vacuum
# Pred: con | Actual: grip
# Pred: con | Actual: pneumonia
# Pred: con | Actual: understanding
# Pred: con | Actual: possess
# Pred: con | Actual: leading
# Pred: con | Actual: r
# Pred: con | Actual: employer
# Pred: con | Actual: prepare
# Pred: con | Actual: anniversary
# Pred: con | Actual: what
# Pred: con | Actual: del
# Pred: con | Actual: truth
# Pred: con | Actual: think
# Pred: con | Actual: content
# Pred: con | Actual: rat
# Pred: con | Actual: anything
# Pred: con | Actual: reckon
# Pred: con | Actual: dangerous
# Pred: con | Actual: va
# Pred: con | Actual: temporarily
# Pred: con | Actual: temperature
# Pred: con | Actual: suits
# Pred: con | Actual: sorority
# Pred: con | Actual: surface
# Pred: con | Actual: mouth
# Pred: con | Actual: anxious
# Pred: con | Actual: happy
# Pred: con | Actual: regained
# Pred: con | Actual: refrigerator
# Pred: con | Actual: destination
# Pred: con | Actual: stomach
# Pred: con | Actual: privilege
# Pred: con | Actual: anniversary
# Pred: con | Actual: collateral
# Pred: con | Actual: colonel
# Pred: con | Actual: arrive
# Pred: con | Actual: break
# Pred: con | Actual: kindly
# Pred: con | Actual: eaten
# Pred: con | Actual: loud
# Pred: con | Actual: special
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: regained
# Pred: con | Actual: children
# Pred: con | Actual: re
# Pred: con | Actual: are
# Pred: con | Actual: cl
# Pred: con | Actual: irresistible
# Pred: con | Actual: dial
# Pred: con | Actual: sat
# Pred: con | Actual: touched
# Pred: con | Actual: permanent
# Pred: con | Actual: glowed
# Pred: con | Actual: rain
# Pred: con | Actual: looks
# Pred: con | Actual: receiver
# Pred: con | Actual: pretend
# Pred: con | Actual: thin
# Pred: con | Actual: climbing
# Pred: con | Actual: apparent
# Pred: con | Actual: wanted
# Pred: con | Actual: re
# Pred: con | Actual: necessarily
# Pred: con | Actual: court
# Pred: con | Actual: beautiful
# Pred: con | Actual: especially
# Pred: con | Actual: give
# Pred: con | Actual: eliminate
# Pred: con | Actual: initials
# Pred: con | Actual: oxygen
# Pred: con | Actual: various
# Pred: con | Actual: vulgar
# Pred: con | Actual: ton
# Pred: con | Actual: attorneys
# Pred: con | Actual: ex
# Pred: con | Actual: unanimous
# Pred: con | Actual: fight
# Pred: con | Actual: gradually
# Pred: con | Actual: tied
# Pred: con | Actual: decidedly
# Pred: con | Actual: af
# Pred: con | Actual: glass
# Pred: con | Actual: end
# Pred: con | Actual: counsel
# Pred: con | Actual: wrote
# Pred: con | Actual: peculiar
# Pred: con | Actual: destination
# Pred: con | Actual: gem
# Pred: con | Actual: infinite
# Pred: con | Actual: agreement
# Pred: con | Actual: mechanical
# Pred: con | Actual: back
# Pred: con | Actual: accomplished
# Pred: con | Actual: job
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: continent
# Pred: con | Actual: in
# Pred: con | Actual: about
# Pred: con | Actual: closely
# Pred: con | Actual: pro
# Pred: con | Actual: financially
# Pred: con | Actual: remembrance
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: task
# Pred: con | Actual: conscious
# Pred: con | Actual: have
# Pred: con | Actual: berries
# Pred: con | Actual: re
# Pred: con | Actual: appropriate
# Pred: con | Actual: parent
# Pred: con | Actual: va
# Pred: con | Actual: divine
# Pred: con | Actual: broom
# Pred: con | Actual: created
# Pred: con | Actual: half
# Pred: con | Actual: pro
# Pred: con | Actual: ski
# Pred: con | Actual: his
# Pred: con | Actual: package
# Pred: con | Actual: scrambled
# Pred: con | Actual: psychology
# Pred: con | Actual: altitude
# Pred: con | Actual: high
# Pred: con | Actual: sometimes
# Pred: con | Actual: upon
# Pred: con | Actual: repairs
# Pred: con | Actual: wasn
# Pred: con | Actual: accident
# Pred: con | Actual: beneficial
# Pred: con | Actual: collateral
# Pred: con | Actual: re
# Pred: con | Actual: affection
# Pred: con | Actual: innocent
# Pred: con | Actual: phase
# Pred: con | Actual: telephone
# Pred: con | Actual: breakfast
# Pred: con | Actual: eliminated
# Pred: con | Actual: attorneys
# Pred: con | Actual: inaccessible
# Pred: con | Actual: refrigerator
# Pred: con | Actual: timing
# Pred: con | Actual: beneath
# Pred: con | Actual: gauge
# Pred: con | Actual: certainly
# Pred: con | Actual: another
# Pred: con | Actual: cemetery
# Pred: con | Actual: alt
# Pred: con | Actual: so
# Pred: con | Actual: tragedy
# Pred: con | Actual: analyze
# Pred: con | Actual: means
# Pred: con | Actual: specialization
# Pred: con | Actual: lost
# Pred: con | Actual: didn
# Pred: con | Actual: latest
# Pred: con | Actual: del
# Pred: con | Actual: annoyance
# Pred: con | Actual: pounding
# Pred: con | Actual: passenger
# Pred: con | Actual: fundamental
# Pred: con | Actual: sufficient
# Pred: con | Actual: persuade
# Pred: con | Actual: hydraulic
# Pred: con | Actual: recommend
# Pred: con | Actual: myself
# Pred: con | Actual: happily
# Pred: con | Actual: scheduled
# Pred: con | Actual: picturesque
# Pred: con | Actual: idea
# Pred: con | Actual: appear
# Pred: con | Actual: tr
# Pred: con | Actual: summary
# Pred: con | Actual: avoid
# Pred: con | Actual: laboratory
# Pred: con | Actual: peninsula
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: toad
# Pred: con | Actual: scarcely
# Pred: con | Actual: mill
# Pred: con | Actual: accustomed
# Pred: con | Actual: chemistry
# Pred: con | Actual: immediately
# Pred: con | Actual: recognition
# Pred: con | Actual: structures
# Pred: con | Actual: everywhere
# Pred: con | Actual: beautiful
# Pred: con | Actual: preliminary
# Pred: con | Actual: pneumonia
# Pred: con | Actual: con
# Pred: con | Actual: mountainous
# Pred: con | Actual: affectionately
# Pred: con | Actual: effort
# Pred: con | Actual: necessarily
# Pred: con | Actual: specific
# Pred: con | Actual: thorough
# Pred: con | Actual: flag
# Pred: con | Actual: individual
# Pred: con | Actual: factor
# Pred: con | Actual: incident
# Pred: con | Actual: kindergarten
# Pred: con | Actual: cane
# Pred: con | Actual: courtyard
# Pred: con | Actual: would
# Pred: con | Actual: silhouette
# Pred: con | Actual: portuguese
# Pred: con | Actual: initials
# Pred: con | Actual: expenditure
# Pred: con | Actual: pamphlets
# Pred: con | Actual: dr
# Pred: con | Actual: acknowledge
# Pred: con | Actual: accident
# Pred: con | Actual: initials
# Pred: con | Actual: conscious
# Pred: con | Actual: affects
# Pred: con | Actual: table
# Pred: con | Actual: conscience
# Pred: con | Actual: helicopter
# Pred: con | Actual: enjoying
# Pred: con | Actual: gallery
# Pred: con | Actual: philosophical
# Pred: con | Actual: duly
# Accuracy: 0.0061
# Epoch 4, Average Loss: 7.5905
# Accuracy: 0.0061
# Epoch 5, Average Loss: 7.4981
# Pred: con | Actual: comparatively
# Pred: con | Actual: schemes
# Pred: con | Actual: del
# Pred: con | Actual: tournament
# Pred: con | Actual: mysterious
# Pred: con | Actual: ruler
# Pred: con | Actual: violence
# Pred: con | Actual: ru
# Pred: latest | Actual: memory
# Pred: con | Actual: un
# Pred: con | Actual: phase
# Pred: con | Actual: examination
# Pred: con | Actual: accommodations
# Pred: con | Actual: del
# Pred: latest | Actual: rope
# Pred: analysis | Actual: city
# Pred: con | Actual: enjoy
# Pred: con | Actual: strategy
# Pred: con | Actual: altitude
# Pred: latest | Actual: climb
# Pred: con | Actual: extraordinary
# Pred: con | Actual: expenditure
# Pred: con | Actual: criticism
# Pred: pneumonia | Actual: folk
# Pred: pneumonia | Actual: admitted
# Pred: poetry | Actual: who
# Pred: con | Actual: opposite
# Pred: con | Actual: acquaintance
# Pred: con | Actual: initiation
# Pred: con | Actual: material
# Pred: con | Actual: fundamental
# Pred: con | Actual: rough
# Pred: con | Actual: statistics
# Pred: con | Actual: advantage
# Pred: latest | Actual: his
# Pred: latest | Actual: brush
# Pred: latest | Actual: row
# Pred: con | Actual: re
# Pred: con | Actual: millennium
# Pred: con | Actual: introduced
# Pred: con | Actual: referring
# Pred: con | Actual: never
# Pred: con | Actual: understood
# Pred: con | Actual: opposite
# Pred: con | Actual: facilities
# Pred: latest | Actual: adjust
# Pred: con | Actual: fundamental
# Pred: con | Actual: restaurant
# Pred: con | Actual: recommendation
# Pred: con | Actual: favourite
# Pred: con | Actual: conscious
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: grown
# Pred: con | Actual: content
# Pred: con | Actual: guaranteed
# Pred: con | Actual: customer
# Pred: con | Actual: station
# Pred: con | Actual: immediately
# Pred: latest | Actual: army
# Pred: con | Actual: cher
# Pred: con | Actual: con
# Pred: con | Actual: anxiety
# Pred: con | Actual: ready
# Pred: con | Actual: indefinite
# Pred: con | Actual: leading
# Pred: latest | Actual: sell
# Pred: con | Actual: enemies
# Pred: con | Actual: give
# Pred: latest | Actual: now
# Pred: con | Actual: downstairs
# Pred: con | Actual: stopped
# Pred: con | Actual: determined
# Pred: latest | Actual: beg
# Pred: con | Actual: auto
# Pred: con | Actual: definite
# Pred: con | Actual: dangerous
# Pred: latest | Actual: lake
# Pred: con | Actual: specifically
# Pred: con | Actual: gallo
# Pred: con | Actual: melancholy
# Pred: con | Actual: to
# Pred: con | Actual: bankruptcy
# Pred: con | Actual: unfortunate
# Pred: latest | Actual: scar
# Pred: con | Actual: adequate
# Pred: latest | Actual: jam
# Pred: con | Actual: rain
# Pred: con | Actual: successful
# Pred: con | Actual: alumni
# Pred: answer | Actual: scraping
# Pred: con | Actual: beautiful
# Pred: con | Actual: women
# Pred: con | Actual: unfortunate
# Pred: latest | Actual: breathe
# Pred: con | Actual: resulting
# Pred: con | Actual: better
# Pred: con | Actual: destructive
# Pred: con | Actual: immigrant
# Pred: con | Actual: freezing
# Pred: con | Actual: led
# Pred: con | Actual: precision
# Pred: con | Actual: customer
# Pred: latest | Actual: smell
# Pred: con | Actual: precision
# Pred: con | Actual: caught
# Pred: con | Actual: fight
# Pred: con | Actual: becoming
# Pred: con | Actual: undoubtedly
# Pred: con | Actual: conditions
# Pred: con | Actual: con
# Pred: con | Actual: lights
# Pred: con | Actual: successive
# Pred: latest | Actual: log
# Pred: con | Actual: af
# Pred: con | Actual: want
# Pred: con | Actual: beautiful
# Pred: con | Actual: friends
# Pred: analysis | Actual: were
# Pred: con | Actual: of
# Pred: con | Actual: saying
# Pred: con | Actual: elementary
# Pred: con | Actual: patronage
# Pred: pneumonia | Actual: valley
# Pred: con | Actual: infinite
# Pred: con | Actual: ecstasy
# Pred: con | Actual: elementary
# Pred: con | Actual: head
# Pred: con | Actual: definitely
# Pred: con | Actual: seized
# Pred: answer | Actual: bullying
# Pred: latest | Actual: deep
# Pred: con | Actual: flag
# Pred: con | Actual: geometry
# Pred: con | Actual: primary
# Pred: con | Actual: bending
# Pred: con | Actual: accordance
# Pred: con | Actual: sauce
# Pred: pneumonia | Actual: wa
# Pred: answer | Actual: grandpa
# Pred: pneumonia | Actual: amend
# Pred: con | Actual: decidedly
# Pred: con | Actual: sufficient
# Pred: con | Actual: soon
# Pred: con | Actual: poetry
# Pred: con | Actual: spiritual
# Pred: con | Actual: said
# Pred: latest | Actual: street
# Pred: con | Actual: immediately
# Pred: con | Actual: necessarily
# Pred: con | Actual: tournament
# Pred: con | Actual: acknowledging
# Pred: con | Actual: various
# Pred: con | Actual: admitted
# Pred: con | Actual: convenient
# Pred: con | Actual: arrangements
# Pred: answer | Actual: believe
# Pred: con | Actual: permanently
# Pred: analysis | Actual: edge
# Pred: con | Actual: quiet
# Pred: con | Actual: cemetery
# Pred: con | Actual: departure
# Pred: pneumonia | Actual: emission
# Pred: con | Actual: genius
# Pred: con | Actual: discussion
# Pred: con | Actual: disappointment
# Pred: con | Actual: innocent
# Pred: con | Actual: anxious
# Pred: con | Actual: here
# Pred: pneumonia | Actual: pretty
# Pred: con | Actual: says
# Pred: con | Actual: shaggy
# Pred: analysis | Actual: come
# Pred: con | Actual: even
# Pred: con | Actual: math
# Pred: con | Actual: imperial
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: lo
# Pred: con | Actual: collects
# Pred: con | Actual: removed
# Pred: con | Actual: hydraulic
# Pred: con | Actual: would
# Pred: latest | Actual: removed
# Pred: con | Actual: eliminate
# Pred: latest | Actual: horn
# Pred: latest | Actual: towel
# Pred: con | Actual: reporter
# Pred: con | Actual: surface
# Pred: con | Actual: bicycle
# Pred: con | Actual: un
# Pred: con | Actual: conception
# Pred: con | Actual: renew
# Pred: con | Actual: peculiar
# Pred: con | Actual: or
# Pred: con | Actual: suspicion
# Pred: con | Actual: customer
# Pred: latest | Actual: talked
# Pred: pneumonia | Actual: potentially
# Pred: con | Actual: dangerous
# Pred: con | Actual: enthusiastic
# Pred: con | Actual: someone
# Pred: con | Actual: designed
# Pred: con | Actual: trial
# Pred: con | Actual: laboratory
# Pred: con | Actual: reckon
# Pred: con | Actual: precision
# Pred: con | Actual: permanently
# Pred: latest | Actual: run
# Pred: con | Actual: dee
# Pred: con | Actual: alt
# Pred: latest | Actual: leeds
# Pred: con | Actual: business
# Pred: con | Actual: consistent
# Pred: con | Actual: gauge
# Pred: con | Actual: melancholy
# Pred: con | Actual: acceptable
# Pred: pneumonia | Actual: wherever
# Pred: con | Actual: attempts
# Pred: con | Actual: perceive
# Pred: con | Actual: waist
# Pred: con | Actual: con
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: spiritual
# Pred: con | Actual: fra
# Pred: con | Actual: negotiations
# Pred: latest | Actual: hello
# Pred: con | Actual: imagination
# Pred: latest | Actual: do
# Pred: con | Actual: open
# Pred: con | Actual: mono
# Pred: con | Actual: successful
# Pred: con | Actual: supplement
# Pred: con | Actual: weaken
# Pred: con | Actual: triumph
# Pred: con | Actual: facilities
# Pred: con | Actual: familiar
# Pred: analysis | Actual: noisy
# Pred: con | Actual: guided
# Pred: con | Actual: should
# Pred: con | Actual: agencies
# Pred: con | Actual: unsuccessfully
# Pred: con | Actual: politician
# Pred: con | Actual: exciting
# Pred: con | Actual: quality
# Pred: con | Actual: pilot
# Pred: pneumonia | Actual: capacity
# Pred: con | Actual: orchestra
# Pred: pneumonia | Actual: fin
# Pred: con | Actual: courtesy
# Pred: con | Actual: embrace
# Pred: con | Actual: peculiar
# Pred: con | Actual: pursuing
# Pred: latest | Actual: bared
# Pred: latest | Actual: fairly
# Pred: con | Actual: inc
# Pred: con | Actual: grateful
# Pred: con | Actual: fra
# Pred: con | Actual: dip
# Pred: con | Actual: basket
# Pred: con | Actual: supplement
# Pred: con | Actual: accustomed
# Pred: con | Actual: approximately
# Pred: con | Actual: answer
# Pred: con | Actual: of
# Pred: latest | Actual: at
# Pred: con | Actual: seized
# Pred: latest | Actual: cars
# Pred: con | Actual: dangerous
# Pred: con | Actual: symmetry
# Pred: con | Actual: material
# Pred: con | Actual: opened
# Pred: con | Actual: picturesque
# Pred: con | Actual: circling
# Pred: con | Actual: familiar
# Pred: con | Actual: scissors
# Pred: con | Actual: argument
# Pred: pneumonia | Actual: financial
# Pred: con | Actual: arch
# Pred: con | Actual: work
# Pred: latest | Actual: recommendations
# Pred: con | Actual: fundamental
# Pred: pneumonia | Actual: vacuum
# Pred: latest | Actual: grip
# Pred: con | Actual: pneumonia
# Pred: con | Actual: understanding
# Pred: con | Actual: possess
# Pred: latest | Actual: leading
# Pred: con | Actual: r
# Pred: con | Actual: employer
# Pred: con | Actual: prepare
# Pred: con | Actual: anniversary
# Pred: analysis | Actual: what
# Pred: con | Actual: del
# Pred: pneumonia | Actual: truth
# Pred: latest | Actual: think
# Pred: pneumonia | Actual: content
# Pred: latest | Actual: rat
# Pred: pneumonia | Actual: anything
# Pred: con | Actual: reckon
# Pred: con | Actual: dangerous
# Pred: con | Actual: va
# Pred: con | Actual: temporarily
# Pred: con | Actual: temperature
# Pred: poetry | Actual: suits
# Pred: con | Actual: sorority
# Pred: con | Actual: surface
# Pred: latest | Actual: mouth
# Pred: con | Actual: anxious
# Pred: latest | Actual: happy
# Pred: con | Actual: regained
# Pred: con | Actual: refrigerator
# Pred: con | Actual: destination
# Pred: con | Actual: stomach
# Pred: con | Actual: privilege
# Pred: con | Actual: anniversary
# Pred: con | Actual: collateral
# Pred: con | Actual: colonel
# Pred: latest | Actual: arrive
# Pred: con | Actual: break
# Pred: latest | Actual: kindly
# Pred: latest | Actual: eaten
# Pred: con | Actual: loud
# Pred: con | Actual: special
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: regained
# Pred: pneumonia | Actual: children
# Pred: con | Actual: re
# Pred: con | Actual: are
# Pred: con | Actual: cl
# Pred: con | Actual: irresistible
# Pred: con | Actual: dial
# Pred: con | Actual: sat
# Pred: con | Actual: touched
# Pred: con | Actual: permanent
# Pred: con | Actual: glowed
# Pred: answer | Actual: rain
# Pred: answer | Actual: looks
# Pred: con | Actual: receiver
# Pred: con | Actual: pretend
# Pred: con | Actual: thin
# Pred: con | Actual: climbing
# Pred: pneumonia | Actual: apparent
# Pred: poetry | Actual: wanted
# Pred: con | Actual: re
# Pred: con | Actual: necessarily
# Pred: con | Actual: court
# Pred: con | Actual: beautiful
# Pred: con | Actual: especially
# Pred: latest | Actual: give
# Pred: con | Actual: eliminate
# Pred: con | Actual: initials
# Pred: con | Actual: oxygen
# Pred: con | Actual: various
# Pred: latest | Actual: vulgar
# Pred: con | Actual: ton
# Pred: con | Actual: attorneys
# Pred: con | Actual: ex
# Pred: con | Actual: unanimous
# Pred: con | Actual: fight
# Pred: con | Actual: gradually
# Pred: latest | Actual: tied
# Pred: con | Actual: decidedly
# Pred: con | Actual: af
# Pred: latest | Actual: glass
# Pred: con | Actual: end
# Pred: con | Actual: counsel
# Pred: con | Actual: wrote
# Pred: con | Actual: peculiar
# Pred: con | Actual: destination
# Pred: latest | Actual: gem
# Pred: con | Actual: infinite
# Pred: con | Actual: agreement
# Pred: con | Actual: mechanical
# Pred: con | Actual: back
# Pred: con | Actual: accomplished
# Pred: con | Actual: job
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: continent
# Pred: con | Actual: in
# Pred: con | Actual: about
# Pred: con | Actual: closely
# Pred: con | Actual: pro
# Pred: con | Actual: financially
# Pred: con | Actual: remembrance
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: task
# Pred: con | Actual: conscious
# Pred: con | Actual: have
# Pred: con | Actual: berries
# Pred: con | Actual: re
# Pred: con | Actual: appropriate
# Pred: pneumonia | Actual: parent
# Pred: con | Actual: va
# Pred: pneumonia | Actual: divine
# Pred: latest | Actual: broom
# Pred: con | Actual: created
# Pred: latest | Actual: half
# Pred: con | Actual: pro
# Pred: con | Actual: ski
# Pred: latest | Actual: his
# Pred: pneumonia | Actual: package
# Pred: con | Actual: scrambled
# Pred: con | Actual: psychology
# Pred: con | Actual: altitude
# Pred: pneumonia | Actual: high
# Pred: con | Actual: sometimes
# Pred: con | Actual: upon
# Pred: con | Actual: repairs
# Pred: latest | Actual: wasn
# Pred: con | Actual: accident
# Pred: con | Actual: beneficial
# Pred: con | Actual: collateral
# Pred: con | Actual: re
# Pred: con | Actual: affection
# Pred: con | Actual: innocent
# Pred: con | Actual: phase
# Pred: con | Actual: telephone
# Pred: con | Actual: breakfast
# Pred: pneumonia | Actual: eliminated
# Pred: con | Actual: attorneys
# Pred: con | Actual: inaccessible
# Pred: con | Actual: refrigerator
# Pred: latest | Actual: timing
# Pred: answer | Actual: beneath
# Pred: con | Actual: gauge
# Pred: con | Actual: certainly
# Pred: pneumonia | Actual: another
# Pred: con | Actual: cemetery
# Pred: con | Actual: alt
# Pred: con | Actual: so
# Pred: con | Actual: tragedy
# Pred: pneumonia | Actual: analyze
# Pred: latest | Actual: means
# Pred: con | Actual: specialization
# Pred: latest | Actual: lost
# Pred: con | Actual: didn
# Pred: con | Actual: latest
# Pred: con | Actual: del
# Pred: con | Actual: annoyance
# Pred: answer | Actual: pounding
# Pred: pneumonia | Actual: passenger
# Pred: con | Actual: fundamental
# Pred: con | Actual: sufficient
# Pred: con | Actual: persuade
# Pred: con | Actual: hydraulic
# Pred: con | Actual: recommend
# Pred: con | Actual: myself
# Pred: con | Actual: happily
# Pred: con | Actual: scheduled
# Pred: con | Actual: picturesque
# Pred: con | Actual: idea
# Pred: latest | Actual: appear
# Pred: con | Actual: tr
# Pred: pneumonia | Actual: summary
# Pred: latest | Actual: avoid
# Pred: con | Actual: laboratory
# Pred: con | Actual: peninsula
# Pred: con | Actual: miscellaneous
# Pred: latest | Actual: toad
# Pred: con | Actual: scarcely
# Pred: latest | Actual: mill
# Pred: con | Actual: accustomed
# Pred: con | Actual: chemistry
# Pred: con | Actual: immediately
# Pred: con | Actual: recognition
# Pred: con | Actual: structures
# Pred: con | Actual: everywhere
# Pred: con | Actual: beautiful
# Pred: con | Actual: preliminary
# Pred: con | Actual: pneumonia
# Pred: con | Actual: con
# Pred: con | Actual: mountainous
# Pred: con | Actual: affectionately
# Pred: pneumonia | Actual: effort
# Pred: con | Actual: necessarily
# Pred: con | Actual: specific
# Pred: con | Actual: thorough
# Pred: con | Actual: flag
# Pred: con | Actual: individual
# Pred: con | Actual: factor
# Pred: con | Actual: incident
# Pred: con | Actual: kindergarten
# Pred: latest | Actual: cane
# Pred: pneumonia | Actual: courtyard
# Pred: con | Actual: would
# Pred: con | Actual: silhouette
# Pred: con | Actual: portuguese
# Pred: con | Actual: initials
# Pred: con | Actual: expenditure
# Pred: con | Actual: pamphlets
# Pred: latest | Actual: dr
# Pred: con | Actual: acknowledge
# Pred: con | Actual: accident
# Pred: con | Actual: initials
# Pred: con | Actual: conscious
# Pred: pneumonia | Actual: affects
# Pred: pneumonia | Actual: table
# Pred: con | Actual: conscience
# Pred: con | Actual: helicopter
# Pred: con | Actual: enjoying
# Pred: con | Actual: gallery
# Pred: con | Actual: philosophical
# Pred: con | Actual: duly
# Accuracy: 0.0061
# Epoch 6, Average Loss: 7.4325
# Accuracy: 0.0071
# Epoch 7, Average Loss: 7.3721
# Pred: con | Actual: comparatively
# Pred: con | Actual: schemes
# Pred: con | Actual: del
# Pred: miscellaneous | Actual: tournament
# Pred: con | Actual: mysterious
# Pred: answer | Actual: ruler
# Pred: answer | Actual: violence
# Pred: con | Actual: ru
# Pred: answer | Actual: memory
# Pred: con | Actual: un
# Pred: answer | Actual: phase
# Pred: con | Actual: examination
# Pred: con | Actual: accommodations
# Pred: con | Actual: del
# Pred: answer | Actual: rope
# Pred: answer | Actual: city
# Pred: answer | Actual: enjoy
# Pred: con | Actual: strategy
# Pred: con | Actual: altitude
# Pred: answer | Actual: climb
# Pred: con | Actual: extraordinary
# Pred: con | Actual: expenditure
# Pred: con | Actual: criticism
# Pred: answer | Actual: folk
# Pred: answer | Actual: admitted
# Pred: answer | Actual: who
# Pred: con | Actual: opposite
# Pred: miscellaneous | Actual: acquaintance
# Pred: con | Actual: initiation
# Pred: answer | Actual: material
# Pred: con | Actual: fundamental
# Pred: answer | Actual: rough
# Pred: con | Actual: statistics
# Pred: con | Actual: advantage
# Pred: latest | Actual: his
# Pred: latest | Actual: brush
# Pred: latest | Actual: row
# Pred: con | Actual: re
# Pred: con | Actual: millennium
# Pred: con | Actual: introduced
# Pred: con | Actual: referring
# Pred: answer | Actual: never
# Pred: con | Actual: understood
# Pred: answer | Actual: opposite
# Pred: con | Actual: facilities
# Pred: answer | Actual: adjust
# Pred: con | Actual: fundamental
# Pred: con | Actual: restaurant
# Pred: con | Actual: recommendation
# Pred: con | Actual: favourite
# Pred: con | Actual: conscious
# Pred: con | Actual: miscellaneous
# Pred: answer | Actual: grown
# Pred: con | Actual: content
# Pred: con | Actual: guaranteed
# Pred: con | Actual: customer
# Pred: con | Actual: station
# Pred: con | Actual: immediately
# Pred: answer | Actual: army
# Pred: con | Actual: cher
# Pred: con | Actual: con
# Pred: con | Actual: anxiety
# Pred: con | Actual: ready
# Pred: con | Actual: indefinite
# Pred: answer | Actual: leading
# Pred: answer | Actual: sell
# Pred: con | Actual: enemies
# Pred: answer | Actual: give
# Pred: latest | Actual: now
# Pred: con | Actual: downstairs
# Pred: con | Actual: stopped
# Pred: con | Actual: determined
# Pred: answer | Actual: beg
# Pred: pneumonia | Actual: auto
# Pred: con | Actual: definite
# Pred: con | Actual: dangerous
# Pred: answer | Actual: lake
# Pred: con | Actual: specifically
# Pred: miscellaneous | Actual: gallo
# Pred: miscellaneous | Actual: melancholy
# Pred: answer | Actual: to
# Pred: con | Actual: bankruptcy
# Pred: con | Actual: unfortunate
# Pred: latest | Actual: scar
# Pred: con | Actual: adequate
# Pred: latest | Actual: jam
# Pred: con | Actual: rain
# Pred: con | Actual: successful
# Pred: con | Actual: alumni
# Pred: answer | Actual: scraping
# Pred: con | Actual: beautiful
# Pred: con | Actual: women
# Pred: con | Actual: unfortunate
# ...
# Pred: con | Actual: factor
# Pred: con | Actual: incident
# Pred: con | Actual: kindergarten
# Pred: latest | Actual: cane
# Pred: con | Actual: courtyard
# Pred: answer | Actual: would
# Pred: con | Actual: silhouette
# Pred: con | Actual: portuguese
# Pred: pneumonia | Actual: initials
# Pred: con | Actual: expenditure
# Pred: con | Actual: pamphlets
# Pred: answer | Actual: dr
# Pred: con | Actual: acknowledge
# Pred: con | Actual: accident
# Pred: con | Actual: initials
# Pred: con | Actual: conscious
# Pred: answer | Actual: affects
# Pred: answer | Actual: table
# Pred: con | Actual: conscience
# Pred: con | Actual: helicopter
# Pred: con | Actual: enjoying
# Pred: con | Actual: gallery
# Pred: con | Actual: philosophical
# Pred: con | Actual: duly
# Accuracy: 0.0081
# Epoch 8, Average Loss: 7.3240
# Accuracy: 0.0090
# Epoch 9, Average Loss: 7.2884
# Pred: con | Actual: comparatively
# Pred: beautiful | Actual: schemes
# Pred: answer | Actual: del
# Pred: miscellaneous | Actual: tournament
# Pred: con | Actual: mysterious
# Pred: answer | Actual: ruler
# Pred: con | Actual: violence
# Pred: con | Actual: ru
# Pred: answer | Actual: memory
# Pred: con | Actual: un
# Pred: answer | Actual: phase
# Pred: con | Actual: examination
# Pred: con | Actual: accommodations
# Pred: con | Actual: del
# Pred: answer | Actual: rope
# Pred: answer | Actual: city
# Pred: answer | Actual: enjoy
# Pred: con | Actual: strategy
# Pred: con | Actual: altitude
# Pred: answer | Actual: climb
# Pred: con | Actual: extraordinary
# Pred: con | Actual: expenditure
# Pred: con | Actual: criticism
# Pred: answer | Actual: folk
# Pred: answer | Actual: admitted
# Pred: answer | Actual: who
# Pred: answer | Actual: opposite
# Pred: miscellaneous | Actual: acquaintance
# Pred: con | Actual: initiation
# Pred: answer | Actual: material
# Pred: con | Actual: fundamental
# Pred: answer | Actual: rough
# Pred: miscellaneous | Actual: statistics
# Pred: con | Actual: advantage
# Pred: latest | Actual: his
# Pred: latest | Actual: brush
# Pred: latest | Actual: row
# Pred: con | Actual: re
# Pred: con | Actual: millennium
# Pred: con | Actual: introduced
# Pred: con | Actual: referring
# Pred: answer | Actual: never
# Pred: con | Actual: understood
# Pred: answer | Actual: opposite
# Pred: con | Actual: facilities
# Pred: answer | Actual: adjust
# Pred: con | Actual: fundamental
# Pred: con | Actual: restaurant
# Pred: con | Actual: recommendation
# Pred: con | Actual: favourite
# Pred: con | Actual: conscious
# Pred: con | Actual: miscellaneous
# Pred: answer | Actual: grown
# Pred: beautiful | Actual: content
# Pred: con | Actual: guaranteed
# Pred: con | Actual: customer
# Pred: con | Actual: station
# Pred: con | Actual: immediately
# Pred: latest | Actual: army
# Pred: con | Actual: cher
# Pred: con | Actual: con
# Pred: con | Actual: anxiety
# Pred: con | Actual: ready
# Pred: con | Actual: indefinite
# Pred: answer | Actual: leading
# Pred: answer | Actual: sell
# Pred: con | Actual: enemies
# Pred: answer | Actual: give
# Pred: latest | Actual: now
# Pred: con | Actual: downstairs
# Pred: con | Actual: stopped
# Pred: con | Actual: determined
# Pred: answer | Actual: beg
# Pred: con | Actual: auto
# Pred: con | Actual: definite
# Pred: answer | Actual: dangerous
# Pred: answer | Actual: lake
# Pred: con | Actual: specifically
# Pred: prejudice | Actual: gallo
# Pred: miscellaneous | Actual: melancholy
# Pred: answer | Actual: to
# Pred: con | Actual: bankruptcy
# Pred: con | Actual: unfortunate
# Pred: latest | Actual: scar
# Pred: con | Actual: adequate
# Pred: latest | Actual: jam
# Pred: con | Actual: rain
# Pred: con | Actual: successful
# Pred: con | Actual: alumni
# Pred: answer | Actual: scraping
# Pred: beautiful | Actual: beautiful
# Pred: answer | Actual: women
# Pred: con | Actual: unfortunate
# Pred: latest | Actual: breathe
# Pred: con | Actual: resulting
# Pred: answer | Actual: better
# Pred: con | Actual: destructive
# Pred: con | Actual: immigrant
# Pred: answer | Actual: freezing
# Pred: answer | Actual: led
# Pred: con | Actual: precision
# Pred: con | Actual: customer
# Pred: latest | Actual: smell
# Pred: prejudice | Actual: precision
# Pred: answer | Actual: caught
# Pred: answer | Actual: fight
# Pred: con | Actual: becoming
# Pred: con | Actual: undoubtedly
# Pred: miscellaneous | Actual: conditions
# Pred: con | Actual: con
# Pred: answer | Actual: lights
# Pred: con | Actual: successive
# Pred: answer | Actual: log
# Pred: beautiful | Actual: af
# Pred: answer | Actual: want
# Pred: con | Actual: beautiful
# Pred: answer | Actual: friends
# Pred: answer | Actual: were
# Pred: answer | Actual: of
# Pred: answer | Actual: saying
# Pred: con | Actual: elementary
# Pred: con | Actual: patronage
# Pred: answer | Actual: valley
# Pred: con | Actual: infinite
# Pred: miscellaneous | Actual: ecstasy
# Pred: con | Actual: elementary
# Pred: con | Actual: head
# Pred: con | Actual: definitely
# Pred: answer | Actual: seized
# Pred: answer | Actual: bullying
# Pred: answer | Actual: deep
# Pred: con | Actual: flag
# Pred: con | Actual: geometry
# Pred: answer | Actual: primary
# Pred: con | Actual: bending
# Pred: con | Actual: accordance
# Pred: answer | Actual: sauce
# Pred: answer | Actual: wa
# Pred: answer | Actual: grandpa
# Pred: answer | Actual: amend
# Pred: con | Actual: decidedly
# Pred: miscellaneous | Actual: sufficient
# Pred: beautiful | Actual: soon
# Pred: answer | Actual: poetry
# Pred: con | Actual: spiritual
# Pred: answer | Actual: said
# Pred: answer | Actual: street
# Pred: con | Actual: immediately
# Pred: con | Actual: necessarily
# Pred: con | Actual: tournament
# Pred: con | Actual: acknowledging
# Pred: answer | Actual: various
# Pred: con | Actual: admitted
# Pred: con | Actual: convenient
# Pred: con | Actual: arrangements
# Pred: answer | Actual: believe
# Pred: con | Actual: permanently
# Pred: answer | Actual: edge
# Pred: answer | Actual: quiet
# Pred: con | Actual: cemetery
# Pred: answer | Actual: departure
# Pred: answer | Actual: emission
# Pred: answer | Actual: genius
# Pred: con | Actual: discussion
# Pred: miscellaneous | Actual: disappointment
# Pred: con | Actual: innocent
# Pred: beautiful | Actual: anxious
# Pred: answer | Actual: here
# Pred: answer | Actual: pretty
# Pred: answer | Actual: says
# Pred: beautiful | Actual: shaggy
# Pred: answer | Actual: come
# Pred: answer | Actual: even
# Pred: con | Actual: math
# Pred: con | Actual: imperial
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: lo
# Pred: answer | Actual: collects
# Pred: answer | Actual: removed
# Pred: miscellaneous | Actual: hydraulic
# Pred: answer | Actual: would
# Pred: latest | Actual: removed
# Pred: con | Actual: eliminate
# Pred: latest | Actual: horn
# Pred: answer | Actual: towel
# Pred: answer | Actual: reporter
# Pred: con | Actual: surface
# Pred: con | Actual: bicycle
# Pred: con | Actual: un
# Pred: con | Actual: conception
# Pred: answer | Actual: renew
# Pred: con | Actual: peculiar
# Pred: con | Actual: or
# Pred: con | Actual: suspicion
# Pred: con | Actual: customer
# Pred: answer | Actual: talked
# Pred: con | Actual: potentially
# Pred: answer | Actual: dangerous
# Pred: con | Actual: enthusiastic
# Pred: answer | Actual: someone
# Pred: answer | Actual: designed
# Pred: answer | Actual: trial
# Pred: con | Actual: laboratory
# Pred: answer | Actual: reckon
# Pred: miscellaneous | Actual: precision
# Pred: con | Actual: permanently
# Pred: latest | Actual: run
# Pred: answer | Actual: dee
# Pred: con | Actual: alt
# Pred: answer | Actual: leeds
# Pred: answer | Actual: business
# Pred: con | Actual: consistent
# Pred: answer | Actual: gauge
# Pred: con | Actual: melancholy
# Pred: con | Actual: acceptable
# Pred: con | Actual: wherever
# Pred: con | Actual: attempts
# Pred: con | Actual: perceive
# Pred: answer | Actual: waist
# Pred: con | Actual: con
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: spiritual
# Pred: con | Actual: fra
# Pred: con | Actual: negotiations
# Pred: answer | Actual: hello
# Pred: con | Actual: imagination
# Pred: latest | Actual: do
# Pred: answer | Actual: open
# Pred: beautiful | Actual: mono
# Pred: con | Actual: successful
# Pred: con | Actual: supplement
# Pred: answer | Actual: weaken
# Pred: answer | Actual: triumph
# Pred: con | Actual: facilities
# Pred: beautiful | Actual: familiar
# Pred: answer | Actual: noisy
# Pred: beautiful | Actual: guided
# Pred: answer | Actual: should
# Pred: answer | Actual: agencies
# Pred: con | Actual: unsuccessfully
# Pred: con | Actual: politician
# Pred: con | Actual: exciting
# Pred: con | Actual: quality
# Pred: con | Actual: pilot
# Pred: answer | Actual: capacity
# Pred: con | Actual: orchestra
# Pred: answer | Actual: fin
# Pred: con | Actual: courtesy
# Pred: con | Actual: embrace
# Pred: con | Actual: peculiar
# Pred: con | Actual: pursuing
# Pred: latest | Actual: bared
# Pred: answer | Actual: fairly
# Pred: con | Actual: inc
# Pred: con | Actual: grateful
# Pred: con | Actual: fra
# Pred: con | Actual: dip
# Pred: con | Actual: basket
# Pred: miscellaneous | Actual: supplement
# Pred: con | Actual: accustomed
# Pred: con | Actual: approximately
# Pred: con | Actual: answer
# Pred: answer | Actual: of
# Pred: answer | Actual: at
# Pred: con | Actual: seized
# Pred: answer | Actual: cars
# Pred: miscellaneous | Actual: dangerous
# Pred: con | Actual: symmetry
# Pred: con | Actual: material
# Pred: answer | Actual: opened
# Pred: miscellaneous | Actual: picturesque
# Pred: beautiful | Actual: circling
# Pred: con | Actual: familiar
# Pred: con | Actual: scissors
# Pred: con | Actual: argument
# Pred: pneumonia | Actual: financial
# Pred: con | Actual: arch
# Pred: answer | Actual: work
# Pred: dangerous | Actual: recommendations
# Pred: con | Actual: fundamental
# Pred: answer | Actual: vacuum
# Pred: answer | Actual: grip
# Pred: con | Actual: pneumonia
# Pred: con | Actual: understanding
# Pred: con | Actual: possess
# Pred: answer | Actual: leading
# Pred: miscellaneous | Actual: r
# Pred: answer | Actual: employer
# Pred: answer | Actual: prepare
# Pred: con | Actual: anniversary
# Pred: answer | Actual: what
# Pred: con | Actual: del
# Pred: answer | Actual: truth
# Pred: latest | Actual: think
# Pred: answer | Actual: content
# Pred: answer | Actual: rat
# Pred: answer | Actual: anything
# Pred: answer | Actual: reckon
# Pred: con | Actual: dangerous
# Pred: con | Actual: va
# Pred: con | Actual: temporarily
# Pred: con | Actual: temperature
# Pred: answer | Actual: suits
# Pred: con | Actual: sorority
# Pred: con | Actual: surface
# Pred: latest | Actual: mouth
# Pred: con | Actual: anxious
# Pred: answer | Actual: happy
# Pred: answer | Actual: regained
# Pred: con | Actual: refrigerator
# Pred: con | Actual: destination
# Pred: answer | Actual: stomach
# Pred: con | Actual: privilege
# Pred: miscellaneous | Actual: anniversary
# Pred: con | Actual: collateral
# Pred: answer | Actual: colonel
# Pred: answer | Actual: arrive
# Pred: con | Actual: break
# Pred: answer | Actual: kindly
# Pred: latest | Actual: eaten
# Pred: answer | Actual: loud
# Pred: answer | Actual: special
# Pred: miscellaneous | Actual: miscellaneous
# Pred: answer | Actual: regained
# Pred: answer | Actual: children
# Pred: con | Actual: re
# Pred: answer | Actual: are
# Pred: special | Actual: cl
# Pred: miscellaneous | Actual: irresistible
# Pred: answer | Actual: dial
# Pred: con | Actual: sat
# Pred: answer | Actual: touched
# Pred: con | Actual: permanent
# Pred: answer | Actual: glowed
# Pred: answer | Actual: rain
# Pred: answer | Actual: looks
# Pred: con | Actual: receiver
# Pred: answer | Actual: pretend
# Pred: answer | Actual: thin
# Pred: answer | Actual: climbing
# Pred: answer | Actual: apparent
# Pred: answer | Actual: wanted
# Pred: con | Actual: re
# Pred: con | Actual: necessarily
# Pred: con | Actual: court
# Pred: con | Actual: beautiful
# Pred: con | Actual: especially
# Pred: answer | Actual: give
# Pred: answer | Actual: eliminate
# Pred: con | Actual: initials
# Pred: con | Actual: oxygen
# Pred: answer | Actual: various
# Pred: answer | Actual: vulgar
# Pred: con | Actual: ton
# Pred: con | Actual: attorneys
# Pred: con | Actual: ex
# Pred: con | Actual: unanimous
# Pred: answer | Actual: fight
# Pred: con | Actual: gradually
# Pred: answer | Actual: tied
# Pred: con | Actual: decidedly
# Pred: con | Actual: af
# Pred: latest | Actual: glass
# Pred: beautiful | Actual: end
# Pred: con | Actual: counsel
# Pred: answer | Actual: wrote
# Pred: con | Actual: peculiar
# Pred: beautiful | Actual: destination
# Pred: latest | Actual: gem
# Pred: answer | Actual: infinite
# Pred: con | Actual: agreement
# Pred: con | Actual: mechanical
# Pred: answer | Actual: back
# Pred: con | Actual: accomplished
# Pred: con | Actual: job
# Pred: con | Actual: miscellaneous
# Pred: con | Actual: continent
# Pred: con | Actual: in
# Pred: answer | Actual: about
# Pred: answer | Actual: closely
# Pred: con | Actual: pro
# Pred: beautiful | Actual: financially
# Pred: con | Actual: remembrance
# Pred: con | Actual: miscellaneous
# Pred: answer | Actual: task
# Pred: con | Actual: conscious
# Pred: answer | Actual: have
# Pred: answer | Actual: berries
# Pred: beautiful | Actual: re
# Pred: con | Actual: appropriate
# Pred: answer | Actual: parent
# Pred: miscellaneous | Actual: va
# Pred: answer | Actual: divine
# Pred: latest | Actual: broom
# Pred: con | Actual: created
# Pred: answer | Actual: half
# Pred: con | Actual: pro
# Pred: con | Actual: ski
# Pred: answer | Actual: his
# Pred: answer | Actual: package
# Pred: con | Actual: scrambled
# Pred: miscellaneous | Actual: psychology
# Pred: answer | Actual: altitude
# Pred: answer | Actual: high
# Pred: con | Actual: sometimes
# Pred: beautiful | Actual: upon
# Pred: answer | Actual: repairs
# Pred: answer | Actual: wasn
# Pred: con | Actual: accident
# Pred: con | Actual: beneficial
# Pred: miscellaneous | Actual: collateral
# Pred: con | Actual: re
# Pred: con | Actual: affection
# Pred: con | Actual: innocent
# Pred: answer | Actual: phase
# Pred: con | Actual: telephone
# Pred: con | Actual: breakfast
# Pred: answer | Actual: eliminated
# Pred: con | Actual: attorneys
# Pred: con | Actual: inaccessible
# Pred: con | Actual: refrigerator
# Pred: answer | Actual: timing
# Pred: answer | Actual: beneath
# Pred: answer | Actual: gauge
# Pred: con | Actual: certainly
# Pred: answer | Actual: another
# Pred: con | Actual: cemetery
# Pred: con | Actual: alt
# Pred: answer | Actual: so
# Pred: con | Actual: tragedy
# Pred: answer | Actual: analyze
# Pred: latest | Actual: means
# Pred: con | Actual: specialization
# Pred: answer | Actual: lost
# Pred: answer | Actual: didn
# Pred: answer | Actual: latest
# Pred: con | Actual: del
# Pred: con | Actual: annoyance
# Pred: answer | Actual: pounding
# Pred: answer | Actual: passenger
# Pred: con | Actual: fundamental
# Pred: con | Actual: sufficient
# Pred: con | Actual: persuade
# Pred: con | Actual: hydraulic
# Pred: con | Actual: recommend
# Pred: con | Actual: myself
# Pred: answer | Actual: happily
# Pred: con | Actual: scheduled
# Pred: con | Actual: picturesque
# Pred: answer | Actual: idea
# Pred: answer | Actual: appear
# Pred: answer | Actual: tr
# Pred: answer | Actual: summary
# Pred: answer | Actual: avoid
# Pred: con | Actual: laboratory
# Pred: con | Actual: peninsula
# Pred: con | Actual: miscellaneous
# Pred: answer | Actual: toad
# Pred: con | Actual: scarcely
# Pred: latest | Actual: mill
# Pred: con | Actual: accustomed
# Pred: con | Actual: chemistry
# Pred: con | Actual: immediately
# Pred: con | Actual: recognition
# Pred: con | Actual: structures
# Pred: con | Actual: everywhere
# Pred: answer | Actual: beautiful
# Pred: miscellaneous | Actual: preliminary
# Pred: con | Actual: pneumonia
# Pred: con | Actual: con
# Pred: con | Actual: mountainous
# Pred: con | Actual: affectionately
# Pred: answer | Actual: effort
# Pred: con | Actual: necessarily
# Pred: con | Actual: specific
# Pred: con | Actual: thorough
# Pred: con | Actual: flag
# Pred: con | Actual: individual
# Pred: con | Actual: factor
# Pred: con | Actual: incident
# Pred: con | Actual: kindergarten
# Pred: latest | Actual: cane
# Pred: con | Actual: courtyard
# Pred: answer | Actual: would
# Pred: con | Actual: silhouette
# Pred: con | Actual: portuguese
# Pred: pneumonia | Actual: initials
# Pred: con | Actual: expenditure
# Pred: con | Actual: pamphlets
# Pred: answer | Actual: dr
# Pred: con | Actual: acknowledge
# Pred: con | Actual: accident
# Pred: con | Actual: initials
# Pred: con | Actual: conscious
# Pred: answer | Actual: affects
# Pred: answer | Actual: table
# Pred: con | Actual: conscience
# Pred: con | Actual: helicopter
# Pred: con | Actual: enjoying
# Pred: special | Actual: gallery
# Pred: con | Actual: philosophical
# Pred: con | Actual: duly
# Accuracy: 0.0096
# Epoch 10, Average Loss: 7.2691
# Accuracy: 0.0096

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from transformers import BertTokenizer, BertModel
import json

class SpellingDataset(Dataset):
    def __init__(self, spelling_dict, tokenizer, max_length=32):
        self.pairs = []
        for correct, misspellings in spelling_dict.items():
            # Convert correct word to token IDs
            correct_encoding = tokenizer(
                correct,
                padding='max_length',
                max_length=max_length,
                truncation=True,
                add_special_tokens=False,
                return_tensors='pt'
            )

            for misspelling in misspellings:
                self.pairs.append((misspelling, correct))

        self.tokenizer = tokenizer
        self.max_length = max_length

    def __getitem__(self, idx):
        misspelling, correct = self.pairs[idx]

        # Encode misspelling
        misspelling_encoding = self.tokenizer(
            misspelling,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,
            return_tensors='pt'
        )

        # Encode correct word
        correct_encoding = self.tokenizer(
            correct,
            padding='max_length',
            max_length=self.max_length,
            truncation=True,
            add_special_tokens=False,
            return_tensors='pt'
        )

        return {
            'input_ids': misspelling_encoding['input_ids'].squeeze(),
            'attention_mask': misspelling_encoding['attention_mask'].squeeze(),
            'labels': correct_encoding['input_ids'].squeeze()
        }

    def __len__(self):
        return len(self.pairs)

class SpellingCorrector(nn.Module):
    def __init__(self, vocab_size, hidden_size=768):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')

        # Freeze BERT parameters
        for param in self.bert.parameters():
            param.requires_grad = False

        # Simple GRU decoder
        self.decoder = nn.GRU(
            input_size=hidden_size,
            hidden_size=hidden_size,
            num_layers=1,
            batch_first=True
        )

        # Output projection
        self.output = nn.Linear(hidden_size, vocab_size)

    def forward(self, input_ids, attention_mask):
        # Get BERT embeddings
        bert_output = self.bert(input_ids, attention_mask=attention_mask)[0]

        # Decode
        decoded, _ = self.decoder(bert_output)

        # Project to vocabulary
        logits = self.output(decoded)

        return logits

def train_and_evaluate(num_epochs=10, data_path='spelling_dictionary.json'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Load data
    with open(data_path, 'r') as f:
        spelling_dict = json.load(f)

    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = SpellingCorrector(tokenizer.vocab_size).to(device)

    # Create dataset
    dataset = SpellingDataset(spelling_dict, tokenizer)

    # Split dataset
    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=16)

    # Training setup
    criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    best_accuracy = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for batch in train_loader:
            batch = {k: v.to(device) for k, v in batch.items()}

            optimizer.zero_grad()
            output = model(batch['input_ids'], batch['attention_mask'])

            # Reshape for loss calculation
            loss = criterion(
                output.view(-1, tokenizer.vocab_size),
                batch['labels'].view(-1)
            )

            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

        # Evaluate
        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for batch in test_loader:
                batch = {k: v.to(device) for k, v in batch.items()}
                outputs = model(batch['input_ids'], batch['attention_mask'])

                # Only compare first token for accuracy
                predictions = outputs[:, 0].argmax(dim=-1)
                correct += (predictions == batch['labels'][:, 0]).sum().item()
                total += len(predictions)

                # Print examples
                if epoch % 2 == 0:
                    for pred, actual in zip(predictions[:2], batch['labels'][:2]):
                        pred_text = tokenizer.decode([pred], skip_special_tokens=True)
                        actual_text = tokenizer.decode([actual[0]], skip_special_tokens=True)
                        print(f"Pred: {pred_text} | Actual: {actual_text}")

        accuracy = correct / total
        print(f"Accuracy: {accuracy:.4f}")

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_spelling_corrector.pth')

    return model, tokenizer

# Example usage:
# model, tokenizer = train_and_evaluate(num_epochs=10, data_path='your_spelling_dictionary.json')

model, tokenizer = train_and_evaluate(num_epochs=10, data_path= data_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# Pred: destination | Actual: temporarily
# Pred: magnificent | Actual: rainy
# Pred: magnificent | Actual: phase
# Pred: inc | Actual: inc
# Pred: inc | Actual: opportunities
# Pred: guarantee | Actual: happy
# Pred: magnificent | Actual: punishment
# Pred: inc | Actual: attorneys
# Pred: magnificent | Actual: anything
# Pred: miscellaneous | Actual: thin
# Pred: miscellaneous | Actual: extraordinary
# Pred: magnificent | Actual: pilot
# Pred: inc | Actual: sneaking
# Pred: enthusiasm | Actual: phase
# Pred: inc | Actual: as
# Pred: magnificent | Actual: genius
# Pred: guarantee | Actual: referring
# Pred: con | Actual: cancelled
# Pred: enthusiasm | Actual: una
# Pred: magnificent | Actual: driven
# Pred: magnificent | Actual: special
# Pred: con | Actual: exhibition
# Pred: enthusiasm | Actual: sometimes
# Pred: enthusiasm | Actual: thousand
# Pred: magnificent | Actual: organization
# Pred: con | Actual: playground
# Pred: enthusiasm | Actual: accompaniment
# Pred: unanimous | Actual: bird
# Pred: magnificent | Actual: procedure
# Pred: guarantee | Actual: get
# Pred: enthusiasm | Actual: sufficient
# Pred: magnificent | Actual: guardian
# Pred: enthusiasm | Actual: surrounds
# Pred: magnificent | Actual: precision
# Pred: enthusiasm | Actual: altitude
# Pred: miscellaneous | Actual: haven
# Pred: miscellaneous | Actual: above
# Pred: magnificent | Actual: material
# Pred: enthusiasm | Actual: customer
# Pred: especially | Actual: severely
# Pred: inc | Actual: responsible
# Pred: enthusiasm | Actual: want
# Pred: magnificent | Actual: called
# Pred: un | Actual: unconstitutional
# Pred: magnificent | Actual: old
# Pred: miscellaneous | Actual: brought
# Pred: special | Actual: de
# Pred: inc | Actual: ex
# Pred: enthusiasm | Actual: perceive
# Pred: con | Actual: conditions
# Pred: enthusiasm | Actual: our
# Pred: inc | Actual: disappointing
# Pred: guarantee | Actual: chop
# Pred: re | Actual: peculiar
# Pred: enthusiasm | Actual: apparatus
# Pred: special | Actual: thorough
# Pred: magnificent | Actual: although
# Pred: inc | Actual: pneumonia
# Pred: con | Actual: convenient
# Pred: enthusiasm | Actual: recommendation
# Pred: magnificent | Actual: satisfaction
# Pred: guarantee | Actual: admitted
# Pred: guarantee | Actual: gallery
# Pred: miscellaneous | Actual: broke
# Pred: miscellaneous | Actual: miscellaneous
# Pred: enthusiasm | Actual: vo
# Pred: magnificent | Actual: magnificent
# Pred: magnificent | Actual: scarcely
# Pred: con | Actual: having
# Pred: con | Actual: being
# Pred: guarantee | Actual: hang
# Pred: miscellaneous | Actual: grateful
# Pred: magnificent | Actual: noticeable
# Pred: magnificent | Actual: dun
# Pred: con | Actual: cramped
# Pred: miscellaneous | Actual: originally
# Pred: magnificent | Actual: recently
# Pred: un | Actual: unusually
# Pred: answer | Actual: grip
# Pred: con | Actual: experience
# Pred: miscellaneous | Actual: infinite
# Pred: enthusiasm | Actual: efficiency
# Pred: guarantee | Actual: life
# Pred: magnificent | Actual: juice
# Pred: enthusiasm | Actual: diamond
# Pred: con | Actual: ridiculous
# Pred: enthusiasm | Actual: destination
# Pred: magnificent | Actual: peculiar
# Pred: destination | Actual: story
# Pred: inc | Actual: permanently
# Pred: magnificent | Actual: folk
# Pred: magnificent | Actual: sac
# Pred: magnificent | Actual: knife
# Pred: magnificent | Actual: bulletin
# Pred: magnificent | Actual: harassed
# Pred: con | Actual: dart
# Pred: beautiful | Actual: hoarse
# Pred: inc | Actual: st
# Pred: magnificent | Actual: rating
# Pred: magnificent | Actual: from
# Pred: magnificent | Actual: sympathetic
# Pred: con | Actual: conscious
# Pred: magnificent | Actual: traffic
# Pred: enthusiasm | Actual: above
# Pred: guarantee | Actual: guarantee
# Pred: special | Actual: splendid
# Pred: miscellaneous | Actual: semi
# Pred: magnificent | Actual: pack
# Pred: magnificent | Actual: thorough
# Pred: answer | Actual: coach
# Pred: va | Actual: vacancy
# Pred: magnificent | Actual: gallo
# Pred: beautiful | Actual: goodbye
# Pred: con | Actual: refrigerator
# Pred: answer | Actual: army
# Pred: enthusiasm | Actual: enthusiastic
# Pred: inc | Actual: inc
# Pred: magnificent | Actual: always
# Pred: enthusiasm | Actual: health
# Pred: enthusiasm | Actual: approximate
# Pred: miscellaneous | Actual: fruit
# Pred: inc | Actual: employ
# Pred: inc | Actual: refrigerator
# Pred: magnificent | Actual: bureaucracy
# Pred: enthusiasm | Actual: melancholy
# Pred: enthusiasm | Actual: surplus
# Pred: enthusiasm | Actual: wonderful
# Pred: magnificent | Actual: st
# Pred: guarantee | Actual: sank
# Pred: familiar | Actual: peculiar
# Pred: enthusiasm | Actual: suffering
# Pred: enthusiasm | Actual: type
# Pred: guarantee | Actual: knew
# Pred: magnificent | Actual: ami
# Pred: con | Actual: di
# Pred: miscellaneous | Actual: sore
# Pred: magnificent | Actual: mechanical
# Pred: magnificent | Actual: customary
# Pred: enthusiasm | Actual: anniversary
# Pred: guarantee | Actual: back
# Pred: psychology | Actual: children
# Pred: con | Actual: cancelled
# Pred: answer | Actual: searched
# Pred: con | Actual: sorority
# Pred: enthusiasm | Actual: occurrence
# Pred: re | Actual: license
# Pred: enthusiasm | Actual: removed
# Pred: re | Actual: recommendation
# Pred: magnificent | Actual: flag
# Pred: magnificent | Actual: appropriate
# Pred: inc | Actual: greatly
# Pred: miscellaneous | Actual: got
# Pred: magnificent | Actual: documents
# Pred: magnificent | Actual: lots
# Pred: inc | Actual: inc
# Pred: con | Actual: conscience
# Pred: especially | Actual: jewelry
# Pred: miscellaneous | Actual: or
# Pred: enthusiasm | Actual: sometimes
# Pred: con | Actual: convenient
# Pred: inc | Actual: inc
# Pred: magnificent | Actual: suspicion
# Pred: special | Actual: spare
# Pred: con | Actual: i
# Pred: magnificent | Actual: mathematics
# Pred: magnificent | Actual: reckon
# Pred: enthusiasm | Actual: gallo
# Pred: enthusiasm | Actual: tragedy
# Pred: guarantee | Actual: af
# Pred: magnificent | Actual: pamphlet
# Pred: magnificent | Actual: military
# Pred: guarantee | Actual: aunt
# Pred: prejudice | Actual: precision
# Pred: con | Actual: con
# Pred: con | Actual: recommended
# Pred: guarantee | Actual: va
# Pred: con | Actual: received
# Pred: answer | Actual: inaccessible
# Pred: magnificent | Actual: reminded
# Pred: magnificent | Actual: discarded
# Pred: enthusiasm | Actual: anniversary
# Pred: miscellaneous | Actual: sank
# Pred: inc | Actual: incident
# Pred: magnificent | Actual: hydraulic
# Pred: enthusiasm | Actual: cemetery
# Pred: enthusiasm | Actual: diagonal
# Pred: magnificent | Actual: auditorium
# Pred: court | Actual: departure
# Pred: con | Actual: dark
# Pred: miscellaneous | Actual: worst
# Pred: guarantee | Actual: re
# Pred: magnificent | Actual: besides
# Pred: special | Actual: special
# Pred: court | Actual: ins
# Pred: destination | Actual: break
# Pred: answer | Actual: beautiful
# Pred: familiar | Actual: melancholy
# Pred: magnificent | Actual: magnificent
# Pred: magnificent | Actual: forward
# Pred: enthusiasm | Actual: frog
# Pred: con | Actual: calling
# Pred: guarantee | Actual: several
# Pred: inc | Actual: rule
# Pred: magnificent | Actual: attempts
# Pred: magnificent | Actual: certainly
# Pred: enthusiasm | Actual: talked
# Pred: con | Actual: continuous
# Pred: special | Actual: train
# Pred: con | Actual: auditorium
# Pred: enthusiasm | Actual: financially
# Pred: magnificent | Actual: guardian
# Pred: miscellaneous | Actual: circling
# Pred: magnificent | Actual: branches
# Pred: inc | Actual: pneumonia
# Pred: enthusiasm | Actual: anniversary
# Pred: magnificent | Actual: rather
# Pred: inc | Actual: opera
# Pred: miscellaneous | Actual: economical
# Pred: magnificent | Actual: on
# Pred: enthusiasm | Actual: belief
# Pred: guarantee | Actual: biscuits
# Pred: unanimous | Actual: unanimous
# Pred: enthusiasm | Actual: definitely
# Pred: magnificent | Actual: congratulations
# Pred: con | Actual: confusing
# Pred: magnificent | Actual: home
# Pred: con | Actual: conscience
# Pred: enthusiasm | Actual: discretion
# Pred: enthusiasm | Actual: conscious
# Pred: guarantee | Actual: scream
# Pred: magnificent | Actual: mysterious
# Pred: con | Actual: cheaper
# Pred: con | Actual: transferred
# Pred: enthusiasm | Actual: writing
# Pred: guarantee | Actual: wholly
# Pred: magnificent | Actual: orchestra
# Pred: answer | Actual: quickly
# Pred: re | Actual: request
# Pred: miscellaneous | Actual: can
# Pred: magnificent | Actual: accident
# Pred: con | Actual: communicate
# Pred: enthusiasm | Actual: any
# Pred: enthusiasm | Actual: un
# Pred: miscellaneous | Actual: triumph
# Pred: re | Actual: recommendations
# Pred: con | Actual: accomplished
# Pred: con | Actual: lid
# Pred: especially | Actual: equipped
# Pred: enthusiasm | Actual: item
# Pred: miscellaneous | Actual: playing
# Pred: magnificent | Actual: bungalow
# Pred: guarantee | Actual: league
# Pred: con | Actual: con
# Pred: guarantee | Actual: teachers
# Pred: enthusiasm | Actual: medicine
# Pred: magnificent | Actual: luke
# Pred: magnificent | Actual: dining
# Pred: guarantee | Actual: guarantee
# Pred: magnificent | Actual: succession
# Pred: answer | Actual: beautiful
# Pred: answer | Actual: want
# Pred: miscellaneous | Actual: possess
# Pred: con | Actual: curiosity
# Pred: enthusiasm | Actual: poems
# Pred: miscellaneous | Actual: pneumonia
# Pred: miscellaneous | Actual: col
# Pred: magnificent | Actual: got
# Pred: guarantee | Actual: touched
# Pred: magnificent | Actual: pamphlet
# Pred: magnificent | Actual: poly
# Pred: magnificent | Actual: vacancy
# Pred: court | Actual: bulletin
# Pred: enthusiasm | Actual: road
# Pred: inc | Actual: amount
# Pred: enthusiasm | Actual: argument
# Pred: guarantee | Actual: del
# Pred: miscellaneous | Actual: technical
# Pred: psychology | Actual: peculiar
# Pred: psychology | Actual: cancellation
# Pred: magnificent | Actual: planning
# Pred: enthusiasm | Actual: enthusiasm
# Pred: inc | Actual: fire
# Pred: con | Actual: gone
# Pred: immediately | Actual: as
# Pred: miscellaneous | Actual: deny
# Pred: con | Actual: dangerous
# Pred: miscellaneous | Actual: sauce
# Pred: prejudice | Actual: auditorium
# Pred: miscellaneous | Actual: banquet
# Pred: prejudice | Actual: facilities
# Pred: guarantee | Actual: looks
# Pred: guarantee | Actual: around
# Pred: con | Actual: content
# Pred: enthusiasm | Actual: item
# Pred: con | Actual: fra
# Pred: magnificent | Actual: to
# Pred: con | Actual: congress
# Pred: magnificent | Actual: latest
# Pred: unanimous | Actual: north
# Pred: magnificent | Actual: approximately
# Pred: inc | Actual: disappeared
# Pred: enthusiasm | Actual: unexpected
# Pred: con | Actual: important
# Pred: enthusiasm | Actual: significant
# Pred: familiar | Actual: approximate
# Pred: prejudice | Actual: mates
# Pred: magnificent | Actual: scheduled
# Pred: magnificent | Actual: to
# Pred: enthusiasm | Actual: certainly
# Pred: guarantee | Actual: guaranteed
# Pred: con | Actual: unanimous
# Pred: con | Actual: dissatisfaction
# Pred: enthusiasm | Actual: enthusiastic
# Pred: prejudice | Actual: undoubtedly
# Pred: miscellaneous | Actual: techniques
# Pred: enthusiasm | Actual: virtues
# Pred: magnificent | Actual: satisfaction
# Pred: enthusiasm | Actual: dear
# Pred: inc | Actual: understand
# Pred: magnificent | Actual: shook
# Pred: special | Actual: climb
# Pred: inc | Actual: occasionally
# Pred: enthusiasm | Actual: distinguished
# Pred: prejudice | Actual: pre
# Pred: answer | Actual: even
# Pred: enthusiasm | Actual: departure
# Pred: miscellaneous | Actual: specific
# Pred: prejudice | Actual: pretend
# Pred: enthusiasm | Actual: guarantee
# Pred: answer | Actual: court
# Pred: con | Actual: pilot
# Pred: con | Actual: dodged
# Pred: inc | Actual: recommended
# Pred: enthusiasm | Actual: cord
# Pred: magnificent | Actual: mathematics
# Pred: magnificent | Actual: guardian
# Pred: enthusiasm | Actual: del
# Pred: un | Actual: inevitable
# Pred: magnificent | Actual: magnificent
# Pred: magnificent | Actual: gallo
# Pred: guarantee | Actual: who
# Pred: enthusiasm | Actual: permanent
# Pred: magnificent | Actual: loud
# Pred: miscellaneous | Actual: establishing
# Pred: miscellaneous | Actual: express
# Pred: magnificent | Actual: soon
# Pred: magnificent | Actual: pilot
# Pred: enthusiasm | Actual: unfortunate
# Pred: miscellaneous | Actual: done
# Pred: magnificent | Actual: stars
# Pred: enthusiasm | Actual: stomach
# Pred: guarantee | Actual: sauce
# Pred: magnificent | Actual: satisfaction
# Pred: enthusiasm | Actual: tendency
# Pred: enthusiasm | Actual: appreciate
# Pred: con | Actual: radius
# Pred: beautiful | Actual: dangerous
# Pred: psychology | Actual: statistics
# Pred: economics | Actual: attach
# Pred: miscellaneous | Actual: extant
# Pred: magnificent | Actual: getting
# Pred: magnificent | Actual: juicy
# Pred: prejudice | Actual: court
# Pred: magnificent | Actual: nurse
# Pred: magnificent | Actual: mountainous
# Pred: con | Actual: wear
# Pred: miscellaneous | Actual: once
# Pred: enthusiasm | Actual: actually
# Pred: guarantee | Actual: item
# Pred: guarantee | Actual: help
# Pred: magnificent | Actual: every
# Pred: enthusiasm | Actual: exhibition
# Pred: guarantee | Actual: occasionally
# Pred: inc | Actual: applied
# Pred: magnificent | Actual: prefer
# Pred: guarantee | Actual: gallo
# Pred: inc | Actual: indefinitely
# Pred: guarantee | Actual: damaged
# Pred: inc | Actual: photograph
# Pred: enthusiasm | Actual: temporary
# Pred: guarantee | Actual: ruler
# Pred: guarantee | Actual: court
# Pred: prejudice | Actual: prejudice
# Pred: guarantee | Actual: definite
# Pred: enthusiasm | Actual: familiar
# Pred: miscellaneous | Actual: worry
# Pred: magnificent | Actual: everyone
# Pred: magnificent | Actual: water
# Pred: miscellaneous | Actual: chop
# Pred: magnificent | Actual: comparatively
# Pred: enthusiasm | Actual: annum
# Pred: guarantee | Actual: cord
# Pred: answer | Actual: approaching
# Pred: magnificent | Actual: apparatus
# Pred: enthusiasm | Actual: spiritual
# Pred: enthusiasm | Actual: enlightenment
# Pred: guarantee | Actual: give
# Pred: magnificent | Actual: when
# Pred: magnificent | Actual: dart
# Pred: miscellaneous | Actual: temperature
# Pred: inc | Actual: successful
# Pred: con | Actual: common
# Pred: magnificent | Actual: ill
# Pred: inc | Actual: opportunity
# Pred: answer | Actual: miscellaneous
# Pred: inc | Actual: inaccessible
# Pred: miscellaneous | Actual: appreciate
# Pred: magnificent | Actual: whistling
# Pred: magnificent | Actual: strange
# Pred: magnificent | Actual: beneath
# Pred: con | Actual: enthusiastic
# Pred: inc | Actual: competent
# Pred: con | Actual: visited
# Pred: inc | Actual: proceedings
# Pred: enthusiasm | Actual: correspondence
# Pred: magnificent | Actual: signature
# Pred: magnificent | Actual: kindergarten
# Pred: prejudice | Actual: accident
# Pred: con | Actual: dec
# Pred: magnificent | Actual: signature
# Pred: magnificent | Actual: virtues
# Pred: con | Actual: glorious
# Pred: answer | Actual: have
# Pred: magnificent | Actual: h
# Pred: unanimous | Actual: intellectual
# Pred: court | Actual: courtesy
# Pred: guarantee | Actual: really
# Pred: guarantee | Actual: festival
# Pred: familiar | Actual: car
# Pred: magnificent | Actual: special
# Pred: magnificent | Actual: actually
# Pred: magnificent | Actual: equally
# Pred: guarantee | Actual: scissors
# Pred: magnificent | Actual: think
# Pred: prejudice | Actual: precision
# Pred: con | Actual: embarrassed
# Pred: magnificent | Actual: technically
# Pred: enthusiasm | Actual: pilot
# Pred: guarantee | Actual: fire
# Pred: curtains | Actual: servant
# Pred: magnificent | Actual: job
# Pred: miscellaneous | Actual: guarantee
# Pred: miscellaneous | Actual: worth
# Pred: miscellaneous | Actual: accommodation
# Pred: magnificent | Actual: vi
# Pred: miscellaneous | Actual: marriage
# Pred: magnificent | Actual: miracle
# Pred: enthusiasm | Actual: stomach
# Pred: magnificent | Actual: type
# Pred: magnificent | Actual: count
# Pred: magnificent | Actual: privilege
# Pred: con | Actual: girlfriend
# Pred: guarantee | Actual: answer
# Pred: enthusiasm | Actual: visit
# Pred: magnificent | Actual: af
# Pred: guarantee | Actual: guarantee
# Pred: miscellaneous | Actual: pilot
# Pred: enthusiasm | Actual: van
# Pred: magnificent | Actual: correspondence
# Pred: unanimous | Actual: originally
# Pred: inc | Actual: sun
# Pred: magnificent | Actual: fork
# Pred: answer | Actual: apple
# Pred: magnificent | Actual: was
# Pred: enthusiasm | Actual: curtains
# Pred: con | Actual: not
# Pred: answer | Actual: unusually
# Pred: con | Actual: playing
# Pred: enthusiasm | Actual: recognition
# Pred: magnificent | Actual: die
# Pred: con | Actual: indefinite
# Pred: enthusiasm | Actual: anniversary
# Pred: destination | Actual: formed
# Pred: re | Actual: recommendations
# Pred: con | Actual: experience
# Pred: magnificent | Actual: financial
# Pred: magnificent | Actual: audrey
# Pred: magnificent | Actual: turned
# Pred: magnificent | Actual: challenge
# Pred: inc | Actual: noted
# Pred: magnificent | Actual: region
# Pred: magnificent | Actual: suspicion
# Pred: enthusiasm | Actual: annoyance
# Pred: enthusiasm | Actual: noisy
# Pred: familiar | Actual: specimens
# Pred: answer | Actual: for
# Pred: magnificent | Actual: sound
# Pred: inc | Actual: adequate
# Pred: enthusiasm | Actual: remember
# Pred: enthusiasm | Actual: holiday
# Pred: magnificent | Actual: special
# Pred: curtains | Actual: feed
# Pred: guarantee | Actual: neck
# Pred: magnificent | Actual: picturesque
# Pred: inc | Actual: ind
# Pred: magnificent | Actual: dart
# Pred: guarantee | Actual: guard
# Pred: guarantee | Actual: con
# Pred: magnificent | Actual: compelled
# Pred: magnificent | Actual: scandal
# Pred: un | Actual: un
# Pred: magnificent | Actual: special
# Pred: miscellaneous | Actual: crisis
# Pred: re | Actual: departure
# Pred: con | Actual: continuous
# Pred: enthusiasm | Actual: initials
# Pred: prejudice | Actual: hair
# Pred: miscellaneous | Actual: married
# Pred: inc | Actual: kilometre
# Pred: magnificent | Actual: pamphlet
# Pred: magnificent | Actual: pleasant
# Pred: con | Actual: actually
# Pred: magnificent | Actual: familiar
# Pred: con | Actual: definitely
# Pred: con | Actual: acknowledge
# Pred: con | Actual: inaccessible
# Pred: enthusiasm | Actual: annum
# Pred: court | Actual: criticism
# Pred: inc | Actual: opposite
# Pred: enthusiasm | Actual: accident
# Pred: magnificent | Actual: grant
# Pred: unanimous | Actual: af
# Pred: va | Actual: va
# Pred: miscellaneous | Actual: are
# Pred: miscellaneous | Actual: hair
# Pred: magnificent | Actual: anniversary
# Pred: enthusiasm | Actual: un
# Pred: magnificent | Actual: dormitory
# Pred: magnificent | Actual: equally
# Pred: magnificent | Actual: courses
# Pred: miscellaneous | Actual: available
# Pred: beautiful | Actual: careful
# Pred: guarantee | Actual: privilege
# Pred: enthusiasm | Actual: accomplished
# Pred: magnificent | Actual: equally
# Pred: enthusiasm | Actual: vo
# Pred: magnificent | Actual: familiar
# Pred: enthusiasm | Actual: criticism
# Pred: miscellaneous | Actual: secure
# Pred: enthusiasm | Actual: can
# Pred: magnificent | Actual: id
# Pred: miscellaneous | Actual: courtesy
# Pred: magnificent | Actual: auditorium
# Pred: guarantee | Actual: frightened
# Pred: magnificent | Actual: psychology
# Pred: enthusiasm | Actual: surface
# Pred: enthusiasm | Actual: guarantee
# Pred: con | Actual: front
# Pred: guarantee | Actual: quite
# Pred: miscellaneous | Actual: vulgar
# Pred: con | Actual: deco
# Pred: enthusiasm | Actual: temporarily
# Pred: magnificent | Actual: courtesy
# Pred: beautiful | Actual: pilot
# Pred: con | Actual: exhibition
# Pred: magnificent | Actual: grapes
# Pred: miscellaneous | Actual: dinner
# Pred: magnificent | Actual: count
# Pred: con | Actual: reader
# Pred: magnificent | Actual: feet
# Pred: enthusiasm | Actual: affectionately
# Pred: enthusiasm | Actual: poems
# Pred: enthusiasm | Actual: enthusiasm
# Pred: answer | Actual: pneumonia
# Pred: miscellaneous | Actual: orchestra
# Pred: inc | Actual: pneumonia
# Pred: enthusiasm | Actual: negotiations
# Pred: con | Actual: sufficient
# Pred: con | Actual: pamphlets
# Pred: enthusiasm | Actual: about
# Pred: special | Actual: build
# Pred: con | Actual: playing
# Pred: magnificent | Actual: refrigerator
# Pred: enthusiasm | Actual: establishing
# Pred: guarantee | Actual: guarantee
# Pred: magnificent | Actual: magnificent
# Pred: enthusiasm | Actual: required
# Pred: magnificent | Actual: thoroughly
# Pred: magnificent | Actual: works
# Pred: unanimous | Actual: unanimous
# Pred: enthusiasm | Actual: distinguished
# Pred: con | Actual: content
# Pred: answer | Actual: straw
# Pred: miscellaneous | Actual: harassed
# Pred: inc | Actual: opened
# Pred: court | Actual: so
# Pred: magnificent | Actual: operator
# Pred: enthusiasm | Actual: opposite
# Pred: enthusiasm | Actual: resource
# Pred: guarantee | Actual: remembrance
# Pred: magnificent | Actual: observation
# Pred: magnificent | Actual: lunch
# Pred: guarantee | Actual: er
# Pred: enthusiasm | Actual: enemy
# Pred: prejudice | Actual: principles
# Pred: enthusiasm | Actual: completion
# Pred: magnificent | Actual: affection
# Pred: magnificent | Actual: magnificent
# Pred: miscellaneous | Actual: explicit
# Pred: con | Actual: accommodation
# Pred: con | Actual: ridiculous
# Pred: magnificent | Actual: potatoes
# Pred: enthusiasm | Actual: acquaintance
# Pred: magnificent | Actual: channel
# Pred: magnificent | Actual: available
# Pred: enthusiasm | Actual: enlarged
# Pred: miscellaneous | Actual: experience
# Pred: miscellaneous | Actual: affection
# Pred: enthusiasm | Actual: comparative
# Pred: va | Actual: tome
# Pred: magnificent | Actual: minimum
# Pred: guarantee | Actual: no
# Pred: enthusiasm | Actual: annum
# Pred: miscellaneous | Actual: must
# Pred: magnificent | Actual: amount
# Pred: prejudice | Actual: prefer
# Pred: familiar | Actual: approximate
# Pred: magnificent | Actual: poems
# Pred: con | Actual: comfortable
# Pred: magnificent | Actual: surrounded
# Pred: destination | Actual: best
# Pred: magnificent | Actual: accomplished
# Pred: con | Actual: undoubtedly
# Pred: enthusiasm | Actual: melancholy
# Pred: inc | Actual: beautiful
# Pred: magnificent | Actual: happily
# Pred: con | Actual: instant
# Pred: magnificent | Actual: material
# Pred: magnificent | Actual: memorandum
# Pred: guarantee | Actual: surface
# Pred: special | Actual: precision
# Pred: familiar | Actual: i
# Pred: con | Actual: led
# Pred: magnificent | Actual: algorithms
# Pred: enthusiasm | Actual: accustomed
# Pred: miscellaneous | Actual: join
# Pred: magnificent | Actual: schemes
# Pred: magnificent | Actual: agencies
# Pred: miscellaneous | Actual: accompanying
# Pred: curtains | Actual: ripe
# Pred: inc | Actual: item
# Pred: enthusiasm | Actual: really
# Pred: inc | Actual: unfortunately
# Pred: magnificent | Actual: liable
# Pred: guarantee | Actual: telephone
# Pred: inc | Actual: sorority
# Pred: enthusiasm | Actual: dilapidated
# Pred: answer | Actual: earth
# Pred: inc | Actual: flag
# Pred: magnificent | Actual: schedule
# Pred: enthusiasm | Actual: decidedly
# Pred: con | Actual: better
# Pred: enthusiasm | Actual: comfortable
# Pred: magnificent | Actual: satisfaction
# Pred: enthusiasm | Actual: recognition
# Pred: especially | Actual: enthusiastic
# Pred: guarantee | Actual: grain
# Pred: answer | Actual: above
# Pred: guarantee | Actual: question
# Pred: enthusiasm | Actual: operator
# Pred: magnificent | Actual: lot
# Pred: enthusiasm | Actual: diamond
# Pred: guarantee | Actual: beg
# Pred: enthusiasm | Actual: approval
# Pred: miscellaneous | Actual: cheat
# Pred: familiar | Actual: doctor
# Pred: magnificent | Actual: awkward
# Pred: con | Actual: approximately
# Pred: magnificent | Actual: permanent
# Pred: enthusiasm | Actual: apparatus
# Pred: enthusiasm | Actual: accustomed
# Pred: con | Actual: marvel
# Pred: miscellaneous | Actual: especially
# Pred: guarantee | Actual: relief
# Pred: magnificent | Actual: statistics
# Pred: inc | Actual: inc
# Pred: con | Actual: for
# Pred: magnificent | Actual: dark
# Pred: guarantee | Actual: notable
# Pred: inc | Actual: ind
# Pred: magnificent | Actual: house
# Pred: guarantee | Actual: final
# Pred: court | Actual: er
# Pred: inc | Actual: inc
# Pred: magnificent | Actual: write
# Pred: guarantee | Actual: enjoy
# Pred: magnificent | Actual: someone
# Pred: magnificent | Actual: restaurant
# Pred: magnificent | Actual: competent
# Pred: guarantee | Actual: things
# Pred: magnificent | Actual: ami
# Pred: con | Actual: pinnacle
# Pred: con | Actual: memorandum
# Pred: court | Actual: juice
# Pred: magnificent | Actual: guard
# Pred: inc | Actual: opposite
# Pred: inc | Actual: anniversary
# Pred: guarantee | Actual: cha
# Pred: magnificent | Actual: swim
# Pred: guarantee | Actual: drum
# Pred: enthusiasm | Actual: laboratory
# Pred: miscellaneous | Actual: actually
# Pred: inc | Actual: satisfaction
# Pred: magnificent | Actual: curious
# Pred: inc | Actual: machine
# Pred: miscellaneous | Actual: orchestra
# Pred: psychology | Actual: damage
# Pred: miscellaneous | Actual: economic
# Pred: miscellaneous | Actual: miscellaneous
# Pred: court | Actual: ag
# Pred: enthusiasm | Actual: anomaly
# Pred: con | Actual: rain
# Pred: guarantee | Actual: women
# Pred: magnificent | Actual: aero
# Pred: enthusiasm | Actual: because
# Pred: enthusiasm | Actual: virtues
# Pred: con | Actual: compound
# Pred: inc | Actual: incorporation
# Pred: con | Actual: economic
# Pred: magnificent | Actual: chop
# Pred: inc | Actual: assistant
# Pred: magnificent | Actual: sorority
# Pred: magnificent | Actual: pilot
# Pred: enthusiasm | Actual: regained
# Pred: inc | Actual: extraordinary
# Pred: magnificent | Actual: trying
# Pred: miscellaneous | Actual: ex
# Pred: enthusiasm | Actual: society
# Pred: inc | Actual: includes
# Pred: magnificent | Actual: va
# Pred: guarantee | Actual: new
# Pred: prejudice | Actual: prejudice
# Pred: inc | Actual: tournament
# Pred: magnificent | Actual: cool
# Pred: enthusiasm | Actual: material
# Pred: guarantee | Actual: tied
# Pred: guarantee | Actual: home
# Pred: miscellaneous | Actual: wish
# Pred: familiar | Actual: psychology
# Pred: enthusiasm | Actual: poly
# Pred: magnificent | Actual: getting
# Pred: miscellaneous | Actual: successful
# Pred: magnificent | Actual: negotiations
# Pred: guarantee | Actual: silly
# Pred: magnificent | Actual: comfortable
# Pred: magnificent | Actual: acc
# Pred: inc | Actual: scrambled
# Pred: re | Actual: tr
# Pred: con | Actual: distinguished
# Pred: guarantee | Actual: dangerous
# Pred: con | Actual: acknowledge
# Pred: inc | Actual: chemistry
# Pred: magnificent | Actual: magnificent
# Pred: magnificent | Actual: lo
# Pred: magnificent | Actual: wanted
# Pred: enthusiasm | Actual: privileged
# Pred: enthusiasm | Actual: purple
# Pred: economics | Actual: activities
# Pred: enthusiasm | Actual: throughout
# Pred: magnificent | Actual: facilities
# Pred: guarantee | Actual: ceased
# Pred: magnificent | Actual: extraordinary
# Pred: miscellaneous | Actual: sauce
# Pred: answer | Actual: them
# Pred: answer | Actual: fight
# Pred: enthusiasm | Actual: curiosity
# Pred: enthusiasm | Actual: criticism
# Pred: magnificent | Actual: freezing
# Pred: enthusiasm | Actual: up
# Pred: con | Actual: curiosity
# Pred: magnificent | Actual: going
# Pred: magnificent | Actual: ground
# Pred: guarantee | Actual: tragedy
# Pred: magnificent | Actual: waiting
# Pred: prejudice | Actual: ink
# Pred: magnificent | Actual: bomb
# Pred: magnificent | Actual: melancholy
# Pred: miscellaneous | Actual: yield
# Pred: inc | Actual: inc
# Pred: prejudice | Actual: mysterious
# Pred: prejudice | Actual: pretend
# Pred: enthusiasm | Actual: criticism
# Pred: inc | Actual: ice
# Pred: enthusiasm | Actual: immediately
# Pred: inc | Actual: scissors
# Pred: magnificent | Actual: bell
# Pred: enthusiasm | Actual: regained
# Pred: guarantee | Actual: plan
# Pred: magnificent | Actual: organization
# Pred: enthusiasm | Actual: attorneys
# Pred: miscellaneous | Actual: shape
# Pred: guarantee | Actual: appreciate
# Pred: familiar | Actual: scarcely
# Pred: magnificent | Actual: privilege
# Pred: con | Actual: sauce
# Pred: magnificent | Actual: sale
# Pred: miscellaneous | Actual: something
# Pred: magnificent | Actual: discuss
# Pred: unanimous | Actual: industry
# Pred: enthusiasm | Actual: intellectual
# Pred: magnificent | Actual: threshold
# Pred: magnificent | Actual: said
# Pred: magnificent | Actual: analysis
# Pred: magnificent | Actual: tragedy
# Pred: enthusiasm | Actual: permanent
# Pred: magnificent | Actual: suspicion
# Pred: answer | Actual: and
# Pred: miscellaneous | Actual: locked
# Pred: enthusiasm | Actual: comparatively
# Pred: magnificent | Actual: ceased
# Pred: magnificent | Actual: between
# Pred: inc | Actual: ins
# Pred: magnificent | Actual: everyone
# Pred: magnificent | Actual: technical
# Pred: con | Actual: annum
# Pred: guarantee | Actual: up
# Pred: court | Actual: dangerous
# Pred: inc | Actual: subterranean
# Pred: magnificent | Actual: freezing
# Pred: enthusiasm | Actual: intellectual
# Pred: enthusiasm | Actual: temperature
# Pred: guarantee | Actual: food
# Pred: guarantee | Actual: forward
# Pred: magnificent | Actual: magnificent
# Pred: familiar | Actual: programmes
# Pred: inc | Actual: dictionary
# Pred: guarantee | Actual: arrangements
# Pred: magnificent | Actual: cemetery
# Pred: guarantee | Actual: tr
# Pred: enthusiasm | Actual: sting
# Pred: magnificent | Actual: definite
# Pred: con | Actual: con
# Pred: guarantee | Actual: likes
# Pred: magnificent | Actual: item
# Pred: con | Actual: acknowledging
# Pred: magnificent | Actual: spacecraft
# Pred: magnificent | Actual: regained
# Pred: con | Actual: knife
# Pred: guarantee | Actual: would
# Pred: magnificent | Actual: do
# Pred: guarantee | Actual: busy
# Pred: magnificent | Actual: dec
# Pred: unanimous | Actual: unanimous
# Pred: enthusiasm | Actual: built
# Pred: answer | Actual: annum
# Pred: con | Actual: magnificent
# Pred: magnificent | Actual: content
# Pred: con | Actual: conscience
# Pred: con | Actual: criticism
# Pred: magnificent | Actual: ski
# Pred: con | Actual: fra
# Pred: answer | Actual: honest
# Pred: magnificent | Actual: boyfriend
# Pred: miscellaneous | Actual: pockets
# Pred: magnificent | Actual: healthy
# Pred: magnificent | Actual: complexion
# Pred: con | Actual: ridiculous
# Pred: magnificent | Actual: commemorated
# Pred: psychology | Actual: damage
# Pred: answer | Actual: ref
# Pred: psychology | Actual: frightened
# Pred: enthusiasm | Actual: enthusiasm
# Pred: con | Actual: similarity
# Pred: enthusiasm | Actual: st
# Pred: enthusiasm | Actual: abandon
# Pred: inc | Actual: br
# Pred: magnificent | Actual: economical
# Pred: miscellaneous | Actual: genius
# Pred: magnificent | Actual: female
# Pred: enthusiasm | Actual: infinite
# Pred: con | Actual: con
# Pred: enthusiasm | Actual: basketball
# Pred: inc | Actual: include
# Pred: inc | Actual: removed
# Pred: guarantee | Actual: gauge
# Pred: miscellaneous | Actual: end
# Pred: miscellaneous | Actual: take
# Pred: magnificent | Actual: financially
# Pred: familiar | Actual: satisfaction
# Pred: miscellaneous | Actual: hates
# Pred: miscellaneous | Actual: exceptionally
# Pred: court | Actual: train
# Pred: inc | Actual: unanimous
# Pred: magnificent | Actual: ski
# Pred: enthusiasm | Actual: tournament
# Pred: guarantee | Actual: trousers
# Pred: miscellaneous | Actual: cemetery
# Pred: guarantee | Actual: chemistry
# Pred: miscellaneous | Actual: describing
# Pred: magnificent | Actual: houses
# Pred: miscellaneous | Actual: had
# Pred: magnificent | Actual: food
# Pred: guarantee | Actual: biscuits
# Pred: enthusiasm | Actual: del
# Pred: magnificent | Actual: curiosity
# Pred: miscellaneous | Actual: sort
# Pred: miscellaneous | Actual: away
# Pred: enthusiasm | Actual: technical
# Pred: inc | Actual: opportunities
# Pred: inc | Actual: ex
# Pred: con | Actual: heightened
# Pred: unanimous | Actual: removed
# Pred: familiar | Actual: copy
# Pred: guarantee | Actual: had
# Pred: magnificent | Actual: avoid
# Pred: magnificent | Actual: prior
# Pred: enthusiasm | Actual: parallel
# Pred: enthusiasm | Actual: guarantee
# Pred: enthusiasm | Actual: st
# Pred: magnificent | Actual: memorandum
# Pred: answer | Actual: usual
# Pred: magnificent | Actual: peculiar
# Pred: psychology | Actual: spade
# Pred: enthusiasm | Actual: temporary
# Pred: guarantee | Actual: searched
# Pred: miscellaneous | Actual: beautiful
# Pred: magnificent | Actual: stomach
# Pred: enthusiasm | Actual: latest
# Pred: magnificent | Actual: cha
# Pred: psychology | Actual: clouds
# Pred: enthusiasm | Actual: surrendered
# Pred: con | Actual: ex
# Pred: con | Actual: r
# Pred: enthusiasm | Actual: memorandum
# Pred: enthusiasm | Actual: sorority
# Pred: magnificent | Actual: family
# Pred: guarantee | Actual: melancholy
# Pred: enthusiasm | Actual: equipped
# Pred: inc | Actual: permanently
# Pred: magnificent | Actual: railway
# Pred: magnificent | Actual: shown
# Pred: magnificent | Actual: picturesque
# Pred: magnificent | Actual: bear
# Pred: magnificent | Actual: anticipation
# Pred: magnificent | Actual: jumped
# Pred: con | Actual: prep
# Pred: guarantee | Actual: raining
# Pred: enthusiasm | Actual: surrounded
# Pred: inc | Actual: fra
# Pred: magnificent | Actual: anniversary
# Pred: miscellaneous | Actual: initials
# Pred: miscellaneous | Actual: technical
# Pred: enthusiasm | Actual: sauce
# Pred: magnificent | Actual: recommend
# Pred: magnificent | Actual: ponder
# Pred: enthusiasm | Actual: prior
# Pred: familiar | Actual: specimen
# Pred: con | Actual: temperature
# Pred: guarantee | Actual: primary
# Pred: miscellaneous | Actual: picturesque
# Pred: guarantee | Actual: inverted
# Pred: inc | Actual: exhibition
# Pred: guarantee | Actual: to
# Pred: miscellaneous | Actual: vulgar
# Pred: magnificent | Actual: fascination
# Pred: psychology | Actual: catalogue
# Pred: con | Actual: conception
# Pred: magnificent | Actual: prophecy
# Pred: magnificent | Actual: documents
# Pred: magnificent | Actual: fundamental
# Pred: enthusiasm | Actual: sufficient
# Pred: familiar | Actual: chapter
# Pred: miscellaneous | Actual: es
# Pred: magnificent | Actual: pamphlets
# Pred: inc | Actual: unemployed
# Accuracy: 0.0347
# Epoch 2, Average Loss: 6.9104
# Accuracy: 0.0534
# Epoch 3, Average Loss: 6.5704
# Pred: especially | Actual: thoroughly
# Pred: undoubtedly | Actual: children
# Pred: guarantee | Actual: tax
# Pred: unanimous | Actual: disappointment
# Pred: va | Actual: anxiety
# Pred: prejudice | Actual: specifically
# Pred: beautiful | Actual: dark
# Pred: indefinitely | Actual: subterranean
# Pred: definitely | Actual: gloves
# Pred: un | Actual: unanimous
# Pred: guarantee | Actual: guaranteed
# Pred: guarantee | Actual: down
# Pred: answer | Actual: advantage
# Pred: answer | Actual: to
# Pred: miscellaneous | Actual: frames
# Pred: magnificent | Actual: ra
# Pred: answer | Actual: again
# Pred: indefinite | Actual: initiation
# Pred: minimum | Actual: tracks
# Pred: melancholy | Actual: recommendation
# Pred: guarantee | Actual: sure
# Pred: magnificent | Actual: wishes
# Pred: guarantee | Actual: anything
# Pred: magnificent | Actual: working
# Pred: immediately | Actual: whistling
# Pred: miscellaneous | Actual: throughout
# Pred: guarantee | Actual: maneuver
# Pred: va | Actual: circling
# Pred: guarantee | Actual: class
# Pred: prejudice | Actual: president
# Pred: prejudice | Actual: annum
# Pred: guarantee | Actual: hoax
# Pred: miscellaneous | Actual: ten
# Pred: un | Actual: umbrella
# Pred: criticism | Actual: criticism
# Pred: guarantee | Actual: filled
# Pred: magnificent | Actual: sacrifice
# Pred: con | Actual: philosophy
# Pred: enthusiasm | Actual: resource
# Pred: undoubtedly | Actual: temporarily
# Pred: guarantee | Actual: rainy
# Pred: magnificent | Actual: phase
# Pred: inc | Actual: inc
# Pred: opposite | Actual: opportunities
# Pred: guarantee | Actual: happy
# Pred: magnificent | Actual: punishment
# Pred: specifically | Actual: attorneys
# Pred: guarantee | Actual: anything
# Pred: miscellaneous | Actual: thin
# Pred: exhibition | Actual: extraordinary
# Pred: philosophy | Actual: pilot
# Pred: subterranean | Actual: sneaking
# Pred: immediately | Actual: phase
# Pred: immediately | Actual: as
# Pred: unanimous | Actual: genius
# Pred: va | Actual: referring
# Pred: con | Actual: cancelled
# Pred: unanimous | Actual: una
# Pred: magnificent | Actual: driven
# Pred: beautiful | Actual: special
# Pred: exhibition | Actual: exhibition
# Pred: sufficiently | Actual: sometimes
# Pred: miscellaneous | Actual: thousand
# Pred: magnificent | Actual: organization
# Pred: inc | Actual: playground
# Pred: enthusiasm | Actual: accompaniment
# Pred: indefinite | Actual: bird
# Pred: guarantee | Actual: procedure
# Pred: va | Actual: get
# Pred: prejudice | Actual: sufficient
# Pred: magnificent | Actual: guardian
# Pred: destination | Actual: surrounds
# Pred: permanently | Actual: precision
# Pred: enthusiasm | Actual: altitude
# Pred: va | Actual: haven
# Pred: beautiful | Actual: above
# Pred: recognition | Actual: material
# Pred: enthusiasm | Actual: customer
# Pred: va | Actual: severely
# Pred: indefinitely | Actual: responsible
# Pred: subterranean | Actual: want
# Pred: successful | Actual: called
# Pred: un | Actual: unconstitutional
# Pred: guarantee | Actual: old
# Pred: miscellaneous | Actual: brought
# Pred: guarantee | Actual: de
# Pred: exhibition | Actual: ex
# Pred: prejudice | Actual: perceive
# Pred: con | Actual: conditions
# Pred: va | Actual: our
# Pred: con | Actual: disappointing
# Pred: answer | Actual: chop
# Pred: material | Actual: peculiar
# Pred: answer | Actual: apparatus
# Pred: special | Actual: thorough
# Pred: melancholy | Actual: although
# Pred: immediately | Actual: pneumonia
# Pred: con | Actual: convenient
# Pred: sufficiently | Actual: recommendation
# Pred: magnificent | Actual: satisfaction
# Pred: va | Actual: admitted
# Pred: guarantee | Actual: gallery
# Pred: miscellaneous | Actual: broke
# Pred: miscellaneous | Actual: miscellaneous
# Pred: vo | Actual: vo
# Pred: magnificent | Actual: magnificent
# Pred: guarantee | Actual: scarcely
# Pred: immediately | Actual: having
# Pred: con | Actual: being
# Pred: guarantee | Actual: hang
# Pred: miscellaneous | Actual: grateful
# Pred: subterranean | Actual: noticeable
# Pred: va | Actual: dun
# Pred: del | Actual: cramped
# Pred: or | Actual: originally
# Pred: re | Actual: recently
# Pred: un | Actual: unusually
# Pred: guarantee | Actual: grip
# Pred: exhibition | Actual: experience
# Pred: guarantee | Actual: infinite
# Pred: enthusiasm | Actual: efficiency
# Pred: guarantee | Actual: life
# Pred: magnificent | Actual: juice
# Pred: undoubtedly | Actual: diamond
# Pred: ridiculous | Actual: ridiculous
# Pred: prejudice | Actual: destination
# Pred: immediately | Actual: peculiar
# Pred: undoubtedly | Actual: story
# Pred: prejudice | Actual: permanently
# Pred: guarantee | Actual: folk
# Pred: magnificent | Actual: sac
# Pred: sufficiently | Actual: knife
# Pred: un | Actual: bulletin
# Pred: va | Actual: harassed
# Pred: indefinite | Actual: dart
# Pred: guarantee | Actual: hoarse
# Pred: opposite | Actual: st
# Pred: magnificent | Actual: rating
# Pred: guarantee | Actual: from
# Pred: sympathetic | Actual: sympathetic
# Pred: con | Actual: conscious
# Pred: magnificent | Actual: traffic
# Pred: anniversary | Actual: above
# Pred: guarantee | Actual: guarantee
# Pred: special | Actual: splendid
# Pred: prejudice | Actual: semi
# Pred: guarantee | Actual: pack
# Pred: melancholy | Actual: thorough
# Pred: answer | Actual: coach
# Pred: va | Actual: vacancy
# Pred: guarantee | Actual: gallo
# Pred: beautiful | Actual: goodbye
# Pred: miscellaneous | Actual: refrigerator
# Pred: answer | Actual: army
# Pred: enthusiasm | Actual: enthusiastic
# Pred: inc | Actual: inc
# Pred: magnificent | Actual: always
# Pred: beautiful | Actual: health
# Pred: beautiful | Actual: approximate
# Pred: miscellaneous | Actual: fruit
# Pred: indefinitely | Actual: employ
# Pred: refrigerator | Actual: refrigerator
# Pred: guarantee | Actual: bureaucracy
# Pred: immediately | Actual: melancholy
# Pred: sufficiently | Actual: surplus
# Pred: immediately | Actual: wonderful
# Pred: prejudice | Actual: st
# Pred: va | Actual: sank
# Pred: sorority | Actual: peculiar
# Pred: suspicion | Actual: suffering
# Pred: opposite | Actual: type
# Pred: guarantee | Actual: knew
# Pred: immediately | Actual: ami
# Pred: con | Actual: di
# Pred: guarantee | Actual: sore
# Pred: approximately | Actual: mechanical
# Pred: comparatively | Actual: customary
# Pred: anniversary | Actual: anniversary
# Pred: minimum | Actual: back
# Pred: guarantee | Actual: children
# Pred: special | Actual: cancelled
# Pred: guarantee | Actual: searched
# Pred: indefinitely | Actual: sorority
# Pred: enthusiasm | Actual: occurrence
# Pred: va | Actual: license
# Pred: successful | Actual: removed
# Pred: re | Actual: recommendation
# Pred: magnificent | Actual: flag
# Pred: guarantee | Actual: appropriate
# Pred: immediately | Actual: greatly
# Pred: miscellaneous | Actual: got
# Pred: magnificent | Actual: documents
# Pred: magnificent | Actual: lots
# Pred: inc | Actual: inc
# Pred: con | Actual: conscience
# Pred: sufficiently | Actual: jewelry
# Pred: or | Actual: or
# Pred: destination | Actual: sometimes
# Pred: undoubtedly | Actual: convenient
# Pred: inc | Actual: inc
# Pred: suspicion | Actual: suspicion
# Pred: special | Actual: spare
# Pred: answer | Actual: i
# Pred: immediately | Actual: mathematics
# Pred: recognition | Actual: reckon
# Pred: psychology | Actual: gallo
# Pred: immediately | Actual: tragedy
# Pred: guarantee | Actual: af
# Pred: prejudice | Actual: pamphlet
# Pred: magnificent | Actual: military
# Pred: answer | Actual: aunt
# Pred: prejudice | Actual: precision
# Pred: con | Actual: con
# Pred: recognition | Actual: recommended
# Pred: va | Actual: va
# Pred: recognition | Actual: received
# Pred: answer | Actual: inaccessible
# Pred: re | Actual: reminded
# Pred: discretion | Actual: discarded
# Pred: enthusiasm | Actual: anniversary
# Pred: court | Actual: sank
# Pred: inc | Actual: incident
# Pred: magnificent | Actual: hydraulic
# Pred: guarantee | Actual: cemetery
# Pred: ridiculous | Actual: diagonal
# Pred: recognition | Actual: auditorium
# Pred: minimum | Actual: departure
# Pred: prejudice | Actual: dark
# Pred: un | Actual: worst
# Pred: guarantee | Actual: re
# Pred: va | Actual: besides
# Pred: special | Actual: special
# Pred: answer | Actual: ins
# Pred: necessarily | Actual: break
# Pred: guarantee | Actual: beautiful
# Pred: melancholy | Actual: melancholy
# Pred: magnificent | Actual: magnificent
# Pred: scheduled | Actual: forward
# Pred: enthusiasm | Actual: frog
# Pred: unanimous | Actual: calling
# Pred: va | Actual: several
# Pred: indefinitely | Actual: rule
# Pred: guarantee | Actual: attempts
# Pred: suspicion | Actual: certainly
# Pred: melancholy | Actual: talked
# Pred: con | Actual: continuous
# Pred: special | Actual: train
# Pred: melancholy | Actual: auditorium
# Pred: financially | Actual: financially
# Pred: guarantee | Actual: guardian
# Pred: occasionally | Actual: circling
# Pred: guarantee | Actual: branches
# Pred: inc | Actual: pneumonia
# Pred: magnificent | Actual: anniversary
# Pred: magnificent | Actual: rather
# Pred: opposite | Actual: opera
# Pred: miscellaneous | Actual: economical
# Pred: prejudice | Actual: on
# Pred: scheduled | Actual: belief
# Pred: guarantee | Actual: biscuits
# Pred: unanimous | Actual: unanimous
# Pred: indefinitely | Actual: definitely
# Pred: magnificent | Actual: congratulations
# Pred: con | Actual: confusing
# Pred: successful | Actual: home
# Pred: con | Actual: conscience
# Pred: destination | Actual: discretion
# Pred: enthusiasm | Actual: conscious
# Pred: va | Actual: scream
# Pred: beautiful | Actual: mysterious
# Pred: ridiculous | Actual: cheaper
# Pred: undoubtedly | Actual: transferred
# Pred: permanently | Actual: writing
# Pred: guarantee | Actual: wholly
# Pred: guarantee | Actual: orchestra
# Pred: answer | Actual: quickly
# Pred: re | Actual: request
# Pred: philosophy | Actual: can
# Pred: scheduled | Actual: accident
# Pred: con | Actual: communicate
# Pred: enthusiasm | Actual: any
# Pred: un | Actual: un
# Pred: beautiful | Actual: triumph
# Pred: recognition | Actual: recommendations
# Pred: immediately | Actual: accomplished
# Pred: especially | Actual: lid
# Pred: enthusiasm | Actual: equipped
# Pred: prejudice | Actual: item
# Pred: beautiful | Actual: playing
# Pred: guarantee | Actual: bungalow
# Pred: shaggy | Actual: league
# Pred: con | Actual: con
# Pred: guarantee | Actual: teachers
# Pred: enthusiasm | Actual: medicine
# Pred: prejudice | Actual: luke
# Pred: philosophy | Actual: dining
# Pred: guarantee | Actual: guarantee
# Pred: suspicion | Actual: succession
# Pred: answer | Actual: beautiful
# Pred: guarantee | Actual: want
# Pred: guarantee | Actual: possess
# Pred: beautiful | Actual: curiosity
# Pred: especially | Actual: poems
# Pred: miscellaneous | Actual: pneumonia
# Pred: beautiful | Actual: col
# Pred: guarantee | Actual: got
# Pred: va | Actual: touched
# Pred: prejudice | Actual: pamphlet
# Pred: magnificent | Actual: poly
# Pred: va | Actual: vacancy
# Pred: destination | Actual: bulletin
# Pred: definitely | Actual: road
# Pred: inc | Actual: amount
# Pred: psychology | Actual: argument
# Pred: guarantee | Actual: del
# Pred: miscellaneous | Actual: technical
# Pred: biscuits | Actual: peculiar
# Pred: psychology | Actual: cancellation
# Pred: magnificent | Actual: planning
# Pred: enthusiasm | Actual: enthusiasm
# Pred: immediately | Actual: fire
# Pred: especially | Actual: gone
# Pred: indefinitely | Actual: as
# Pred: special | Actual: deny
# Pred: prejudice | Actual: dangerous
# Pred: guarantee | Actual: sauce
# Pred: undoubtedly | Actual: auditorium
# Pred: guarantee | Actual: banquet
# Pred: prejudice | Actual: facilities
# Pred: guarantee | Actual: looks
# Pred: va | Actual: around
# Pred: con | Actual: content
# Pred: enthusiasm | Actual: item
# Pred: con | Actual: fra
# Pred: melancholy | Actual: to
# Pred: frightened | Actual: congress
# Pred: sufficiently | Actual: latest
# Pred: unanimous | Actual: north
# Pred: appropriate | Actual: approximately
# Pred: indefinitely | Actual: disappeared
# Pred: unanimous | Actual: unexpected
# Pred: re | Actual: important
# Pred: subterranean | Actual: significant
# Pred: prejudice | Actual: approximate
# Pred: prejudice | Actual: mates
# Pred: immediately | Actual: scheduled
# Pred: guarantee | Actual: to
# Pred: immediately | Actual: certainly
# Pred: guarantee | Actual: guaranteed
# Pred: unanimous | Actual: unanimous
# Pred: indefinitely | Actual: dissatisfaction
# Pred: enthusiasm | Actual: enthusiastic
# Pred: undoubtedly | Actual: undoubtedly
# Pred: miscellaneous | Actual: techniques
# Pred: prejudice | Actual: virtues
# Pred: magnificent | Actual: satisfaction
# Pred: va | Actual: dear
# Pred: immediately | Actual: understand
# Pred: guarantee | Actual: shook
# Pred: guarantee | Actual: climb
# Pred: un | Actual: occasionally
# Pred: unanimous | Actual: distinguished
# Pred: prejudice | Actual: pre
# Pred: va | Actual: even
# Pred: destination | Actual: departure
# Pred: miscellaneous | Actual: specific
# Pred: prejudice | Actual: pretend
# Pred: guarantee | Actual: guarantee
# Pred: court | Actual: court
# Pred: prejudice | Actual: pilot
# Pred: beautiful | Actual: dodged
# Pred: indefinitely | Actual: recommended
# Pred: guarantee | Actual: cord
# Pred: psychology | Actual: mathematics
# Pred: guarantee | Actual: guardian
# Pred: del | Actual: del
# Pred: indefinitely | Actual: inevitable
# Pred: magnificent | Actual: magnificent
# Pred: guarantee | Actual: gallo
# Pred: va | Actual: who
# Pred: permanent | Actual: permanent
# Pred: psychology | Actual: loud
# Pred: va | Actual: establishing
# Pred: exhibition | Actual: express
# Pred: miscellaneous | Actual: soon
# Pred: prejudice | Actual: pilot
# Pred: un | Actual: unfortunate
# Pred: con | Actual: done
# Pred: st | Actual: stars
# Pred: st | Actual: stomach
# Pred: answer | Actual: sauce
# Pred: magnificent | Actual: satisfaction
# Pred: negotiations | Actual: tendency
# Pred: prejudice | Actual: appreciate
# Pred: count | Actual: radius
# Pred: guarantee | Actual: dangerous
# Pred: certainly | Actual: statistics
# Pred: economical | Actual: attach
# Pred: miscellaneous | Actual: extant
# Pred: re | Actual: getting
# Pred: guarantee | Actual: juicy
# Pred: prejudice | Actual: court
# Pred: va | Actual: nurse
# Pred: guarantee | Actual: mountainous
# Pred: beautiful | Actual: wear
# Pred: miscellaneous | Actual: once
# Pred: enthusiasm | Actual: actually
# Pred: guarantee | Actual: item
# Pred: guarantee | Actual: help
# Pred: va | Actual: every
# Pred: exhibition | Actual: exhibition
# Pred: occasionally | Actual: occasionally
# Pred: immediately | Actual: applied
# Pred: magnificent | Actual: prefer
# Pred: guarantee | Actual: gallo
# Pred: indefinitely | Actual: indefinitely
# Pred: guarantee | Actual: damaged
# Pred: philosophy | Actual: photograph
# Pred: negotiations | Actual: temporary
# Pred: guarantee | Actual: ruler
# Pred: special | Actual: court
# Pred: prejudice | Actual: prejudice
# Pred: guarantee | Actual: definite
# Pred: successful | Actual: familiar
# Pred: va | Actual: worry
# Pred: beautiful | Actual: everyone
# Pred: va | Actual: water
# Pred: miscellaneous | Actual: chop
# Pred: magnificent | Actual: comparatively
# Pred: answer | Actual: annum
# Pred: guarantee | Actual: cord
# Pred: anniversary | Actual: approaching
# Pred: magnificent | Actual: apparatus
# Pred: beautiful | Actual: spiritual
# Pred: enthusiasm | Actual: enlightenment
# Pred: guarantee | Actual: give
# Pred: scarcely | Actual: when
# Pred: court | Actual: dart
# Pred: miscellaneous | Actual: temperature
# Pred: prejudice | Actual: successful
# Pred: con | Actual: common
# Pred: scheduled | Actual: ill
# Pred: opposite | Actual: opportunity
# Pred: beautiful | Actual: miscellaneous
# ...
# Pred: flag | Actual: picturesque
# Pred: indefinitely | Actual: ind
# Pred: court | Actual: dart
# Pred: guarantee | Actual: guard
# Pred: sure | Actual: con
# Pred: competent | Actual: compelled
# Pred: melancholy | Actual: scandal
# Pred: un | Actual: un
# Pred: special | Actual: special
# Pred: politician | Actual: crisis
# Pred: tournament | Actual: departure
# Pred: con | Actual: continuous
# Pred: enthusiasm | Actual: initials
# Pred: mortgage | Actual: hair
# Pred: miscellaneous | Actual: married
# Pred: miscellaneous | Actual: kilometre
# Pred: pamphlet | Actual: pamphlet
# Pred: sufficiently | Actual: pleasant
# Pred: approximately | Actual: actually
# Pred: irresistible | Actual: familiar
# Pred: behind | Actual: definitely
# Pred: acknowledge | Actual: acknowledge
# Pred: inaccessible | Actual: inaccessible
# Pred: anniversary | Actual: annum
# Pred: criticism | Actual: criticism
# Pred: opposite | Actual: opposite
# Pred: melancholy | Actual: accident
# Pred: guarantee | Actual: grant
# Pred: unanimous | Actual: af
# Pred: va | Actual: va
# Pred: dart | Actual: are
# Pred: va | Actual: hair
# Pred: anniversary | Actual: anniversary
# Pred: un | Actual: un
# Pred: dormitory | Actual: dormitory
# Pred: efficiency | Actual: equally
# Pred: count | Actual: courses
# Pred: anniversary | Actual: available
# Pred: del | Actual: careful
# Pred: privilege | Actual: privilege
# Pred: acknowledge | Actual: accomplished
# Pred: efficiency | Actual: equally
# Pred: vo | Actual: vo
# Pred: guarantee | Actual: familiar
# Pred: determined | Actual: criticism
# Pred: enthusiastic | Actual: secure
# Pred: immediately | Actual: can
# Pred: undoubtedly | Actual: id
# Pred: courtesy | Actual: courtesy
# Pred: auditorium | Actual: auditorium
# Pred: guarantee | Actual: frightened
# Pred: r | Actual: psychology
# Pred: sufficient | Actual: surface
# Pred: enthusiasm | Actual: guarantee
# Pred: beautiful | Actual: front
# Pred: great | Actual: quite
# Pred: guarantee | Actual: vulgar
# Pred: pinnacle | Actual: deco
# Pred: indefinitely | Actual: temporarily
# Pred: anniversary | Actual: courtesy
# Pred: satisfaction | Actual: pilot
# Pred: exhibition | Actual: exhibition
# Pred: gradually | Actual: grapes
# Pred: bicycle | Actual: dinner
# Pred: count | Actual: count
# Pred: ridiculous | Actual: reader
# Pred: fascinating | Actual: feet
# Pred: especially | Actual: affectionately
# Pred: prejudice | Actual: poems
# Pred: gorgeous | Actual: enthusiasm
# Pred: as | Actual: pneumonia
# Pred: occasionally | Actual: orchestra
# Pred: physician | Actual: pneumonia
# Pred: negotiations | Actual: negotiations
# Pred: sufficiently | Actual: sufficient
# Pred: permanently | Actual: pamphlets
# Pred: satisfaction | Actual: about
# Pred: frightened | Actual: build
# Pred: beautiful | Actual: playing
# Pred: refrigerator | Actual: refrigerator
# Pred: especially | Actual: establishing
# Pred: guarantee | Actual: guarantee
# Pred: magnificent | Actual: magnificent
# Pred: remember | Actual: required
# Pred: melancholy | Actual: thoroughly
# Pred: minimum | Actual: works
# Pred: unanimous | Actual: unanimous
# Pred: distinguished | Actual: distinguished
# Pred: con | Actual: content
# Pred: sure | Actual: straw
# Pred: indefinite | Actual: harassed
# Pred: opposite | Actual: opened
# Pred: women | Actual: so
# Pred: opposite | Actual: operator
# Pred: opposite | Actual: opposite
# Pred: recognition | Actual: resource
# Pred: remember | Actual: remembrance
# Pred: sufficiently | Actual: observation
# Pred: minimum | Actual: lunch
# Pred: guarantee | Actual: er
# Pred: enthusiastic | Actual: enemy
# Pred: prejudice | Actual: principles
# Pred: communicate | Actual: completion
# Pred: af | Actual: affection
# Pred: magnificent | Actual: magnificent
# Pred: actually | Actual: explicit
# Pred: acknowledge | Actual: accommodation
# Pred: ridiculous | Actual: ridiculous
# Pred: guaranteed | Actual: potatoes
# Pred: acquaintance | Actual: acquaintance
# Pred: gorgeous | Actual: channel
# Pred: avoid | Actual: available
# Pred: enthusiasm | Actual: enlarged
# Pred: ep | Actual: experience
# Pred: affection | Actual: affection
# Pred: comparatively | Actual: comparative
# Pred: va | Actual: tome
# Pred: cha | Actual: minimum
# Pred: del | Actual: no
# Pred: satisfaction | Actual: annum
# Pred: sure | Actual: must
# Pred: pamphlets | Actual: amount
# Pred: prejudice | Actual: prefer
# Pred: infinite | Actual: approximate
# Pred: pamphlets | Actual: poems
# Pred: competent | Actual: comfortable
# Pred: sufficient | Actual: surrounded
# Pred: destination | Actual: best
# Pred: accomplished | Actual: accomplished
# Pred: undoubtedly | Actual: undoubtedly
# Pred: anniversary | Actual: melancholy
# Pred: beautiful | Actual: beautiful
# Pred: occasionally | Actual: happily
# Pred: ridiculous | Actual: instant
# Pred: temporarily | Actual: material
# Pred: memorandum | Actual: memorandum
# Pred: really | Actual: surface
# Pred: procedure | Actual: precision
# Pred: scarcely | Actual: i
# Pred: con | Actual: led
# Pred: af | Actual: algorithms
# Pred: acc | Actual: accustomed
# Pred: who | Actual: join
# Pred: horse | Actual: schemes
# Pred: instruments | Actual: agencies
# Pred: accompanying | Actual: accompanying
# Pred: done | Actual: ripe
# Pred: enthusiastic | Actual: item
# Pred: pinnacle | Actual: really
# Pred: unfortunately | Actual: unfortunately
# Pred: behind | Actual: liable
# Pred: guarantee | Actual: telephone
# Pred: distinguished | Actual: sorority
# Pred: del | Actual: dilapidated
# Pred: suitable | Actual: earth
# Pred: immediately | Actual: flag
# Pred: scheduled | Actual: schedule
# Pred: destination | Actual: decidedly
# Pred: anxiety | Actual: better
# Pred: curiosity | Actual: comfortable
# Pred: satisfaction | Actual: satisfaction
# Pred: recognition | Actual: recognition
# Pred: temperature | Actual: enthusiastic
# Pred: guarantee | Actual: grain
# Pred: ecstasy | Actual: above
# Pred: question | Actual: question
# Pred: immediately | Actual: operator
# Pred: alumni | Actual: lot
# Pred: determined | Actual: diamond
# Pred: question | Actual: beg
# Pred: anniversary | Actual: approval
# Pred: miscellaneous | Actual: cheat
# Pred: scarcely | Actual: doctor
# Pred: philosophy | Actual: awkward
# Pred: inaccessible | Actual: approximately
# Pred: permanently | Actual: permanent
# Pred: unanimous | Actual: apparatus
# Pred: accompanying | Actual: accustomed
# Pred: successful | Actual: marvel
# Pred: ex | Actual: especially
# Pred: guarantee | Actual: relief
# Pred: material | Actual: statistics
# Pred: inc | Actual: inc
# Pred: beautiful | Actual: for
# Pred: prejudice | Actual: dark
# Pred: avoid | Actual: notable
# Pred: indefinitely | Actual: ind
# Pred: criticism | Actual: house
# Pred: turned | Actual: final
# Pred: stomach | Actual: er
# Pred: inc | Actual: inc
# Pred: pinnacle | Actual: write
# Pred: va | Actual: enjoy
# Pred: va | Actual: someone
# Pred: restaurant | Actual: restaurant
# Pred: comparatively | Actual: competent
# Pred: sure | Actual: things
# Pred: restaurant | Actual: ami
# Pred: ridiculous | Actual: pinnacle
# Pred: specifically | Actual: memorandum
# Pred: annum | Actual: juice
# Pred: gradually | Actual: guard
# Pred: opposite | Actual: opposite
# Pred: indefinitely | Actual: anniversary
# Pred: va | Actual: cha
# Pred: beautiful | Actual: swim
# Pred: women | Actual: drum
# Pred: suspicion | Actual: laboratory
# Pred: courtesy | Actual: actually
# Pred: af | Actual: satisfaction
# Pred: curiosity | Actual: curious
# Pred: picturesque | Actual: machine
# Pred: orchestra | Actual: orchestra
# Pred: scarcely | Actual: damage
# Pred: economics | Actual: economic
# Pred: count | Actual: miscellaneous
# Pred: melancholy | Actual: ag
# Pred: anniversary | Actual: anomaly
# Pred: melancholy | Actual: rain
# Pred: va | Actual: women
# Pred: splendid | Actual: aero
# Pred: del | Actual: because
# Pred: virtues | Actual: virtues
# Pred: competent | Actual: compound
# Pred: inc | Actual: incorporation
# Pred: economical | Actual: economic
# Pred: tragedy | Actual: chop
# Pred: restaurant | Actual: assistant
# Pred: sorority | Actual: sorority
# Pred: congratulations | Actual: pilot
# Pred: melancholy | Actual: regained
# Pred: ex | Actual: extraordinary
# Pred: triumph | Actual: trying
# Pred: extraordinary | Actual: ex
# Pred: fundamental | Actual: society
# Pred: inc | Actual: includes
# Pred: af | Actual: va
# Pred: va | Actual: new
# Pred: prejudice | Actual: prejudice
# Pred: tournament | Actual: tournament
# Pred: beautiful | Actual: cool
# Pred: analysis | Actual: material
# Pred: va | Actual: tied
# Pred: so | Actual: home
# Pred: wishes | Actual: wish
# Pred: psychology | Actual: psychology
# Pred: del | Actual: poly
# Pred: gradually | Actual: getting
# Pred: court | Actual: successful
# Pred: negotiations | Actual: negotiations
# Pred: va | Actual: silly
# Pred: guarantee | Actual: comfortable
# Pred: acknowledge | Actual: acc
# Pred: successful | Actual: scrambled
# Pred: re | Actual: tr
# Pred: unanimous | Actual: distinguished
# Pred: guarantee | Actual: dangerous
# Pred: acknowledge | Actual: acknowledge
# Pred: criticism | Actual: chemistry
# Pred: magnificent | Actual: magnificent
# Pred: dormitory | Actual: lo
# Pred: fra | Actual: wanted
# Pred: privilege | Actual: privileged
# Pred: beautiful | Actual: purple
# Pred: negotiations | Actual: activities
# Pred: distinguished | Actual: throughout
# Pred: vacancy | Actual: facilities
# Pred: should | Actual: ceased
# Pred: extraordinary | Actual: extraordinary
# Pred: sorority | Actual: sauce
# Pred: the | Actual: them
# Pred: question | Actual: fight
# Pred: correspondence | Actual: curiosity
# Pred: criticism | Actual: criticism
# Pred: fra | Actual: freezing
# Pred: anniversary | Actual: up
# Pred: suspicion | Actual: curiosity
# Pred: gorgeous | Actual: going
# Pred: melancholy | Actual: ground
# Pred: tragedy | Actual: tragedy
# Pred: what | Actual: waiting
# Pred: stomach | Actual: ink
# Pred: searched | Actual: bomb
# Pred: melancholy | Actual: melancholy
# Pred: thoroughly | Actual: yield
# Pred: inc | Actual: inc
# Pred: facilities | Actual: mysterious
# Pred: prejudice | Actual: pretend
# Pred: criticism | Actual: criticism
# Pred: melancholy | Actual: ice
# Pred: immediately | Actual: immediately
# Pred: inc | Actual: scissors
# Pred: minimum | Actual: bell
# Pred: beautiful | Actual: regained
# Pred: sure | Actual: plan
# Pred: fundamental | Actual: organization
# Pred: attorneys | Actual: attorneys
# Pred: special | Actual: shape
# Pred: guarantee | Actual: appreciate
# Pred: familiar | Actual: scarcely
# Pred: privilege | Actual: privilege
# Pred: suspicion | Actual: sauce
# Pred: acc | Actual: sale
# Pred: miscellaneous | Actual: something
# Pred: discretion | Actual: discuss
# Pred: indefinitely | Actual: industry
# Pred: enthusiasm | Actual: intellectual
# Pred: sufficiently | Actual: threshold
# Pred: philosophy | Actual: said
# Pred: anniversary | Actual: analysis
# Pred: tragedy | Actual: tragedy
# Pred: permanent | Actual: permanent
# Pred: suspicion | Actual: suspicion
# Pred: anxiety | Actual: and
# Pred: dormitory | Actual: locked
# Pred: competent | Actual: comparatively
# Pred: ceased | Actual: ceased
# Pred: gorgeous | Actual: between
# Pred: indefinitely | Actual: ins
# Pred: necessarily | Actual: everyone
# Pred: fascinating | Actual: technical
# Pred: sufficiently | Actual: annum
# Pred: annum | Actual: up
# Pred: traffic | Actual: dangerous
# Pred: subterranean | Actual: subterranean
# Pred: biscuits | Actual: freezing
# Pred: enthusiasm | Actual: intellectual
# Pred: temperature | Actual: temperature
# Pred: scarcely | Actual: food
# Pred: question | Actual: forward
# Pred: magnificent | Actual: magnificent
# Pred: psychology | Actual: programmes
# Pred: psychology | Actual: dictionary
# Pred: annoyance | Actual: arrangements
# Pred: negotiations | Actual: cemetery
# Pred: del | Actual: tr
# Pred: stomach | Actual: sting
# Pred: negotiations | Actual: definite
# Pred: con | Actual: con
# Pred: what | Actual: likes
# Pred: melancholy | Actual: item
# Pred: acknowledge | Actual: acknowledging
# Pred: scheduled | Actual: spacecraft
# Pred: r | Actual: regained
# Pred: sank | Actual: knife
# Pred: relief | Actual: would
# Pred: sorority | Actual: do
# Pred: biscuits | Actual: busy
# Pred: decidedly | Actual: dec
# Pred: undoubtedly | Actual: unanimous
# Pred: biscuits | Actual: built
# Pred: remembrance | Actual: annum
# Pred: psychology | Actual: magnificent
# Pred: opposite | Actual: content
# Pred: con | Actual: conscience
# Pred: criticism | Actual: criticism
# Pred: va | Actual: ski
# Pred: precision | Actual: fra
# Pred: flag | Actual: honest
# Pred: negotiations | Actual: boyfriend
# Pred: sure | Actual: pockets
# Pred: negotiations | Actual: healthy
# Pred: approximately | Actual: complexion
# Pred: ridiculous | Actual: ridiculous
# Pred: comparatively | Actual: commemorated
# Pred: af | Actual: damage
# Pred: remember | Actual: ref
# Pred: pinnacle | Actual: frightened
# Pred: enthusiasm | Actual: enthusiasm
# Pred: cha | Actual: similarity
# Pred: st | Actual: st
# Pred: satisfaction | Actual: abandon
# Pred: beautiful | Actual: br
# Pred: economics | Actual: economical
# Pred: melancholy | Actual: genius
# Pred: bankruptcy | Actual: female
# Pred: infinite | Actual: infinite
# Pred: con | Actual: con
# Pred: magnificent | Actual: basketball
# Pred: inc | Actual: include
# Pred: noticeable | Actual: removed
# Pred: guarantee | Actual: gauge
# Pred: geometry | Actual: end
# Pred: philosophy | Actual: take
# Pred: negotiations | Actual: financially
# Pred: satisfaction | Actual: satisfaction
# Pred: subterranean | Actual: hates
# Pred: exquisite | Actual: exceptionally
# Pred: question | Actual: train
# Pred: unanimous | Actual: unanimous
# Pred: philosophy | Actual: ski
# Pred: tournament | Actual: tournament
# Pred: tragedy | Actual: trousers
# Pred: cemetery | Actual: cemetery
# Pred: efficiency | Actual: chemistry
# Pred: decidedly | Actual: describing
# Pred: negotiations | Actual: houses
# Pred: what | Actual: had
# Pred: financially | Actual: food
# Pred: biscuits | Actual: biscuits
# Pred: del | Actual: del
# Pred: fundamental | Actual: curiosity
# Pred: miscellaneous | Actual: sort
# Pred: opposite | Actual: away
# Pred: temperature | Actual: technical
# Pred: opposite | Actual: opportunities
# Pred: exhibition | Actual: ex
# Pred: guarantee | Actual: heightened
# Pred: unanimous | Actual: removed
# Pred: familiar | Actual: copy
# Pred: negotiations | Actual: had
# Pred: avoid | Actual: avoid
# Pred: privilege | Actual: prior
# Pred: bicycle | Actual: parallel
# Pred: guarantee | Actual: guarantee
# Pred: st | Actual: st
# Pred: specifically | Actual: memorandum
# Pred: fascinating | Actual: usual
# Pred: peculiar | Actual: peculiar
# Pred: psychology | Actual: spade
# Pred: anniversary | Actual: temporary
# Pred: question | Actual: searched
# Pred: miscellaneous | Actual: beautiful
# Pred: sufficient | Actual: stomach
# Pred: anniversary | Actual: latest
# Pred: cha | Actual: cha
# Pred: exists | Actual: clouds
# Pred: surrounded | Actual: surrendered
# Pred: ex | Actual: ex
# Pred: extraordinary | Actual: r
# Pred: memorandum | Actual: memorandum
# Pred: sorority | Actual: sorority
# Pred: fascinating | Actual: family
# Pred: melancholy | Actual: melancholy
# Pred: efficiency | Actual: equipped
# Pred: permanently | Actual: permanently
# Pred: magnificent | Actual: railway
# Pred: fundamental | Actual: shown
# Pred: technical | Actual: picturesque
# Pred: dormitory | Actual: bear
# Pred: anticipating | Actual: anticipation
# Pred: politician | Actual: jumped
# Pred: necessarily | Actual: prep
# Pred: determined | Actual: raining
# Pred: surrounded | Actual: surrounded
# Pred: fra | Actual: fra
# Pred: satisfaction | Actual: anniversary
# Pred: anxious | Actual: initials
# Pred: geometry | Actual: technical
# Pred: guarantee | Actual: sauce
# Pred: recommended | Actual: recommend
# Pred: ridiculous | Actual: ponder
# Pred: guarantee | Actual: prior
# Pred: special | Actual: specimen
# Pred: del | Actual: temperature
# Pred: sufficiently | Actual: primary
# Pred: acc | Actual: picturesque
# Pred: infinite | Actual: inverted
# Pred: exhibition | Actual: exhibition
# Pred: bankruptcy | Actual: to
# Pred: poetry | Actual: vulgar
# Pred: satisfaction | Actual: fascination
# Pred: catalogue | Actual: catalogue
# Pred: con | Actual: conception
# Pred: technical | Actual: prophecy
# Pred: politician | Actual: documents
# Pred: satisfaction | Actual: fundamental
# Pred: biscuits | Actual: sufficient
# Pred: familiar | Actual: chapter
# Pred: minimum | Actual: es
# Pred: sorority | Actual: pamphlets
# Pred: unanimous | Actual: unemployed
# Accuracy: 0.1819
# Epoch 10, Average Loss: 5.5304
# Accuracy: 0.1901

# %%
import shutil

# Define the source and destination paths
source_path = 'spelling_corrector_model.pth'  # Path to the saved model
destination_path = '/content/drive/MyDrive/NLP/spelling_corrector_model.pth'  # Destination path in your Drive

# Copy the file
shutil.copy(source_path, destination_path)

print(f"Model copied to: {destination_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-40ec132123ab> in <cell line: 0>()
#       6
#       7 # Copy the file
# ----> 8 shutil.copy(source_path, destination_path)
#       9
#      10 print(f"Model copied to: {destination_path}")
#
# /usr/lib/python3.11/shutil.py in copy(src, dst, follow_symlinks)
#     429     if os.path.isdir(dst):
#     430         dst = os.path.join(dst, os.path.basename(src))
# --> 431     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     432     copymode(src, dst, follow_symlinks=follow_symlinks)
#     433     return dst
#
# /usr/lib/python3.11/shutil.py in copyfile(src, dst, follow_symlinks)
#     254         os.symlink(os.readlink(src), dst)
#     255     else:
# --> 256         with open(src, 'rb') as fsrc:
#     257             try:
#     258                 with open(dst, 'wb') as fdst:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'spelling_corrector_model.pth'
